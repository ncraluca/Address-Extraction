# %% [markdown]
# ### Libraries needed in this project

# %%
import asyncio
import aiohttp
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin, urlparse
import httpx
import pandas as pd
from geopy.adapters import AioHTTPAdapter
from geopy.geocoders import Nominatim
import pyap
from aiohttp import ClientSession
import time

# %% [markdown]
# #### Extracting the domains from the .parquet file

# %%
df_parquet = pd.read_parquet('D:/list of company websites.snappy.parquet')

# %% [markdown]
# ## US addresses

# %%
# Domains list
domains = df_parquet.head(850)['domain']  
domains
# Out:
# 0        umbrawindowtinting.com
# 1                embcmonroe.org
# 2               caffeygroup.com
# 3                sk4designs.com
# 4            draftingdesign.com
#                  ...
# 845                  joylux.com
# 846        kupferbergcenter.org
# 847    flstatewideinsurance.com
# 848      solarlightsandmore.com
# 849         mysticalpoodles.com
# Name: domain, Length: 850, dtype: object

# %% [markdown]
# #### Function that from a domain verifiy if it's https or http

# %%
async def get_url_scheme(domain, timeout=5):
    # finding out if the domain is https or http
    try:
        async with httpx.AsyncClient(verify=False) as client:
            # a get request to the https address
            response = await client.get('https://' + domain, timeout=timeout)
            
            # extract the url where the request was redirected
            url_string = str(response.url)
            
            # decide if the url it's https or http (if it is not https we asume it is http)
            if url_string.startswith('https://'):
                return domain, 'https'
            else:
                return domain, 'http'
    # if an exception occured we assume it is an http and we will check later if it is valid
    except httpx.RequestError as e:
        return domain, 'http'
    except httpx.HTTPError as e:
        # treating the cases where we have a SSL error
        if isinstance(e, httpx.HTTPError) and isinstance(e.__cause__, httpx.ConnectError):
            return domain, 'http'
        else:
            raise e

# %% [markdown]
# - Asynchronous main function where for the domains list we obtain the url scheme

# %%
async def main(domains):
    tasks = [get_url_scheme(domain) for domain in domains]
    results = await asyncio.gather(*tasks, return_exceptions=True)
    return results

# %%
# Here the main function is runned
results = await main(domains)

# %% [markdown]
# #### Printing the results

# %%
# just to check if everything is ok
complete_urls = []
for result in results:
    if isinstance(result, tuple):
        domain, scheme = result
        complete_url = f"{scheme}://{domain}"
        print(f"Url complet: {complete_url}")
        complete_urls.append(complete_url)
    else:
        print(f"Rezultat neașteptat: {result}")
# Out:
# Url complet: https://umbrawindowtinting.com
# Url complet: https://embcmonroe.org
# Url complet: https://caffeygroup.com
# Url complet: https://sk4designs.com
# Url complet: https://draftingdesign.com
# Url complet: http://truesdail.com
# Url complet: https://seedsourceag.com
# Url complet: https://romebeerfest.com
# Url complet: https://beerock.com
# Url complet: https://cabwhp.org
# Url complet: http://saintmlc.com
# Url complet: https://dillonmusic.com
# Url complet: https://societyfortheblind.org
# Url complet: https://perfectsearchinc.com
# Url complet: https://wyandottewinery.com
# Url complet: http://thespiritofblackjackmountain.com
# Url complet: https://kingdomtel.com
# Url complet: http://triadstage.org
# Url complet: http://savagecbd.com
# Url complet: https://clubk-9.com
# Url complet: https://katerisyracuse.com
# Url complet: https://triplecrownconstruction.com
# Url complet: https://greyhackle.com
# Url complet: https://wildandwanderful.com
# Url complet: https://coastalpaddlecompany.com
# Url complet: https://casepaper.com
# Url complet: https://searchouthomes.com
# Url complet: https://richardbrothersfinancial.com
# Url complet: https://paramountlandtitle.com
# Url complet: https://villageatfourhills.com
# Url complet: https://aiwoodwork.com
# Url complet: https://infometrica.com
# Url complet: https://twinpondsnashua.com
# Url complet: https://oauconsulting.com
# Url complet: https://neutresalon.com
# Url complet: https://glacier.chat
# Url complet: https://systemadix.com
# Url complet: https://your-doctor.org
# Url complet: https://seniorcareagencyny.com
# Url complet: https://plentyconsulting.com
# Url complet: https://ohnstadlaw.com
# Url complet: https://superfitfoods.co
# Url complet: https://newandblue.com
# Url complet: http://sonomastarparty.com
# Url complet: https://animaledzoocation.com
# Url complet: https://seforensic.com
# Url complet: https://allmakeappliancerepair.com
# Url complet: https://305painting.com
# Url complet: https://persianbijar.com
# Url complet: https://medhomeplus.org
# Url complet: https://yuppypuppyboutique.com
# Url complet: https://thebestvintageclothing.com
# Url complet: https://isberg-nott.com
# Url complet: http://csccpas.com
# Url complet: https://stmatthewmedina.org
# Url complet: https://georgebrownphotography.com
# Url complet: https://atlasuhv.com
# Url complet: https://gopremier.biz
# Url complet: https://rockvilledwiattorney.com
# Url complet: https://atlanticbeach-nc.com
# Url complet: https://kiddsmith.com
# Url complet: https://sheriford.com
# Url complet: http://seahawkmuffler.com
# Url complet: https://dakotamanagement.com
# Url complet: https://jackiescleaning.com
# Url complet: https://purcellvilledental.com
# Url complet: https://fcllp.com
# Url complet: https://artofthelakes.org
# Url complet: https://songfest.us
# Url complet: https://vahcbsa.org
# Url complet: https://ayalaboring.com
# Url complet: https://b-wise.com
# Url complet: https://bentsoninsurance.net
# Url complet: https://starkconsult.com
# Url complet: https://namastereiki.com
# Url complet: https://hugsforhealing.org
# Url complet: https://allenvillagejewelers.com
# Url complet: https://ipanex.com
# Url complet: https://sboji.com
# Url complet: https://panniergraphics.com
# Url complet: https://unitedairconditioning.com
# Url complet: http://bbbiking.com
# Url complet: https://csuoberlin.com
# Url complet: https://embracecomputers.com
# Url complet: https://events2atee.com
# Url complet: https://roensalvage.com
# Url complet: https://microcapmarketplace.com
# Url complet: https://marbenbland.com
# Url complet: https://whitehorsecustomz.com
# Url complet: http://onefinedayproductions.com
# Url complet: https://hennejewelers.com
# Url complet: https://hscpoly.com
# Url complet: https://appwinit.com
# Url complet: http://howardinsuranceinc.com
# Url complet: https://millerindustrial.com
# Url complet: http://melaniericcardi.com
# Url complet: https://achieveservices.net
# Url complet: https://billproctorandassociates.com
# Url complet: https://habeggercorp.com
# Url complet: https://pridescholarships.com
# Url complet: https://thegrindcoffeebar.com
# Url complet: https://aaronsantosdentistry.com
# Url complet: https://itconductor.com
# Url complet: https://heidimitchellgolf.com
# Url complet: https://teamsunbuilders.com
# Url complet: https://acaletics.net
# Url complet: https://fresnogreekfest.com
# Url complet: https://trinityrentals.com
# Url complet: https://lifebalancesports.com
# Url complet: https://mid-america.com
# Url complet: http://liftsouth.com
# Url complet: https://blackriverpallet.com
# Url complet: https://firstchoicemech.com
# Url complet: https://easolutions.net
# Url complet: https://onlinemarketingmuscle.com
# Url complet: https://raymondkeyandsons.com
# Url complet: https://goldridgecompanies.com
# Url complet: https://luxuryhomecouncil.com
# Url complet: http://plainsmanswitching.com
# Url complet: https://ageinplaceofnewengland.com
# Url complet: https://sellersconstruction.net
# Url complet: https://rapidriverloggingcamp.com
# Url complet: https://enidmad.org
# Url complet: http://americanconcretetrucking.com
# Url complet: https://able-plumbing.net
# Url complet: https://weddingphoto-video.com
# Url complet: http://ibex.us.com
# Url complet: https://washingtonareafuelfund.org
# Url complet: https://chcseia.com
# Url complet: https://zaplingstudios.com
# Url complet: https://gipreit.com
# Url complet: https://takearax.com
# Url complet: https://floridaorchestra.org
# Url complet: https://cityvisions.com
# Url complet: https://luckyprints.com
# Url complet: https://anikadenise.com
# Url complet: https://bwglaw.net
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://devact.com
# Url complet: https://wickedislandbakery.com
# Url complet: https://tmgi.net
# Url complet: https://josephebberweinart.com
# Url complet: http://stylemultimedia.com
# Url complet: https://obgyngroup.com
# Url complet: https://royersford.com
# Url complet: https://selnertreeshrubcare.com
# Url complet: https://barmarketingbasics.com
# Url complet: https://gbox.com
# Url complet: https://maguirechevroletcadillac.com
# Url complet: https://rokkan.com
# Url complet: http://endries.com
# Url complet: https://stmindustries.com
# Url complet: https://sczc.org
# Url complet: https://fott.org
# Url complet: https://msland.com
# Url complet: https://drpierrerousse.net
# Url complet: https://jjastorsrestaurant.com
# Url complet: https://foxbridge.com
# Url complet: https://andersrice.com
# Url complet: https://albeeappliances.com
# Url complet: https://blackbookmarketresearch.com
# Url complet: https://acflagandbanner.com
# Url complet: https://sjcadets.org
# Url complet: https://biblebee.org
# Url complet: https://dr-todd.com
# Url complet: http://securecdp.com
# Url complet: https://suralink.com
# Url complet: http://dairyagendatoday.com
# Url complet: https://wayco.com
# Url complet: https://clovispointsolutions.com
# Url complet: https://ksafe.com
# Url complet: https://rossmoncure.com
# Url complet: https://youthchallengesports.com
# Url complet: https://eyewitnessforlife.org
# Url complet: https://thecharlescompany.com
# Url complet: http://30aproperties4sale.com
# Url complet: https://alwaysmovingandrelocation.org
# Url complet: https://mindsmack.com
# Url complet: https://indilab.com
# Url complet: https://brmins.com
# Url complet: https://juiceshop.com
# Url complet: https://odhlegal.com
# Url complet: https://ccaltd.com
# Url complet: https://hodgepodgebakeshop.weebly.com
# Url complet: https://crossroadsretreat.org
# Url complet: https://garagedoorrepair-sierramadre.com
# Url complet: https://hinoofcolumbia.com
# Url complet: https://centurycontractors.net
# Url complet: https://militiahillsecurity.com
# Url complet: https://summitdebate.com
# Url complet: https://otsegocd.org
# Url complet: http://jonesmachine.com
# Url complet: https://cherryridgeconstruction.com
# Url complet: https://gandwengineering.com
# Url complet: https://goleadingit.com
# Url complet: https://lotussalonny.com
# Url complet: https://athensgop.com
# Url complet: http://branchcolonialhouse.com
# Url complet: https://tacticalmuscle.com
# Url complet: https://bridge.legal
# Url complet: https://holmesandturner.com
# Url complet: https://hamiltonroofingandacoustical.com
# Url complet: https://lnrothberg.com
# Url complet: https://colts.com
# Url complet: http://deloach.com
# Url complet: https://speedy-pak.com
# Url complet: https://forestrylaw.com
# Url complet: https://airspaceconsulting.com
# Url complet: http://individualbizsolutions.com
# Url complet: https://distance-educator.com
# Url complet: https://casaallegra.org
# Url complet: https://christsmission.org
# Url complet: https://sussexanimalclinic.com
# Url complet: https://monsterdisplays.com
# Url complet: https://pinetreeseafood.com
# Url complet: https://frenchwide.com
# Url complet: http://isell30a.com
# Url complet: https://tpcsecurity.com
# Url complet: https://ehstech.com
# Url complet: https://emilyseventsaz.com
# Url complet: https://cybersofttechnologies.com
# Url complet: https://promptcaremd.com
# Url complet: https://planetbids.com
# Url complet: https://studentsuccess.co
# Url complet: https://kingkream.com
# Url complet: https://argocontact.com
# Url complet: https://specialtybolt.com
# Url complet: https://grablerealestate.com
# Url complet: https://tsaworld.com
# Url complet: https://enhancedlandscape.com
# Url complet: https://hypnosistrainingnewyork.org
# Url complet: https://jobmatic.com
# Url complet: https://westcoastseafood.com
# Url complet: https://kaleabay.com
# Url complet: https://martinselfstorage.com
# Url complet: https://corpimprints.com
# Url complet: https://treehill.org
# Url complet: https://cannabis-seed.us
# Url complet: https://heavenlysunshine.com
# Url complet: https://pure111.com
# Url complet: https://mbanj.com
# Url complet: https://willowtool.com
# Url complet: https://tatankastone.com
# Url complet: https://bayareaturf.net
# Url complet: https://pakwanrestaurant.com
# Url complet: https://advnetsol.com
# Url complet: https://dynamichealthcarolinas.com
# Url complet: https://bordolay.com
# Url complet: https://decorativeartsbyjep.com
# Url complet: https://ncc.us
# Url complet: https://southernsoulstudio.com
# Url complet: https://have2020.com
# Url complet: https://tricountymustangclub.com
# Url complet: https://tristatecontainer.com
# Url complet: https://naceyes.com
# Url complet: https://sweetbyholly.com
# Url complet: https://manudyn.com
# Url complet: http://madmikeandfriends.com
# Url complet: https://postermuseum.com
# Url complet: https://resortsltd.com
# Url complet: https://thedevoregroup.com
# Url complet: https://wargoenterprises.com
# Url complet: https://gunsafes.com
# Url complet: https://customrebuiltcarbs.com
# Url complet: https://gardenplaincoop.com
# Url complet: https://wisr.edu
# Url complet: https://milwaukee-montessori.org
# Url complet: https://awrestorations.com
# Url complet: https://tripeek.com
# Url complet: http://scparanormal.com
# Url complet: https://dallasprowebdesigners.com
# Url complet: http://racecarshocks.com
# Url complet: https://northparkpres.org
# Url complet: https://a-baldoverhead.com
# Url complet: https://lgsbythecreek.com
# Url complet: https://sterlingridingacademy.com
# Url complet: https://jtownbible.org
# Url complet: https://spifunds.com
# Url complet: https://rybergconstruction.net
# Url complet: https://channell.com
# Url complet: https://terradynecountryclub.com
# Url complet: https://bestnapleshomesearch.com
# Url complet: http://gardenscapetransport.com
# Url complet: https://rawhidedistributors.com
# Url complet: https://adgcreative.net
# Url complet: https://jandrcustomwalls.com
# Url complet: https://wildlifeart.org
# Url complet: https://johnwhansen.com
# Url complet: http://tshirtconcepts.net
# Url complet: https://kapitalelectric.com
# Url complet: https://taillight.com
# Url complet: http://tstventures.com
# Url complet: http://restaurant-roswellga.com
# Url complet: https://njng.com
# Url complet: http://houma-rentals.com
# Url complet: https://justaminutellc.com
# Url complet: https://ekeepersystems.com
# Url complet: https://crownpaintinginc.com
# Url complet: https://platformq.com
# Url complet: https://accredited-appraisal.com
# Url complet: https://xtremewirelessnsyracuse.com
# Url complet: https://davetyler.net
# Url complet: http://jornadaogia.com
# Url complet: https://mattressplus.tv
# Url complet: https://winehausfw.com
# Url complet: http://vamonosmoving.com
# Url complet: https://jetinc.net
# Url complet: https://barbarabartlein.com
# Url complet: https://flippincritters.com
# Url complet: http://motion-labs.com
# Url complet: https://williesrestaurants.com
# Url complet: https://intersectionmusic.org
# Url complet: http://bellastonecare.com
# Url complet: https://fbassoc.com
# Url complet: https://ynotitalian.com
# Url complet: https://vitalizechiropractic.com
# Url complet: https://cbssquaredinc.com
# Url complet: https://mobilecloudlab.com
# Url complet: https://shearfashions.com
# Url complet: https://stgcom.com
# Url complet: https://bopatelectric.com
# Url complet: https://cincinnatifleetcare.com
# Url complet: https://sorrentoeast.org
# Url complet: https://dmaa.net
# Url complet: https://textbooksolutions.com
# Url complet: https://sherrylimd.com
# Url complet: https://apieceofcake11.com
# Url complet: https://portcitygraphics.com
# Url complet: https://libboo.com
# Url complet: https://lascruxes.com
# Url complet: https://icscomplete.com
# Url complet: https://rememberthosemoments.com
# Url complet: https://harnesswealth.com
# Url complet: https://entosdesign.com
# Url complet: https://thecolombygroup.com
# Url complet: https://seniorvillagerehab.com
# Url complet: https://mansionssouth.com
# Url complet: https://adastra-films.com
# Url complet: http://pearlleather.com
# Url complet: https://merrickgroupinc.com
# Url complet: https://adsdry.com
# Url complet: https://dillinghammurphy.com
# Url complet: https://bodyjewelrycompany.com
# Url complet: http://shopcapitalhatters.com
# Url complet: https://mjobriendesign.com
# Url complet: https://scottyshubcaps.com
# Url complet: https://landco-inc.com
# Url complet: http://fm99.com
# Url complet: https://frontdoorstl.com
# Url complet: http://rosesacrossamerica.com
# Url complet: https://garydawsonlaw.com
# Url complet: https://c-s-stables.com
# Url complet: https://kimberlybrockbooks.com
# Url complet: https://eatrightdelaware.org
# Url complet: https://bestwebhosting.com
# Url complet: https://masterrenovationsinc.com
# Url complet: https://patiocomforts.com
# Url complet: https://elogiq.com
# Url complet: https://ossininglibrary.org
# Url complet: https://inetmotors.com
# Url complet: https://dabba4u.com
# Url complet: https://urbanacres.com
# Url complet: https://perryridgelandfill.com
# Url complet: https://fountainhillsapartments.com
# Url complet: https://portertwp.org
# Url complet: http://americansurvey.com
# Url complet: https://thecreditpeople.com
# Url complet: https://matrixdesigncompanies.com
# Url complet: https://piranhablonde.com
# Url complet: http://aimnorth.com
# Url complet: https://boccarossainsurance.com
# Url complet: https://sundowninc.org
# Url complet: https://isetoday.com
# Url complet: https://janestreetproductions.com
# Url complet: https://withouraloha.com
# Url complet: https://abmechanical.com
# Url complet: https://salvometalworks.com
# Url complet: http://amsgenetics.com
# Url complet: https://brycsoccer.com
# Url complet: https://copyarmy.com
# Url complet: https://lombardglobal.com
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://webcointeractive.com
# Url complet: https://violenceinterventionprogram.org
# Url complet: http://millspacktrips.com
# Url complet: https://thesophiacenterforspirituality.org
# Url complet: http://myrollingoaksapartments.com
# Url complet: http://sysbytc.com
# Url complet: https://boyleinsures.com
# Url complet: https://stanleyreid.com
# Url complet: http://scottklareichdds.com
# Url complet: https://b29investments.com
# Url complet: http://amaurisilva.com
# Url complet: https://mgtreeservices.com
# Url complet: https://hullstrategies.com
# Url complet: http://sacredbrewing.com
# Url complet: https://jdsclubs.com
# Url complet: https://jenbeckeracupuncture.com
# Url complet: https://martialartshealing.com
# Url complet: http://techsea.com
# Url complet: https://hebrewfreeloandc.org
# Url complet: https://azcrystal.com
# Url complet: https://ypmphotography.com
# Url complet: https://burnsidebrewco.com
# Url complet: https://creative-earthscapes.com
# Url complet: https://actionfigurefit.com
# Url complet: https://flit.co
# Url complet: https://uniquelibrary.com
# Url complet: https://newdaychurchnetwork.org
# Url complet: https://crystalcoastnc.org
# Url complet: https://sarahssilks.com
# Url complet: https://classicgardens.com
# Url complet: http://nemesisinteractive.com
# Url complet: https://seanzmortgage.com
# Url complet: http://suresigngraphics.com
# Url complet: https://soteria.io
# Url complet: http://hodgsonsinc.com
# Url complet: https://catapultcreativemedia.com
# Url complet: http://lssa2320.org
# Url complet: http://drbangert.com
# Url complet: http://stadiumchiropractic.com
# Url complet: http://smokyhillmuseum.org
# Url complet: http://clvillage.net
# Url complet: http://backefinancial.com
# Url complet: http://steelspan.com
# Url complet: http://socoinstitute.org
# Url complet: http://creartiveinc.com
# Url complet: http://jonesgrove.com
# Url complet: http://johanningsinc.com
# Url complet: https://pproa.org
# Url complet: http://daybreakoutsourcing.com
# Url complet: https://sacredspacemiami.com
# Url complet: http://whitehallcamp.org
# Url complet: http://tjsfabrics.com
# Url complet: http://rbroadconcrete.com
# Url complet: http://wingchungainesville.com
# Url complet: http://thelargeformatstore.com
# Url complet: http://aprexec.com
# Url complet: http://truesmilesmiami.com
# Url complet: http://sealwatch.com
# Url complet: http://safebasementsinc.com
# Url complet: http://urbanironcraft.com
# Url complet: http://genebellassociates.com
# Url complet: http://beemlaw.com
# Url complet: http://shorecorporation.com
# Url complet: http://avalonlimos.com
# Url complet: http://daytonamitsu.com
# Url complet: http://lamprinostv.com
# Url complet: http://centerlinelogistics.com
# Url complet: http://ctfamilypt.com
# Url complet: http://wichitaacademyofpharmacists.org
# Url complet: http://dreng.com
# Url complet: http://ohpsych.org
# Url complet: http://servemenow.org
# Url complet: http://primafacie.net
# Url complet: http://peoplefirstlawyers.com
# Url complet: http://seachangeprogram.org
# Url complet: http://watershedmaterials.com
# Url complet: http://billysingh.com
# Url complet: http://ecocolorssalon.com
# Url complet: http://arrowgiftshop.com
# Url complet: http://barrierlining.com
# Url complet: http://taabc.org
# Url complet: http://agoraproductions.org
# Url complet: http://concrete-canvas.net
# Url complet: http://pswrehab.com
# Url complet: http://campwalden-ny.com
# Url complet: http://airstreamlosangeles.com
# Url complet: http://tpabenchmark.com
# Url complet: http://usourceenergy.com
# Url complet: http://alldolly.com
# Url complet: http://toroslawnmower.com
# Url complet: http://smartwarehousing.com
# Url complet: http://pointofdata.com
# Url complet: http://paykings.com
# Url complet: http://fatandjuicy.com
# Url complet: http://ces-group.net
# Url complet: http://mulchandsod.com
# Url complet: http://barrywilliamsplumbing.com
# Url complet: http://commongroundchildcare.org
# Url complet: http://binghamtoncustomtshirts.com
# Url complet: http://thomcomm.com
# Url complet: http://michellebrumley.com
# Url complet: http://poulsbofamilydentistry.com
# Url complet: http://modelgroup.net
# Url complet: http://ad-west.com
# Url complet: http://remingtons.pro
# Url complet: http://camelot-enterprises.com
# Url complet: http://breslaucapital.com
# Url complet: http://fundakrines.com
# Url complet: http://monkeybargym.com
# Url complet: http://dawnequipment.us
# Url complet: http://alphapurewater.com
# Url complet: http://scenicviewcc.com
# Url complet: http://ortonceramic.com
# Url complet: http://happystagger.com
# Url complet: http://bcpas.com
# Url complet: http://dontrecordsmusicgroup.com
# Url complet: http://abetterbugman.com
# Url complet: http://heavensbestofbirmingham.com
# Url complet: http://subaruofrichmond.com
# Url complet: http://alexanderdeiser.com
# Url complet: http://younits.com
# Url complet: http://txinsight.com
# Url complet: http://r-d-p-consulting.com
# Url complet: http://optimumcarehomecare.com
# Url complet: http://acmg.net
# Url complet: http://adkfragrancefarm.com
# Url complet: http://aperations.com
# Url complet: http://cmcregaff.com
# Url complet: http://banknsb.com
# Url complet: http://solidrenovations.com
# Url complet: http://sardisbaptist.com
# Url complet: http://yanceyworks.com
# Url complet: http://bocahomecareservices.com
# Url complet: http://excellandscapemgmt.com
# Url complet: http://masterstch.com
# Url complet: http://womenwhocode.com
# Url complet: http://bigideas.com
# Url complet: http://iqfitness.net
# Url complet: http://4parkwayhonda.com
# Url complet: http://cjmcbride.org
# Url complet: http://aatoppers.com
# Url complet: http://magnetpi.com
# Url complet: http://kansascyclist.com
# Url complet: http://trinityairmedical.com
# Url complet: http://tcwrcmoldremoval.com
# Url complet: http://tellusoperating.com
# Url complet: http://alexanderfamilybuickgmc.com
# Url complet: http://santasophia.org
# Url complet: http://thepeopleofpokemongo.com
# Url complet: http://itpro.tv
# Url complet: http://premierdentalcareofbuckhead.com
# Url complet: http://lexmundi.com
# Url complet: http://hamlinlakeboatrentals.com
# Url complet: http://adventures-in-learning.org
# Url complet: http://bernsteinsfashions.com
# Url complet: http://danashouse.org
# Url complet: http://thundermountainharley.com
# Url complet: http://tarynreed.com
# Url complet: http://marysvillelib.org
# Url complet: http://lnlconstruction.com
# Url complet: http://goodshepherdofcashiers.com
# Url complet: http://upstatetelecom.com
# Url complet: http://aurasalonnashville.com
# Url complet: http://bitcoinzusa.com
# Url complet: http://zenogroupinvestments.com
# Url complet: http://multilayer.com
# Url complet: http://roundtheworldsurplus.com
# Url complet: http://cacustomaquariums.com
# Url complet: http://oldehomestead.com
# Url complet: http://kauffmangas.com
# Url complet: http://stitchmine.com
# Url complet: http://stationinnpa.com
# Url complet: http://newportbutane.com
# Url complet: http://tulsadoorman.com
# Url complet: http://westfloproducts.com
# Url complet: http://erling.com
# Url complet: http://sprucemountaininn.com
# Url complet: http://abc-assembly.com
# Url complet: http://statmedical.net
# Url complet: http://outsourcingnetwork.com
# Url complet: http://tbtyler.com
# Url complet: http://championrescuetools.com
# Url complet: http://texasafterviolence.org
# Url complet: http://tenderle.org
# Url complet: http://applepiememories.com
# Url complet: http://ferrellaw.com
# Url complet: http://frclothingandsupply.com
# Url complet: http://thevetcenter.com
# Url complet: http://itsabouttimeboutique.com
# Url complet: http://pchandy.net
# Url complet: http://selectcore.com
# Url complet: http://thehuntsvilledentist.com
# Url complet: http://quantumhelicopters.com
# Url complet: http://horizonconvention.com
# Url complet: http://paisansrest.com
# Url complet: http://wvcrossroads.com
# Url complet: http://ourbellinis.com
# Url complet: http://thebluapple.com
# Url complet: http://poly6.com
# Url complet: http://cityave.org
# Url complet: http://reshapelifesciences.com
# Url complet: http://kleinwoodvision.com
# Url complet: http://thewokdallastx.com
# Url complet: http://terraliftinternational.com
# Url complet: http://changemanagementreview.com
# Url complet: http://cphconsultants.com
# Url complet: http://ultimatemuskyguide.com
# Url complet: http://thekeirweimerteam.com
# Url complet: http://bgcworcester.org
# Url complet: http://tudorpickering.com
# Url complet: http://kenleigh-acres.com
# Url complet: http://viddoctor.com
# Url complet: http://oncuestaging.com
# Url complet: http://westbrosinc.com
# Url complet: http://l4sg.com
# Url complet: http://oakandfort.com
# Url complet: http://tagatuci.com
# Url complet: http://newhomemedia.net
# Url complet: http://fantasyphotography.com
# Url complet: http://econic.co
# Url complet: http://northquabbinforestry.com
# Url complet: http://chasepropertyllc.com
# Url complet: http://demaeng.com
# Url complet: http://jamessurdam.com
# Url complet: http://kellyandstonearchitects.com
# Url complet: http://idn-inc.com
# Url complet: http://pruitt-igoebeesanctuary.com
# Url complet: http://greenterrahomes.com
# Url complet: http://trivan.com
# Url complet: http://birminghambuilder.com
# Url complet: http://cliosoft.com
# Url complet: http://knowlabs.co
# Url complet: http://petiteflowerssanantonio.com
# Url complet: http://fccmwc.org
# Url complet: http://greenwave.us.com
# Url complet: http://interimlender.com
# Url complet: http://blueoceanvillas.com
# Url complet: http://oakhousefilms.com
# Url complet: http://medicalwhite.com
# Url complet: http://sage-research.com
# Url complet: http://dellsducks.com
# Url complet: http://floridacommercialteam.com
# Url complet: http://drdansiegel.com
# Url complet: http://grabitinc.com
# Url complet: http://chisholmarchitects.com
# Url complet: http://jillkonrath.com
# Url complet: http://novellasrecycling.com
# Url complet: http://southboundandcompany.com
# Url complet: http://miamifloridahomesecurity.com
# Url complet: http://elchicanomusic.com
# Url complet: http://trifectamedspanyc.com
# Url complet: http://santaclarajumpers.com
# Url complet: http://lchealth.org
# Url complet: http://mimovers.org
# Url complet: http://kidderroofing.com
# Url complet: http://hancock.k12.ga.us
# Url complet: http://lrgmarketing.com
# Url complet: http://apicaucus.org
# Url complet: http://lovethypetbklyn.com
# Url complet: http://mscenteroftidewater.com
# Url complet: http://exquisitecarsale.com
# Url complet: http://pripo.com
# Url complet: http://andonelect.com
# Url complet: http://toplinetireandauto.com
# Url complet: http://slavkin.net
# Url complet: http://diversitycrna.org
# Url complet: http://moline.com
# Url complet: http://verasoft.com
# Url complet: http://laceyoga.com
# Url complet: http://glenellynfamilymusicschool.com
# Url complet: http://arizonainkstudios.com
# Url complet: http://xraydocs.com
# Url complet: http://inter-tax.net
# Url complet: http://ranchsystems.com
# Url complet: http://componentsignage.com
# Url complet: http://weberortho.com
# Url complet: http://folsomshope.org
# Url complet: http://victoralanphoto.com
# Url complet: http://dulichgiaremag.com
# Url complet: http://realdealsnow.com
# Url complet: http://precisioninternational.com
# Url complet: http://instituteod.com
# Url complet: http://rbhmedia.com
# Url complet: http://ktmtalk.com
# Url complet: http://dentremovalcedarfalls.com
# Url complet: http://ccslableaks.com
# Url complet: http://schoolofcosmeticarts.com
# Url complet: http://stonehousebaking.com
# Url complet: http://jamesdemars.com
# Url complet: http://coregearusa.com
# Url complet: http://tetonthaivillage.com
# Url complet: http://kindlersgemjewelers.com
# Url complet: http://littletrendsetter.com
# Url complet: http://tamethewater.com
# Url complet: http://bobosremi.com
# Url complet: http://historicldstours.com
# Url complet: http://bakerbrand.com
# Url complet: http://hopeihave.org
# Url complet: http://burdelaw.com
# Url complet: http://bregmanpartners.com
# Url complet: http://losangelespest.com
# Url complet: http://techforce.ai
# Url complet: http://taxprepusa.com
# Url complet: http://1stopmodelshoots.com
# Url complet: http://wesleyhousing.org
# Url complet: http://londonburyhomes.com
# Url complet: http://roanefamilydental.com
# Url complet: http://stbernardhs.com
# Url complet: http://newleafsc.com
# Url complet: http://voodooconsulting.com
# Url complet: http://scoreboardmn.com
# Url complet: http://manddbirdfarm.com
# Url complet: http://leathercoatsetc.com
# Url complet: http://coxreels.com
# Url complet: http://promoviper.com
# Url complet: http://appcasual.net
# Url complet: http://meditatingentrepreneur.com
# Url complet: http://silverminemotors.com
# Url complet: http://fivedegreesconsulting.com
# Url complet: http://greenelectricsolarsolutions.com
# Url complet: http://salesianhigh.org
# Url complet: http://fiba.net
# Url complet: http://billingssecuritycameras.com
# Url complet: http://div.energy
# Url complet: http://valentbiosciences.com
# Url complet: http://switcheyecenter.com
# Url complet: http://henges.com
# Url complet: http://tkimages.com
# Url complet: http://canceriq.com
# Url complet: http://tapestrips.com
# Url complet: http://springshare.com
# Url complet: http://teladata.com
# Url complet: http://spencercreativegroup.com
# Url complet: http://parkwaytoyota.com
# Url complet: http://airform.co
# Url complet: http://sureleader.com
# Url complet: http://tomgillam.com
# Url complet: http://merchantportfolios.com
# Url complet: http://bootleggerlasvegas.com
# Url complet: http://mojenta.com
# Url complet: http://sherinixonteam.com
# Url complet: http://synpoly.com
# Url complet: http://vkhall-law.com
# Url complet: http://usfaiu.com
# Url complet: http://wheelalignmenttorrance.com
# Url complet: http://plurfectinc.com
# Url complet: http://harborlightsri.com
# Url complet: http://gokeyless.com
# Url complet: http://tcors.com
# Url complet: http://stonearchcapital.com
# Url complet: http://fmsymphony.org
# Url complet: http://gtownradio.com
# Url complet: http://marylandlanguage.com
# Url complet: http://jankeco.com
# Url complet: http://millerconsultants.com
# Url complet: http://tradingpinsdirect.com
# Url complet: http://blueprinthomeinspection.com
# Url complet: http://spokenwordimages.com
# Url complet: http://toandr.com
# Url complet: http://amerifirstloan.com
# Url complet: http://ranking-konzept.de
# Url complet: http://scadametrics.com
# Url complet: http://joejohnstattoos.com
# Url complet: http://caribbean-sea.org
# Url complet: http://rek-ins.com
# Url complet: http://usmrc.org
# Url complet: http://accu-profile.com
# Url complet: http://chrislowry.com
# Url complet: http://innocon.com
# Url complet: http://artslettersandnumbers.com
# Url complet: http://clandestinodining.com
# Url complet: http://silverlakepress.net
# Url complet: http://tri-starmechanical.com
# Url complet: http://vbclink.com
# Url complet: http://veteransrebuildinglife.org
# Url complet: http://mimivax.com
# Url complet: http://bmbeans.com
# Url complet: http://oregonsportshall.org
# Url complet: http://barefootinternational.com
# Url complet: http://airservicesco.com
# Url complet: http://deltaglobalinvestments.com
# Url complet: http://aurorak12.org
# Url complet: http://thevillahome.com
# Url complet: http://ateras.com
# Url complet: http://shellblack.com
# Url complet: http://brooksidechapelfh.com
# Url complet: http://turntablelab.com
# Url complet: http://rodneyyoungphotography.com
# Url complet: http://superiordistribution.net
# Url complet: http://curekc.org
# Url complet: http://powertofly.com
# Url complet: http://dfrealtors.com
# Url complet: http://counter-productions.org
# Url complet: http://gianellis.net
# Url complet: http://alphamedaesthetics.com
# Url complet: http://moviestarjacket.com
# Url complet: http://ugrokit.com
# Url complet: http://atlinkcom.com
# Url complet: http://shadowhills.org
# Url complet: http://smallgirlspr.com
# Url complet: http://warsawwireless.com
# Url complet: http://murane.com
# Url complet: http://complimentarycrap.com
# Url complet: http://pusd.us
# Url complet: http://designcontractservices.com
# Url complet: http://starontheright.com
# Url complet: http://crossfitrockland.com
# Url complet: http://classappliance.com
# Url complet: http://goldak.com
# Url complet: http://visitstegen.com
# Url complet: http://florestaurant.com
# Url complet: http://cebroker.com
# Url complet: http://vetsource.com
# Url complet: http://emsono.com
# Url complet: http://vcms.org
# Url complet: http://jeffersonatplymouthapartments.com
# Url complet: http://armstrongambulance.com
# Url complet: http://homebrewing.org
# Url complet: http://photoartsmarin.com
# Url complet: http://trockilaw.com
# Url complet: http://sidebysideclubhouse.org
# Url complet: http://boulderbrook.com
# Url complet: http://myahbags.com
# Url complet: http://camphillvillage.org
# Url complet: http://ultimaterotator.com
# Url complet: http://hvac-tech.com
# Url complet: http://brycetech.com
# Url complet: http://parry-insurance.com
# Url complet: http://wtxfoodbank.org
# Url complet: http://nationalforests.org
# Url complet: http://mapsautocenter.com
# Url complet: http://dcsrvcenter.com
# Url complet: http://fairmans.com
# Url complet: http://rewinddance.org
# Url complet: http://paintingconcepts.com
# Url complet: http://magnummobilesv.com
# Url complet: http://endevon.com
# Url complet: http://csphotohk.com
# Url complet: http://lancastermennonite.org
# Url complet: http://canyonviewah.com
# Url complet: http://ewingbuildingandcabinets.com
# Url complet: http://teamecco.org
# Url complet: http://chsoft.com
# Url complet: http://cre8group.com
# Url complet: http://outoftownclothing.com
# Url complet: http://revdemand.com
# Url complet: http://theflounderfishcamp.com
# Url complet: http://dignifiedhomeloans.com
# Url complet: http://grfamilychiropractic.com
# Url complet: http://thornefinancialpartners.com
# Url complet: http://heritagelifestyledoors.com
# Url complet: http://nextuptv.com
# Url complet: http://theswag.com
# Url complet: http://thordieselclub.org
# Url complet: http://haightvineyards.com
# Url complet: http://eastbaypreschools.com
# Url complet: http://milehightattoo.com
# Url complet: http://cornerstone-mosinee.com
# Url complet: http://drinkmebeverages.com
# Url complet: http://greatstatetransmissions.com
# Url complet: http://renderplus.com
# Url complet: http://upswing.com
# Url complet: http://theorganicbutcher.com
# Url complet: http://joylux.com
# Url complet: http://kupferbergcenter.org
# Url complet: http://flstatewideinsurance.com
# Url complet: http://solarlightsandmore.com
# Url complet: http://mysticalpoodles.com

# %%
len(complete_urls)
# Out:
# 848

# %% [markdown]
# _____
# #### Function that checks if an URL is valid

# %%
import httpx

async def check_url_async(url, timeout=5):
    try:
        async with httpx.AsyncClient(verify = False) as client:
            response = await client.head(url, timeout=timeout)
            # If the response has the status code  = 200 then it is successful
            return response.status_code == 200
    except httpx.HTTPStatusError:
        return False
    except httpx.RequestError:
        return False

# %% [markdown]
# ####  Function that filters asynchronously the list of URLS with the check_url_async function

# %%
import asyncio

async def filter_urls_async(urls):
    valid_urls = []
    tasks = [check_url_async(url) for url in urls]
    results = await asyncio.gather(*tasks)
    for url, result in zip(urls, results):
        if result:
            valid_urls.append(url)
    return valid_urls

# %% [markdown]
# - Asynchronously main function where we apply the filter to the list of urls and obtain the valid ones

# %%
async def main():
    valid_urls = await filter_urls_async(complete_urls)
    return valid_urls

# %%
valid_urls = await main()

# %%
len(valid_urls)
# Out:
# 226

# %% [markdown]
# #### Function that loads an URL ignoring the ssl errors
# - in general it's not recommended, but in this case we don't have a choice

# %%
import asyncio
import aiohttp
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

async def fetch(session, url):
    try:
        async with session.get(url, ssl=False, timeout=10) as response:
            # If the response has the status code  = 200 then it is successful
            if response.status == 200:
                body = await response.read()
                # we use latin-1 because if we use utf-8 we will have errors
                return body.decode('latin-1', errors='ignore')
            else:
                print(f"This URL is not accessible: {url}")
                return None
    except asyncio.TimeoutError:
        print(f"Timeout occurred for URL: {url}")
        return None

# %% [markdown]
# ####  Function that returns URLs starting from an URL
# - the URLs are filtered with keywords (on that URLs it's most probable to have an address)

# %%
async def find_urls_with_keywords(url, keywords):
    found_urls = set()
    
    async with aiohttp.ClientSession() as session:
        html = await fetch(session, url)
        if html:
            found_urls.add(url)
            # extracting the html content from the page
            soup = BeautifulSoup(html, 'html.parser')
            # we will keep only the <a href> tags where we can find links to other pages of the website
            links = soup.find_all('a', href=True)
            tasks = []
            for link in links:
                href = link['href']
                # ignoring if the link is to the mail
                if href.startswith('mailto:'):
                    continue
                parsed_url = urlparse(href)
                path = parsed_url.path
                # we keep the urls that have the keywords in it (where is most probably to find an address)
                for keyword in keywords:
                    if re.search(r'\b{}\b'.format(re.escape(keyword)), path, re.IGNORECASE):
                        full_url = urljoin(url, href)
                        found_urls.add(full_url)
                        break
            await asyncio.gather(*tasks)
    return found_urls

# %% [markdown]
# - Async main function that for a list of urls generate a bigger list with the urls that have a high chance to have an address

# %%
async def main(valid_urls):
    # that is the list with the keywords where is a chance to find an address
    keywords = ['connect', 'contact', 'kontakt', 'impressum', 'adresse', 'reach', 'datenschutz', 'home']
    tasks = [find_urls_with_keywords(url, keywords) for url in valid_urls]
    final_urls = await asyncio.gather(*tasks)
    return final_urls

# %%
final_urls = await main(valid_urls)
# Out:
# Timeout occurred for URL: https://floridaorchestra.org
# Timeout occurred for URL: http://sonomastarparty.com

# %%
urls_list = []
for set_elem in final_urls:
    for elem in set_elem:
        urls_list.append(elem)

# %%
len(urls_list)
# Out:
# 417

# %% [markdown]
# #### Checking the new list of URLS and the invalid ones will be eliminated

# %%
async def main():
    valid_urls = await filter_urls_async(urls_list)
    return valid_urls

# %%
urls_list = await main()

# %%
len(urls_list)
# Out:
# 391

# %% [markdown]
# #### Making a DataFrame to save the valid URLS into a .csv to using them later

# %%
import pandas as pd

df = pd.DataFrame(columns = ["URL"])

df
# Out:
# Empty DataFrame
# Columns: [URL]
# Index: []

# %%
# building the rows
for url in urls_list:
    individual_row_data = [url]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                          URL
# 0                     https://embcmonroe.org
# 1    https://embcmonroe.org/connect-with-us/
# 2             https://sk4designs.com/contact
# 3                     https://sk4designs.com
# 4                 https://draftingdesign.com
# ..                                       ...
# 386   http://greenelectricsolarsolutions.com
# 387            http://merchantportfolios.com
# 388                       http://synpoly.com
# 389                    http://vkhall-law.com
# 390        http://wheelalignmenttorrance.com
#
# [391 rows x 1 columns]

# %% [markdown]
# #### Exporting the final urls into a .csv

# %%
df.to_csv("US_URLS.csv", index=False)

# %% [markdown]
# #### Reading the urls from the CSV

# %%
import pandas as pd
urls = pd.read_csv("US_URLS.csv")

# %%
urls
# Out:
#                                          URL
# 0                     https://embcmonroe.org
# 1    https://embcmonroe.org/connect-with-us/
# 2             https://sk4designs.com/contact
# 3                     https://sk4designs.com
# 4                 https://draftingdesign.com
# ..                                       ...
# 386   http://greenelectricsolarsolutions.com
# 387            http://merchantportfolios.com
# 388                       http://synpoly.com
# 389                    http://vkhall-law.com
# 390        http://wheelalignmenttorrance.com
#
# [391 rows x 1 columns]

# %%
print(urls['URL'][0])
# Out:
# https://embcmonroe.org

# %% [markdown]
# #### Function that extracts the address from a page if it's possible

# %%
async def extract_addresses_from_url_async(url):
    async with aiohttp.ClientSession() as session:
        try:
            async with session.get(url, ssl=False, timeout=30) as response:
                # If the response has not the status code  = 200 then it is unsuccessful
                if response.status != 200:
                    return None
                
                binary_data = await response.read()
                page_text = binary_data.decode('latin-1')
                
        except asyncio.TimeoutError:
            print(f"Timeout occurred while fetching URL: {url}")
            return None
        except aiohttp.ClientError as e:
            print(f"Error occurred while fetching URL '{url}': {e}")
            return None
        except aiohttp.ClientConnectorError as e:
            print(f"Error connecting to server: {e}")
            return None
        
        # We verify if we received the status code 429 (Too Many Requests)
        if response.status == 429:
            print(f"Too Many Requests received. Retrying after waiting.")
            await asyncio.sleep(5)  # We wait 5 sec before to retry it
            return await extract_addresses_from_url_async(url)  # Recall the function
        
        try:
            # extracting the html content from the page
            soup = BeautifulSoup(page_text, 'html.parser')
        except:
            return None
        
        try:
            # extracting the text from the page
            page_text = soup.get_text()
        except:
            return None
        
        try:
            # find an US address in the text using pyap.parse function (from the pyap library)
            addresses = pyap.parse(page_text, country='US')
        except:
            return None
        
        return [url, addresses]

# %% [markdown]
# - Asynchronous main function where with the list of URLS we extract addresses asynchronously

# %%
async def main(urls_list):
    tasks = [extract_addresses_from_url_async(url) for url in urls_list]
    final_addresses = await asyncio.gather(*tasks, return_exceptions=True)
    return final_addresses

# %%
final_addresses = await main(urls['URL'])

# %%
final_addresses
# Out:
# [['https://embcmonroe.org',
#   [503 Maurice St. Monroe, NC 28112, 503 Maurice Street Monroe, NC 28112]],
#  ['https://embcmonroe.org/connect-with-us/',
#   [503 Maurice Street Monroe, NC 28112]],
#  ['https://sk4designs.com/contact',
#   [295 Mahoney Drive, Unit K Telluride, CO 81432]],
#  ['https://sk4designs.com', []],
#  ['https://draftingdesign.com', []],
#  ['https://draftingdesign.com/contact.htm', []],
#  ['https://beerock.com', []],
#  ['http://saintmlc.com/contact-us.html', []],
#  ['http://saintmlc.com', []],
#  ['https://societyfortheblind.org/about-us/contact-us/', []],
#  ['https://societyfortheblind.org/events/sip-coffee-and-connect-a-virtual-support-group-for-seniors-319/',
#   []],
#  ['https://clubk-9.com', []],
#  ['https://clubk-9.com/home', []],
#  ['https://katerisyracuse.com', []],
#  ['https://wildandwanderful.com', []],
#  ['https://coastalpaddlecompany.com', []],
#  ['https://casepaper.com/contact-us/',
#   [3333 N.W. 116th Street Miami, FL 33167,
#    499 East Tioga Street Philadelphia, PA 19134,
#    9168 Hermosa Avenue Rancho Cucamonga, CA 91730,
#    900 West 45th Street Chicago, IL 60609,
#    2018 Brevard Road High Point, NC 27263,
#    604 Railroad Avenue Osgood, IN 47037]],
#  ['https://casepaper.com', []],
#  ['https://searchouthomes.com/for-home-buyers/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com/before-selling-your-home/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com/before-buying-a-home/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com/contact/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com/buying-your-first-home/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com/home-seller-report/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com/for-home-sellers/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://searchouthomes.com/sell-your-home-fast/',
#   [1739 S. Jade Way, Suite 100, Meridian, Idaho 83642,
#    AND IDENTIFY REAL ESTATE PROFESSIONALS WHO ARE ME]],
#  ['https://paramountlandtitle.com/contact-2/',
#   [8904 Sony Lane, Knoxville, TN 37923, 8904 Sony Lane, Knoxville, TN 37923]],
#  ['https://paramountlandtitle.com', [8904 Sony Lane, Knoxville, TN 37923]],
#  ['https://aiwoodwork.com', []],
#  ['https://infometrica.com', []],
#  ['https://oauconsulting.com', []],
#  ['https://neutresalon.com',
#   [And Spa101 S Market Street, Frederick, MD 21701,
#    And Spa 101 S Market Street, Frederick, MD 21701]],
#  ['https://neutresalon.com/contact/',
#   [101 S Market Street, Frederick, MD 21701,
#    and 85 toward Market St, Merge onto MD,
#    And Spa101 S Market Street, Frederick, MD 21701,
#    And Spa 101 S Market Street, Frederick, MD 21701]],
#  ['https://glacier.chat/contact', []],
#  ['https://glacier.chat', []],
#  ['https://systemadix.com',
#   [122 East Patrick Street, Suite 120, Frederick, MD 21701]],
#  ['http://systemadix.com/contact-us/',
#   [122 East Patrick Street, Suite 120, Frederick, MD 21701]],
#  ['https://animaledzoocation.com', []],
#  ['https://allmakeappliancerepair.com', []],
#  ['https://medhomeplus.org', []],
#  ['https://thebestvintageclothing.com', []],
#  ['https://thebestvintageclothing.com/pages/contact-us', []],
#  ['https://georgebrownphotography.com/contact-us', []],
#  ['https://georgebrownphotography.com', []],
#  ['https://rockvilledwiattorney.com', []],
#  ['https://atlanticbeach-nc.com',
#   [125 West Fort Macon Rd Atlantic Beach, NC 28512]],
#  ['https://kiddsmith.com/home',
#   [117 Riviera Drive, Boiling Springs, SC 29316,
#    117 Riviera Drive, Boiling Springs, SC 29316]],
#  ['https://kiddsmith.com',
#   [117 Riviera Drive, Boiling Springs, SC 29316,
#    117 Riviera Drive, Boiling Springs, SC 29316]],
#  ['https://sheriford.com', []],
#  ['https://dakotamanagement.com', []],
#  ['https://dakotamanagement.com/contact-us', []],
#  ['https://jackiescleaning.com/contact-us/',
#   [116 Crowley Rd, Lewiston, ME 04240, 116 Crowley Rd, Lewiston, ME 04240]],
#  ['https://jackiescleaning.com', [116 Crowley Rd, Lewiston, ME 04240]],
#  ['https://purcellvilledental.com',
#   [609 East Main Street, Suite T, Purcellville, VA 20132]],
#  ['https://purcellvilledental.com/contact/',
#   [609 East Main Street, Suite T, Purcellville, VA 20132,
#    609 East Main Street, Suite T, Purcellville, VA 20132]],
#  ['https://fcllp.com',
#   [570 Lexington Avenue, New York, NY 10022,
#    59 Elm Street, New Haven, CT 06510]],
#  ['https://hugsforhealing.org/contact/', []],
#  ['https://hugsforhealing.org', []],
#  ['https://ipanex.com/contact.html',
#   [2745 N. Amber Street, Philadelphia, PA 19134]],
#  ['https://ipanex.com', []],
#  ['https://panniergraphics.com',
#   [345 Oak Road, Gibsonia, PA 15044, 345 Oak Road Gibsonia, PA 15044]],
#  ['https://panniergraphics.com/contact/',
#   [345 Oak Road, Gibsonia, PA 15044,
#    345 Oak Road, Gibsonia, PA 15044,
#    345 Oak Road Gibsonia, PA 15044]],
#  ['https://unitedairconditioning.com/contact-us/',
#   [13150 S Belcher Rd, Largo, FL 33773, 13150 S Belcher Rd, Largo, FL 33773]],
#  ['https://unitedairconditioning.com', [13150 S Belcher Rd, Largo, FL 33773]],
#  ['https://events2atee.com/contact/', []],
#  ['https://events2atee.com', []],
#  ['https://marbenbland.com/new-home', []],
#  ['https://marbenbland.com', []],
#  ['https://achieveservices.net',
#   [1000 Parkwood Circle SE STE 900 Atlanta, GA 30339]],
#  ['https://habeggercorp.com/contact',
#   [11413 Enterprise Park Drive Sharonville, OH 45241]],
#  ['https://habeggercorp.com',
#   [11413 Enterprise Park Drive Sharonville, OH 45241]],
#  ['https://pridescholarships.com', []],
#  ['https://thegrindcoffeebar.com',
#   [9532 West Linebaugh Ave, Tampa, FL 33626,
#    9532 West Linebaugh Avenue, Tampa, FL, USA]],
#  ['https://heidimitchellgolf.com',
#   [3254 Clubside View Ct SWSnellville, GA 30039,
#    3254 Clubside View Ct SWSnellville, GA 30039]],
#  ['https://heidimitchellgolf.com/contact/',
#   [3254 Clubside View Ct SWSnellville, GA 30039,
#    3254 Clubside View Ct SWSnellville, GA 30039,
#    3254 Clubside View Ct SWSnellville, GA 30039]],
#  ['https://acaletics.net', []],
#  ['https://fresnogreekfest.com', []],
#  ['https://lifebalancesports.com/contact-form-2/', []],
#  ['https://lifebalancesports.com', []],
#  ['http://liftsouth.com', []],
#  ['https://blackriverpallet.com', [410 E Roosevelt, Ave Zeeland, MI 49424]],
#  ['http://blackriverpallet.com/contact.html',
#   [410 E Roosevelt Ave, Zeeland, MI 49424,
#    410 E Roosevelt, Ave Zeeland, MI 49424]],
#  ['https://easolutions.net', [and ERP consulting to Brooks., STATES INDUSTRI]],
#  ['https://easolutions.net/contact-eas/', []],
#  ['https://onlinemarketingmuscle.com',
#   [128 Millport Circle, Suite 200Greenville, SC 29607]],
#  ['https://onlinemarketingmuscle.com/contact/',
#   [128 Millport Circle, Suite 200Greenville, SC 29607]],
#  ['https://luxuryhomecouncil.com/contact', []],
#  ['https://luxuryhomecouncil.com', []],
#  ['https://rapidriverloggingcamp.com', [2024 RAPID RIVER LOGGING CAMP]],
#  ['https://weddingphoto-video.com', []],
#  ['http://ibex.us.com', []],
#  ['http://ibex.us.com/contact.htm',
#   [4451 Brookfield Corporate Drive, Suite 106Chantilly, VA 20151]],
#  ['https://washingtonareafuelfund.org', []],
#  ['https://washingtonareafuelfund.org/contact/',
#   [11690 Doolitte Drive, Waldorf, MD 20602,
#    223 West 5th St., Frederick, MD 21701,
#    20021 Aircraft Dr., Germantown, MD 20874,
#    1804 Mt Vernon Ave., Alexandria, VA 22301,
#    518 S. Glebe Rd., Arlington, VA 22204,
#    300 Fort Collier Rd., Winchester, VA 22603,
#    10 Cardinal Park Dr., Leesburg, VA 20175,
#    1483 Old Bridge Rd., Suite 102, Woodbridge, VA 22192]],
#  ['https://gipreit.com', [401 E Jackson St Ste 3300 Tampa, FL 33602]],
#  ['https://gipreit.com/contact/',
#   [401 E Jackson St Ste 3300, Tampa, FL 33602,
#    401 E Jackson St Ste 3300 Tampa, FL 33602]],
#  ['https://cityvisions.com', []],
#  ['https://cityvisions.com/contact.htm', []],
#  ['https://luckyprints.com/contact/',
#   [2023 W. Carroll Ave, Chicago, IL 60612]],
#  ['https://luckyprints.com', []],
#  ['https://tmgi.net', [46169 Westlake Drive, Suite 240, Sterling, VA 20165]],
#  ['http://stylemultimedia.com', []],
#  ['https://obgyngroup.com', []],
#  ['https://obgyngroup.com/contact', []],
#  ['https://barmarketingbasics.com',
#   [2 controllable factors that drive businessSEACH ENGINE]],
#  ['https://sczc.org', [113 School Street, Santa Cruz, CA 95060]],
#  ['https://sczc.org/contact', [113 School Street, Santa Cruz, CA 95060]],
#  ['https://fott.org',
#   [and more.SendThis site is protected by reCA,
#    1300 SW 54 Avenue, Plantation, FL 33317]],
#  ['https://msland.com/contact/', []],
#  ['https://msland.com', []],
#  ['https://drpierrerousse.net', []],
#  ['http://drpierrerousse.net/contact/', []],
#  ['https://jjastorsrestaurant.com', []],
#  ['https://foxbridge.com', []],
#  ['https://foxbridge.com/contact-us/', []],
#  ['https://blackbookmarketresearch.com', []],
#  ['https://blackbookmarketresearch.com/contact', []],
#  ['https://biblebee.org', []],
#  ['https://dr-todd.com', []],
#  ['http://dairyagendatoday.com', []],
#  ['https://wayco.com', []],
#  ['https://clovispointsolutions.com',
#   [11169 Lake Chapel Lane, Reston, VA 20191]],
#  ['https://ksafe.com', [1618 Main Street, Baker, LA 70714]],
#  ['https://eyewitnessforlife.org/contact-us/',
#   [2525 N Mayfair Rd, Suite 30 Milwaukee WI 53226,
#    2525 N Mayfair Rd, Suite 30, Wauwatosa, WI 53226]],
#  ['https://eyewitnessforlife.org',
#   [2525 N Mayfair Rd, Suite 30, Wauwatosa, WI 53226]],
#  ['https://thecharlescompany.com/contact-us/',
#   [9666 E Riggs Rd, Suite 136, Sun Lakes, AZ 85248]],
#  ['https://thecharlescompany.com', []],
#  ['https://thecharlescompany.com/service/home-insurance/',
#   [and all of Arizona. The office is located in Sun Lakes, AZ]],
#  ['https://alwaysmovingandrelocation.org/contact-us/', []],
#  ['https://alwaysmovingandrelocation.org', []],
#  ['https://mindsmack.com', []],
#  ['https://juiceshop.com/pages/contact-us',
#   [540 Barneveld Ave, Unit CSan Francisco, CA 94124]],
#  ['https://juiceshop.com', []],
#  ['https://ccaltd.com', []],
#  ['https://ccaltd.com/contact/', []],
#  ['https://hodgepodgebakeshop.weebly.com',
#   [3361 Mccracken Street, Muskegon, MI 49441]],
#  ['https://centurycontractors.net', []],
#  ['http://jonesmachine.com',
#   [1590 Foothill Dr. Suite 1, Boulder City, Nevada, 89005]],
#  ['http://jonesmachine.com/contact/contact-1/',
#   [1590 Foothill Dr. Suite 1 Boulder City, Nevada, 89005,
#    1590 Foothill Dr. Suite 1, Boulder City, Nevada, 89005]],
#  ['https://tacticalmuscle.com',
#   [1015 W CENTERVILLE RD STE 105, GARLAND TX 75041]],
#  ['http://tacticalmuscle.com/contact-us/',
#   [1015 W CENTERVILLE RD STE 105, GARLAND, TX 75041,
#    1015 W CENTERVILLE RD STE 105, GARLAND TX 75041]],
#  ['http://deloach.com', []],
#  ['https://speedy-pak.com/contact-us/', []],
#  ['https://speedy-pak.com', []],
#  ['https://forestrylaw.com',
#   [12 Fountain Plaza, Suite 600, Buffalo, NY 14202]],
#  ['https://distance-educator.com', []],
#  ['https://sussexanimalclinic.com/contact/',
#   [64 W24280 Main Street, Sussex, WI 53089,
#    64 W24280 Main Street, Sussex, WI 53089]],
#  ['https://sussexanimalclinic.com', [64 W24280 Main Street, Sussex, WI 53089]],
#  ['https://pinetreeseafood.com', []],
#  ['https://pinetreeseafood.com/contact/', []],
#  ['https://cybersofttechnologies.com',
#   [9418 Annapolis Road, Suite 200 Lanham, MD 20706]],
#  ['https://cybersofttechnologies.com/contact/',
#   [9418 Annapolis Road, Suite 200, Lanham, MD 20706,
#    9418 Annapolis Road, Suite 200 Lanham, MD 20706]],
#  ['https://promptcaremd.com', []],
#  ['https://planetbids.com', []],
#  ['https://studentsuccess.co', []],
#  ['https://studentsuccess.co/contact/', []],
#  ['https://kingkream.com/contact.html', []],
#  ['https://kingkream.com', []],
#  ['https://grablerealestate.com',
#   [6387 Camp Bowie Blvd B 325, Fort Worth, Texas 76107]],
#  ['https://tsaworld.com', []],
#  ['https://enhancedlandscape.com/contact-us/',
#   [28447 Witherspoon Parkway, Valencia, CA 91355,
#    28447 Witherspoon Parkway, Valencia, CA 91355,
#    5410 Cameron St. Ste 106, Las Vegas, NV 89118,
#    5410 Cameron St. Ste 106, Las Vegas, NV 89118,
#    3373 Luyung Drive, Rancho Cordova, CA 95742,
#    2038 N Ventura Ave, Ventura, CA 93001,
#    17645 Sierra Highway Canyon Country, CA 91351,
#    1938 East Thousand Oaks Boulevard, Thousand Oaks, CA, USA,
#    3302 Gulf Street, Bakersfield CA,
#    541 N Dewitt Ave, Clovis, CA 93612,
#    28447 Witherspoon Parkway, Valencia, CA 91355]],
#  ['https://enhancedlandscape.com',
#   [28447 Witherspoon Parkway, Valencia, CA 91355]],
#  ['https://hypnosistrainingnewyork.org', []],
#  ['https://westcoastseafood.com/contact/', []],
#  ['https://westcoastseafood.com', []],
#  ['https://kaleabay.com/contact/',
#   [13910 Old Coast Road, Naples, FL 34110,
#    13910 Old Coast Rd., Naples, FL 34110,
#    13910 Old Coast Rd., Naples, FL 34110]],
#  ['https://kaleabay.com',
#   [13910 Old Coast Rd., Naples, FL 34110,
#    13910 Old Coast Rd., Naples, FL 34110]],
#  ['https://cannabis-seed.us', []],
#  ['https://heavenlysunshine.com',
#   [9170 Southview Street, Southaven, MS 38671]],
#  ['https://heavenlysunshine.com/contact/',
#   [9170 Southview Street, Southaven, MS 38671]],
#  ['https://mbanj.com/contact', []],
#  ['https://mbanj.com', []],
#  ['https://site.pheedloop.com/event/2024Regional/home', []],
#  ['https://tatankastone.com', [one Inc.13525 A St, Omaha, Nebraska 68144]],
#  ['https://pakwanrestaurant.com', []],
#  ['https://advnetsol.com', []],
#  ['https://bordolay.com/pages/contact.html', []],
#  ['https://bordolay.com', []],
#  ['https://decorativeartsbyjep.com', []],
#  ['https://decorativeartsbyjep.com/contact/', []],
#  ['https://ncc.us',
#   [815 Commerce Drive, Suite 270, Oak Brook, IL, 60523,
#    675 Bed Medical Center in Illinois,
#    815 Commerce Dr. Suite 270 Oak Brook, IL 60523]],
#  ['https://tristatecontainer.com',
#   [1440 Bridgewater Rd., Bensalem, PA 18020,
#    2260 State Rd., Bensalem, PA 18020]],
#  ['https://tristatecontainer.com/contact/', []],
#  ['https://naceyes.com', [3208 N. University Drive, Nacogdoches, TX, 75965]],
#  ['https://naceyes.com/contact/',
#   [3208 N. University Drive, Nacogdoches, TX 75965,
#    3208 N. University Drive, Nacogdoches, TX, 75965]],
#  ['https://manudyn.com', []],
#  ['https://manudyn.com/contact-manufacturing-software.aspx',
#   [875 Mamaroneck Ave, Suite 204, Mamaroneck, NY 10543]],
#  ['https://postermuseum.com/pages/contact-us',
#   [122 Chambers St, Tribeca, New York, 122 Chambers St., New York, NY, 10007]],
#  ['https://postermuseum.com', [122 Chambers St., New York, NY, 10007]],
#  ['https://gardenplaincoop.com', []],
#  ['https://gardenplaincoop.com/pages/contact.php',
#   [106 E. South Ave, Cheney, KS 67025,
#    401 N. Main, Garden Plain, KS 67050,
#    8500 SE Burns Ave., Kingman, KS 67068]],
#  ['https://wisr.edu/home/contact/',
#   [1812 San Pedro Ave., Berkeley, CA 94707,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/degree-programs/edd-education-program/',
#   [and evaluation is guided by WI,
#    and evaluation is guided by WI,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/degree-programs/ms-education-program/',
#   [and justice. Main Mission and Features of the MS,
#    and curriculum is guided by WI,
#    and curriculum is guided by WI,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/educational-seminars/',
#   [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/student-services/',
#   [and contact information is published on WI,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/student-services/student-records-diplomas-transcripts/',
#   [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/degree-programs/mft-lpcc-program/',
#   [1625 N Market Blvd., Suite S-200Sacramento, CA 95834,
#    and the cultural mores and values common in California,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu', [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/degree-programs/continuing-education-ceus/',
#   [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/consumer-disclosures/',
#   [1812 San Pedro Ave., Berkeley, CA,
#    1747 N. Market Blvd., Suite 225, Sacramento, CA 95834,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/about/', [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu//contact/',
#   [1812 San Pedro Ave., Berkeley, CA 94707,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/student-services/career-resources/',
#   [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/about/center-child-family-development/',
#   [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/degree-programs/',
#   [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/admissions/tuition/',
#   [1812 San Pedro Ave., Berkeley, CA 94707,
#    1747 North Market Blvd., Suite 225, Sacramento, CA 95834,
#    1747 N. Market Blvd., Suite 225, Sacramento, CA 95833,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/faculty-profiles/',
#   [1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://wisr.edu/home/admissions/',
#   [ten notice of cancellation is sent. If WI,
#    1812 San Pedro Ave., Berkeley, CA, 94707]],
#  ['https://tripeek.com/home/', []],
#  ['https://tripeek.com', []],
#  ['https://tripeek.com/contact-us/', []],
#  ['https://tripeek.com/home-eu/', []],
#  ['http://scparanormal.com', []],
#  ['http://scparanormal.com/contact-us.html', []],
#  ['https://a-baldoverhead.com', []],
#  ['https://a-baldoverhead.com/contact/', []],
#  ['https://lgsbythecreek.com', []],
#  ['https://sterlingridingacademy.com', []],
#  ['https://spifunds.com', [47 Maple Street, Suite 103 Summit, NJ 07901]],
#  ['https://terradynecountryclub.com',
#   [1400 Terradyne Drive, Andover, KS 67002-9211]],
#  ['https://terradynecountryclub.com/contact/',
#   [1400 Terradyne Drive, Andover, KS 67002-9211]],
#  ['https://bestnapleshomesearch.com/instant-home-valuation',
#   [1495 Pine Ridge Rd #1Naples, FL 34109]],
#  ['https://bestnapleshomesearch.com', [1495 Pine Ridge Rd #1Naples, FL 34109]],
#  ['https://bestnapleshomesearch.com/content/Pricing-your-home',
#   [1495 Pine Ridge Rd #1Naples, FL 34109,
#    1495 Pine Ridge Rd #1Naples, FL 34109]],
#  ['https://bestnapleshomesearch.com/home-valuation',
#   [1495 Pine Ridge Rd #1Naples, FL 34109,
#    1495 Pine Ridge Rd #1Naples, FL 34109]],
#  ['https://bestnapleshomesearch.com/contact',
#   [1495 Pine Ridge Rd #1Naples, FL 34109,
#    1495 Pine Ridge Rd #1Naples, FL 34109]],
#  ['https://bestnapleshomesearch.com/content/Preparing-Your-Home-to-Sell',
#   [1495 Pine Ridge Rd #1Naples, FL 34109,
#    1495 Pine Ridge Rd #1Naples, FL 34109]],
#  ['https://bestnapleshomesearch.com/content/Costs-Related-to-the-Sale-of-Your-Home',
#   [1495 Pine Ridge Rd #1Naples, FL 34109,
#    1495 Pine Ridge Rd #1Naples, FL 34109]],
#  ['http://gardenscapetransport.com/contact.html',
#   [38 and Sandy Point Road, Eau Claire, PA 16030]],
#  ['http://gardenscapetransport.com', []],
#  ['http://tshirtconcepts.net/contact-us/', []],
#  ['http://tshirtconcepts.net', []],
#  ['https://justaminutellc.com', []],
#  ['https://justaminutellc.com/contact-us/',
#   [70 S. Val Vista Dr., Gilbert, AZ 85296]],
#  ['https://ekeepersystems.com',
#   [7701 W Kilgore Ave, Suite 1B, Yorktown, IN 47396]],
#  ['https://ekeepersystems.com/contact/',
#   [7701 W Kilgore Ave, Suite 1B, Yorktown, IN 47396,
#    7701 W Kilgore Ave, Suite 1B, Yorktown, IN 47396]],
#  ['https://platformq.com', [100 Crescent Road, Needham, MA 02494]],
#  ['https://davetyler.net/contact-me/', []],
#  ['https://davetyler.net', []],
#  ['https://winehausfw.com',
#   [and shop in the Near Southside of Fort Worth, Texas,
#    1628 Park Place Ave, Fort Worth, TX 76110]],
#  ['https://flippincritters.com', []],
#  ['https://vitalizechiropractic.com',
#   [4980 Benchmark Centre, Swansea, IL 62226]],
#  ['https://vitalizechiropractic.com/contact/',
#   [4980 Benchmark Centre, Swansea, IL 62226,
#    4980 Benchmark Centre, Swansea, IL 62226,
#    4980 Benchmark Centre, Swansea, IL 62226]],
#  ['https://mobilecloudlab.com', []],
#  ['https://mobilecloudlab.com/contact-us/',
#   [39111 Paseo Padre, Pkwy, Ste 301, Fremont CA 94538]],
#  ['https://shearfashions.com', []],
#  ['https://stgcom.com', [1401 Wardingley Ave.Columbiana, OH 44408]],
#  ['https://stgcom.com/contact/',
#   [1401 Wardingley Ave. Columbiana, OH 44408,
#    1401 Wardingley Ave.Columbiana, OH 44408]],
#  ['https://cincinnatifleetcare.com',
#   [10000 Commerce Park DrWest Chester, OH 45246]],
#  ['https://cincinnatifleetcare.com/contact-us/',
#   [10000 Commerce Park DrWest Chester, OH 45246]],
#  ['https://sherrylimd.com', []],
#  ['https://apieceofcake11.com/contact.html',
#   [709 Rt.9 SouthCape May Court House, NJ 08210,
#    709 U.S. 9, Cape May Court House, NJ 08210]],
#  ['https://apieceofcake11.com', [709 U.S. 9, Cape May Court House, NJ 08210]],
#  ['https://libboo.com', []],
#  ['https://libboo.com/contact', []],
#  ['https://lascruxes.com', []],
#  ['https://lascruxes.com/contact', []],
#  ['https://thecolombygroup.com', []],
#  ['https://thecolombygroup.com/contact', []],
#  ['https://adastra-films.com/contact-production-audiovisuelle/', []],
#  ['https://adastra-films.com', []],
#  ['http://pearlleather.com/home.html', []],
#  ['http://pearlleather.com', []],
#  ['https://adsdry.com',
#   [12094 Anderson Rd, Suite 330, Tampa, FL 33625,
#    12094 Anderson Rd, Suite 330 Tampa, FL 33625]],
#  ['https://adsdry.com/contact-us/#contactus',
#   [12094 Anderson Rd, Suite 330, Tampa, FL 33625,
#    12094 Anderson Rd, Suite 330 Tampa, FL 33625]],
#  ['https://adsdry.com/contact-us/',
#   [12094 Anderson Rd, Suite 330, Tampa, FL 33625,
#    12094 Anderson Rd, Suite 330 Tampa, FL 33625]],
#  ['https://mjobriendesign.com', []],
#  ['https://scottyshubcaps.com/contact/', []],
#  ['https://scottyshubcaps.com', []],
#  ['https://landco-inc.com', []],
#  ['https://c-s-stables.com', []],
#  ['https://kimberlybrockbooks.com', []],
#  ['https://eatrightdelaware.org', []],
#  ['https://eatrightdelaware.org/contact/', []],
#  ['https://bestwebhosting.com', []],
#  ['https://bestwebhosting.com/contact-best-web-hosting/', []],
#  ['https://elogiq.com', []],
#  ['https://elogiq.com/contact.php',
#   [996 Old Eagle School Rd, Suite 1106, Wayne, PA 19087]],
#  ['https://www.inetmotors.com/contact',
#   [11522695 Villa Creek Drive Farmers Branch, TX 75234,
#    2695 Villa Creek Drive Farmers Branch, TX 75234]],
#  ['https://inetmotors.com',
#   [11522695 Villa Creek Drive Farmers Branch, TX 75234,
#    2695 Villa Creek DriveFarmers Branch, TX 75234]],
#  ['https://fountainhillsapartments.com', []],
#  ['https://portertwp.org', [12828 McKay St, Sunbury, Ohio 43074]],
#  ['https://matrixdesigncompanies.com', []],
#  ['https://sundowninc.org/contact-us/', []],
#  ['https://sundowninc.org', []],
#  ['https://janestreetproductions.com', []],
#  ['https://brycsoccer.com', []],
#  ['https://b29investments.com', []],
#  ['https://mgtreeservices.com/index.php/contact-us/', []],
#  ['https://mgtreeservices.com', []],
#  ['http://mgtreeservices.com/index.php/contact-us/', []],
#  ['https://hullstrategies.com', []],
#  ['https://jdsclubs.com', []],
#  ['https://jdsclubs.com/pages/contact', []],
#  ['https://jenbeckeracupuncture.com', []],
#  ['https://jenbeckeracupuncture.com/contact/', []],
#  ['https://azcrystal.com', []],
#  ['https://ypmphotography.com', []],
#  ['https://ypmphotography.com/contact-us/', []],
#  ['https://creative-earthscapes.com', []],
#  ['https://creative-earthscapes.com/contact.php', []],
#  ['https://classicgardens.com',
#   [1855 Carson Road Birmingham, AL 35215,
#    1855 Carson Road, Birmingham, AL 35215]],
#  ['https://classicgardens.com/contact/',
#   [1855 Carson Road Birmingham, AL 35215,
#    1855 Carson Road, Birmingham, AL 35215]],
#  ['https://soteria.io/contact-us/', []],
#  ['https://soteria.io', []],
#  ['https://catapultcreativemedia.com', []],
#  ['http://clvillage.net', []],
#  ['http://steelspan.com', []],
#  ['http://jonesgrove.com', []],
#  ['http://jonesgrove.com/contact.html', []],
#  ['https://pproa.org/contact/',
#   [3131 Bell St., Suite 209 Amarillo, Texas 79106,
#    3131 Bell St., Suite 209 Amarillo, Texas 79106,
#    3131 Bell St., Suite 209 Amarillo, Texas 79106]],
#  ['https://pproa.org',
#   [3131 Bell St., Suite 209 Amarillo, Texas 79106,
#    3131 Bell St., Suite 209 Amarillo, Texas 79106]],
#  ['https://sacredspacemiami.com', []],
#  ['https://sacredspacemiami.com/pages/contact', []],
#  ['https://sacredspacemiami.com/pages/contact#pressinquiries', []],
#  ['https://sacredspacemiami.com/pages/contact#careers', []],
#  ['http://tjsfabrics.com', []],
#  ['https://sites.google.com/chathamboat.com/tours/home', []],
#  ['http://sealwatch.com', []],
#  ['http://shorecorporation.com', [2305 Duss Ave. Suite 3Ambridge, PA 15003]],
#  ['http://primafacie.net', []],
#  ['http://www.primafacie.net/contact.html', []],
#  ['http://ecocolorssalon.com/home.html',
#   [1860 N Rock Springs Rd Suite 101 Atlanta, Georgia 30324,
#    1860 N Rock Springs Rd Suite 101 Atlanta GA 30324 USA]],
#  ['http://ecocolorssalon.com',
#   [1860 N Rock Springs Rd Suite 101 Atlanta, Georgia 30324,
#    1860 N Rock Springs Rd Suite 101 Atlanta GA 30324 USA]],
#  ['http://ecocolorssalon.com/contact-us.html',
#   [1860 N Rock Springs Rd Suite 101 Atlanta, Georgia 30324,
#    1860 N Rock Springs Rd Suite 101 Atlanta GA 30324 USA]],
#  ['http://barrierlining.com', []],
#  ['http://barrierlining.com/contact.htm', []],
#  ['http://concrete-canvas.net', []],
#  ['http://pswrehab.com/home/AdultDayPrograms',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com/home/adultdayprograms',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com/home/index',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com/home/employee',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com', [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com/home/IndependentLivingProgram',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com/home/workprograms',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com/home/department',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://pswrehab.com/home#services',
#   [194 West Poplar Avenue, Porterville, CA 93257]],
#  ['http://toroslawnmower.com', []],
#  ['http://pointofdata.com/contact.htm',
#   [909 West Main Street Suite 200, Monroe, WA 98272]],
#  ['http://pointofdata.com', []],
#  ['http://thomcomm.com/contact.php', []],
#  ['http://thomcomm.com', []],
#  ['http://breslaucapital.com', []],
#  ['http://breslaucapital.com/contact-us/',
#   [18 East 16th Street Ste. 307, New York, NY 10003]],
#  ['http://dawnequipment.us', []],
#  ['http://magnetpi.com', []],
#  ['http://thepeopleofpokemongo.com',
#   [6 Bay Bridge Road, Suite 1, Brunswick, ME 04011]],
#  ['http://lnlconstruction.com', []],
#  ['http://lnlconstruction.com/contact.html',
#   [231 Concord St., Zillah, WA 98953]],
#  ['http://upstatetelecom.com', []],
#  ['http://upstatetelecom.com/contact.htm', []],
#  ['http://roundtheworldsurplus.com', []],
#  ['http://oldehomestead.com', []],
#  ['http://abc-assembly.com', [7230 Empire Central Drive Houston, TX 77040]],
#  ['http://abc-assembly.com/contact.html',
#   [7230 Empire Central Drive Houston, TX 77040,
#    7230 Empire Central Drive Houston, TX 77040]],
#  ['http://tenderle.org', []],
#  ['http://applepiememories.com', []],
#  ['http://ferrellaw.com', []],
#  ['http://thevetcenter.com/contact.html',
#   [5200 NW 43rd Street, Suite 501, Gainesville, FL 32606,
#    5200 NW 43RD STREET, SUITE 501, GAINESVILLE, FL 32606,
#    5200 NW 43RD STREET, SUITE 501, GAINESVILLE, FL 32606]],
#  ['http://thevetcenter.com',
#   [5200 NW 43RD STREET, SUITE 501, GAINESVILLE, FL 32606,
#    5200 NW 43RD STREET, SUITE 501, GAINESVILLE, FL 32606]],
#  ['http://cphconsultants.com', []],
#  ['http://cphconsultants.com/contact-us/',
#   [101 South Wenatchee Ave., Suite C3, Wenatchee, WA 98801]],
#  ['http://l4sg.com', []],
#  ['http://fantasyphotography.com', []],
#  ['http://fantasyphotography.com/contact/', []],
#  ['http://pruitt-igoebeesanctuary.com', []],
#  ['http://kidderroofing.com', []],
#  ['http://exquisitecarsale.com', []],
#  ['http://slavkin.net', []],
#  ['http://inter-tax.net', []],
#  ['http://www.myintertax.com/home.html', []],
#  ['http://www.myintertax.com/contact-us.html', []],
#  ['https://weberortho.com/contact-weber-orthodontics/doctor-referral/', []],
#  ['http://weberortho.com', []],
#  ['https://weberortho.com/contact-weber-orthodontics/',
#   [210 W. Willow Ave.Wheaton, Illinois]],
#  ['https://weberortho.com/contact-weber-orthodontics/schedule-an-appointment/',
#   []],
#  ['http://realdealsnow.com', []],
#  ['http://rbhmedia.com',
#   [25 History Center Oak Ridge, TN, 12 Hatch Terrace, Dobbs Ferry, NY 10522]],
#  ['http://jamesdemars.com', []],
#  ['http://hopeihave.org', []],
#  ['http://losangelespest.com', []],
#  ['http://taxprepusa.com', []],
#  ['http://1stopmodelshoots.com', []],
#  ['http://stbernardhs.com', []],
#  ['http://greenelectricsolarsolutions.com', []],
#  ['http://merchantportfolios.com', []],
#  ['http://synpoly.com', [69 Sugar, Land, TEXAS, 77487-0069]],
#  ['http://vkhall-law.com', []],
#  ['http://wheelalignmenttorrance.com',
#   [and Repair Center in Torrance California 90501]]]

# %%
addresses_list = [element for element in final_addresses if element is not None and element[1]]

# %%
addresses_list[0][1]
# Out:
# [503 Maurice St. Monroe, NC 28112, 503 Maurice Street Monroe, NC 28112]

# %% [markdown]
# #### Function that checks if an extracted address is valid and complete the address with the missing elements (for example: country)

# %%
def extract_address(text):
    # we use the geopy library to check if the address is real and parsing the address
    geolocator = Nominatim(user_agent="Jupyter Notebook")
    location = geolocator.geocode(text, addressdetails=True, timeout = 5)
    try:
        if location:
            print("Locatia este corecta")
            return location.raw['address']
        else:
            print("The address is not valid")
            return None
    except Exception as e:
        print(f"Location failed: {e}")
        return None

# %% [markdown]
# #### Saving the valid addresses into a .CSV

# %%
real_addresses = []

# %% [markdown]
# #### Making the DataFrame for the Addresses List

# %%
import pandas as pd

df = pd.DataFrame(columns = ["URL", "Country", "Region", "City", "Postcode", "Road", "Road number"])

df
# Out:
# Empty DataFrame
# Columns: [URL, Country, Region, City, Postcode, Road, Road number]
# Index: []

# %% [markdown]
# #### For each URL we will check if the found address is real and put the valid ones into the CSV
# - we can't make this step asynchronous because the Geopy library allows only 1 request per second

# %%
# elem is a list, where elem[0] is the url of the page and elem[1] is a list that contains all the addresses found at the elem[0]
    # print(elem[0])
    # elem [1] contains the list of the addresses
    for adresa in elem[1]:
        # print(adresa)
        
        # we extract the address with geopy if it is real
        real_address = extract_address(adresa)
        if real_address != None:
            # parsing the address that was found
            if 'country' in real_address:
                country = real_address['country']
            else:
                country = ""
                
            if 'county' in real_address:
                region = real_address['county']
            else:
                region = ""
                
            if 'city' in real_address:
                city = real_address['city']
            elif 'village' in real_address:
                city = real_address['village']
            else:
                city = ""
                
            if 'postcode' in real_address:
                postcode = real_address['postcode']
            else:
                postcode = ""
                
            if 'road' in real_address:
                road = real_address['road']
            else:
                road = ""
                
            if 'house_number' in real_address:
                no_road = real_address['house_number']
            else:
                no_road = ""
            
            # build the row for the frame
            individual_row_data = [elem[0], country, region, city, postcode, road, no_road]
            lengthh = len(df)
            df.loc[lengthh] = individual_row_data
            print("valid")
        else:
            print("invalid")
# Out:
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid

# %%
df
# Out:
#                                                    URL        Country  \
# 0                               https://embcmonroe.org  United States
# 1                               https://embcmonroe.org  United States
# 2              https://embcmonroe.org/connect-with-us/  United States
# 3                    https://casepaper.com/contact-us/  United States
# 4                    https://casepaper.com/contact-us/  United States
# ..                                                 ...            ...
# 102                http://pswrehab.com/home/department  United States
# 103                  http://pswrehab.com/home#services  United States
# 104            http://lnlconstruction.com/contact.html  United States
# 105  https://weberortho.com/contact-weber-orthodont...  United States
# 106                                http://rbhmedia.com  United States
#
#                     Region              City Postcode                Road  \
# 0             Union County            Monroe    28112      Maurice Street
# 1             Union County            Monroe    28112      Maurice Street
# 2             Union County            Monroe    28112      Maurice Street
# 3      Philadelphia County      Philadelphia    19134   East Tioga Street
# 4    San Bernardino County  Rancho Cucamonga    91730      Hermosa Avenue
# ..                     ...               ...      ...                 ...
# 102          Tulare County       Porterville    93257  West Poplar Avenue
# 103          Tulare County       Porterville    93257  West Poplar Avenue
# 104                                   Zillah    98953      Concord Street
# 105          DuPage County                      60187  West Willow Avenue
# 106     Westchester County                      10522       Hatch Terrace
#
#     Road number
# 0           503
# 1           503
# 2           503
# 3           499
# 4          9168
# ..          ...
# 102         194
# 103         194
# 104         231
# 105         210
# 106          12
#
# [107 rows x 7 columns]

# %%
df.to_csv("Addresses.csv", index=False)

# %% [markdown]
# ## Deutsch Addresses

# %%
domainsD = df_parquet.iloc[850:1622]['domain']

# %%
# the Deutsch domains are in the range (850->1621)
domainsD
# Out:
# 850                 kuk24.de
# 851      tremco-illbruck.com
# 852           cantus-bahn.de
# 853            pastisani.com
# 854       akzent-personal.de
#                 ...
# 1617    fertighaus-keitel.de
# 1618          theveryend.net
# 1619     boerse-stuttgart.de
# 1620      startupjoblist.com
# 1621          ecco-reisen.de
# Name: domain, Length: 772, dtype: object

# %% [markdown]
# - Asynchronous main function where for the domains list we obtain the url scheme

# %%
async def main(domains):
    tasks = [get_url_scheme(domain) for domain in domains]
    results = await asyncio.gather(*tasks, return_exceptions=True)
    return results

# %%
resultsD = await main(domainsD)

# %%
resultsD
# Out:
# [('kuk24.de', 'https'),
#  ('tremco-illbruck.com', 'https'),
#  ('cantus-bahn.de', 'https'),
#  ('pastisani.com', 'https'),
#  ('akzent-personal.de', 'https'),
#  ('eurofighter.com', 'https'),
#  ('marry-jim.com', 'https'),
#  ('weinanzeiger.com', 'https'),
#  ('teleclinic.com', 'https'),
#  ('infinity-reisen.com', 'https'),
#  ('rtc-c.com', 'http'),
#  ('freiberuflervermittlung.de', 'https'),
#  ('scheurer-arbeitsbuehnen.de', 'https'),
#  ('aycan.de', 'https'),
#  ('cimt.eu', 'https'),
#  ('hopegala.de', 'https'),
#  ('binect.de', 'https'),
#  ('antenne-bethel.de', 'https'),
#  ('gross-fuchs.com', 'https'),
#  ('cortec-neuro.com', 'https'),
#  ('schuhhause.de', 'https'),
#  ('biosicherheit.de', 'https'),
#  ('twt-online-marketing.de', 'https'),
#  ('audiopro.de', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('hostnet.de', 'https'),
#  ('wissensschule.de', 'https'),
#  ('bdia.de', 'https'),
#  ('projektadler.com', 'http'),
#  ('deutscheip.de', 'https'),
#  ('echt-leben.com', 'https'),
#  ('spectra.de', 'https'),
#  ('infuu.de', 'https'),
#  ('app-smart.com', 'https'),
#  ('tanztheater-hanke.de', 'https'),
#  ('erci-fanprojekt.de', 'https'),
#  ('winnerbatterien.de', 'https'),
#  ('itsmgroup.com', 'https'),
#  ('sweet-n-low.de', 'https'),
#  ('usa-amerika.com', 'https'),
#  ('kessel.de', 'https'),
#  ('sommerwiewinter.com', 'http'),
#  ('ixenso.com', 'https'),
#  ('alegria-seminare.de', 'https'),
#  ('scheu-group.com', 'https'),
#  ('youngtimertrophy.de', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('bad-harzburg.de', 'https'),
#  ('begehbares-glas.com', 'https'),
#  ('maessorrstructorr.com', 'http'),
#  ('startupsucht.com', 'https'),
#  ('cbk.de', 'http'),
#  ('quorion.de', 'https'),
#  ('trademachines.com', 'https'),
#  ('mcon.net', 'https'),
#  ('ekiem.de', 'https'),
#  ('rapidminer.com', 'https'),
#  ('portraitbox.com', 'https'),
#  ('eventflotte.de', 'https'),
#  ('westpharma.com', 'https'),
#  ('tdh.de', 'https'),
#  ('rs-torsysteme.de', 'https'),
#  ('jovoto.com', 'http'),
#  ('gelbeseiten.de', 'https'),
#  ('the-wedding-brothers.com', 'http'),
#  ('meinldrumfestival.com', 'https'),
#  ('fau.eu', 'https'),
#  ('polizeioldtimer.de', 'https'),
#  ('robertwilsonstiftung.com', 'https'),
#  ('service-design-network.org', 'https'),
#  ('kmweg.com', 'https'),
#  ('go-east.de', 'https'),
#  ('reichweite.de', 'https'),
#  ('pixupmedia.com', 'https'),
#  ('innovative-pixel.de', 'https'),
#  ('inkota.de', 'https'),
#  ('fogra.org', 'https'),
#  ('klickrent.de', 'https'),
#  ('shalom-israel-reisen.de', 'https'),
#  ('isdera.com', 'https'),
#  ('wahretabelle.de', 'https'),
#  ('malteserjugend-speyer.de', 'https'),
#  ('uds-beratung.de', 'https'),
#  ('joest-racing.de', 'https'),
#  ('gini.net', 'https'),
#  ('bfacademy.com', 'https'),
#  ('hk-bs.de', 'https'),
#  ('englishendurance.com', 'https'),
#  ('teampenta.eu', 'https'),
#  ('kamps.de', 'https'),
#  ('kinderturnstiftung-bw.de', 'https'),
#  ('fuseroom.com', 'https'),
#  ('esta-pro.org', 'https'),
#  ('data2fact.de', 'https'),
#  ('dirigent-gesucht.de', 'https'),
#  ('ad-vanced.de', 'http'),
#  ('nextim.de', 'https'),
#  ('dedeso.com', 'https'),
#  ('bmw-z1.club', 'https'),
#  ('flyermaschine.de', 'https'),
#  ('net-toys.de', 'https'),
#  ('ebozon-verlag.com', 'https'),
#  ('meininger.de', 'https'),
#  ('talesfromtheinside.com', 'https'),
#  ('academyconsult.de', 'https'),
#  ('checkdomain.de', 'https'),
#  ('mobexo.de', 'https'),
#  ('nuvitababy.com', 'https'),
#  ('refund.me', 'https'),
#  ('nabu.de', 'https'),
#  ('systeme24.de', 'https'),
#  ('rainer-spiering.de', 'https'),
#  ('famastiltaurus.com', 'http'),
#  ('cbm.org', 'https'),
#  ('science-on-stage.eu', 'https'),
#  ('solaranlagen-portal.de', 'https'),
#  ('minespider.com', 'https'),
#  ssl.SSLError(1,
#               '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)'),
#  ('big-picture.com', 'https'),
#  ('mdrconsulting.com', 'https'),
#  ('landmark-fine-travel.de', 'https'),
#  ('helloclue.com', 'https'),
#  ('franken-consulting.org', 'http'),
#  ('skalar.marketing', 'https'),
#  ('bioanalyt.com', 'https'),
#  ssl.SSLError(1,
#               '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)'),
#  ('golocal.de', 'https'),
#  ('ammt.com', 'https'),
#  ('fusionchef.de', 'https'),
#  ('internetx.com', 'https'),
#  ('campingshop-24.de', 'https'),
#  ('salz-mischer.de', 'https'),
#  ('inbalance-yoga.net', 'http'),
#  ('bettmer.de', 'https'),
#  ('devk.de', 'https'),
#  ('teamwire.eu', 'https'),
#  ('erfolgx.de', 'https'),
#  ('running-wild.de', 'https'),
#  ('intergral.com', 'https'),
#  ('brotfabrik-berlin.de', 'https'),
#  ('dailyme.de', 'https'),
#  ('wordifyapp.com', 'https'),
#  ('vermes.com', 'https'),
#  ('sebastian-klammer.de', 'http'),
#  ('rapidmail.de', 'https'),
#  ('nittardi.com', 'https'),
#  ('realcube.com', 'https'),
#  ('strateco.group', 'https'),
#  ('stadionwelt.de', 'https'),
#  ('partitions-musicales.net', 'https'),
#  ('decaconnect.com', 'https'),
#  ('jkstein.de', 'https'),
#  ('skoobe.de', 'https'),
#  ('cheatbook.de', 'https'),
#  ('bundesjugend.de', 'https'),
#  ('youperience.com', 'https'),
#  ('g-m-m.de', 'https'),
#  ('werhatoffen.de', 'https'),
#  ('twintecgroup.com', 'https'),
#  ('frankfurt-holm.de', 'https'),
#  ('eve-images.com', 'https'),
#  ('trankvile.com', 'https'),
#  ('kiwi-consulting.de', 'https'),
#  ('schuberth.com', 'https'),
#  ('smartray.com', 'https'),
#  ('sinoian.com', 'https'),
#  ('dus.com', 'https'),
#  ('digitalcoregraphics.de', 'https'),
#  ('postproductions.de', 'https'),
#  ('dualinnovation.com', 'https'),
#  ('quattrocelli.de', 'https'),
#  ('appclouds.de', 'https'),
#  ('daa-wirtschaftsakademie.de', 'https'),
#  ('onventis.de', 'https'),
#  ('krups.com', 'https'),
#  ('voon.de', 'https'),
#  ('malteser-wetzlar.de', 'https'),
#  ('ifw-dresden.de', 'https'),
#  ('lisekruegerbarth.com', 'https'),
#  ('enablesecurity.com', 'https'),
#  ('sams-think-special.de', 'https'),
#  ('franzel.de', 'https'),
#  ('leanport.de', 'https'),
#  ('invesdor.de', 'https'),
#  ('berliner-filmfestivals.de', 'https'),
#  ('dresden-onlineshop.de', 'https'),
#  ('typo.cz', 'https'),
#  ('frings.com', 'https'),
#  ('neuhauspartners.com', 'https'),
#  ('inside-digital.de', 'https'),
#  ('mowaii.com', 'https'),
#  ('wiverndigital.com', 'https'),
#  ('berliner-unterwelten.de', 'https'),
#  ('aopn.com', 'https'),
#  ('stefanhobmaier.com', 'https'),
#  ('kuechenstud.io', 'https'),
#  ('drehmoment-gmbh.de', 'https'),
#  ('oezgen-senol.de', 'https'),
#  ('wotechsolar.com', 'http'),
#  ('horze.eu', 'https'),
#  ('aesir-interactive.com', 'https'),
#  ('hirschberg-sauerland.de', 'https'),
#  ('bespoky.com', 'https'),
#  ('gpmoto.de', 'https'),
#  ('weddingcam.de', 'https'),
#  ('laguiole-laguiole.de', 'https'),
#  ('basic.de', 'https'),
#  ('igo-werbeartikel.de', 'https'),
#  ('fct-akademie.com', 'https'),
#  ('reiten-in-mv.de', 'https'),
#  ('zahlungsvereinbarung.com', 'https'),
#  ('theatermakeup.de', 'https'),
#  ('ackee.cz', 'https'),
#  ('haasehof.de', 'https'),
#  ('element.de', 'https'),
#  ('jazzradio.net', 'https'),
#  ('eps-personal.org', 'https'),
#  ('renereif.de', 'https'),
#  ('stein-automation.de', 'https'),
#  ('mp-gruppe.de', 'https'),
#  ('gargiulo.de', 'https'),
#  ('aetka.de', 'https'),
#  ('dkou.org', 'https'),
#  ('pixelboxx.com', 'https'),
#  ('goettfert.de', 'https'),
#  ('delphin.com', 'https'),
#  ('studio-ahoi.de', 'https'),
#  ('dectomusic.com', 'http'),
#  ('ctr-fahrzeuge.de', 'https'),
#  ('wunderstudios.com', 'https'),
#  ('gmx.net', 'https'),
#  ('swfr.de', 'https'),
#  ('tophotelprojects.com', 'https'),
#  ('co2-meter.net', 'http'),
#  ('billiger-mietwagen.de', 'https'),
#  ('orbitlog.com', 'http'),
#  ('sync.blue', 'https'),
#  ('kunstverein-bielefeld.de', 'https'),
#  ('cliffstevens.com', 'https'),
#  ('himmelhochjauchzend.com', 'https'),
#  ('perfekt-dienstleistungen.com', 'https'),
#  ('ralphjo.com', 'https'),
#  ('csu.de', 'http'),
#  ('garnetbag.com', 'http'),
#  ('smiletrain.de', 'https'),
#  ('innoactive.io', 'https'),
#  ('ngn-europe.com', 'https'),
#  ('microtool.de', 'https'),
#  ('amex-sanivar.com', 'https'),
#  ('sprachrausch.com', 'https'),
#  ('dirkbecker-entertainment.de', 'https'),
#  ('blackpearlfilm.com', 'http'),
#  ('appel.de', 'https'),
#  ('marco-arena.de', 'https'),
#  ('sysy.com', 'https'),
#  ('bos-buero.de', 'https'),
#  ('tobaccofreeliving.org', 'https'),
#  ('hotel-badischerhof-badenbaden.de', 'https'),
#  ('treesidemusic.com', 'http'),
#  ('zahnarzt.ac', 'https'),
#  ('pikasslifestyle.com', 'https'),
#  ('consulegis.com', 'https'),
#  ('leagasdelaney.de', 'https'),
#  ('care.de', 'https'),
#  ('allectra.com', 'https'),
#  ('cellsystems.eu', 'https'),
#  ('epo.org', 'https'),
#  ('getrental.de', 'https'),
#  ('thedailyjournalist.com', 'https'),
#  ('marcmichaelmueller.com', 'https'),
#  ('german-pellets.de', 'https'),
#  ('dr-estrich.com', 'http'),
#  ('hundekoerbchen-kaufen.de', 'http'),
#  ('moberries.com', 'https'),
#  ('y-square.de', 'https'),
#  ('ludwigtype.de', 'https'),
#  ('makers.do', 'https'),
#  ('datamonk.com', 'http'),
#  ('ferrostaal.com', 'https'),
#  ('nature-trails-events.de', 'https'),
#  ('thecornerhotel.de', 'https'),
#  ('pwc.de', 'https'),
#  ('papiernetz.de', 'https'),
#  ('integrationmatters.com', 'https'),
#  ('hotelcult.de', 'https'),
#  ('master-vergleich.com', 'https'),
#  ('signavio.com', 'https'),
#  ('evoloop.com', 'https'),
#  ('fertan.de', 'https'),
#  ('awchamburg.org', 'https'),
#  ('nugzblacky.com', 'https'),
#  ('mobi-test.de', 'https'),
#  ('m-cube.de', 'https'),
#  ('filmconfect.com', 'https'),
#  ('review-troll.com', 'https'),
#  ('horst-busch.de', 'https'),
#  ('k-konzept.de', 'https'),
#  ('naturprodukte24.net', 'https'),
#  ('promotion-werft.de', 'https'),
#  ('sumuphosting.com', 'http'),
#  ('nextevolution.de', 'https'),
#  ('compiricus.com', 'https'),
#  ('kalthoff-kollegen.de', 'https'),
#  ('werbemax.de', 'https'),
#  ('stephanieforryan.com', 'https'),
#  ('casino-poker-manager.com', 'https'),
#  ('awesomeberlin.net', 'https'),
#  ('mitsicherheitbesser.de', 'https'),
#  ('charcotfootcourses.org', 'https'),
#  ('mercoline.de', 'https'),
#  ('malteserjugend-trier.de', 'https'),
#  ('das-beste-in-frankreich.de', 'https'),
#  ('elitegermanshepherds.com', 'https'),
#  ('vancado.de', 'https'),
#  ('genver.de', 'https'),
#  ('lichtundschatten-3d.de', 'https'),
#  ('viereck-hydraulik.com', 'https'),
#  ('poison-berlin.com', 'https'),
#  ('kulmens.de', 'https'),
#  ('marsheproductions.com', 'https'),
#  ('bembeltown.de', 'http'),
#  ('sld.gs', 'http'),
#  ('ardour.de', 'https'),
#  ('demoup-cliplister.com', 'https'),
#  ('cubecms.org', 'https'),
#  ('paintballpark.de', 'https'),
#  ('tacalyx.com', 'https'),
#  ('mylsp.de', 'https'),
#  ('360t.com', 'https'),
#  ('leon-nanodrugs.com', 'https'),
#  ('ux3d.io', 'https'),
#  ('onlineprinters.com', 'https'),
#  ('junges-uno-netzwerk.de', 'https'),
#  ('flugsam.de', 'https'),
#  ('proxy-studios.com', 'https'),
#  ('max-planck-innovation.com', 'https'),
#  ('holidu.com', 'https'),
#  ('verbio.de', 'https'),
#  ('elsa-frankfurt.de', 'http'),
#  ('voya.ai', 'https'),
#  ('brainseeker.de', 'https'),
#  ('atrium2000.com', 'https'),
#  ('container-xchange.com', 'https'),
#  ('kwon.com', 'https'),
#  ('ego4u.com', 'https'),
#  ('bishop-gmbh.com', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('software-architecture-camp.de', 'https'),
#  ('opencore.com', 'http'),
#  ('lalelu.de', 'https'),
#  ('friedrichskoog.de', 'https'),
#  ('vsb.energy', 'https'),
#  ('seezigeuner.de', 'https'),
#  ('fame-creativelab.com', 'https'),
#  ('reineckerprolexia.de', 'https'),
#  ('amparex.com', 'https'),
#  ('mwaysolutions.com', 'https'),
#  ('eqs.com', 'https'),
#  ('bzweic.de', 'https'),
#  ('photokina.de', 'https'),
#  ('heilfastentherapie.com', 'https'),
#  ('xtrasystem.com', 'https'),
#  ('e-breuninger.de', 'https'),
#  ('ajrwebdesign.com', 'https'),
#  ('jds-sommer.de', 'https'),
#  ('apartment-hotel.de', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('klingel-med.de', 'https'),
#  ('joinairbank.com', 'http'),
#  ('connectivisten.de', 'https'),
#  ('novostrat.com', 'https'),
#  ('venista-ventures.com', 'https'),
#  ('ppro.com', 'https'),
#  ('horizonttours.de', 'https'),
#  ('geco-event.com', 'https'),
#  ('caddycool.com', 'https'),
#  ('sauber-man.com', 'https'),
#  ('praktiker.de', 'https'),
#  ('ideenpla.net', 'https'),
#  ('fs-etit.de', 'https'),
#  ('m-und-h.de', 'https'),
#  ('private-arbeitsagentur.eu', 'http'),
#  ('schwimmbad-schmierer.de', 'https'),
#  ('roadshow-experts.de', 'https'),
#  ('createmeaning.com', 'https'),
#  ('myrkothum.com', 'https'),
#  ('per4med.de', 'https'),
#  ('purchaze.com', 'https'),
#  ('hausambergshepherds.com', 'https'),
#  ('innovative-navigation.de', 'https'),
#  ('schlafenderhase.com', 'https'),
#  ('kellerkommando.de', 'https'),
#  ('brandmaker.com', 'https'),
#  ('markengold.de', 'https'),
#  ('zeninvest.de', 'https'),
#  ('poggemoeller.co', 'https'),
#  ('corporate-karma.de', 'https'),
#  ('laokoongruppe.com', 'https'),
#  ('adivarius.de', 'https'),
#  ('kerkhoff-consulting.com', 'https'),
#  ('intercard.org', 'https'),
#  ('elsmannimmobilien.de', 'https'),
#  ('erneuerbareenergien.de', 'https'),
#  ('bergmanclinics-klinikimpark.de', 'https'),
#  ('wrestleking.de', 'https'),
#  ('weigelworld.org', 'https'),
#  ('apo-buy.com', 'https'),
#  ('lacba.org', 'https'),
#  ('davengo.com', 'https'),
#  ('quartier-theater.de', 'https'),
#  ('postuning.com', 'https'),
#  ('k-is.com', 'https'),
#  ('simple-fax.de', 'https'),
#  ('b-s.de', 'https'),
#  ('diebayerische.de', 'https'),
#  ('frents.com', 'https'),
#  ('thc-testing.com', 'https'),
#  ('unimed.de', 'https'),
#  ('start-online-therapie.de', 'https'),
#  ('medialab-internetagentur.de', 'https'),
#  ('amadeus-fire.de', 'https'),
#  ('lampenwelt.de', 'https'),
#  ('global-mobility.com', 'https'),
#  ('joeusa.com', 'http'),
#  ('sternen-schluchsee.de', 'https'),
#  ('kaifu-lodge.de', 'https'),
#  ('cinepostproduction.de', 'https'),
#  ('hoppegarten.com', 'https'),
#  ('cpl-sachse.de', 'https'),
#  ('kreutzer-consulting.com', 'https'),
#  ('pschyrembel.de', 'https'),
#  ('seat.de', 'https'),
#  ('hbo2.de', 'https'),
#  ('isystems-integration.com', 'https'),
#  ('everbase.net', 'http'),
#  ('frontalvision.com', 'https'),
#  ('monocrom.de', 'https'),
#  ('laufpix.de', 'https'),
#  ('kuriershop.de', 'https'),
#  ('efaflex.com', 'https'),
#  ('jetsgroup.com', 'https'),
#  ('tutanota.com', 'https'),
#  ('startnext.com', 'https'),
#  ('yummystories.de', 'http'),
#  ('himmelspagode.de', 'https'),
#  ('zapf-creation.com', 'https'),
#  ('europarc.org', 'https'),
#  ('regupol.com', 'https'),
#  ('solvatis.de', 'https'),
#  ('lustre.org', 'https'),
#  ('lysicom.de', 'https'),
#  ('mindlab.de', 'https'),
#  ('ortholutions.de', 'http'),
#  ('miet24.de', 'https'),
#  ('mooc-beratung.de', 'https'),
#  ('helmag.com', 'https'),
#  ('secret-music.net', 'https'),
#  ('raysono.com', 'https'),
#  ('hirschen.com', 'https'),
#  ('hochseilgarten-neutraubling.net', 'http'),
#  ('hyperstone.com', 'https'),
#  ('studdex.com', 'https'),
#  ('toolsgroup.com', 'https'),
#  ('ifabrik.de', 'https'),
#  ('phrase.com', 'https'),
#  ('berenberg.de', 'https'),
#  ('honeymoments.de', 'https'),
#  ('wedding-youandme.com', 'https'),
#  ('nandurion.de', 'https'),
#  ('schaffenwir.com', 'https'),
#  ('4dgo.de', 'http'),
#  ('myreiseforum.de', 'https'),
#  ('acxiom.de', 'https'),
#  ('brandperfection.de', 'https'),
#  ('borgmann-krefeld.de', 'https'),
#  ('chameleon-system.de', 'https'),
#  ('ho-ersoka.de', 'https'),
#  ('plu.de', 'https'),
#  ('tiesolution.de', 'https'),
#  ('e-fellows.net', 'https'),
#  ('energiekontor.de', 'https'),
#  ('upon-onlinemarketing.com', 'https'),
#  ('statt-theater.net', 'https'),
#  ('nexworld.tv', 'https'),
#  ('lcs-schlieben.de', 'https'),
#  ('telerion.com', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('reiseservice-heinz.de', 'https'),
#  ('semprebonita.de', 'https'),
#  ('pferdebild.de', 'https'),
#  ('aqon-pure.com', 'https'),
#  ('p-21.de', 'https'),
#  ('ssmsboost.com', 'https'),
#  ('coi.de', 'https'),
#  ('printus.de', 'https'),
#  ('kiwi.de', 'https'),
#  ('hesse-mechatronics.com', 'https'),
#  ('berlinlofts.com', 'https'),
#  ('birgithart.com', 'https'),
#  ('porsche-design.com', 'https'),
#  ('in-chemnitz.de', 'http'),
#  ('bowlers-inn.de', 'https'),
#  ('kobra-net.de', 'https'),
#  ('microdoc.com', 'https'),
#  ('pixeltricks.de', 'https'),
#  ('pia.me', 'https'),
#  ('strompreisvergleich24.com', 'https'),
#  ('lehnenmusic.com', 'https'),
#  ('prostinternational.com', 'https'),
#  ('helee-expo.com', 'https'),
#  ('abcadamas.de', 'https'),
#  ('trelock.de', 'https'),
#  ('impreg.de', 'https'),
#  ('prosanova.net', 'https'),
#  ('clueso.de', 'https'),
#  ('lieblingstasche.de', 'https'),
#  ('bwpapersystems.com', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('datac-gmbh.de', 'https'),
#  ('kompakt.fm', 'https'),
#  ('shows-artists.com', 'https'),
#  ('bio-naturwelt.de', 'https'),
#  ('admanagerforum.de', 'https'),
#  ('delphi-advisors.com', 'https'),
#  ('jk-kom.de', 'https'),
#  ('schmeckthal-gruppe.de', 'https'),
#  ('bc-diagnostics.com', 'https'),
#  ('rbvc.com', 'https'),
#  ('airnergy.shop', 'https'),
#  ('konzeptimmobilien.de', 'https'),
#  ('merantix.com', 'https'),
#  ('cmc-silenta.com', 'https'),
#  ('tvm-lifescience.com', 'https'),
#  ('meeresblick-baabe.de', 'https'),
#  ('langermediaconsulting.de', 'https'),
#  ('littlesun.org', 'https'),
#  ('drk-bos.de', 'https'),
#  ('spanndeckenstudio.de', 'http'),
#  ('esome.com', 'https'),
#  ('xell.ag', 'https'),
#  ('mergeflow.com', 'https'),
#  ('hitchon.de', 'https'),
#  ('dts.de', 'https'),
#  ('imaos.de', 'http'),
#  ssl.SSLError(1,
#               '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1006)'),
#  ('fogjoggers.com', 'https'),
#  ('lightweb-media.de', 'https'),
#  ('claritos.de', 'https'),
#  ('server-konfigurieren.de', 'https'),
#  ('weihnachtskultparty.de', 'https'),
#  ('diekavallerie.de', 'https'),
#  ('schnatterer.com', 'http'),
#  ('hochschwarzwald.de', 'https'),
#  ('severn.de', 'https'),
#  ('mehrfachsparen.de', 'https'),
#  ('visionconnect.de', 'https'),
#  ('antondoll.de', 'https'),
#  ('hohnwerbetechnik.com', 'https'),
#  ('redmarketing.de', 'https'),
#  ('neschen.de', 'https'),
#  ('dopavision.com', 'https'),
#  ('kmbmedia.de', 'https'),
#  ('lps-laser.de', 'https'),
#  ('ihs-gmbh.de', 'https'),
#  ('wandres.com', 'https'),
#  ('reisefanten.de', 'https'),
#  ('revell.de', 'https'),
#  ('drmannahs.com', 'https'),
#  ('wiedemann.de', 'https'),
#  ('wiblishauser-seminare.de', 'https'),
#  ssl.SSLError(1,
#               '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1006)'),
#  ('justwatch.com', 'https'),
#  ('artaqua.de', 'https'),
#  ('vr-on.com', 'https'),
#  ('awantego.com', 'https'),
#  ('modus-werbung.de', 'https'),
#  ('fotos-verkaufen.de', 'https'),
#  ('games-bavaria.com', 'https'),
#  ('horizont.com', 'https'),
#  ('farinda-club.de', 'http'),
#  ('ernstings-family.com', 'https'),
#  ('shopclever.de', 'https'),
#  ('alpha-communication.com', 'https'),
#  ('alexander-training.de', 'https'),
#  ('mekos.de', 'https'),
#  ('quintex.eu', 'https'),
#  ('china-outbound.com', 'https'),
#  ('pixialisten.de', 'https'),
#  ('eprairie.com', 'http'),
#  ('malteserjugend-bamberg.de', 'https'),
#  ('icmfs2015.com', 'https'),
#  ('dress-for-less.co.uk', 'https'),
#  ('gfn.de', 'https'),
#  ('openwallsgallery.com', 'https'),
#  ('das-comitee.com', 'https'),
#  ('altec-cs.com', 'http'),
#  ('scoop-yard.de', 'https'),
#  ('lagerflaeche.de', 'https'),
#  ('perfectlingua.com', 'https'),
#  ('mandalka.name', 'http'),
#  ('siemens-healthineers.com', 'https'),
#  ('kraiburg-relastec.com', 'https'),
#  ('danhills.de', 'https'),
#  ('r2p.com', 'https'),
#  ('drk-rhein-nahe.de', 'https'),
#  ('sirisvegler.com', 'https'),
#  ('null-leasing.com', 'https'),
#  ('uhlmann.de', 'https'),
#  ('dervizz.com', 'https'),
#  ('ps-antriebstechnik.de', 'https'),
#  ('rheinruhronline.de', 'https'),
#  ('evorait.com', 'https'),
#  ('flyair41.de', 'https'),
#  ('jur.solutions', 'https'),
#  ('mester.de', 'https'),
#  ('xell-consulting.de', 'https'),
#  ('agbf.com', 'https'),
#  ('sake-kontor.de', 'https'),
#  ('reefcheck.de', 'https'),
#  ('overnightprints.de', 'https'),
#  ('pinchart.de', 'https'),
#  ('starface.com', 'https'),
#  ('fgk-cro.com', 'https'),
#  ('berlin-partner.de', 'https'),
#  ('beds24.com', 'https'),
#  ('microsonic.de', 'https'),
#  ('realtennisnetwork.com', 'https'),
#  ('alvi.de', 'https'),
#  ('billig-banner24.de', 'https'),
#  ('frenzelit.com', 'https'),
#  ('agenturhuette.de', 'https'),
#  ('lintec-gmbh.de', 'https'),
#  ('sea-distribution.com', 'https'),
#  ('rheinfabrik.de', 'https'),
#  ('mfg.de', 'https'),
#  ('imiconsulting.com', 'https'),
#  ('fastbolt.com', 'https'),
#  ('junge-presse.de', 'https'),
#  ('subsiege-game.com', 'https'),
#  ('codydawg.de', 'https'),
#  ('porzellanklinik-bremen.de', 'https'),
#  ('raeume-zum-feiern.de', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('hils-it.com', 'https'),
#  ('fesa.de', 'https'),
#  ('sportsfreude.com', 'https'),
#  ('airportzentrale.de', 'https'),
#  ('ms-holz.de', 'https'),
#  ('cupcino.com', 'https'),
#  ('synergie.de', 'https'),
#  ('visomax.de', 'https'),
#  ('stefan-plenk.com', 'https'),
#  ('lufapak.de', 'https'),
#  ('metalized.de', 'https'),
#  ('vileda.com', 'https'),
#  ('pulscamp.de', 'https'),
#  ('a-maze.net', 'https'),
#  ('vsda.de', 'https'),
#  ('spindash.de', 'https'),
#  ('rictv.de', 'http'),
#  ('jonnyfresh.com', 'https'),
#  ('ihk-party.de', 'https'),
#  ('arbeiten-bei-stihl.de', 'https'),
#  ('unwomen.de', 'https'),
#  ('unicum.de', 'https'),
#  ('fgk-rs.com', 'https'),
#  ('slf-fraureuth.de', 'https'),
#  ('freizeichen.com', 'https'),
#  ('andymagro.com', 'https'),
#  ('windowspro.de', 'https'),
#  ('prepaid-usenet.de', 'https'),
#  ('aliaxis.de', 'https'),
#  ('axonic.com', 'https'),
#  ('axiogenesis.com', 'http'),
#  ('weareforeal.com', 'https'),
#  ssl.SSLError(1,
#               '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)'),
#  ('rapidshape.de', 'https'),
#  ('schmidtner-gmbh.de', 'https'),
#  ('kf-interactive.com', 'https'),
#  ('jungmann.de', 'https'),
#  ('plista.com', 'http'),
#  ('sobis.com', 'https'),
#  ('flymo.com', 'https'),
#  ('stickybiscuits.com', 'http'),
#  ('prehkeytec.com', 'https'),
#  ('testboy.de', 'https'),
#  ('cast-pharma.com', 'https'),
#  ('gid-it.de', 'https'),
#  ('raphs-bbq-truck.de', 'https'),
#  ('tischlerei-jagsch.de', 'https'),
#  ('bonn.de', 'https'),
#  ('mysumtu.com', 'https'),
#  ('irist.com', 'http'),
#  ('cheplapharm.com', 'https'),
#  ('pernetix.de', 'https'),
#  ('drivedevilbiss-int.com', 'https'),
#  ('microtrac.com', 'https'),
#  ('pyrotechnik24.com', 'https'),
#  ('plutosport.de', 'https'),
#  ('eventcompanies.de', 'https'),
#  ('fcstpauli-afm.de', 'http'),
#  ('clevermemo.com', 'http'),
#  ('sylt-ferienwohnungen-urlaub.de', 'https'),
#  ('calw.de', 'https'),
#  ('thestrategyweb.com', 'http'),
#  ('artgovt.com', 'http'),
#  ('eve-audio.com', 'http'),
#  ('itonics-innovation.com', 'http'),
#  ('cosmetix.net', 'http'),
#  ('uniboxapp.com', 'https'),
#  ('haubermethod.com', 'http'),
#  ('digitaleheimat.de', 'http'),
#  ('protosoft.de', 'http'),
#  ('undercover.de', 'http'),
#  ('dieselkrad.info', 'http'),
#  ('dexter-international.com', 'http'),
#  ('istapower.de', 'http'),
#  ('quipu.de', 'http'),
#  ('ihc-solutions.de', 'http'),
#  ('guthaben-kaufen.com', 'http'),
#  ('swox.com', 'http'),
#  ('pink-engineer.de', 'http'),
#  ('misseverywhere.com', 'http'),
#  ('smartclip.tv', 'http'),
#  ('fnverlag.de', 'http'),
#  ('berliner-philharmoniker.de', 'http'),
#  ('pattern-paradise.com', 'http'),
#  ('edias.com', 'http'),
#  ('neuromerchandisinggroup.com', 'http'),
#  ('rw-kupplungen.de', 'http'),
#  ('mobiuslabs.com', 'http'),
#  ('vmray.com', 'http'),
#  ('theblankswebsite.com', 'http'),
#  ('smartmedia24.de', 'http'),
#  ('webanizer.de', 'http'),
#  ('ladypopular.de', 'http'),
#  ('hypersoft.com', 'http'),
#  ('h2fly.de', 'http'),
#  ('targetesports.com', 'http'),
#  ('chocion.com', 'http'),
#  ('topcruiseemployer.com', 'http'),
#  ('gletschercola.de', 'http'),
#  ('crowdfunding.de', 'http'),
#  ('bureau-heintz.de', 'http'),
#  ('coffee-fellows.com', 'http'),
#  ('christengemeinde.com', 'http'),
#  ('fernbus24.de', 'http'),
#  ('jena-optronik.de', 'http'),
#  ('ads-systems.com', 'http'),
#  ('luxx-film.com', 'http'),
#  ('heldentaten.net', 'http'),
#  ('bae-berlin.de', 'http'),
#  ('springmaus-theater.de', 'http'),
#  ('modusconsult.de', 'http'),
#  ('daniel-philipp.com', 'http'),
#  ('catinberlin.com', 'http'),
#  ('schwing-technologies.com', 'http'),
#  ('kinderkuechekaufen.de', 'http'),
#  ('derwil.com', 'http'),
#  ('saarcamp.de', 'http'),
#  ('conflict-minerals.com', 'http'),
#  ('alpenverein.de', 'http'),
#  ('qoniac.com', 'http'),
#  ('treatwell.de', 'http'),
#  ('wirsindhelden.com', 'http'),
#  ('artviper-werbeagentur.de', 'http'),
#  ('chapeau-restaurant.com', 'http'),
#  ('fertighaus-keitel.de', 'http'),
#  ('theveryend.net', 'http'),
#  ('boerse-stuttgart.de', 'http'),
#  ('startupjoblist.com', 'http'),
#  ('ecco-reisen.de', 'http')]

# %%
# Printing the results
complete_urlsD = []
for result in resultsD:
    if isinstance(result, tuple):
        domain, scheme = result
        complete_url = f"{scheme}://{domain}"
        print(f"Url complet: {complete_url}")
        complete_urlsD.append(complete_url)
    else:
        print(f"Rezultat neașteptat: {result}")
# Out:
# Url complet: https://kuk24.de
# Url complet: https://tremco-illbruck.com
# Url complet: https://cantus-bahn.de
# Url complet: https://pastisani.com
# Url complet: https://akzent-personal.de
# Url complet: https://eurofighter.com
# Url complet: https://marry-jim.com
# Url complet: https://weinanzeiger.com
# Url complet: https://teleclinic.com
# Url complet: https://infinity-reisen.com
# Url complet: http://rtc-c.com
# Url complet: https://freiberuflervermittlung.de
# Url complet: https://scheurer-arbeitsbuehnen.de
# Url complet: https://aycan.de
# Url complet: https://cimt.eu
# Url complet: https://hopegala.de
# Url complet: https://binect.de
# Url complet: https://antenne-bethel.de
# Url complet: https://gross-fuchs.com
# Url complet: https://cortec-neuro.com
# Url complet: https://schuhhause.de
# Url complet: https://biosicherheit.de
# Url complet: https://twt-online-marketing.de
# Url complet: https://audiopro.de
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://hostnet.de
# Url complet: https://wissensschule.de
# Url complet: https://bdia.de
# Url complet: http://projektadler.com
# Url complet: https://deutscheip.de
# Url complet: https://echt-leben.com
# Url complet: https://spectra.de
# Url complet: https://infuu.de
# Url complet: https://app-smart.com
# Url complet: https://tanztheater-hanke.de
# Url complet: https://erci-fanprojekt.de
# Url complet: https://winnerbatterien.de
# Url complet: https://itsmgroup.com
# Url complet: https://sweet-n-low.de
# Url complet: https://usa-amerika.com
# Url complet: https://kessel.de
# Url complet: http://sommerwiewinter.com
# Url complet: https://ixenso.com
# Url complet: https://alegria-seminare.de
# Url complet: https://scheu-group.com
# Url complet: https://youngtimertrophy.de
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://bad-harzburg.de
# Url complet: https://begehbares-glas.com
# Url complet: http://maessorrstructorr.com
# Url complet: https://startupsucht.com
# Url complet: http://cbk.de
# Url complet: https://quorion.de
# Url complet: https://trademachines.com
# Url complet: https://mcon.net
# Url complet: https://ekiem.de
# Url complet: https://rapidminer.com
# Url complet: https://portraitbox.com
# Url complet: https://eventflotte.de
# Url complet: https://westpharma.com
# Url complet: https://tdh.de
# Url complet: https://rs-torsysteme.de
# Url complet: http://jovoto.com
# Url complet: https://gelbeseiten.de
# Url complet: http://the-wedding-brothers.com
# Url complet: https://meinldrumfestival.com
# Url complet: https://fau.eu
# Url complet: https://polizeioldtimer.de
# Url complet: https://robertwilsonstiftung.com
# Url complet: https://service-design-network.org
# Url complet: https://kmweg.com
# Url complet: https://go-east.de
# Url complet: https://reichweite.de
# Url complet: https://pixupmedia.com
# Url complet: https://innovative-pixel.de
# Url complet: https://inkota.de
# Url complet: https://fogra.org
# Url complet: https://klickrent.de
# Url complet: https://shalom-israel-reisen.de
# Url complet: https://isdera.com
# Url complet: https://wahretabelle.de
# Url complet: https://malteserjugend-speyer.de
# Url complet: https://uds-beratung.de
# Url complet: https://joest-racing.de
# Url complet: https://gini.net
# Url complet: https://bfacademy.com
# Url complet: https://hk-bs.de
# Url complet: https://englishendurance.com
# Url complet: https://teampenta.eu
# Url complet: https://kamps.de
# Url complet: https://kinderturnstiftung-bw.de
# Url complet: https://fuseroom.com
# Url complet: https://esta-pro.org
# Url complet: https://data2fact.de
# Url complet: https://dirigent-gesucht.de
# Url complet: http://ad-vanced.de
# Url complet: https://nextim.de
# Url complet: https://dedeso.com
# Url complet: https://bmw-z1.club
# Url complet: https://flyermaschine.de
# Url complet: https://net-toys.de
# Url complet: https://ebozon-verlag.com
# Url complet: https://meininger.de
# Url complet: https://talesfromtheinside.com
# Url complet: https://academyconsult.de
# Url complet: https://checkdomain.de
# Url complet: https://mobexo.de
# Url complet: https://nuvitababy.com
# Url complet: https://refund.me
# Url complet: https://nabu.de
# Url complet: https://systeme24.de
# Url complet: https://rainer-spiering.de
# Url complet: http://famastiltaurus.com
# Url complet: https://cbm.org
# Url complet: https://science-on-stage.eu
# Url complet: https://solaranlagen-portal.de
# Url complet: https://minespider.com
# Rezultat neașteptat: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)
# Url complet: https://big-picture.com
# Url complet: https://mdrconsulting.com
# Url complet: https://landmark-fine-travel.de
# Url complet: https://helloclue.com
# Url complet: http://franken-consulting.org
# Url complet: https://skalar.marketing
# Url complet: https://bioanalyt.com
# Rezultat neașteptat: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)
# Url complet: https://golocal.de
# Url complet: https://ammt.com
# Url complet: https://fusionchef.de
# Url complet: https://internetx.com
# Url complet: https://campingshop-24.de
# Url complet: https://salz-mischer.de
# Url complet: http://inbalance-yoga.net
# Url complet: https://bettmer.de
# Url complet: https://devk.de
# Url complet: https://teamwire.eu
# Url complet: https://erfolgx.de
# Url complet: https://running-wild.de
# Url complet: https://intergral.com
# Url complet: https://brotfabrik-berlin.de
# Url complet: https://dailyme.de
# Url complet: https://wordifyapp.com
# Url complet: https://vermes.com
# Url complet: http://sebastian-klammer.de
# Url complet: https://rapidmail.de
# Url complet: https://nittardi.com
# Url complet: https://realcube.com
# Url complet: https://strateco.group
# Url complet: https://stadionwelt.de
# Url complet: https://partitions-musicales.net
# Url complet: https://decaconnect.com
# Url complet: https://jkstein.de
# Url complet: https://skoobe.de
# Url complet: https://cheatbook.de
# Url complet: https://bundesjugend.de
# Url complet: https://youperience.com
# Url complet: https://g-m-m.de
# Url complet: https://werhatoffen.de
# Url complet: https://twintecgroup.com
# Url complet: https://frankfurt-holm.de
# Url complet: https://eve-images.com
# Url complet: https://trankvile.com
# Url complet: https://kiwi-consulting.de
# Url complet: https://schuberth.com
# Url complet: https://smartray.com
# Url complet: https://sinoian.com
# Url complet: https://dus.com
# Url complet: https://digitalcoregraphics.de
# Url complet: https://postproductions.de
# Url complet: https://dualinnovation.com
# Url complet: https://quattrocelli.de
# Url complet: https://appclouds.de
# Url complet: https://daa-wirtschaftsakademie.de
# Url complet: https://onventis.de
# Url complet: https://krups.com
# Url complet: https://voon.de
# Url complet: https://malteser-wetzlar.de
# Url complet: https://ifw-dresden.de
# Url complet: https://lisekruegerbarth.com
# Url complet: https://enablesecurity.com
# Url complet: https://sams-think-special.de
# Url complet: https://franzel.de
# Url complet: https://leanport.de
# Url complet: https://invesdor.de
# Url complet: https://berliner-filmfestivals.de
# Url complet: https://dresden-onlineshop.de
# Url complet: https://typo.cz
# Url complet: https://frings.com
# Url complet: https://neuhauspartners.com
# Url complet: https://inside-digital.de
# Url complet: https://mowaii.com
# Url complet: https://wiverndigital.com
# Url complet: https://berliner-unterwelten.de
# Url complet: https://aopn.com
# Url complet: https://stefanhobmaier.com
# Url complet: https://kuechenstud.io
# Url complet: https://drehmoment-gmbh.de
# Url complet: https://oezgen-senol.de
# Url complet: http://wotechsolar.com
# Url complet: https://horze.eu
# Url complet: https://aesir-interactive.com
# Url complet: https://hirschberg-sauerland.de
# Url complet: https://bespoky.com
# Url complet: https://gpmoto.de
# Url complet: https://weddingcam.de
# Url complet: https://laguiole-laguiole.de
# Url complet: https://basic.de
# Url complet: https://igo-werbeartikel.de
# Url complet: https://fct-akademie.com
# Url complet: https://reiten-in-mv.de
# Url complet: https://zahlungsvereinbarung.com
# Url complet: https://theatermakeup.de
# Url complet: https://ackee.cz
# Url complet: https://haasehof.de
# Url complet: https://element.de
# Url complet: https://jazzradio.net
# Url complet: https://eps-personal.org
# Url complet: https://renereif.de
# Url complet: https://stein-automation.de
# Url complet: https://mp-gruppe.de
# Url complet: https://gargiulo.de
# Url complet: https://aetka.de
# Url complet: https://dkou.org
# Url complet: https://pixelboxx.com
# Url complet: https://goettfert.de
# Url complet: https://delphin.com
# Url complet: https://studio-ahoi.de
# Url complet: http://dectomusic.com
# Url complet: https://ctr-fahrzeuge.de
# Url complet: https://wunderstudios.com
# Url complet: https://gmx.net
# Url complet: https://swfr.de
# Url complet: https://tophotelprojects.com
# Url complet: http://co2-meter.net
# Url complet: https://billiger-mietwagen.de
# Url complet: http://orbitlog.com
# Url complet: https://sync.blue
# Url complet: https://kunstverein-bielefeld.de
# Url complet: https://cliffstevens.com
# Url complet: https://himmelhochjauchzend.com
# Url complet: https://perfekt-dienstleistungen.com
# Url complet: https://ralphjo.com
# Url complet: http://csu.de
# Url complet: http://garnetbag.com
# Url complet: https://smiletrain.de
# Url complet: https://innoactive.io
# Url complet: https://ngn-europe.com
# Url complet: https://microtool.de
# Url complet: https://amex-sanivar.com
# Url complet: https://sprachrausch.com
# Url complet: https://dirkbecker-entertainment.de
# Url complet: http://blackpearlfilm.com
# Url complet: https://appel.de
# Url complet: https://marco-arena.de
# Url complet: https://sysy.com
# Url complet: https://bos-buero.de
# Url complet: https://tobaccofreeliving.org
# Url complet: https://hotel-badischerhof-badenbaden.de
# Url complet: http://treesidemusic.com
# Url complet: https://zahnarzt.ac
# Url complet: https://pikasslifestyle.com
# Url complet: https://consulegis.com
# Url complet: https://leagasdelaney.de
# Url complet: https://care.de
# Url complet: https://allectra.com
# Url complet: https://cellsystems.eu
# Url complet: https://epo.org
# Url complet: https://getrental.de
# Url complet: https://thedailyjournalist.com
# Url complet: https://marcmichaelmueller.com
# Url complet: https://german-pellets.de
# Url complet: http://dr-estrich.com
# Url complet: http://hundekoerbchen-kaufen.de
# Url complet: https://moberries.com
# Url complet: https://y-square.de
# Url complet: https://ludwigtype.de
# Url complet: https://makers.do
# Url complet: http://datamonk.com
# Url complet: https://ferrostaal.com
# Url complet: https://nature-trails-events.de
# Url complet: https://thecornerhotel.de
# Url complet: https://pwc.de
# Url complet: https://papiernetz.de
# Url complet: https://integrationmatters.com
# Url complet: https://hotelcult.de
# Url complet: https://master-vergleich.com
# Url complet: https://signavio.com
# Url complet: https://evoloop.com
# Url complet: https://fertan.de
# Url complet: https://awchamburg.org
# Url complet: https://nugzblacky.com
# Url complet: https://mobi-test.de
# Url complet: https://m-cube.de
# Url complet: https://filmconfect.com
# Url complet: https://review-troll.com
# Url complet: https://horst-busch.de
# Url complet: https://k-konzept.de
# Url complet: https://naturprodukte24.net
# Url complet: https://promotion-werft.de
# Url complet: http://sumuphosting.com
# Url complet: https://nextevolution.de
# Url complet: https://compiricus.com
# Url complet: https://kalthoff-kollegen.de
# Url complet: https://werbemax.de
# Url complet: https://stephanieforryan.com
# Url complet: https://casino-poker-manager.com
# Url complet: https://awesomeberlin.net
# Url complet: https://mitsicherheitbesser.de
# Url complet: https://charcotfootcourses.org
# Url complet: https://mercoline.de
# Url complet: https://malteserjugend-trier.de
# Url complet: https://das-beste-in-frankreich.de
# Url complet: https://elitegermanshepherds.com
# Url complet: https://vancado.de
# Url complet: https://genver.de
# Url complet: https://lichtundschatten-3d.de
# Url complet: https://viereck-hydraulik.com
# Url complet: https://poison-berlin.com
# Url complet: https://kulmens.de
# Url complet: https://marsheproductions.com
# Url complet: http://bembeltown.de
# Url complet: http://sld.gs
# Url complet: https://ardour.de
# Url complet: https://demoup-cliplister.com
# Url complet: https://cubecms.org
# Url complet: https://paintballpark.de
# Url complet: https://tacalyx.com
# Url complet: https://mylsp.de
# Url complet: https://360t.com
# Url complet: https://leon-nanodrugs.com
# Url complet: https://ux3d.io
# Url complet: https://onlineprinters.com
# Url complet: https://junges-uno-netzwerk.de
# Url complet: https://flugsam.de
# Url complet: https://proxy-studios.com
# Url complet: https://max-planck-innovation.com
# Url complet: https://holidu.com
# Url complet: https://verbio.de
# Url complet: http://elsa-frankfurt.de
# Url complet: https://voya.ai
# Url complet: https://brainseeker.de
# Url complet: https://atrium2000.com
# Url complet: https://container-xchange.com
# Url complet: https://kwon.com
# Url complet: https://ego4u.com
# Url complet: https://bishop-gmbh.com
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://software-architecture-camp.de
# Url complet: http://opencore.com
# Url complet: https://lalelu.de
# Url complet: https://friedrichskoog.de
# Url complet: https://vsb.energy
# Url complet: https://seezigeuner.de
# Url complet: https://fame-creativelab.com
# Url complet: https://reineckerprolexia.de
# Url complet: https://amparex.com
# Url complet: https://mwaysolutions.com
# Url complet: https://eqs.com
# Url complet: https://bzweic.de
# Url complet: https://photokina.de
# Url complet: https://heilfastentherapie.com
# Url complet: https://xtrasystem.com
# Url complet: https://e-breuninger.de
# Url complet: https://ajrwebdesign.com
# Url complet: https://jds-sommer.de
# Url complet: https://apartment-hotel.de
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://klingel-med.de
# Url complet: http://joinairbank.com
# Url complet: https://connectivisten.de
# Url complet: https://novostrat.com
# Url complet: https://venista-ventures.com
# Url complet: https://ppro.com
# Url complet: https://horizonttours.de
# Url complet: https://geco-event.com
# Url complet: https://caddycool.com
# Url complet: https://sauber-man.com
# Url complet: https://praktiker.de
# Url complet: https://ideenpla.net
# Url complet: https://fs-etit.de
# Url complet: https://m-und-h.de
# Url complet: http://private-arbeitsagentur.eu
# Url complet: https://schwimmbad-schmierer.de
# Url complet: https://roadshow-experts.de
# Url complet: https://createmeaning.com
# Url complet: https://myrkothum.com
# Url complet: https://per4med.de
# Url complet: https://purchaze.com
# Url complet: https://hausambergshepherds.com
# Url complet: https://innovative-navigation.de
# Url complet: https://schlafenderhase.com
# Url complet: https://kellerkommando.de
# Url complet: https://brandmaker.com
# Url complet: https://markengold.de
# Url complet: https://zeninvest.de
# Url complet: https://poggemoeller.co
# Url complet: https://corporate-karma.de
# Url complet: https://laokoongruppe.com
# Url complet: https://adivarius.de
# Url complet: https://kerkhoff-consulting.com
# Url complet: https://intercard.org
# Url complet: https://elsmannimmobilien.de
# Url complet: https://erneuerbareenergien.de
# Url complet: https://bergmanclinics-klinikimpark.de
# Url complet: https://wrestleking.de
# Url complet: https://weigelworld.org
# Url complet: https://apo-buy.com
# Url complet: https://lacba.org
# Url complet: https://davengo.com
# Url complet: https://quartier-theater.de
# Url complet: https://postuning.com
# Url complet: https://k-is.com
# Url complet: https://simple-fax.de
# Url complet: https://b-s.de
# Url complet: https://diebayerische.de
# Url complet: https://frents.com
# Url complet: https://thc-testing.com
# Url complet: https://unimed.de
# Url complet: https://start-online-therapie.de
# Url complet: https://medialab-internetagentur.de
# Url complet: https://amadeus-fire.de
# Url complet: https://lampenwelt.de
# Url complet: https://global-mobility.com
# Url complet: http://joeusa.com
# Url complet: https://sternen-schluchsee.de
# Url complet: https://kaifu-lodge.de
# Url complet: https://cinepostproduction.de
# Url complet: https://hoppegarten.com
# Url complet: https://cpl-sachse.de
# Url complet: https://kreutzer-consulting.com
# Url complet: https://pschyrembel.de
# Url complet: https://seat.de
# Url complet: https://hbo2.de
# Url complet: https://isystems-integration.com
# Url complet: http://everbase.net
# Url complet: https://frontalvision.com
# Url complet: https://monocrom.de
# Url complet: https://laufpix.de
# Url complet: https://kuriershop.de
# Url complet: https://efaflex.com
# Url complet: https://jetsgroup.com
# Url complet: https://tutanota.com
# Url complet: https://startnext.com
# Url complet: http://yummystories.de
# Url complet: https://himmelspagode.de
# Url complet: https://zapf-creation.com
# Url complet: https://europarc.org
# Url complet: https://regupol.com
# Url complet: https://solvatis.de
# Url complet: https://lustre.org
# Url complet: https://lysicom.de
# Url complet: https://mindlab.de
# Url complet: http://ortholutions.de
# Url complet: https://miet24.de
# Url complet: https://mooc-beratung.de
# Url complet: https://helmag.com
# Url complet: https://secret-music.net
# Url complet: https://raysono.com
# Url complet: https://hirschen.com
# Url complet: http://hochseilgarten-neutraubling.net
# Url complet: https://hyperstone.com
# Url complet: https://studdex.com
# Url complet: https://toolsgroup.com
# Url complet: https://ifabrik.de
# Url complet: https://phrase.com
# Url complet: https://berenberg.de
# Url complet: https://honeymoments.de
# Url complet: https://wedding-youandme.com
# Url complet: https://nandurion.de
# Url complet: https://schaffenwir.com
# Url complet: http://4dgo.de
# Url complet: https://myreiseforum.de
# Url complet: https://acxiom.de
# Url complet: https://brandperfection.de
# Url complet: https://borgmann-krefeld.de
# Url complet: https://chameleon-system.de
# Url complet: https://ho-ersoka.de
# Url complet: https://plu.de
# Url complet: https://tiesolution.de
# Url complet: https://e-fellows.net
# Url complet: https://energiekontor.de
# Url complet: https://upon-onlinemarketing.com
# Url complet: https://statt-theater.net
# Url complet: https://nexworld.tv
# Url complet: https://lcs-schlieben.de
# Url complet: https://telerion.com
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://reiseservice-heinz.de
# Url complet: https://semprebonita.de
# Url complet: https://pferdebild.de
# Url complet: https://aqon-pure.com
# Url complet: https://p-21.de
# Url complet: https://ssmsboost.com
# Url complet: https://coi.de
# Url complet: https://printus.de
# Url complet: https://kiwi.de
# Url complet: https://hesse-mechatronics.com
# Url complet: https://berlinlofts.com
# Url complet: https://birgithart.com
# Url complet: https://porsche-design.com
# Url complet: http://in-chemnitz.de
# Url complet: https://bowlers-inn.de
# Url complet: https://kobra-net.de
# Url complet: https://microdoc.com
# Url complet: https://pixeltricks.de
# Url complet: https://pia.me
# Url complet: https://strompreisvergleich24.com
# Url complet: https://lehnenmusic.com
# Url complet: https://prostinternational.com
# Url complet: https://helee-expo.com
# Url complet: https://abcadamas.de
# Url complet: https://trelock.de
# Url complet: https://impreg.de
# Url complet: https://prosanova.net
# Url complet: https://clueso.de
# Url complet: https://lieblingstasche.de
# Url complet: https://bwpapersystems.com
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://datac-gmbh.de
# Url complet: https://kompakt.fm
# Url complet: https://shows-artists.com
# Url complet: https://bio-naturwelt.de
# Url complet: https://admanagerforum.de
# Url complet: https://delphi-advisors.com
# Url complet: https://jk-kom.de
# Url complet: https://schmeckthal-gruppe.de
# Url complet: https://bc-diagnostics.com
# Url complet: https://rbvc.com
# Url complet: https://airnergy.shop
# Url complet: https://konzeptimmobilien.de
# Url complet: https://merantix.com
# Url complet: https://cmc-silenta.com
# Url complet: https://tvm-lifescience.com
# Url complet: https://meeresblick-baabe.de
# Url complet: https://langermediaconsulting.de
# Url complet: https://littlesun.org
# Url complet: https://drk-bos.de
# Url complet: http://spanndeckenstudio.de
# Url complet: https://esome.com
# Url complet: https://xell.ag
# Url complet: https://mergeflow.com
# Url complet: https://hitchon.de
# Url complet: https://dts.de
# Url complet: http://imaos.de
# Rezultat neașteptat: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1006)
# Url complet: https://fogjoggers.com
# Url complet: https://lightweb-media.de
# Url complet: https://claritos.de
# Url complet: https://server-konfigurieren.de
# Url complet: https://weihnachtskultparty.de
# Url complet: https://diekavallerie.de
# Url complet: http://schnatterer.com
# Url complet: https://hochschwarzwald.de
# Url complet: https://severn.de
# Url complet: https://mehrfachsparen.de
# Url complet: https://visionconnect.de
# Url complet: https://antondoll.de
# Url complet: https://hohnwerbetechnik.com
# Url complet: https://redmarketing.de
# Url complet: https://neschen.de
# Url complet: https://dopavision.com
# Url complet: https://kmbmedia.de
# Url complet: https://lps-laser.de
# Url complet: https://ihs-gmbh.de
# Url complet: https://wandres.com
# Url complet: https://reisefanten.de
# Url complet: https://revell.de
# Url complet: https://drmannahs.com
# Url complet: https://wiedemann.de
# Url complet: https://wiblishauser-seminare.de
# Rezultat neașteptat: [SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1006)
# Url complet: https://justwatch.com
# Url complet: https://artaqua.de
# Url complet: https://vr-on.com
# Url complet: https://awantego.com
# Url complet: https://modus-werbung.de
# Url complet: https://fotos-verkaufen.de
# Url complet: https://games-bavaria.com
# Url complet: https://horizont.com
# Url complet: http://farinda-club.de
# Url complet: https://ernstings-family.com
# Url complet: https://shopclever.de
# Url complet: https://alpha-communication.com
# Url complet: https://alexander-training.de
# Url complet: https://mekos.de
# Url complet: https://quintex.eu
# Url complet: https://china-outbound.com
# Url complet: https://pixialisten.de
# Url complet: http://eprairie.com
# Url complet: https://malteserjugend-bamberg.de
# Url complet: https://icmfs2015.com
# Url complet: https://dress-for-less.co.uk
# Url complet: https://gfn.de
# Url complet: https://openwallsgallery.com
# Url complet: https://das-comitee.com
# Url complet: http://altec-cs.com
# Url complet: https://scoop-yard.de
# Url complet: https://lagerflaeche.de
# Url complet: https://perfectlingua.com
# Url complet: http://mandalka.name
# Url complet: https://siemens-healthineers.com
# Url complet: https://kraiburg-relastec.com
# Url complet: https://danhills.de
# Url complet: https://r2p.com
# Url complet: https://drk-rhein-nahe.de
# Url complet: https://sirisvegler.com
# Url complet: https://null-leasing.com
# Url complet: https://uhlmann.de
# Url complet: https://dervizz.com
# Url complet: https://ps-antriebstechnik.de
# Url complet: https://rheinruhronline.de
# Url complet: https://evorait.com
# Url complet: https://flyair41.de
# Url complet: https://jur.solutions
# Url complet: https://mester.de
# Url complet: https://xell-consulting.de
# Url complet: https://agbf.com
# Url complet: https://sake-kontor.de
# Url complet: https://reefcheck.de
# Url complet: https://overnightprints.de
# Url complet: https://pinchart.de
# Url complet: https://starface.com
# Url complet: https://fgk-cro.com
# Url complet: https://berlin-partner.de
# Url complet: https://beds24.com
# Url complet: https://microsonic.de
# Url complet: https://realtennisnetwork.com
# Url complet: https://alvi.de
# Url complet: https://billig-banner24.de
# Url complet: https://frenzelit.com
# Url complet: https://agenturhuette.de
# Url complet: https://lintec-gmbh.de
# Url complet: https://sea-distribution.com
# Url complet: https://rheinfabrik.de
# Url complet: https://mfg.de
# Url complet: https://imiconsulting.com
# Url complet: https://fastbolt.com
# Url complet: https://junge-presse.de
# Url complet: https://subsiege-game.com
# Url complet: https://codydawg.de
# Url complet: https://porzellanklinik-bremen.de
# Url complet: https://raeume-zum-feiern.de
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://hils-it.com
# Url complet: https://fesa.de
# Url complet: https://sportsfreude.com
# Url complet: https://airportzentrale.de
# Url complet: https://ms-holz.de
# Url complet: https://cupcino.com
# Url complet: https://synergie.de
# Url complet: https://visomax.de
# Url complet: https://stefan-plenk.com
# Url complet: https://lufapak.de
# Url complet: https://metalized.de
# Url complet: https://vileda.com
# Url complet: https://pulscamp.de
# Url complet: https://a-maze.net
# Url complet: https://vsda.de
# Url complet: https://spindash.de
# Url complet: http://rictv.de
# Url complet: https://jonnyfresh.com
# Url complet: https://ihk-party.de
# Url complet: https://arbeiten-bei-stihl.de
# Url complet: https://unwomen.de
# Url complet: https://unicum.de
# Url complet: https://fgk-rs.com
# Url complet: https://slf-fraureuth.de
# Url complet: https://freizeichen.com
# Url complet: https://andymagro.com
# Url complet: https://windowspro.de
# Url complet: https://prepaid-usenet.de
# Url complet: https://aliaxis.de
# Url complet: https://axonic.com
# Url complet: http://axiogenesis.com
# Url complet: https://weareforeal.com
# Rezultat neașteptat: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1006)
# Url complet: https://rapidshape.de
# Url complet: https://schmidtner-gmbh.de
# Url complet: https://kf-interactive.com
# Url complet: https://jungmann.de
# Url complet: http://plista.com
# Url complet: https://sobis.com
# Url complet: https://flymo.com
# Url complet: http://stickybiscuits.com
# Url complet: https://prehkeytec.com
# Url complet: https://testboy.de
# Url complet: https://cast-pharma.com
# Url complet: https://gid-it.de
# Url complet: https://raphs-bbq-truck.de
# Url complet: https://tischlerei-jagsch.de
# Url complet: https://bonn.de
# Url complet: https://mysumtu.com
# Url complet: http://irist.com
# Url complet: https://cheplapharm.com
# Url complet: https://pernetix.de
# Url complet: https://drivedevilbiss-int.com
# Url complet: https://microtrac.com
# Url complet: https://pyrotechnik24.com
# Url complet: https://plutosport.de
# Url complet: https://eventcompanies.de
# Url complet: http://fcstpauli-afm.de
# Url complet: http://clevermemo.com
# Url complet: https://sylt-ferienwohnungen-urlaub.de
# Url complet: https://calw.de
# Url complet: http://thestrategyweb.com
# Url complet: http://artgovt.com
# Url complet: http://eve-audio.com
# Url complet: http://itonics-innovation.com
# Url complet: http://cosmetix.net
# Url complet: https://uniboxapp.com
# Url complet: http://haubermethod.com
# Url complet: http://digitaleheimat.de
# Url complet: http://protosoft.de
# Url complet: http://undercover.de
# Url complet: http://dieselkrad.info
# Url complet: http://dexter-international.com
# Url complet: http://istapower.de
# Url complet: http://quipu.de
# Url complet: http://ihc-solutions.de
# Url complet: http://guthaben-kaufen.com
# Url complet: http://swox.com
# Url complet: http://pink-engineer.de
# Url complet: http://misseverywhere.com
# Url complet: http://smartclip.tv
# Url complet: http://fnverlag.de
# Url complet: http://berliner-philharmoniker.de
# Url complet: http://pattern-paradise.com
# Url complet: http://edias.com
# Url complet: http://neuromerchandisinggroup.com
# Url complet: http://rw-kupplungen.de
# Url complet: http://mobiuslabs.com
# Url complet: http://vmray.com
# Url complet: http://theblankswebsite.com
# Url complet: http://smartmedia24.de
# Url complet: http://webanizer.de
# Url complet: http://ladypopular.de
# Url complet: http://hypersoft.com
# Url complet: http://h2fly.de
# Url complet: http://targetesports.com
# Url complet: http://chocion.com
# Url complet: http://topcruiseemployer.com
# Url complet: http://gletschercola.de
# Url complet: http://crowdfunding.de
# Url complet: http://bureau-heintz.de
# Url complet: http://coffee-fellows.com
# Url complet: http://christengemeinde.com
# Url complet: http://fernbus24.de
# Url complet: http://jena-optronik.de
# Url complet: http://ads-systems.com
# Url complet: http://luxx-film.com
# Url complet: http://heldentaten.net
# Url complet: http://bae-berlin.de
# Url complet: http://springmaus-theater.de
# Url complet: http://modusconsult.de
# Url complet: http://daniel-philipp.com
# Url complet: http://catinberlin.com
# Url complet: http://schwing-technologies.com
# Url complet: http://kinderkuechekaufen.de
# Url complet: http://derwil.com
# Url complet: http://saarcamp.de
# Url complet: http://conflict-minerals.com
# Url complet: http://alpenverein.de
# Url complet: http://qoniac.com
# Url complet: http://treatwell.de
# Url complet: http://wirsindhelden.com
# Url complet: http://artviper-werbeagentur.de
# Url complet: http://chapeau-restaurant.com
# Url complet: http://fertighaus-keitel.de
# Url complet: http://theveryend.net
# Url complet: http://boerse-stuttgart.de
# Url complet: http://startupjoblist.com
# Url complet: http://ecco-reisen.de

# %%
len(complete_urlsD)
# Out:
# 760

# %% [markdown]
# - Asynchronously main function where we apply the filter to the list of urls and obtain the valid ones

# %%
async def main():
    valid_urls = await filter_urls_async(complete_urlsD)
    return valid_urls

# %%
valid_urlsD = await main()

# %%
len(valid_urlsD)
# Out:
# 225

# %% [markdown]
# - Async main function that for a list of urls generate a bigger list with the urls that have a high chance to have an address

# %%
async def main(valid_urls):
    keywords = ['connect', 'contact', 'kontakt', 'impressum', 'adresse', 'reach', 'datenschutz', 'home']
    tasks = [find_urls_with_keywords(url, keywords) for url in valid_urls]
    final_urls = await asyncio.gather(*tasks)
    return final_urls

# %%
final_urlsD = await main(valid_urlsD)

# %%
urls_listD = []
for set_elem in final_urlsD:
    for elem in set_elem:
        urls_listD.append(elem)

# %%
len(urls_listD)
# Out:
# 620

# %% [markdown]
# #### Checking the new list of URLS and the invalid ones will be eliminated

# %%
async def main():
    valid_urls = await filter_urls_async(urls_listD)
    return valid_urls

# %%
urls_listD = await main()

# %%
len(urls_listD)
# Out:
# 554

# %% [markdown]
# #### Making a DataFrame to save the valid URLS into a .csv to using them later

# %%
import pandas as pd

df = pd.DataFrame(columns = ["URL"])

df
# Out:
# Empty DataFrame
# Columns: [URL]
# Index: []

# %%
# building the rows
for url in urls_listD:
    individual_row_data = [url]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                                  URL
# 0                 https://www.cantus-bahn.de/kontakt
# 1                             https://cantus-bahn.de
# 2      https://www.cantus-bahn.de/metamenu/impressum
# 3    https://www.cantus-bahn.de/metamenu/datenschutz
# 4                              https://pastisani.com
# ..                                               ...
# 549               http://neuromerchandisinggroup.com
# 550                      http://theblankswebsite.com
# 551              http://theblankswebsite.com/contact
# 552                          http://gletschercola.de
# 553                              http://fernbus24.de
#
# [554 rows x 1 columns]

# %%
df.to_csv("Deutsch_URLS.csv", index=False)

# %% [markdown]
# #### Reading the urls from the CSV

# %%
import pandas as pd
urlsD = pd.read_csv("Deutsch_URLS.csv")

# %%
urlsD['URL']
# Out:
# 0                   https://www.cantus-bahn.de/kontakt
# 1                               https://cantus-bahn.de
# 2        https://www.cantus-bahn.de/metamenu/impressum
# 3      https://www.cantus-bahn.de/metamenu/datenschutz
# 4                                https://pastisani.com
#                             ...
# 549                 http://neuromerchandisinggroup.com
# 550                        http://theblankswebsite.com
# 551                http://theblankswebsite.com/contact
# 552                            http://gletschercola.de
# 553                                http://fernbus24.de
# Name: URL, Length: 554, dtype: object

# %% [markdown]
# #### Function that extracts the address from a page if it's possible
# - for the deutsch addresses we use 2 regexes
# - one is for the Road + Road Number
# - the other one is for the City + Postcode
# - to obtain a real address we will make the cartesian product (it's not the fast way but we will be sure the real address is in it)
# - to reduce the list we put the condition that an address have maximum 7 words

# %%
async def extract_addresses_from_url_deutsch_async(url, regex_pattern, regex_pattern2):
    async with aiohttp.ClientSession() as session:
        try:
            async with session.get(url, ssl=False, timeout=30) as response:
                if response.status != 200:
                    return None
                
                binary_data = await response.read()
                try:
                    page_text = binary_data.decode('utf-8')
                except:
                    page_text = binary_data.decode('latin-1')
                
        except asyncio.TimeoutError:
            print(f"Timeout occurred while fetching URL: {url}")
            return None
        except aiohttp.ClientError as e:
            print(f"Error occurred while fetching URL '{url}': {e}")
            return None
        except aiohttp.ClientConnectorError as e:
            print(f"Error connecting to server: {e}")
            return None
        
        # if we have the status code 429 (Too Many Requests)
        if response.status == 429:
            print(f"Too Many Requests received. Retrying after waiting.")
            await asyncio.sleep(5)  # we wait 5 second to retry
            return await extract_addresses_from_url_async(url)  # Recall the function
        
        try:
            # extracts the html content
            soup = BeautifulSoup(page_text, 'html.parser')
        except:
            return None
        
        try:
            # extracts all the paragraphs (all the addresses are in a <p> tag *from my experience)
            paragraphs = soup.find_all('p')
        except:
            return None
        
        try:
            for paragraph in paragraphs:
                # Finding all the <br> or <br/> tags
                br_tags = paragraph.find_all(['br', 'br/'])
        
                for br_tag in br_tags:
                    # Replace <br> or <br/> with newline character (\n)
                    br_tag.replace_with('\n ')
                if paragraph.string == None:
                    paragraph.append('\n')
        except:
            return None
        
        # Store all paragraph text in a single variable
        all_text = ""
        for paragraph in paragraphs:
            all_text += paragraph.text
            all_text += '\n'
            
         # Initialize city list
        cities = []
        
        # Initialize street list
        streets = []
        
        # Search for regex pattern for the street & street number
        matches = re.finditer(regex_pattern, all_text, re.MULTILINE)
        
        for match in matches:
            # print(match.group(0))
            streets.append(match.group(0))
        # print(streets)
        
        # Search for regex pattern for the postal code & city
        matches = re.finditer(regex_pattern2, all_text, re.MULTILINE)
        for match in matches:
            # print(match.group(0))
            cities.append(match.group(0))
        # print(cities)
        
        # a list that retain all the combinations between cities & streets
        addresses = []
        
        for i in range(0, len(streets)):
            for j in range(0, len(cities)):
                address = streets[i] + ' ' + cities[j]
                words = address.split()
                # print(words)
                if len(words) <= 7 and '\n' not in address and '\t' not in address:
                    addresses.append(address)
                
        addresses = set(addresses)
        addresses = list(addresses)
        print(addresses)        
        return [url, addresses]

# %%
# Regex pattern
# street + street number regex (Deutsch Address)
regex_pattern = r"((Ober|Unter den|An |Im |Platz |Berg |Am |Alt\-).+|(?:([A-Z][a-zäüö-]+){1,2})).([Cc]haussee|[Aa]llee|[sS]tr(\.|(a(ss|ß)e))|[Rr]ing|berg|moos|gasse|grund|hörn| Nord|graben|[mM]arkt|[Uu]fer|[Ss]tieg|[Ll]inden|[Dd]amm|[pP]latz|brücke|Steinbüchel|Burg|stiege|[Ww]eg|rain|park|[Ww]eide|[Hh][oö]f|pfad|garten|bogen|passage).+?(\d{1,4})([a-zäöüß]+)?(\-?\d{1,4}[a-zäöüß]?)?"

# Postal Code + City/Town (Deutsch Address)
regex_pattern2 = r"(?<![\.\d])(\d{4,5})\b\s*?([A-Za-zÄÖÜäöüß]+(?:[A-Za-zÄÖÜäöüß -]*[A-Za-zÄÖÜäöüß]+)?)\b"

# %% [markdown]
# - Asynchronous main function where with the list of URLS we extract addresses asynchronously

# %%
async def main(urls_list, r1, r2):
    tasks = [extract_addresses_from_url_deutsch_async(url, r1, r2) for url in urls_list]
    final_addresses = await asyncio.gather(*tasks, return_exceptions=True)
    return final_addresses

# %%
final_addressesD = await main(urlsD['URL'], regex_pattern, regex_pattern2)
# Out:
# ['Maffeistr. 12 2023 Weltkonferenz AHK', 'Maffeistrasse 12 93059 Regensburg', 'Augustenstr. 3 93049 Regensburg', 'Augustenstr. 3 2023 Weltkonferenz AHK', 'Maffeistr. 12 93049 Regensburg', 'Maffeistrasse 12 2023 Weltkonferenz AHK', 'Augustenstr. 3 93059 Regensburg', 'Maffeistrasse 12 8568  Handelsregister', 'Maffeistrasse 12 93049 Regensburg', 'Maffeistr. 12 93059 Regensburg', 'Augustenstr. 3 8568  Handelsregister', 'Maffeistr. 12 8568  Handelsregister']
# ['Orber Straße 30 60386 Frankfurt']
# []
# ['Schorndorfer Straße 27 70734 Fellbach', 'Schorndorfer Straße 27 70736 Fellbach', 'Sonnenbühlstr. 23 70736 Fellbach', 'Sonnenbühlstr. 23 70734 Fellbach', 'Schorndorfer Straße 27 1600 Amphitheatre Parkway', 'Sonnenbühlstr. 23 1600 Amphitheatre Parkway']
# ['Franz-Ulrich-Straße 18 34117 Kassel']
# ['Schorndorfer Straße 27 70736 Fellbach']
# []
# ['Rechtsgrundlage hierfür ist Art. 6 60386 Frankfurt', 'Elgendorfer Str. 57 56410 Montabaur', 'Elgendorfer Str. 57 60386 Frankfurt', 'Orber Straße 30 56410 Montabaur', 'Orber Straße 30 60386 Frankfurt', 'Rechtsgrundlage hierfür ist Art. 6 56410 Montabaur']
# ['Schorndorfer Straße 27 70736 Fellbach', 'Schorndorferstraße 27 70736 Fellbach']
# ['Wilhelmine-Gemberg-Weg 6 33209 B', 'Bänschstr. 58 27628 Hagen im Bremischen', 'Bänschstr. 58 10247 Berlin', 'Wilhelmine-Gemberg-Weg 6 10179 Berlin', 'Wilhelmine-Gemberg-Weg 6 27628 Hagen im Bremischen', 'Bänschstr. 58 33209 B', 'Wilhelmine-Gemberg-Weg 6 10247 Berlin', 'Bänschstr. 58 10179 Berlin']
# []
# ['Schorndorferstr. 27 70734 Fellbach', 'Schorndorferstr. 27 10006 Berlin', 'Schorndorfer Straße 27 70734 Fellbach', 'Schorndorferstr. 27 77694 Kehl', 'Schorndorfer Straße 27 70736 Fellbach', 'Sonnenbühlstr. 23 10006 Berlin', 'Schorndorferstr. 27 70736 Fellbach', 'Sonnenbühlstr. 23 70736 Fellbach', 'Sonnenbühlstr. 23 77694 Kehl', 'Sonnenbühlstr. 23 70734 Fellbach', 'Schorndorfer Straße 27 77694 Kehl', 'Schorndorfer Straße 27 10006 Berlin']
# ['Bahnstr. 14 69483 Wald-Michelbach']
# []
# ['Rechtsgrundlage ist Art. 6 2024 Kamps GmbH', 'Rechtsgrundlage ist Art. 6 59000 Lille']
# []
# ['Kuhstraße 3 47918 Tönisvorst']
# []
# []
# ['Casterfeldstr. 66-72 68199 Mannheim']
# []
# []
# []
# ['Casterfeldstr. 66-72 68199 Mannheim']
# ['Wilhelmine-Gemberg-Weg 6 2024 werden über', 'Wilhelmine-Gemberg-Weg 6 2023 in Frankfurt am Main', 'Wilhelmine-Gemberg-Weg 6 10179 Berlin']
# []
# []
# []
# []
# []
# ['Rechtsgrundlage hierfür ist Art. 6 66571 Eppelborn', 'Bahnhofstraße 34 22305 Hamburg', 'Rechtsgrundlage hierfür ist Art. 6 69483 Wald-Michelbach', 'Bahnhofstraße 34 69483 Wald-Michelbach', 'Bahnhofstraße 34 66571 Eppelborn', 'Bahnstr. 14 22305 Hamburg', 'Rechtsgrundlage hierfür ist Art. 6 22305 Hamburg', 'Bahnstr. 14 66571 Eppelborn', 'Bahnstr. 14 69483 Wald-Michelbach']
# ['Einsteinring 1a 85609 Aschheim b']
# ['Enderstraße 94 01277 Dresden', 'Münsterstraße 1853111 2021 by HOPE-Gala', 'Enderstraße 94 2021 by HOPE-Gala', 'Münsterstraße 1853111 01277 Dresden']
# ['Einsteinring 1a 85609 Aschheim b']
# []
# []
# ['Enderstraße 94 01277 Dresden', 'Münsterstraße 1853111 2021 by HOPE-Gala', 'Enderstraße 94 2021 by HOPE-Gala', 'Münsterstraße 1853111 01277 Dresden']
# ['Rechtsgrundlage Richtlinie 2004 34369 Hofgeismar', 'Neue Straße 22 34369 Hofgeismar', 'Rechtsgrundlage ist Art. 6 34369 Hofgeismar']
# ['Klingenberg 35 74523 Schwäbisch Hall']
# ['Enderstraße 94 01277 Dresden', 'Münsterstraße 18 01277 Dresden', 'Münsterstraße 1853111 2021 by HOPE-Gala', 'Münsterstraße 1853111 53111 Bonn', 'Münsterstraße 1853111 01277 Dresden', 'Münsterstraße 18 2021 by HOPE-Gala', 'Münsterstraße 18 53111 Bonn', 'Enderstraße 94 53111 Bonn', 'Enderstraße 94 2021 by HOPE-Gala']
# []
# []
# ['Münsterstraße 1853111 2023 von', 'Enderstraße 94 01277 Dresden', 'Münsterstraße 1853111 2021 by HOPE-Gala', 'Enderstraße 94 2023 zur', 'Enderstraße 94 2021 und', 'Münsterstraße 1853111 2023 zur', 'Münsterstraße 1853111 2021 und', 'Münsterstraße 1853111 01277 Dresden', 'Enderstraße 94 2023 von', 'Enderstraße 94 2021 by HOPE-Gala']
# []
# []
# []
# ['Köpenicker Str. 18-20 5000 Models', 'Köpenicker Str. 18-20 10997 Berlin']
# ['Kressengartenstraße 10 90402 Nürnberg']
# ['Kraus Straße 16 2123 Kronberg']
# []
# ['Rechtsgrundlage hierfür ist § 26 91710 Gunzenhausen', 'Leopoldstraße 62 91710 Gunzenhausen', 'Rechtsgrundlage hierfür ist Art. 6 91710 Gunzenhausen', 'Kalmarweg 14-5 2023 Academy Consult e', 'Rechtsgrundlage hierfür ist § 26 02141 USA', 'Rechtsgrundlage hierfür ist Art. 6 02141 USA', 'Industriestr. 25 80802 München', 'Kalmarweg 14-5 80802 München', 'Leopoldstraße 62 80802 München', 'Leopoldstraße 62 02141 USA', 'Kalmarweg 14-5 02141 USA', 'Industriestr. 25 02141 USA', 'Industriestr. 25 9723 JG Groningen', 'Kalmarweg 14-5 91710 Gunzenhausen', 'Rechtsgrundlage hierfür ist Art. 6 80802 München', 'Industriestr. 25 91710 Gunzenhausen', 'Industriestr. 25 2023 Academy Consult e', 'Leopoldstraße 62 2023 Academy Consult e', 'Leopoldstraße 62 9723 JG Groningen', 'Rechtsgrundlage hierfür ist § 26 80802 München', 'Kalmarweg 14-5 9723 JG Groningen']
# ['Kressengartenstraße 10 90402 Nürnberg', 'Kressengartenstraße 10 22763 Hamburg', 'Rechtsgrundlage ist Artikel 6 90402 Nürnberg', 'Rechtsgrundlage ist Artikel 6 22763 Hamburg']
# []
# ['Rheinstraße 17 14513 Teltow']
# []
# ['Leopoldstraße 62 80802 München', 'Leopoldstraße 62 2023 Academy Consult e']
# ['Denkmalgasse 18 2172 Schrattenbe']
# ['Swiggerweg 1 74523 Schwäbisch Hall']
# []
# []
# []
# ['Stollbergstraße 22 80539 München']
# []
# []
# ['Kurfürstendamm 21 20354 Hamburg', 'Stollbergstraße 22 80539 München', 'Grünstraße 17 80539 München', 'Stollbergstraße 22 20354 Hamburg', 'Stollbergstraße 22 10719 Berlin', 'Grünstraße 17 10719 Berlin', 'Kurfürstendamm 21 10719 Berlin', 'Kurfürstendamm 21 80539 München', 'Grünstraße 17 20354 Hamburg']
# ['Leopoldstraße 62 80802 München', 'Leopoldstraße 62 2023 Academy Consult e']
# ['Rheinstraße 17 14513 Teltow']
# []
# []
# []
# []
# ['Woyrschweg 54 22761 Hamburg', 'Walther-von-Cronberg-Platz 15 60594 Frankfurt am Main', 'Walther-von-Cronberg-Platz 15 22761 Hamburg', 'Woyrschweg 54 60594 Frankfurt am Main']
# []
# []
# ['Cyriaxstraße 103 2020 bereits  aus über', 'Cyriaxstraße 103 2000 die Gründungsfeier zum', 'Raiffeisenstraße 1 35043 Marburg', 'Raiffeisenstraße 1 35037 Marburg', 'Cyriaxstraße 103 1990 e', 'Cyriaxstraße 103 35037 Marburg', 'Raiffeisenstraße 1 2020 bereits  aus über', 'Cyriaxstraße 103 35043 Marburg', 'Raiffeisenstraße 1 1990 e', 'Raiffeisenstraße 1 2000 die Gründungsfeier zum']
# []
# ['Woyrschweg 54 22761 Hamburg', 'Walther-von-Cronberg-Platz 15 60594 Frankfurt am Main', 'Walther-von-Cronberg-Platz 15 22761 Hamburg', 'Woyrschweg 54 60594 Frankfurt am Main']
# []
# []
# []
# ['Nordfeldweg 87 33659 Bielefeld']
# ['Nordfeldweg 87 33659 Bielefeld']
# []
# []
# ['Nordfeldweg 87 33659 Bielefeld']
# ['Ridlerstr. 57 27001 zertifiziert', 'Ridlerstr. 57 80339 München']
# []
# ['Rechtsgrundlage hierfür ist § 26 33659 Bielefeld', 'Rechtsgrundlage hierfür ist § 26 10587 Berlin', 'Pascalstraße 10 33659 Bielefeld', 'Nordfeldweg 87 33659 Bielefeld', 'Nordfeldweg 87 10587 Berlin', 'Pascalstraße 10 10587 Berlin']
# ['Am Wacholderberg 9 61462 Königstein']
# []
# []
# []
# ['Nordfeldweg 87 33659 Bielefeld']
# ['Wandlhamerstraße 25 82166 Gräfelfing']
# ['Wandlhamerstraße 25 82166 Gräfelfing']
# ['Tittmoninger Strasse 11 81679 München', 'Tittmoninger Strasse 11 28013 Madrid', 'Tittmoninger Strasse 11 40219 Düsseldorf']
# ['Tittmoninger Strasse 11 81679 München']
# []
# ['Landsberger Straße 94 2024 GoLocal GmbH', 'Landsberger Straße 94 80339 München']
# ['Raiffeisenstr. 1 06618\xa0nach', 'Raiffeisenstraße 1 35043 Marburg', 'Raiffeisenstr. 1 1990 e', 'Raiffeisenstr. 1 35043 Marburg', 'Raiffeisenstraße 1 1990 e', 'Raiffeisenstraße 1 06618\xa0nach']
# ['Hohenzollernring 54 50672 Köln', 'Hohenzollernring 54 2029 Stierlin Court', 'Köpenicker Str. 126 81679 München', 'Tittmoninger Strasse 11 50672 Köln', 'Hohenzollernring 54 6011 Wellington', 'Köpenicker Str. 126 1355 Market St', 'Köpenicker Str. 126 10179 Berlin', 'Hohenzollernring 54 10179 Berlin', 'Tittmoninger Strasse 11 94043 USA', 'Hohenzollernring 54 1600 Amphitheatre Parkway', 'Tittmoninger Strasse 11 81679 München', 'Tittmoninger Strasse 11 10179 Berlin', 'Hohenzollernring 54 1355 Market St', 'Tittmoninger Strasse 11 1600 Amphitheatre Parkway', 'Köpenicker Str. 126 94043 USA', 'Hohenzollernring 54 81679 München', 'Tittmoninger Strasse 11 6011 Wellington', 'Köpenicker Str. 126 1600 Amphitheatre Parkway', 'Köpenicker Str. 126 6011 Wellington', 'Tittmoninger Strasse 11 1355 Market St', 'Hohenzollernring 54 94043 USA', 'Köpenicker Str. 126 50672 Köln', 'Köpenicker Str. 126 2029 Stierlin Court', 'Tittmoninger Strasse 11 2029 Stierlin Court']
# []
# []
# ['Landsberger Straße 94 80339 München']
# []
# []
# []
# ['Ridlerstr. 57 48153 Münster', 'Marienplatz 2 80339 München', 'Hafenstrasse 32 80339 München', 'Marienplatz 2 80331 München', 'Hafenstrasse 32 80331 München', 'Hafenstrasse 32 02141 USA', 'Ridlerstr. 57 02141 USA', 'Marienplatz 2 27001 zertifiziert', 'Hafenstrasse 32 48153 Münster', 'Ridlerstr. 57 27001 zertifiziert', 'Marienplatz 2 02141 USA', 'Ridlerstr. 57 80339 München', 'Marienplatz 2 48153 Münster', 'Ridlerstr. 57 80331 München', 'Hafenstrasse 32 27001 zertifiziert']
# ['Wandlhamerstraße 25 82166 Gräfelfing']
# []
# []
# []
# []
# []
# []
# []
# []
# ['Sonnenstr. 6 90537 Feucht']
# []
# []
# ['Rechtsgrundlage hierfür ist Art. 6 10719 Berlin', 'Rechtsgrundlage ist Art. 6 10719 Berlin', 'Kurfürstendamm 212 10719 Berlin', 'Kurfürstendamm 21 10719 Berlin']
# []
# []
# ['Sonnenstr. 6 90537 Feucht bei Nürnberg']
# []
# []
# []
# []
# ['Passauer Str. 8-9 10789 Berlin']
# []
# []
# ['Leopoldstr. 21 6011 Wellington', 'Leopoldstr. 21 80802 München']
# []
# ['Wiesenhüttenplatz 25 60329 Frankfurt am Main']
# ['Lindenstraße.5 27419 Sittensen', 'Lindenstraße 5 27419 Sittensen']
# ['Lindenstraße.5 27419 Sittensen', 'Lindenstraße 5 27419 Sittensen', 'Lindenstraße.5 1600 Amphitheatre Parkway', 'Lindenstraße 5 1600 Amphitheatre Parkway']
# ['Wiesenhüttenplatz 25 60329 Frankfurt am Main', 'Wiesenhüttenplatz 25 08523 Plauen', 'Wettiner Platz 10 08523 Plauen', 'Reichsstraße 3 60329 Frankfurt am Main', 'Reichsstraße 3 08523 Plauen', 'Wiesenhüttenplatz 25 01067 Dresden', 'Wettiner Platz 10 01067 Dresden', 'Reichsstraße 3 01067 Dresden', 'Wettiner Platz 10 60329 Frankfurt am Main']
# ['Lindenstraße.5 27419 Sittensen']
# ['Lindenstraße.5 27419 Sittensen', 'Lindenstraße 5 27419 Sittensen']
# []
# []
# []
# ['Bessie-Coleman-Straße 7 60549 Frankfurt am Main', 'Bessie-Coleman-Str. 7 60549 Frankfurt am Main']
# ['Bessie-Coleman-Straße 7 60549 Frankfurt am Main']
# ['Haller Straße 54 74189 Weinsberg', 'Elgendorfer Straße 57 56410 Montabaur', 'Haller Straße 54 56410 Montabaur', 'Elgendorfer Straße 57 74189 Weinsberg']
# ['Weinsberg, 08 2023 von KIWI Consulting', 'Weinsberg, 01 2023 von KIWI Consulting', 'Weinsberg, 08 2024 von KIWI Consulting', 'Weinsberg, 01 2024 von KIWI Consulting', 'Weinsberg, 09 2024 von KIWI Consulting', 'Weinsberg, 09 2023 von KIWI Consulting', 'Weinsberg, 03 2024 von KIWI Consulting', 'Weinsberg, 03 2023 von KIWI Consulting']
# ['Haller Straße 54 74189 Weinsberg', 'Odenwaldstr. 14 69190 Walldorf', 'Haller Straße 54 22297 Hamburg', 'Haller Straße 54 69190 Walldorf', 'Odenwaldstr. 14 74189 Weinsberg', 'Odenwaldstr. 14 22297 Hamburg']
# ['Köpenicker Str. 126 2018 geltenden Datenschutzgrundverordnung', 'Solmsstraße 83 2018 geltenden Datenschutzgrundverordnung', 'Rechtsgrundlage hierfür ist Art. 6 10179 Berlin', 'Rechtsgrundlage dafür ist Art. 6 10179 Berlin', 'Köpenicker Str. 126 60549 Frankfurt am Main', 'Bessie-Coleman-Str. 7 60549 Frankfurt am Main', 'Bessie-Coleman-Straße 7 2018 geltenden Datenschutzgrundverordnung', 'Bessie-Coleman-Straße 7 60549 Frankfurt am Main', 'Solmsstraße 83 10179 Berlin', 'Bessie-Coleman-Str. 7 10179 Berlin', 'Rechtsgrundlage ist Art. 6 10179 Berlin', 'Köpenicker Str. 126 10179 Berlin', 'Bessie-Coleman-Straße 7 10179 Berlin', 'Bessie-Coleman-Str. 7 2018 geltenden Datenschutzgrundverordnung', 'Rechtsgrundlage ist Art. 6 2018 geltenden Datenschutzgrundverordnung', 'Solmsstraße 83 60486 Frankfurt am Main', 'Köpenicker Str. 126 60486 Frankfurt am Main', 'Bessie-Coleman-Str. 7 60486 Frankfurt am Main', 'Solmsstraße 83 60549 Frankfurt am Main', 'Bessie-Coleman-Straße 7 60486 Frankfurt am Main']
# []
# []
# []
# []
# []
# []
# []
# ['Industriestraße 12 86609 Donauwörth']
# []
# ['Rechtsgrundlage hierfür ist Art. 6 1058 Kopenhagen', 'Rechtsgrundlage hierfür ist § 26 78532 Tuttlingen', 'Werderstraße 16 71272 Renningen', 'Rechtsgrundlage hierfür ist Art. 6 20354 Hamburg', 'Rechtsgrundlage hierfür ist § 26 71272 Renningen', 'Dammtorstraße 30 1058 Kopenhagen', 'Nelkenstraße 36 20354 Hamburg', 'Werderstraße 16 1058 Kopenhagen', 'Rechtsgrundlage hierfür ist § 26 1058 Kopenhagen', 'Dammtorstraße 30 78532 Tuttlingen', 'Rechtsgrundlage hierfür ist Art. 6 78532 Tuttlingen', 'Nelkenstraße 36 78532 Tuttlingen', 'Werderstraße 16 78532 Tuttlingen', 'Werderstraße 16 20354 Hamburg', 'Rechtsgrundlage hierfür ist § 26 20354 Hamburg', 'Rechtsgrundlage hierfür ist Art. 6 71272 Renningen', 'Dammtorstraße 30 71272 Renningen', 'Dammtorstraße 30 20354 Hamburg', 'Nelkenstraße 36 1058 Kopenhagen', 'Nelkenstraße 36 71272 Renningen']
# []
# []
# ['Werderstraße 16 78048 Villingen-Schwenningen', 'Nelkenstraße 36 78048 Villingen-Schwenningen', 'Robert-Bosch-Straße 9 71272 Renningen', 'Robert-Bosch-Straße 9 78048 Villingen-Schwenningen', 'Nelkenstraße 36 78532 Tuttlingen', 'Werderstraße 16 78532 Tuttlingen', 'Werderstraße 16 71272 Renningen', 'Nelkenstraße 36 71272 Renningen', 'Robert-Bosch-Straße 9 78532 Tuttlingen']
# ['Emmy-Noether-Straße 25 25524 Itzehoe', 'Emmy-Noether-Straße 25 21079 Hamburg']
# []
# ['Emmy-Noether-Straße 25 25524 Itzehoe', 'Emmy-Noether-Straße 25 21079 Hamburg']
# ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']
# ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']
# ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']
# []
# []
# []
# []
# []
# ['Elbstraße 145a 2020 und', 'Elbstraße 145a 2021 für Gustavo Gusto', 'Elbstraße 145a 22767 Hamburg']
# []
# ['Elbstraße 145a 22767\xa0Hamburg', 'Elbstraße 145a 22767 Hamburg']
# []
# []
# ['Brabandstrasse 7 20354 Hamburg', 'Poststrasse 14-16 20354 Hamburg']
# ['Emmy-Noether-Straße 25 25524 Itzehoe', 'Emmy-Noether-Straße 25 21079 Hamburg']
# ['Elbstraße 145a 20124 Milano', 'Elbstraße 145a 22767 Hamburg']
# ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']
# ['Bradandstrasse 7 22297 Hamburg']
# []
# ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']
# []
# ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']
# []
# ['Holzmarkt 7 72070 Tübingen', 'Doblerstraße 14 72074 Tübingen', 'Doblerstraße 14 72070 Tübingen', 'Holzmarkt 7 72074 Tübingen']
# []
# ['Anselm-Feuerbach-Str. 6 67227 Frankenthal', 'Anselm-Feuerbach-Str. 6 1345 Gwangmyeong-Si']
# ['Baden-Württemberg, Postfach 10 1500 Mitarbeitern an', 'Baden-Württemberg, Postfach 10 70025 Stuttgart', 'Baden-Württemberg, Postfach 10 75181 Pforzheim', 'Hanauer Straße 5-7 70025 Stuttgart', 'Hanauer Straße 5-7 75181 Pforzheim', 'Hanauer Straße 5-7 1500 Mitarbeitern an']
# ['Frankenburgstr. 31 48431 Rheine', 'Frankenburgstr. 31 2000 Frederiksberg']
# []
# ['Planufer 92e 10967 Berlin']
# ['Landgraf-Georg-Straße 4 64283 Darmstadt']
# []
# ['Heider Weg 42 27777 Ganderkesee', 'Heider Weg 42 2000 digital fotografiert', 'Heider Weg 42 1968 bis Hongkong']
# []
# []
# ['Elektrastraße 6a 81925 Munich']
# []
# []
# []
# ['Stadthausbrücke 5 20355 Hamburg']
# []
# ['Lindwurmstr. 109 80337 München']
# ['Elektrastrasse 6 10115 Berlin', 'Elektrastrasse 6 70469 Stuttgart Germany', 'Elektrastrasse 6 81925 Munich', 'Novalisstrasse 12 81925 Munich', 'Elektrastraße 6a 10115 Berlin', 'Elektrastraße 6a 81925 Munich', 'Bludenzer Str. 6 81925 Munich', 'Elektrastraße 6a 70469 Stuttgart Germany', 'Novalisstrasse 12 10115 Berlin', 'Bludenzer Str. 6 70469 Stuttgart Germany', 'Novalisstrasse 12 70469 Stuttgart Germany', 'Bludenzer Str. 6 10115 Berlin']
# ['Planufer 92e 10967 Berlin']
# ['Boschring 7 56422 Wirges', 'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel', 'Boschring 7 55252 Mainz-Kastel', 'Fritz-Ullmann-Straße 4 56422 Wirges']
# []
# []
# ['Wehrstraße 24-26 53773 Hennef']
# ['Fruchtallee 23 20259 Hamburg']
# ['Fruchtallee 23 20259 Hamburg']
# []
# []
# []
# ['Planufer 92e 10967 Berlin', 'Planufer 92e 1601 S California Ave', 'Planufer 92e 1601 Willow Road']
# []
# ['Hammer Straße 341 59229 Ahlen']
# []
# ['Rechtsgrundlage ist Art.\xa06 2021 KULMENS', 'Rechtsgrundlage ist Art.\xa06 84028 Landshut']
# []
# []
# ['Hammer Straße 341 59229 Ahlen']
# ['Oberbayern, Max-Joseph-Str. 2 91154 Roth', 'Waldstr. 22 91154 Roth', 'Waldstr. 22 91189 Rohr b', 'Oberbayern, Max-Joseph-Str. 2 2024 ATRIUM Invest GmbH', 'Weinbergweg 1 2024 ATRIUM Invest GmbH', 'Weinbergweg 1 91154 Roth', 'Nürnberg HRB 33145 80333 München', 'Waldstr. 22 80333 München', 'Weinbergweg 1 91189 Rohr b', 'Weinbergweg 1 80333 München', 'Nürnberg HRB 33145 2024 ATRIUM Invest GmbH', 'Waldstr. 22 2024 ATRIUM Invest GmbH', 'Nürnberg HRB 33145 91154 Roth', 'Oberbayern, Max-Joseph-Str. 2 91189 Rohr b', 'Oberbayern, Max-Joseph-Str. 2 80333 München', 'Nürnberg HRB 33145 91189 Rohr b']
# []
# []
# ['Vordergrund stehen. Am 27 2023 was', 'Vordergrund stehen. Am 27 2022 levels', 'Vordergrund stehen. Am 27 60314 Frankfurt', 'Vordergrund stehen. Am 27 1963 reichen', 'Landstr. 146 2023 um', 'Landstr. 146 60314 Frankfurt', 'Vordergrund stehen. Am 27 2023 in Switzerland', 'Landstr. 146 2022 levels', 'Landstr. 146 1963 reichen', 'Vordergrund stehen. Am 27 2023 um', 'Landstr. 146 2023 was', 'Landstr. 146 2023 in Switzerland']
# []
# ['Waldstr. 22 1600 Amphitheatre Parkway', 'Waldstr. 22 2024 ATRIUM Invest GmbH', 'Waldstr. 22 1601 S', 'Waldstr. 22 91189 Rohr']
# ['Landstr. 146 1601 S', 'Landstr. 146 2029 Stierlin Court', 'Landstr. 146 60314 Frankfurt', 'Gänsemarkt 43 1601 S', 'Landstr. 146 1600 Amphitheatre Parkway', 'Gänsemarkt 43 60314 Frankfurt', 'Gänsemarkt 43 20354 Hamburg', 'Landstr. 146 20354 Hamburg', 'Gänsemarkt 43 1600 Amphitheatre Parkway', 'Gänsemarkt 43 2029 Stierlin Court']
# ['Burgstrasse, 27 60316 Frankfurt', 'Landstr. 146 60314 Frankfurt', 'Burgstrasse, 27 2017 fame creative lab', 'Burgstrasse, 27 60314 Frankfurt', 'Landstr. 146 60316 Frankfurt', 'Landstr. 146 2017 fame creative lab']
# ['Landstr. 146 60314 Frankfurt', 'Landstr. 146 2222 islands', 'Landstr. 146 2023 World Travel Awards']
# []
# []
# ['Rechtsgrundlage ist Art. 6 1600 Amphitheater Parkway', 'Rechtsgrundlage ist Art. 6 65232 Taunusstein', 'Rechtsgrundlage ist Art. 6 1355 Market St', 'Mainstraße 6 2029 Stierlin Court', 'Gänsemarkt 43 21079 Hamburg', 'Gänsemarkt 43 1595 Spring Hill Road', 'Mainstraße 6 1601 S California Ave', 'Gänsemarkt 43 65232 Taunusstein', 'Gänsemarkt 43 1600 Amphitheater Parkway', 'Rechtsgrundlage ist Art. 6 2029 Stierlin Court', 'Mainstraße 6 1600 Amphitheater Parkway', 'Rechtsgrundlage ist Art. 6 20354 Hamburg', 'Gänsemarkt 43 2029 Stierlin Court', 'Gänsemarkt 43 1601 S California Ave', 'Mainstraße 6 1355 Market St', 'Mainstraße 6 21079 Hamburg', 'Mainstraße 6 20354 Hamburg', 'Gänsemarkt 43 1355 Market St', 'Rechtsgrundlage ist Art. 6 21079 Hamburg', 'Mainstraße 6 1595 Spring Hill Road', 'Mainstraße 6 65232 Taunusstein', 'Gänsemarkt 43 20354 Hamburg']
# []
# []
# ['Präsident-Herwig-Straße 24 36119 Neuhof-Dorfborn', 'Präsident-Herwig-Straße 24 27472 Cuxhaven', 'Präsident-Herwig-Straße 24 21079 Hamburg']
# ['Landgraf-Georg-Straße 4 64283 Darmstadt']
# []
# []
# ['Rathausallee 72-76 22846 Norderstedt', 'Rathausallee 72-76 20457 Hamburg']
# []
# ['Stadthausbrücke 5 20095 Hamburg', 'Stadthausbrücke 5 20355 Hamburg']
# ['Wehrstr. 24-26 1601 S', 'Wehrstraße 24-26 1601 S', 'Wehrstraße 24-26 2011 by Airnergy International GmbH', 'Wehrstr. 24-26 53773 Hennef', 'Wehrstr. 24-26 2011 by Airnergy International GmbH', 'Wehrstraße 24-26 53773 Hennef']
# []
# []
# []
# []
# []
# []
# []
# ['Landgraf-Georg-Straße 4 64283 Darmstadt']
# ['Hanauer Straße 5-7 75181 Pforzheim', 'Hanauer Straße 5-7 1500 Mitarbeitern an']
# []
# []
# []
# ['Atoomweg 6 20457\xa0Hamburg', 'Eichhornstraße 3 20457\xa0Hamburg', 'Eichhornstraße 3 10785 Berlin', 'Rosenfelder Str. 15-16 20459 Hamburg', 'Rosenfelder Str. 15-16 9743 AK Groningen', 'Rosenfelder Str. 15-16 10315 Berlin', 'Eichhornstraße 3 2338 Luxemburg', 'Rosenfelder Str. 15-16 10785 Berlin', 'Atoomweg 6 1600 Amphitheatre Parkway', 'Rosenfelder Str. 15-16 20457\xa0Hamburg', 'Atoomweg 6 2338 Luxemburg', 'Atoomweg 6 9743 AK Groningen', 'Rosenfelder Str. 15-16 2338 Luxemburg', 'Eichhornstraße 3 1600 Amphitheatre Parkway', 'Eichhornstraße 3 20459 Hamburg', 'Atoomweg 6 10315 Berlin', 'Eichhornstraße 3 10315 Berlin', 'Eichhornstraße 3 9743 AK Groningen', 'Atoomweg 6 20459 Hamburg', 'Atoomweg 6 10785 Berlin', 'Rosenfelder Str. 15-16 1600 Amphitheatre Parkway']
# ['Norwegen (NO, +47 2024 CTR-Fahrzeugtechnik GmbH']
# ['Zimmermannstraße 26 10969 Berlin']
# ['Jesinger Straße 52 1600 Amphitheatre Parkway', 'Jesinger Straße 52 73230 Kirchheim unter Teck', 'Jesinger Straße 52 94066 San Bruno']
# []
# []
# []
# []
# ['Jesinger Straße 52 73230 Kirchheim unter Teck']
# []
# ['Zeughausgasse 4 91154 Roth']
# []
# ['Am Rosenberg 2 1601 S', 'Am Rosenberg 2 54518 Osann-Monzel', 'Am Rosenberg 2 2024 CTR-Fahrzeugtechnik GmbH', 'Am Rosenberg 2 1600 Amphitheatre Parkway']
# ['Brunnenstraße 120 22763 Hamburg']
# ['Brunnenstraße 120 22767 Hamburg']
# []
# []
# []
# []
# []
# []
# []
# ['Adlerstraße 61 76137 Karlsruhe']
# []
# ['Homberger Weg 4-6 34497 Korbach', 'Homberger Weg 4-6 67360 Eschbach', 'Homberger Weg 4-6 1215 SL - Medvode']
# ['Rechtsgrundlage sind Art. 6 82481 Mittenwald', 'Rechtsgrundlage ist Art. 6 82481 Mittenwald', 'Rechtsgrundlage hierfür ist Art. 88 82481 Mittenwald']
# []
# []
# []
# []
# []
# ['Lise-Meitner-Str. 6 28359 Bremen']
# []
# []
# []
# ['Bundesgartenschau 2023 2021 nach', 'Bundesgartenschau 2023 2022 lautet das Motto', 'Bundesgartenschau 2023 2024 statt', 'Bundesgartenschau 2023 2023 gemeinsam mit Partner', 'Bundesgartenschau 2023 2023 lautet das Motto']
# ['Wittelsbacherring 9 10115 Berlin', 'Anklamer Straße 38 53115 Bonn', 'Anklamer Straße 38 10115 Berlin', 'Wittelsbacherring 9 53115 Bonn']
# []
# ['Seehofstr. 15 14169 Berlin']
# []
# []
# ['Kaskelstraße 53 10317 Berlin']
# ['Adlerstraße 61 76137 Karlsruhe']
# []
# []
# []
# []
# []
# []
# []
# []
# ['Luther Weg 77 31515 Wunstorf']
# ['Carl-Bosch-Str. 14 63814 Mainaschaff', 'Carl-Bosch-Str. 14 1601 Willow Road', 'Carl-Bosch-Str. 14 1355 Market Street', 'Carl-Bosch-Str. 14 1600 Amphitheatre Parkway']
# ['Baselstrasse 47 6003 Luzern']
# []
# ['Westhafenplatz 1 60327 Frankfurt am Main', 'Berliner Allee 47 64295 Darmstadt', 'Berliner Allee 47 60327 Frankfurt am Main', 'Westhafenplatz 1 64295 Darmstadt']
# ['Adlerstraße 61 2489 Berlin', 'Sandner Straße 3 76137 Karlsruhe', 'Max-Planck-Straße 3 1100 Wien', 'Zimmerstraße 6 76137\xa0Karlsruhe', 'Max-Planck-Straße 3 76137 Karlsruhe', 'Zimmerstraße 6 2489 Berlin', 'Sandner Straße 3 1100 Wien', 'Max-Planck-Straße 3 76137\xa0Karlsruhe', 'Adlerstraße 61 76137\xa0Karlsruhe', 'Sandner Straße 3 76137\xa0Karlsruhe', 'Sandner Straße 3 2489 Berlin', 'Adlerstraße 61 76137 Karlsruhe', 'Adlerstraße 61 1100 Wien', 'Zimmerstraße 6 76137 Karlsruhe', 'Max-Planck-Straße 3 2489 Berlin', 'Zimmerstraße 6 1100 Wien']
# ['Bayernstraße 10 30855 Langenhagen']
# ['Stephanstraße 60 2024 berlinlofts', 'Stephanstraße 60 10559 Berlin']
# ['Boschring 7 56422 Wirges', 'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel', 'Boschring 7 55252 Mainz-Kastel', 'Fritz-Ullmann-Straße 4 56422 Wirges']
# []
# ['Poststraße 49 1601 S', 'Poststraße 49 63801 Kleinostheim']
# ['Westhafenplatz 1 60327 Frankfurt am Main', 'Berliner Allee 47 64295 Darmstadt', 'Berliner Allee 47 60327 Frankfurt am Main', 'Westhafenplatz 1 64295 Darmstadt']
# []
# ['Gebirgspionierstr. 22 60486 Frankfurt', 'Voltastraße 84 60486 Frankfurt', 'Gebirgspionierstr. 22 82481 Mittenwald', 'Voltastraße 84 82481 Mittenwald']
# ['Anklamer Straße 38 53115 Bonn', 'Anklamer Straße 38 10115 Berlin', 'Rechtsgrundlage ist Art. 6 86150 Augsburg', 'Schießgrabenstr. 32 86150 Augsburg', 'Wittelsbacherring 9 2449 Luxemburg', 'Schießgrabenstr. 32 1601 S', 'Anklamer Straße 38 1601 S', 'Konrad-Adenauer-Ufer 85 1355 Market St', 'Rechtsgrundlage ist Art. 6 1600 Amphitheatre Parkway', 'Wittelsbacherring 9 10115 Berlin', 'Konrad-Adenauer-Ufer 85 1601 Willow Road', 'Rechtsgrundlage ist Art. 6 1601 Willow Road', 'Wittelsbacherring 9 1600 Amphitheatre Parkway', 'Wittelsbacherring 9 1601 S', 'Konrad-Adenauer-Ufer 85 80339 München', 'Anklamer Straße 38 1601 Willow Road', 'Rechtsgrundlage ist Art. 6 1355 Market St', 'Rechtsgrundlage ist Art. 6 1601 S', 'Schießgrabenstr. 32 1601 Willow Road', 'Konrad-Adenauer-Ufer 85 1600 Amphitheatre Parkway', 'Schießgrabenstr. 32 80339 München', 'Wittelsbacherring 9 1355 Market St', 'Konrad-Adenauer-Ufer 85 50668 Köln', 'Anklamer Straße 38 1600 Amphitheatre Parkway', 'Konrad-Adenauer-Ufer 85 86150 Augsburg', 'Rechtsgrundlage ist Art. 6 50668 Köln', 'Wittelsbacherring 9 53115 Bonn', 'Konrad-Adenauer-Ufer 85 2449 Luxemburg', 'Konrad-Adenauer-Ufer 85 1601 S', 'Anklamer Straße 38 2449 Luxemburg', 'Anklamer Straße 38 80339 München', 'Schießgrabenstr. 32 50668 Köln', 'Rechtsgrundlage ist Art. 6 53115 Bonn', 'Rechtsgrundlage ist Art. 6 10115 Berlin', 'Anklamer Straße 38 50668 Köln', 'Wittelsbacherring 9 86150 Augsburg', 'Anklamer Straße 38 1355 Market St', 'Konrad-Adenauer-Ufer 85 53115 Bonn', 'Rechtsgrundlage ist Art. 6 2449 Luxemburg', 'Rechtsgrundlage ist Art. 6 80339 München', 'Schießgrabenstr. 32 10115 Berlin', 'Schießgrabenstr. 32 2449 Luxemburg', 'Schießgrabenstr. 32 53115 Bonn', 'Schießgrabenstr. 32 1355 Market St', 'Anklamer Straße 38 86150 Augsburg', 'Wittelsbacherring 9 1601 Willow Road', 'Wittelsbacherring 9 50668 Köln', 'Schießgrabenstr. 32 1600 Amphitheatre Parkway', 'Wittelsbacherring 9 80339 München', 'Konrad-Adenauer-Ufer 85 10115 Berlin']
# []
# []
# []
# ['Hanauer Straße 6 1500 Mitarbeitern an', 'Hanauer Straße 6 75181 Pforzheim', 'Hanauer Straße 7 75181 Pforzheim', 'Hanauer Straße 7 1500 Mitarbeitern an', 'Hanauer Straße 5-7 75181 Pforzheim', 'Hanauer Straße 5-7 1500 Mitarbeitern an']
# []
# []
# []
# []
# ['Seehofstr. 15 14169 Berlin']
# ['Junkersring 5 53844 Troisdorf']
# []
# ['Junkersring 5 53844 Troisdorf']
# ['Binger Straße 25 2024 aktualisiert']
# ['Schmilinskystr. 45 20099 Hamburg']
# ['Heider Weg 42 27777 Ganderkesee', 'Heider Weg 42 77694 Kehl am Rhein']
# []
# []
# []
# []
# ['Schwamberger/Volkergasse 4 1150 Wien']
# ['Seehofstr. 15 14169 Berlin']
# []
# ['Wehrstraße 24-26 53773 Hennef Telefon', 'Wehrstraße 24-26 2029 Stierlin Court', 'Dammtorstraße 29-32 1600 Amphitheatre Parkway', 'Wehrstraße 24-26 1600 Amphitheatre Parkway', 'Wehrstr. 26 53773 Hennef Telefon', 'Wehrstraße 24-26 53773 Hennef', 'Wehrstr. 26 2029 Stierlin Court', 'Dammtorstraße 29-32 53773 Hennef Telefon', 'Dammtorstraße 29-32 53773 Hennef', 'Wehrstr. 26 1355 Market Street', 'Wehrstr. 26 1601 Willow Road', 'Wehrstr. 26 20354 Hamburg', 'Wehrstr. 26 53773 Hennef', 'Wehrstr. 26 1600 Amphitheatre Parkway', 'Dammtorstraße 29-32 20354 Hamburg', 'Dammtorstraße 29-32 2029 Stierlin Court', 'Wehrstraße 24-26 1355 Market Street', 'Dammtorstraße 29-32 1355 Market Street', 'Dammtorstraße 29-32 1601 Willow Road', 'Wehrstraße 24-26 1601 Willow Road', 'Wehrstraße 24-26 20354 Hamburg']
# ['Adlerstraße 61 76137 Karlsruhe']
# []
# []
# []
# []
# ['Rechtsgrundlage des Art. 6 20355 Hamburg', 'Stadthausbrücke 5 02141 USA', 'Rechtsgrundlage von Art. 6 20355 Hamburg', 'Rechtsgrundlage hierfür ist Art. 6 20459 Hamburg', 'Rechtsgrundlage des Art. 6 20459 Hamburg', 'Rechtsgrundlage von Art. 6 20459 Hamburg', 'Rechtsgrundlage in Art. 6 20459 Hamburg', 'Rechtsgrundlage des Art. 6 02141 USA', 'Stadthausbrücke 5 20459 Hamburg', 'Rechtsgrundlage in Art. 6 20355 Hamburg', 'Stadthausbrücke 5 20355 Hamburg', 'Rechtsgrundlage von Art. 6 02141 USA', 'Rechtsgrundlage hierfür ist Art. 6 02141 USA', 'Rechtsgrundlage in Art. 6 02141 USA', 'Rechtsgrundlage hierfür ist Art. 6 20355 Hamburg']
# ['Hanauer Straße 5-7 75181 Pforzheim', 'Hanauer Straße 5-7 1500 Mitarbeitern an']
# ['Westhafenplatz 1 60327 Frankfurt am Main', 'Berliner Allee 47 64295 Darmstadt', 'Berliner Allee 47 60327 Frankfurt am Main', 'Westhafenplatz 1 64295 Darmstadt']
# []
# ['Lindwurmstr. 109 80337 München']
# ['Rigistr. 8-10 12277 Berlin', 'Subbelrather Str. 15 50823 Köln', 'Rigistr. 8-10 50823 Köln', 'Rigistr. 8-10 2019 by', 'Subbelrather Str. 15 2019 by', 'Subbelrather Str. 15 12277 Berlin']
# ['Berner Straße 74 60437 Frankfurt am Main']
# []
# ['Münzstr. 21 10178 Berlin']
# []
# ['I-Gebiet Weidenbusch · Boschring 7 55252 Mainz-Kastel', 'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel', 'Waldring 43 56422 Wirges', 'Waldring 43 44789 Bochum', 'Fritz-Ullmann-Straße 4 56422 Wirges', 'I-Gebiet Weidenbusch · Boschring 7 44789 Bochum', 'Fritz-Ullmann-Straße 4 44789 Bochum', 'Waldring 43 55252 Mainz-Kastel', 'I-Gebiet Weidenbusch · Boschring 7 56422 Wirges']
# []
# ['Rosentalstraße 8 72070 Tübingen']
# []
# ['Hüfferstr. 54 79098 Freiburg i', 'Augustinerplatz 2 79098 Freiburg i', 'Augustinerplatz 2 33378 Rheda-Wiedenbrück', 'Hüfferstr. 54 33378 Rheda-Wiedenbrück']
# ['Bayernstraße 10 30855 Langenhagen']
# []
# ['Zehdenicker Str. 21 10119 Berlin']
# ['Hermsheimer Straße 3 2019 by', 'Rigistraße 8 12277 Berlin', 'Rigistr. 8 2019 by', 'Rigistraße 8 68163 Mannheim', 'Hermsheimer Straße 3 10559 Berlin', 'Turmstraße 21 68163 Mannheim', 'Turmstraße 21 10559 Berlin', 'Rigistraße 8 2019 by', 'Hermsheimer Straße 3 12277 Berlin', 'Rigistraße 8 10559 Berlin', 'Rigistr. 8 10559 Berlin', 'Hermsheimer Straße 3 68163 Mannheim', 'Rigistr. 8 12277 Berlin', 'Turmstraße 21 12277 Berlin', 'Rigistr. 8 68163 Mannheim', 'Turmstraße 21 2019 by']
# ['Schwedlerstr. 8 60314 Frankfurt am Main']
# ['Wehrstraße 24-26 93300 an', 'Wehrstraße 24-26 2022 mit verbesserten Duokats', 'Wehrstraße 24-26 53773 Hennef']
# ['Lindwurmstr. 109 80337 München']
# ['Schwedlerstr. 8 10117 Berlin', 'Albrechtstraße 10 10117 Berlin']
# []
# ['Stadthausbrücke 5 20355 Hamburg']
# []
# []
# []
# []
# ['Im Gewerbepark 8 79252 Stegen']
# ['Hauptbahnhofs ist nur 500m 55131 Mainz', 'Binger Straße 25 55131 Mainz']
# ['Schellingstr. 109a 8078 München', 'Schellingstr. 109a 80798 München']
# ['Schellingstr. 109a 2449 Luxembourg', 'Schellingstr. 109a 80798 München']
# []
# ['Schmilinskystraße 45 20099 Hamburg']
# ['Landgraf-Georg-Straße 4 64283 Darmstadt']
# []
# ['Heider Weg 42 27777 Ganderkesee']
# ['Schlesische Straße 26 10997 Berlin']
# []
# []
# ['Frankenstraße 185 45134 Essen', 'Frankenstraße 185 1600 Amphitheatre Parkway']
# []
# []
# ['Köpenicker Straße 126 91710 Gunzenhausen', 'Rosentalstraße 8 10179 Berlin', 'Rechtsgrundlage hierfür ist § 26 91710 Gunzenhausen', 'Rechtsgrundlage hierfür ist Art. 6 91710 Gunzenhausen', 'Industriestr. 25 22305 Hamburg', 'Rechtsgrundlage hierfür ist Art. 6 10179 Berlin', 'Rechtsgrundlage hierfür ist Art. 6 22305 Hamburg', 'Rosentalstraße 8 91710 Gunzenhausen', 'Köpenicker Straße 126 22305 Hamburg', 'Rechtsgrundlage hierfür ist § 26 72070 Tübingen', 'Rosentalstraße 8 22305 Hamburg', 'Rechtsgrundlage hierfür ist Art. 6 72070 Tübingen', 'Rechtsgrundlage hierfür ist § 26 10179 Berlin', 'Köpenicker Straße 126 72070 Tübingen', 'Industriestr. 25 91710 Gunzenhausen', 'Industriestr. 25 10179 Berlin', 'Rechtsgrundlage hierfür ist § 26 22305 Hamburg', 'Köpenicker Straße 126 10179 Berlin', 'Rosentalstraße 8 72070 Tübingen', 'Industriestr. 25 72070 Tübingen']
# []
# []
# ['Landsberger Straße 392 81241 München']
# ['Salzdahlumer Str. 196 2024 simple-fax', 'Salzdahlumer Str. 196 38126 Braunschweig']
# []
# []
# ['Dammtorstraße 29-32 20354 Hamburg', 'Rechtsgrundlage der Verarbeitung Art. 6 20354 Hamburg', 'Rechtsgrundlage der Verarbeitung Art. 6 20253 Hamburg', 'Dammtorstraße 29-32 1355 Market Street', 'Hoheluftchaussee 40 20354 Hamburg', 'Hoheluftchaussee 40 1601 Willow Road', 'Dammtorstraße 29-32 1601 Willow Road', 'Hoheluftchaussee 40 20253 Hamburg', 'Hoheluftchaussee 40 1355 Market Street', 'Rechtsgrundlage dieser Verarbeitung Art. 6 20253 Hamburg', 'Rechtsgrundlage dieser Verarbeitung Art. 6 20354 Hamburg', 'Dammtorstraße 29-32 20253 Hamburg']
# ['Gartenstraße 45 04936 Schlieben', 'Gartenstr.45 04936 Schlieben']
# []
# []
# []
# ['Oberaltenallee 20 22081 Hamburg', 'Oberaltenallee 20 20457 Hamburg']
# []
# []
# ['Altostr. 25f 10117 Berlin', 'Reinhardtstr.52 10117 Berlin', 'Reinhardtstr.52 83219 Starnberg', 'Altostr. 25f 83219 Starnberg']
# ['Gartenstraße 45 04936 Schlieben']
# []
# ['Vaartweg 36 80339 München', 'Heimeranstraße 35 4731 RA Oudenbosch', 'Heimeranstraße 35 5637 Beinwil', 'Vaartweg 36 5637 Beinwil', 'Heimeranstraße 35 80339 München', 'Vaartweg 36 4731 RA Oudenbosch']
# ['Beta-Straße 1 85774 Unterföhring', 'Beta-Straße 1 2023 CinePostproduction GmbH']
# []
# ['Kiesteichweg 21 68199 Mannheim']
# ['Frankenstraße 185 45134 Essen']
# ['Lange Straße 14 2017 Fehldiagnose', 'Lange Straße 14 2017 Räuber Hotzenplotz', 'Lange Straße 14 34454 Bad Arolsen-Mengeringhausen', 'Lange Straße 14 2022 Taxi Taxi', 'Lange Straße 14 2023 Das Oslo-Syndrom', 'Lange Straße 14 2023 Das kalte Herz', 'Lange Straße 14 2018 Aufguss', 'Lange Straße 14 2019 Stumm', 'Lange Straße 14 2019 Die Feuerzangenbowle', 'Lange Straße 14 2019 Jubiläum', 'Lange Straße 14 2017 Sebastian Sternenputtzer', 'Lange Straße 14 2021 Jakobs-Wunder-Abend', 'Lange Straße 14 2018 Ein Jedermann']
# []
# ['Pamplonastraße 19 30539 Hannover', 'Pamplonastraße 19 33106 Paderborn', 'Dammtorstraße 30 1601 Willow Road', 'Dammtorstraße 30 01801 USA', 'Paderborner Straße 33 40213 Düsseldorf', 'Paderborner Straße 33 20354 Hamburg', 'Kavalleriestraße 2-4 40213 Düsseldorf', 'Kavalleriestraße 2-4 33106 Paderborn', 'Kavalleriestraße 2-4 30539 Hannover', 'Pamplonastraße 19 33161 Hövelhof', 'Dammtorstraße 30 30539 Hannover', 'Dammtorstraße 30 33106 Paderborn', 'Paderborner Straße 33 01801 USA', 'Pamplonastraße 19 20354 Hamburg', 'Kavalleriestraße 2-4 1601 Willow Road', 'Dammtorstraße 30 33161 Hövelhof', 'Pamplonastraße 19 1601 Willow Road', 'Pamplonastraße 19 01801 USA', 'Kavalleriestraße 2-4 01801 USA', 'Paderborner Straße 33 30539 Hannover', 'Dammtorstraße 30 40213 Düsseldorf', 'Paderborner Straße 33 33106 Paderborn', 'Kavalleriestraße 2-4 20354 Hamburg', 'Paderborner Straße 33 1601 Willow Road', 'Pamplonastraße 19 40213 Düsseldorf', 'Paderborner Straße 33 33161 Hövelhof', 'Dammtorstraße 30 20354 Hamburg', 'Kavalleriestraße 2-4 33161 Hövelhof']
# ['Kaskelstr. 53 10317 Berlin']
# []
# []
# []
# []
# ['Paderborner Straße 33 33161 Hövelhof']
# ['Homberger Weg 4-6 34497 Korbach']
# ['Gluckstr. 57 2016 COTRI moves to Hamburg', 'Gluckstr. 57 2002 PhD', 'Gluckstr. 57 2023 and beyond', 'Gluckstr. 57 2023 Start COTMI weekly publication', 'Gluckstr. 57 2023 Restart China outbound tourism', 'Gluckstr. 57 1978 First visit of Prof', 'Gluckstr. 57 22081 Hamburg', 'Gluckstr. 57 2008 COTRI moves to Heide', 'Gluckstr. 57 1957 in West-Berlin']
# ['Ringbahnstraße 16 2023 CinePostproduction GmbH', 'Beta-Straße 1 85774 Unterföhring', 'Beta-Straße 1 2023 CinePostproduction GmbH', 'Beta-Straße 1 12099 Berlin', 'Ringbahnstraße 16 12099 Berlin', 'Ringbahnstraße 16 85774 Unterföhring']
# ['Königinstraße 28 33609 Bielefeld', 'Königinstraße 28 33613 Bielefeld', 'Königinstraße 28 80802 München', 'Königinstraße 28 2024 Mester']
# ['Luther Weg 77 1601 Willow Road', 'Dammtorstraße 29-32 20354 Hamburg', 'Luther Weg 77 20354 Hamburg', 'Luther Weg 77 31515 Wunstorf', 'Dammtorstraße 29-32 1600 Amphitheatre Parkway', 'Dammtorstraße 29-32 1355 Market Street', 'Luther Weg 77 1600 Amphitheatre Parkway', 'Luther Weg 77 2029 Stierlin Court', 'Dammtorstraße 29-32 31515 Wunstorf', 'Dammtorstraße 29-32 1601 Willow Road', 'Luther Weg 77 1601 South California Avenue', 'Dammtorstraße 29-32 2029 Stierlin Court', 'Dammtorstraße 29-32 1601 South California Avenue', 'Luther Weg 77 1355 Market Street']
# ['Magnusstr. 11 12489 Berlin']
# ['Stadtstraße 2 10900 Berlin', 'Stadtstraße 2 79104 Freiburg']
# []
# []
# []
# ['Kornstraße 31 30167 Hannover']
# []
# ['Brunnenstr. 153 10115 Berlin']
# ['Paderborner Straße 33 33161 Hövelhof']
# ['Beta-Straße 1 85774 Unterföhring', 'Beta-Straße 1 1600 Amphitheatre Parkway', 'Beta-Straße 1 2023 CinePostproduction GmbH']
# []
# ['Friedrichstraße 95 1027 Budapest', 'Friedrichstraße 95 80339 Munich', 'Heimeranstrasse 35 80339 Munich', 'Friedrichstraße 95 10117 Berlin', 'Heimeranstrasse 35 1027 Budapest', 'Heimeranstrasse 35 10117 Berlin']
# ['Am Staudamm 24 91710 Gunzenhausen', 'Am Staudamm 24 02906 Quitzdorf am See', 'Industriestr. 25 94043 USA', 'Am Staudamm 24 1600 Amphitheatre Parkway', 'Am Staudamm 24 94043 USA', 'Industriestr. 25 1600 Amphitheatre Parkway', 'Industriestr. 25 91710 Gunzenhausen', 'Industriestr. 25 02906 Quitzdorf am See']
# ['Hoheluftbrücke\xa0+ 6 20253 Hamburg', 'Hoheluftchaussee 40 20253 Hamburg', 'Hoheluftbrücke\xa0+ 5 20253 Hamburg', 'Eppendorfer Weg (Ost)\xa0+ 4 20253 Hamburg']
# []
# []
# ['Heimeranstrasse 35 80339 Munich']
# []
# []
# ['Homberger Weg 4-6 34497 Korbach']
# []
# ['Seehofstr. 15 14169 Berlin']
# []
# ['Goethestr. 112 63067 Offenbach']
# []
# ['Seizstraße 2-4 54290 Trier', 'Seizstraße 2-4 2023 Titles', 'Seizstraße 2-4 2024 by FOREAL']
# []
# []
# ['Wittelsbacherring 9 53115 Bonn', 'Stahlgruberring 3 81829 München', 'Wittelsbacherring 9 81829 München', 'Wittelsbacherring 9 6363 eingetragen', 'Stahlgruberring 3 6363 eingetragen', 'Stahlgruberring 3 53115 Bonn']
# ['Thadenstrasse 134 07819 Nuestra Sra', 'Thadenstrasse 134 22767 Hamburg']
# ['Rechtsgrundlage hierfür ist Art. 6 34497 Korbach', 'Mengeringhäuser Str. 15 34497 Korbach', 'Mengeringhäuser Str. 15 80331 München', 'Homberger Weg 4-6 80331 München', 'Homberger Weg 4-6 34497 Korbach', 'Homberger Weg 4-6 34454 Bad Arolsen', 'Rechtsgrundlage hierfür ist Art. 6 80331 München', 'Mengeringhäuser Str. 15 34454 Bad Arolsen']
# []
# []
# []
# []
# ['Rigistraße 8-10 2019 by', 'Rigistraße 8-10 12277 Berlin']
# []
# []
# []
# []
# ['Im Gewerbepark 8 79252 Stegen', 'Im Gewerbepark 8 41460 Neuss']
# ['Berner Straße 74 60437 Frankfurt am Main', 'Finanzmarktregulatorik 2023 60437 Frankfurt am Main']
# []
# []
# []
# []
# ['Subbelrather Str. 15 2018 by', 'Rigistr. 8-10 12277 Berlin', 'Friedensallee 254 81373 München', 'Friedensallee 254 50823 Köln', 'Radlkoferstraße 2 2018 by', 'Rigistr. 8-10 22763 Hamburg', 'Radlkoferstraße 2 81373 München', 'Radlkoferstraße 2 50823 Köln', 'Friedensallee 254 2018 by', 'Friedensallee 254 22763 Hamburg', 'Rigistr. 8-10 50823 Köln', 'Subbelrather Str. 15 81373 München', 'Rigistr. 8-10 81373 München', 'Radlkoferstraße 2 22763 Hamburg', 'Subbelrather Str. 15 50823 Köln', 'Radlkoferstraße 2 12277 Berlin', 'Subbelrather Str. 15 12277 Berlin', 'Friedensallee 254 12277 Berlin', 'Subbelrather Str. 15 22763 Hamburg', 'Rigistr. 8-10 2018 by']
# ['Turnringen, Girevoy (Wettkampf-Kettlebells), Concept2 20253 Hamburg', 'Hoheluftchaussee 40 20253 Hamburg']
# []
# ['Heimeranstrasse 35 80339 Munich']
# ['Klingenberger Straße 4 74223 Flein', 'Fabrikstraße 8 74223 Flein', 'Klingenberger Straße 4 74232 Abstatt', 'Fabrikstraße 8 74232 Abstatt']
# ['Steinkirchring 35 1601 S', 'Steinkirchring 35 1601 Willow Road', 'Steinkirchring 35 1600 Amphitheatre Parkway', 'Steinkirchring 35 78056 VS-Schwenningen', 'Steinkirchring 35 1355 Market St']
# ['Hoheluftchaussee 40 20253 Hamburg']
# ['Am Staudamm 24 02906 Quitzdorf am See']
# ['Rigistraße 10 12277 Berlin', 'Rigistraße 10 2019 by']
# ['Steinkirchring 35 78056 VS-Schwenningen']
# []
# []
# []
# []
# ['Lise-Meitner-Straße 6 10627 Berlin', 'Kantstraße 99 10627 Berlin', 'Lise-Meitner-Straße 6 28359 Bremen', 'Kantstraße 99 28359 Bremen']
# []
# ['Alexander-Training, Robert Brandl, Oskar-Stalf-Str. 37 85665 Moosach']
# ['Horneckgasse 6 3950 Arrowhead Street', 'Marienstraße 13 1123 Kamehameha Hwy Ste D', 'Marienstraße 13 1170 Vienna', 'Horneckgasse 6 1170 Vienna', 'Horneckgasse 6 1010 Common Street', 'Horneckgasse 6 1430 Broadway', 'Horneckgasse 6 06526 Sangerhausen', 'Marienstraße 13 06526 Sangerhausen', 'Marienstraße 13 1430 Broadway', 'Horneckgasse 6 9440\xa0S', 'Horneckgasse 6 1123 Kamehameha Hwy Ste D', 'Horneckgasse 6 4150 Santa Monica Blvd', 'Marienstraße 13 1010 Common Street', 'Marienstraße 13 3950 Arrowhead Street', 'Marienstraße 13 4150 Santa Monica Blvd', 'Marienstraße 13 9440\xa0S']
# []
# []
# []
# ['Zimmermannweg 28 64285 Darmstadt', 'Bessunger Str. 5 64285 Darmstadt', 'Zimmermannweg 28 64289 Darmstadt', 'Bessunger Str. 5 64289 Darmstadt']
# ['Ohlrattweg 5 20537 Hamburg', 'Ullsteinstraße 130 25497 Prisdorf', 'Borstelmannsweg 133 12109 Berlin', 'Ohlrattweg 5 1021 KP Amsterdam', 'Ohlrattweg 5 12109 Berlin', 'Ullsteinstraße 130 02494 USA', 'Rechtsgrundlage ist Art. 6 25497 Prisdorf', 'Ullsteinstraße 130 1021 KP Amsterdam', 'Ullsteinstraße 130 12109 Berlin', 'Rechtsgrundlage ist Art. 6 1021 KP Amsterdam', 'Borstelmannsweg 133 1021 KP Amsterdam', 'Borstelmannsweg 133 20537 Hamburg', 'Borstelmannsweg 133 25497 Prisdorf', 'Rechtsgrundlage ist Art. 6 12109 Berlin', 'Ohlrattweg 5 25497 Prisdorf', 'Ohlrattweg 5 02494 USA', 'Rechtsgrundlage ist Art. 6 20537 Hamburg', 'Rechtsgrundlage ist Art. 6 02494 USA', 'Ullsteinstraße 130 20537 Hamburg', 'Borstelmannsweg 133 02494 USA']
# []
# ['Zülpicher Straße 221 50937 Köln', 'Rechtsgrundlage von Art. 6 1600 Amphitheatre Parkway', 'Rechtsgrundlage hierbei ist Art. 6 50823 Köln', 'Rechtsgrundlage ist Art. 6 50823 Köln', 'Rechtsgrundlage ist Art. 6 1600 Amphitheatre Parkway', 'Rechtsgrundlage ist Art. 6 50937 Köln', 'Zülpicher Straße 221 1600 Amphitheatre Parkway', 'Rechtsgrundlage hierbei ist Art. 6 50937 Köln', 'Rechtsgrundlage von Art. 6 94043 USA', 'Rechtsgrundlage hierbei ist Art. 6 94043 USA', 'Vogelsanger Str. 82 1600 Amphitheatre Parkway', 'Rechtsgrundlage ist Art. 6 94043 USA', 'Rechtsgrundlage von Art. 6 50937 Köln', 'Vogelsanger Str. 82 94043 USA', 'Rechtsgrundlage von Art. 6 50823 Köln', 'Vogelsanger Str. 82 50823 Köln', 'Zülpicher Straße 221 50823 Köln', 'Vogelsanger Str. 82 50937 Köln', 'Zülpicher Straße 221 94043 USA']
# ['Borstelmannsweg 133 20537 Hamburg']
# ['Seegarten 44 97297 Waldbüttelbrunn']
# []
# []
# []
# []
# []
# []
# []
# ['Landsberger Straße 392 81241 München']
# ['Kornstraße 31 30167 Hannover']
# []
# []
# ['Landsberger Straße 392 81241 München']
# []
# []
# ['Grafenberger Allee 277-287 40237 Düsseldorf', 'Grafenberger Allee 277-287 81241 München', 'Heilbronner Strasse 150 10557 Berlin', 'Landsberger Straße 392 81241 München', 'Poststraße 2-4 20095 Hamburg', 'Poststraße 2-4 40237 Düsseldorf', 'Heilbronner Strasse 150 60329 Frankfurt a', 'Grafenberger Allee 277-287 20095 Hamburg', 'Bertha-Benz-Straße 5 60329 Frankfurt a', 'Bertha-Benz-Straße 5 40237 Düsseldorf', 'Landsberger Straße 392 40237 Düsseldorf', 'Poststraße 2-4 60329 Frankfurt a', 'Grafenberger Allee 277-287 60329 Frankfurt a', 'Landsberger Straße 392 10557 Berlin', 'Poststraße 2-4 10557 Berlin', 'Heilbronner Strasse 150 40237 Düsseldorf', 'Heilbronner Strasse 150 81241 München', 'Poststraße 2-4 81241 München', 'Grafenberger Allee 277-287 10557 Berlin', 'Heilbronner Strasse 150 20095 Hamburg', 'Landsberger Straße 392 60329 Frankfurt a', 'Bertha-Benz-Straße 5 10557 Berlin', 'Landsberger Straße 392 20095 Hamburg', 'Bertha-Benz-Straße 5 20095 Hamburg', 'Bertha-Benz-Straße 5 81241 München']
# ['Landsberger Straße 392 81241 München']
# ['Altostr. 25f 82319 Starnberg']
# []
# []
# []
# ['Scheuermann stiegen 2009 68199 Mannheim', 'Kiesteichweg 21 68199 Mannheim']
# []
# ['Talstraße 126 79194 Gundelfingen']
# []
# ['Borstelmannsweg 133 20537 Hamburg']
# []
# ['Davoser Str. 1g 14199 Berlin']
# []
# []
# ['Rechtsgrundlagen: Einwilligung (Art. 6 64289 Darmstadt', 'Zimmermannweg 28 64289 Darmstadt']
# ['Zimmermannweg 28 64289 Darmstadt']
# []
# ['Christinenstraße 7 40880 Ratingen']
# []
# ['Christinenstr. 7-7a 40880 Ratingen', 'Christinenstraße 7 40880 Ratingen']
# ['Oberneuhofstrasse 1 2023 ZenInvest', 'Oberneuhofstrasse 1 6340 Baar']
# Error occurred while fetching URL 'https://axonic.com/contact/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://imiconsulting.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://axonic.com': [WinError 10053] An established connection was aborted by the software in your host machine
# []
# []
# ['Johann-Krane-Weg 37 2022 TRELOCK GmbH', 'Johann-Krane-Weg 37 48149 Münster', 'Johann-Krane-Weg 37 48042 Münster']
# ['Johann-Krane-Weg 37 2022 TRELOCK GmbH', 'Johann-Krane-Weg 37 48149 Münster', 'Johann-Krane-Weg 37 48042 Münster']
# ['Johann-Krane-Weg 37 2022 TRELOCK GmbH', 'Johann-Krane-Weg 37 48149 Münster', 'Johann-Krane-Weg 37 48042 Münster']
# ['Johann-Krane-Weg 37 2022 TRELOCK GmbH', 'Johann-Krane-Weg 37 48149 Münster', 'Johann-Krane-Weg 37 48042 Münster']
# ['Johann-Krane-Weg 37 2022 TRELOCK GmbH', 'Johann-Krane-Weg 37 48149 Münster', 'Johann-Krane-Weg 37 48042 Münster']
# Timeout occurred while fetching URL: https://berlinlofts.com/en/contact

# %%
final_addressesD
# Out:
# [['https://www.cantus-bahn.de/kontakt', []],
#  ['https://cantus-bahn.de', []],
#  ['https://www.cantus-bahn.de/metamenu/impressum',
#   ['Franz-Ulrich-Straße 18 34117 Kassel']],
#  ['https://www.cantus-bahn.de/metamenu/datenschutz',
#   ['Rechtsgrundlage Richtlinie 2004 34369 Hofgeismar',
#    'Neue Straße 22 34369 Hofgeismar',
#    'Rechtsgrundlage ist Art. 6 34369 Hofgeismar']],
#  ['https://pastisani.com', []],
#  ['https://pastisani.com/impressum/', ['Orber Straße 30 60386 Frankfurt']],
#  ['https://pastisani.com/datenschutz/',
#   ['Rechtsgrundlage hierfür ist Art. 6 60386 Frankfurt',
#    'Elgendorfer Str. 57 56410 Montabaur',
#    'Elgendorfer Str. 57 60386 Frankfurt',
#    'Orber Straße 30 56410 Montabaur',
#    'Orber Straße 30 60386 Frankfurt',
#    'Rechtsgrundlage hierfür ist Art. 6 56410 Montabaur']],
#  ['https://marry-jim.com/impressum/', ['Am Wacholderberg 9 61462 Königstein']],
#  ['https://marry-jim.com/contact/', []],
#  ['https://marry-jim.com', []],
#  ['https://weinanzeiger.com/contact', []],
#  ['https://weinanzeiger.com', ['Denkmalgasse 18 2172 Schrattenbe']],
#  ['https://weinanzeiger.com/impressum-p32', ['Kraus Straße 16 2123 Kronberg']],
#  ['https://infinity-reisen.com/impressum/',
#   ['Schorndorferstr. 27 70734 Fellbach',
#    'Schorndorferstr. 27 10006 Berlin',
#    'Schorndorfer Straße 27 70734 Fellbach',
#    'Schorndorferstr. 27 77694 Kehl',
#    'Schorndorfer Straße 27 70736 Fellbach',
#    'Sonnenbühlstr. 23 10006 Berlin',
#    'Schorndorferstr. 27 70736 Fellbach',
#    'Sonnenbühlstr. 23 70736 Fellbach',
#    'Sonnenbühlstr. 23 77694 Kehl',
#    'Sonnenbühlstr. 23 70734 Fellbach',
#    'Schorndorfer Straße 27 77694 Kehl',
#    'Schorndorfer Straße 27 10006 Berlin']],
#  ['https://infinity-reisen.com', ['Schorndorfer Straße 27 70736 Fellbach']],
#  ['https://infinity-reisen.com/datenschutz/',
#   ['Schorndorfer Straße 27 70734 Fellbach',
#    'Schorndorfer Straße 27 70736 Fellbach',
#    'Sonnenbühlstr. 23 70736 Fellbach',
#    'Sonnenbühlstr. 23 70734 Fellbach',
#    'Schorndorfer Straße 27 1600 Amphitheatre Parkway',
#    'Sonnenbühlstr. 23 1600 Amphitheatre Parkway']],
#  ['https://infinity-reisen.com/kontakt/',
#   ['Schorndorfer Straße 27 70736 Fellbach',
#    'Schorndorferstraße 27 70736 Fellbach']],
#  ['http://rtc-c.com',
#   ['Maffeistr. 12 2023 Weltkonferenz AHK',
#    'Maffeistrasse 12 93059 Regensburg',
#    'Augustenstr. 3 93049 Regensburg',
#    'Augustenstr. 3 2023 Weltkonferenz AHK',
#    'Maffeistr. 12 93049 Regensburg',
#    'Maffeistrasse 12 2023 Weltkonferenz AHK',
#    'Augustenstr. 3 93059 Regensburg',
#    'Maffeistrasse 12 8568  Handelsregister',
#    'Maffeistrasse 12 93049 Regensburg',
#    'Maffeistr. 12 93059 Regensburg',
#    'Augustenstr. 3 8568  Handelsregister',
#    'Maffeistr. 12 8568  Handelsregister']],
#  ['https://freiberuflervermittlung.de/impressum/', []],
#  ['https://freiberuflervermittlung.de/datenschutz/', []],
#  ['https://freiberuflervermittlung.de', []],
#  ['https://hopegala.de/kontakt',
#   ['Enderstraße 94 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Enderstraße 94 2021 by HOPE-Gala',
#    'Münsterstraße 1853111 01277 Dresden']],
#  ['https://hopegala.de/impressum',
#   ['Enderstraße 94 01277 Dresden',
#    'Münsterstraße 18 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Münsterstraße 1853111 53111 Bonn',
#    'Münsterstraße 1853111 01277 Dresden',
#    'Münsterstraße 18 2021 by HOPE-Gala',
#    'Münsterstraße 18 53111 Bonn',
#    'Enderstraße 94 53111 Bonn',
#    'Enderstraße 94 2021 by HOPE-Gala']],
#  ['https://hopegala.de/datenschutz',
#   ['Enderstraße 94 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Enderstraße 94 2021 by HOPE-Gala',
#    'Münsterstraße 1853111 01277 Dresden']],
#  ['https://hopegala.de',
#   ['Münsterstraße 1853111 2023 von',
#    'Enderstraße 94 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Enderstraße 94 2023 zur',
#    'Enderstraße 94 2021 und',
#    'Münsterstraße 1853111 2023 zur',
#    'Münsterstraße 1853111 2021 und',
#    'Münsterstraße 1853111 01277 Dresden',
#    'Enderstraße 94 2023 von',
#    'Enderstraße 94 2021 by HOPE-Gala']],
#  ['https://gross-fuchs.com/contact', []],
#  ['https://gross-fuchs.com', []],
#  ['https://schuhhause.de', ['Kuhstraße 3 47918 Tönisvorst']],
#  ['https://bdia.de/impressum/',
#   ['Wilhelmine-Gemberg-Weg 6 33209 B',
#    'Bänschstr. 58 27628 Hagen im Bremischen',
#    'Bänschstr. 58 10247 Berlin',
#    'Wilhelmine-Gemberg-Weg 6 10179 Berlin',
#    'Wilhelmine-Gemberg-Weg 6 27628 Hagen im Bremischen',
#    'Bänschstr. 58 33209 B',
#    'Wilhelmine-Gemberg-Weg 6 10247 Berlin',
#    'Bänschstr. 58 10179 Berlin']],
#  ['https://bdia.de',
#   ['Wilhelmine-Gemberg-Weg 6 2024 werden über',
#    'Wilhelmine-Gemberg-Weg 6 2023 in Frankfurt am Main',
#    'Wilhelmine-Gemberg-Weg 6 10179 Berlin']],
#  ['https://infuu.de/tablet/home-office/', []],
#  ['https://infuu.de/impressum', []],
#  ['https://infuu.de', []],
#  ['https://infuu.de/notebook/home-office/', []],
#  ['https://infuu.de/kamera/home-office/', []],
#  ['https://tanztheater-hanke.de', []],
#  ['https://www.winnerbatterien.de/Privatsphaere-und-Datenschutz',
#   ['Casterfeldstr. 66-72 68199 Mannheim']],
#  ['https://winnerbatterien.de', []],
#  ['https://www.winnerbatterien.de/Impressum',
#   ['Casterfeldstr. 66-72 68199 Mannheim']],
#  ['https://winnerbatterien.de/Kontakt', []],
#  ['https://usa-amerika.com', []],
#  ['https://begehbares-glas.com/datenschutz-2/',
#   ['Rechtsgrundlage hierfür ist § 26 33659 Bielefeld',
#    'Rechtsgrundlage hierfür ist § 26 10587 Berlin',
#    'Pascalstraße 10 33659 Bielefeld',
#    'Nordfeldweg 87 33659 Bielefeld',
#    'Nordfeldweg 87 10587 Berlin',
#    'Pascalstraße 10 10587 Berlin']],
#  ['https://begehbares-glas.com/impressum/',
#   ['Nordfeldweg 87 33659 Bielefeld']],
#  ['https://begehbares-glas.com', ['Nordfeldweg 87 33659 Bielefeld']],
#  ['https://begehbares-glas.com/en/home-en/',
#   ['Nordfeldweg 87 33659 Bielefeld']],
#  ['https://begehbares-glas.com/kontakt/', ['Nordfeldweg 87 33659 Bielefeld']],
#  ['http://maessorrstructorr.com', []],
#  ['https://meinldrumfestival.com', []],
#  ['https://polizeioldtimer.de',
#   ['Cyriaxstraße 103 2020 bereits  aus über',
#    'Cyriaxstraße 103 2000 die Gründungsfeier zum',
#    'Raiffeisenstraße 1 35043 Marburg',
#    'Raiffeisenstraße 1 35037 Marburg',
#    'Cyriaxstraße 103 1990 e',
#    'Cyriaxstraße 103 35037 Marburg',
#    'Raiffeisenstraße 1 2020 bereits  aus über',
#    'Cyriaxstraße 103 35043 Marburg',
#    'Raiffeisenstraße 1 1990 e',
#    'Raiffeisenstraße 1 2000 die Gründungsfeier zum']],
#  ['https://polizeioldtimer.de/impressum-datenschutz',
#   ['Raiffeisenstr. 1 06618\xa0nach',
#    'Raiffeisenstraße 1 35043 Marburg',
#    'Raiffeisenstr. 1 1990 e',
#    'Raiffeisenstr. 1 35043 Marburg',
#    'Raiffeisenstraße 1 1990 e',
#    'Raiffeisenstraße 1 06618\xa0nach']],
#  ['https://www.skmb.de/de/home.html', []],
#  ['https://robertwilsonstiftung.com', []],
#  ['https://go-east.de/kontakt', []],
#  ['https://go-east.de/impressum',
#   ['Woyrschweg 54 22761 Hamburg',
#    'Walther-von-Cronberg-Platz 15 60594 Frankfurt am Main',
#    'Walther-von-Cronberg-Platz 15 22761 Hamburg',
#    'Woyrschweg 54 60594 Frankfurt am Main']],
#  ['https://go-east.de', []],
#  ['https://go-east.de/impressum#bildnachweis',
#   ['Woyrschweg 54 22761 Hamburg',
#    'Walther-von-Cronberg-Platz 15 60594 Frankfurt am Main',
#    'Walther-von-Cronberg-Platz 15 22761 Hamburg',
#    'Woyrschweg 54 60594 Frankfurt am Main']],
#  ['https://fogra.org', []],
#  ['https://fogra.org/impressum', ['Einsteinring 1a 85609 Aschheim b']],
#  ['https://fogra.org/kontakt', ['Einsteinring 1a 85609 Aschheim b']],
#  ['https://isdera.com', []],
#  ['https://joest-racing.de/datenschutz/',
#   ['Rechtsgrundlage hierfür ist Art. 6 66571 Eppelborn',
#    'Bahnhofstraße 34 22305 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 69483 Wald-Michelbach',
#    'Bahnhofstraße 34 69483 Wald-Michelbach',
#    'Bahnhofstraße 34 66571 Eppelborn',
#    'Bahnstr. 14 22305 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 22305 Hamburg',
#    'Bahnstr. 14 66571 Eppelborn',
#    'Bahnstr. 14 69483 Wald-Michelbach']],
#  ['https://joest-racing.de/impressum/', ['Bahnstr. 14 69483 Wald-Michelbach']],
#  ['https://joest-racing.de', []],
#  ['https://gini.net/impressum/',
#   ['Ridlerstr. 57 27001 zertifiziert', 'Ridlerstr. 57 80339 München']],
#  ['https://gini.net', []],
#  ['https://gini.net/produkte/bezahlen/pay-connect/', []],
#  ['https://gini.net/datenschutz/',
#   ['Ridlerstr. 57 48153 Münster',
#    'Marienplatz 2 80339 München',
#    'Hafenstrasse 32 80339 München',
#    'Marienplatz 2 80331 München',
#    'Hafenstrasse 32 80331 München',
#    'Hafenstrasse 32 02141 USA',
#    'Ridlerstr. 57 02141 USA',
#    'Marienplatz 2 27001 zertifiziert',
#    'Hafenstrasse 32 48153 Münster',
#    'Ridlerstr. 57 27001 zertifiziert',
#    'Marienplatz 2 02141 USA',
#    'Ridlerstr. 57 80339 München',
#    'Marienplatz 2 48153 Münster',
#    'Ridlerstr. 57 80331 München',
#    'Hafenstrasse 32 27001 zertifiziert']],
#  ['https://kamps.de', []],
#  ['https://kamps.de/datenschutz',
#   ['Rechtsgrundlage ist Art. 6 2024 Kamps GmbH',
#    'Rechtsgrundlage ist Art. 6 59000 Lille']],
#  ['https://kamps.de/impressum', []],
#  ['https://esta-pro.org', []],
#  ['https://dedeso.com/kontakt/', []],
#  ['https://dedeso.com/impressum/', []],
#  ['https://dedeso.com', []],
#  ['https://talesfromtheinside.com', []],
#  ['https://talesfromtheinside.com/contact/', []],
#  ['https://academyconsult.de/unternehmen/impressum/',
#   ['Leopoldstraße 62 80802 München',
#    'Leopoldstraße 62 2023 Academy Consult e']],
#  ['https://academyconsult.de/impressum/',
#   ['Leopoldstraße 62 80802 München',
#    'Leopoldstraße 62 2023 Academy Consult e']],
#  ['https://academyconsult.de/unternehmen/datenschutz/',
#   ['Rechtsgrundlage hierfür ist § 26 91710 Gunzenhausen',
#    'Leopoldstraße 62 91710 Gunzenhausen',
#    'Rechtsgrundlage hierfür ist Art. 6 91710 Gunzenhausen',
#    'Kalmarweg 14-5 2023 Academy Consult e',
#    'Rechtsgrundlage hierfür ist § 26 02141 USA',
#    'Rechtsgrundlage hierfür ist Art. 6 02141 USA',
#    'Industriestr. 25 80802 München',
#    'Kalmarweg 14-5 80802 München',
#    'Leopoldstraße 62 80802 München',
#    'Leopoldstraße 62 02141 USA',
#    'Kalmarweg 14-5 02141 USA',
#    'Industriestr. 25 02141 USA',
#    'Industriestr. 25 9723 JG Groningen',
#    'Kalmarweg 14-5 91710 Gunzenhausen',
#    'Rechtsgrundlage hierfür ist Art. 6 80802 München',
#    'Industriestr. 25 91710 Gunzenhausen',
#    'Industriestr. 25 2023 Academy Consult e',
#    'Leopoldstraße 62 2023 Academy Consult e',
#    'Leopoldstraße 62 9723 JG Groningen',
#    'Rechtsgrundlage hierfür ist § 26 80802 München',
#    'Kalmarweg 14-5 9723 JG Groningen']],
#  ['https://academyconsult.de', []],
#  ['https://nuvitababy.com', []],
#  ['https://solaranlagen-portal.de/infoseiten/datenschutz',
#   ['Kressengartenstraße 10 90402 Nürnberg',
#    'Kressengartenstraße 10 22763 Hamburg',
#    'Rechtsgrundlage ist Artikel 6 90402 Nürnberg',
#    'Rechtsgrundlage ist Artikel 6 22763 Hamburg']],
#  ['https://solaranlagen-portal.de/infoseiten/impressum',
#   ['Kressengartenstraße 10 90402 Nürnberg']],
#  ['https://solaranlagen-portal.de', []],
#  ['https://big-picture.com/contact.html', []],
#  ['https://big-picture.com',
#   ['Köpenicker Str. 18-20 5000 Models', 'Köpenicker Str. 18-20 10997 Berlin']],
#  ['https://helloclue.com', []],
#  ['https://skalar.marketing', []],
#  ['https://skalar.marketing/datenschutz',
#   ['Hüfferstr. 54 79098 Freiburg i',
#    'Augustinerplatz 2 79098 Freiburg i',
#    'Augustinerplatz 2 33378 Rheda-Wiedenbrück',
#    'Hüfferstr. 54 33378 Rheda-Wiedenbrück']],
#  ['https://skalar.marketing/impressum', []],
#  ['https://skalar.marketing/kontakt', []],
#  ['https://www.bioanalyt.com/impressum/', ['Rheinstraße 17 14513 Teltow']],
#  ['https://bioanalyt.com', []],
#  ['https://www.bioanalyt.com/contact/', ['Rheinstraße 17 14513 Teltow']],
#  ['https://golocal.de/kontakt/', ['Landsberger Straße 94 80339 München']],
#  ['https://golocal.de/impressum/',
#   ['Landsberger Straße 94 2024 GoLocal GmbH',
#    'Landsberger Straße 94 80339 München']],
#  ['https://golocal.de', []],
#  ['https://ammt.com', []],
#  ['https://ammt.com/contact/',
#   ['Anselm-Feuerbach-Str. 6 67227 Frankenthal',
#    'Anselm-Feuerbach-Str. 6 1345 Gwangmyeong-Si']],
#  ['https://fusionchef.de', []],
#  ['http://inbalance-yoga.net', []],
#  ['http://inbalance-yoga.net/Datenschutz.html',
#   ['Swiggerweg 1 74523 Schwäbisch Hall']],
#  ['http://inbalance-yoga.net/impressum.php',
#   ['Klingenberg 35 74523 Schwäbisch Hall']],
#  ['https://bettmer.de', []],
#  ['https://teamwire.eu/impressum/', ['Tittmoninger Strasse 11 81679 München']],
#  ['https://teamwire.eu/datenschutz/',
#   ['Hohenzollernring 54 50672 Köln',
#    'Hohenzollernring 54 2029 Stierlin Court',
#    'Köpenicker Str. 126 81679 München',
#    'Tittmoninger Strasse 11 50672 Köln',
#    'Hohenzollernring 54 6011 Wellington',
#    'Köpenicker Str. 126 1355 Market St',
#    'Köpenicker Str. 126 10179 Berlin',
#    'Hohenzollernring 54 10179 Berlin',
#    'Tittmoninger Strasse 11 94043 USA',
#    'Hohenzollernring 54 1600 Amphitheatre Parkway',
#    'Tittmoninger Strasse 11 81679 München',
#    'Tittmoninger Strasse 11 10179 Berlin',
#    'Hohenzollernring 54 1355 Market St',
#    'Tittmoninger Strasse 11 1600 Amphitheatre Parkway',
#    'Köpenicker Str. 126 94043 USA',
#    'Hohenzollernring 54 81679 München',
#    'Tittmoninger Strasse 11 6011 Wellington',
#    'Köpenicker Str. 126 1600 Amphitheatre Parkway',
#    'Köpenicker Str. 126 6011 Wellington',
#    'Tittmoninger Strasse 11 1355 Market St',
#    'Hohenzollernring 54 94043 USA',
#    'Köpenicker Str. 126 50672 Köln',
#    'Köpenicker Str. 126 2029 Stierlin Court',
#    'Tittmoninger Strasse 11 2029 Stierlin Court']],
#  ['https://teamwire.eu', []],
#  ['https://teamwire.eu/kontakt/',
#   ['Tittmoninger Strasse 11 81679 München',
#    'Tittmoninger Strasse 11 28013 Madrid',
#    'Tittmoninger Strasse 11 40219 Düsseldorf']],
#  ['https://wordifyapp.com', []],
#  ['https://realcube.com/datenschutz/',
#   ['Kurfürstendamm 21 20354 Hamburg',
#    'Stollbergstraße 22 80539 München',
#    'Grünstraße 17 80539 München',
#    'Stollbergstraße 22 20354 Hamburg',
#    'Stollbergstraße 22 10719 Berlin',
#    'Grünstraße 17 10719 Berlin',
#    'Kurfürstendamm 21 10719 Berlin',
#    'Kurfürstendamm 21 80539 München',
#    'Grünstraße 17 20354 Hamburg']],
#  ['https://realcube.com', []],
#  ['https://realcube.com/impressum/', ['Stollbergstraße 22 80539 München']],
#  ['https://partitions-musicales.net', []],
#  ['https://decaconnect.com/contact/index.html', []],
#  ['https://decaconnect.com', []],
#  ['https://frankfurt-holm.de', []],
#  ['https://frankfurt-holm.de/impressum/',
#   ['Bessie-Coleman-Straße 7 60549 Frankfurt am Main',
#    'Bessie-Coleman-Str. 7 60549 Frankfurt am Main']],
#  ['https://frankfurt-holm.de/datenschutz/',
#   ['Köpenicker Str. 126 2018 geltenden Datenschutzgrundverordnung',
#    'Solmsstraße 83 2018 geltenden Datenschutzgrundverordnung',
#    'Rechtsgrundlage hierfür ist Art. 6 10179 Berlin',
#    'Rechtsgrundlage dafür ist Art. 6 10179 Berlin',
#    'Köpenicker Str. 126 60549 Frankfurt am Main',
#    'Bessie-Coleman-Str. 7 60549 Frankfurt am Main',
#    'Bessie-Coleman-Straße 7 2018 geltenden Datenschutzgrundverordnung',
#    'Bessie-Coleman-Straße 7 60549 Frankfurt am Main',
#    'Solmsstraße 83 10179 Berlin',
#    'Bessie-Coleman-Str. 7 10179 Berlin',
#    'Rechtsgrundlage ist Art. 6 10179 Berlin',
#    'Köpenicker Str. 126 10179 Berlin',
#    'Bessie-Coleman-Straße 7 10179 Berlin',
#    'Bessie-Coleman-Str. 7 2018 geltenden Datenschutzgrundverordnung',
#    'Rechtsgrundlage ist Art. 6 2018 geltenden Datenschutzgrundverordnung',
#    'Solmsstraße 83 60486 Frankfurt am Main',
#    'Köpenicker Str. 126 60486 Frankfurt am Main',
#    'Bessie-Coleman-Str. 7 60486 Frankfurt am Main',
#    'Solmsstraße 83 60549 Frankfurt am Main',
#    'Bessie-Coleman-Straße 7 60486 Frankfurt am Main']],
#  ['https://frankfurt-holm.de/kontakt/',
#   ['Bessie-Coleman-Straße 7 60549 Frankfurt am Main']],
#  ['https://kiwi-consulting.de/datenschutz',
#   ['Haller Straße 54 74189 Weinsberg',
#    'Elgendorfer Straße 57 56410 Montabaur',
#    'Haller Straße 54 56410 Montabaur',
#    'Elgendorfer Straße 57 74189 Weinsberg']],
#  ['https://kiwi-consulting.de',
#   ['Weinsberg, 08 2023 von KIWI Consulting',
#    'Weinsberg, 01 2023 von KIWI Consulting',
#    'Weinsberg, 08 2024 von KIWI Consulting',
#    'Weinsberg, 01 2024 von KIWI Consulting',
#    'Weinsberg, 09 2024 von KIWI Consulting',
#    'Weinsberg, 09 2023 von KIWI Consulting',
#    'Weinsberg, 03 2024 von KIWI Consulting',
#    'Weinsberg, 03 2023 von KIWI Consulting']],
#  ['https://kiwi-consulting.de/impressum',
#   ['Haller Straße 54 74189 Weinsberg',
#    'Odenwaldstr. 14 69190 Walldorf',
#    'Haller Straße 54 22297 Hamburg',
#    'Haller Straße 54 69190 Walldorf',
#    'Odenwaldstr. 14 74189 Weinsberg',
#    'Odenwaldstr. 14 22297 Hamburg']],
#  ['https://schuberth.com', []],
#  ['https://quattrocelli.de/kontakt', []],
#  ['https://quattrocelli.de/impressum', []],
#  ['https://quattrocelli.de', []],
#  ['https://lisekruegerbarth.com', []],
#  ['https://sams-think-special.de/kontakt/',
#   ['Wandlhamerstraße 25 82166 Gräfelfing']],
#  ['https://sams-think-special.de', ['Wandlhamerstraße 25 82166 Gräfelfing']],
#  ['https://sams-think-special.de/datenschutz/',
#   ['Wandlhamerstraße 25 82166 Gräfelfing']],
#  ['https://frings.com/kontakt/', []],
#  ['https://frings.com', []],
#  ['https://mowaii.com/datenschutz/', []],
#  ['https://mowaii.com', []],
#  ['https://mowaii.com/impressum/', []],
#  ['https://wiverndigital.com', []],
#  ['https://aopn.com/content/7-Datenschutz',
#   ['Steinkirchring 35 1601 S',
#    'Steinkirchring 35 1601 Willow Road',
#    'Steinkirchring 35 1600 Amphitheatre Parkway',
#    'Steinkirchring 35 78056 VS-Schwenningen',
#    'Steinkirchring 35 1355 Market St']],
#  ['https://aopn.com/content/5-impressum',
#   ['Steinkirchring 35 78056 VS-Schwenningen']],
#  ['https://aopn.com', []],
#  ['https://aopn.com/kontakt', []],
#  ['https://stefanhobmaier.com', []],
#  ['https://drehmoment-gmbh.de/impressum/',
#   ['Holzmarkt 7 72070 Tübingen',
#    'Doblerstraße 14 72074 Tübingen',
#    'Doblerstraße 14 72070 Tübingen',
#    'Holzmarkt 7 72074 Tübingen']],
#  ['https://drehmoment-gmbh.de', []],
#  ['https://oezgen-senol.de/datenschutz/', ['Sonnenstr. 6 90537 Feucht']],
#  ['https://oezgen-senol.de', []],
#  ['https://oezgen-senol.de/impressum/',
#   ['Sonnenstr. 6 90537 Feucht bei Nürnberg']],
#  ['https://aesir-interactive.com', []],
#  ['https://zahlungsvereinbarung.com/kontakt/', []],
#  ['https://zahlungsvereinbarung.com', []],
#  ['https://haasehof.de/kontakt',
#   ['Lindenstraße.5 27419 Sittensen', 'Lindenstraße 5 27419 Sittensen']],
#  ['https://haasehof.de', ['Lindenstraße.5 27419 Sittensen']],
#  ['https://haasehof.de/datenschutz',
#   ['Lindenstraße.5 27419 Sittensen',
#    'Lindenstraße 5 27419 Sittensen',
#    'Lindenstraße.5 1600 Amphitheatre Parkway',
#    'Lindenstraße 5 1600 Amphitheatre Parkway']],
#  ['https://haasehof.de/impressum',
#   ['Lindenstraße.5 27419 Sittensen', 'Lindenstraße 5 27419 Sittensen']],
#  ['https://element.de/kontakt/',
#   ['Wiesenhüttenplatz 25 60329 Frankfurt am Main',
#    'Wiesenhüttenplatz 25 08523 Plauen',
#    'Wettiner Platz 10 08523 Plauen',
#    'Reichsstraße 3 60329 Frankfurt am Main',
#    'Reichsstraße 3 08523 Plauen',
#    'Wiesenhüttenplatz 25 01067 Dresden',
#    'Wettiner Platz 10 01067 Dresden',
#    'Reichsstraße 3 01067 Dresden',
#    'Wettiner Platz 10 60329 Frankfurt am Main']],
#  ['https://element.de', []],
#  ['https://element.de/datenschutz/',
#   ['Leopoldstr. 21 6011 Wellington', 'Leopoldstr. 21 80802 München']],
#  ['https://element.de/impressum/',
#   ['Wiesenhüttenplatz 25 60329 Frankfurt am Main']],
#  ['https://jazzradio.net', []],
#  ['https://jazzradio.net/kontakt/', []],
#  ['https://jazzradio.net/impressum/', ['Passauer Str. 8-9 10789 Berlin']],
#  ['https://eps-personal.org/impressum',
#   ['Werderstraße 16 78048 Villingen-Schwenningen',
#    'Nelkenstraße 36 78048 Villingen-Schwenningen',
#    'Robert-Bosch-Straße 9 71272 Renningen',
#    'Robert-Bosch-Straße 9 78048 Villingen-Schwenningen',
#    'Nelkenstraße 36 78532 Tuttlingen',
#    'Werderstraße 16 78532 Tuttlingen',
#    'Werderstraße 16 71272 Renningen',
#    'Nelkenstraße 36 71272 Renningen',
#    'Robert-Bosch-Straße 9 78532 Tuttlingen']],
#  ['https://eps-personal.org/kontakt', []],
#  ['https://eps-personal.org', []],
#  ['https://eps-personal.org/datenschutz',
#   ['Rechtsgrundlage hierfür ist Art. 6 1058 Kopenhagen',
#    'Rechtsgrundlage hierfür ist § 26 78532 Tuttlingen',
#    'Werderstraße 16 71272 Renningen',
#    'Rechtsgrundlage hierfür ist Art. 6 20354 Hamburg',
#    'Rechtsgrundlage hierfür ist § 26 71272 Renningen',
#    'Dammtorstraße 30 1058 Kopenhagen',
#    'Nelkenstraße 36 20354 Hamburg',
#    'Werderstraße 16 1058 Kopenhagen',
#    'Rechtsgrundlage hierfür ist § 26 1058 Kopenhagen',
#    'Dammtorstraße 30 78532 Tuttlingen',
#    'Rechtsgrundlage hierfür ist Art. 6 78532 Tuttlingen',
#    'Nelkenstraße 36 78532 Tuttlingen',
#    'Werderstraße 16 78532 Tuttlingen',
#    'Werderstraße 16 20354 Hamburg',
#    'Rechtsgrundlage hierfür ist § 26 20354 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 71272 Renningen',
#    'Dammtorstraße 30 71272 Renningen',
#    'Dammtorstraße 30 20354 Hamburg',
#    'Nelkenstraße 36 1058 Kopenhagen',
#    'Nelkenstraße 36 71272 Renningen']],
#  ['https://aetka.de/shop/smart-home-netzwerk/computer-switch/1052/tp-link-tl-sg105-5-port-gigabit-desktop-switch',
#   []],
#  ['https://aetka.de/shop/smart-home-netzwerk/repeater/9569/avm-fritz-repeater-1200-ax',
#   []],
#  ['https://aetka.de/shop/smart-home-netzwerk/powerline/15377/avm-fritz-powerline-1240-ax-wlan-set',
#   []],
#  ['https://aetka.de/shop/smart-home-netzwerk/computer-switch/1051/tp-link-tl-sg108-8-port-gigabit-desktop-switch',
#   []],
#  ['https://aetka.de', []],
#  ['https://aetka.de/impressum', []],
#  ['https://aetka.de/datenschutz',
#   ['Rechtsgrundlage hierfür ist Art. 6 10719 Berlin',
#    'Rechtsgrundlage ist Art. 6 10719 Berlin',
#    'Kurfürstendamm 212 10719 Berlin',
#    'Kurfürstendamm 21 10719 Berlin']],
#  ['https://aetka.de/kontakt-zu-uns', []],
#  ['https://aetka.de/shop/smart-home-netzwerk/sicherheitstechnik/15837/avm-fritz-dect-350',
#   []],
#  ['https://dkou.org', []],
#  ['https://studio-ahoi.de', []],
#  ['https://studio-ahoi.de/datenschutz/', ['Brunnenstraße 120 22763 Hamburg']],
#  ['https://studio-ahoi.de/impressum-kontakt/',
#   ['Brunnenstraße 120 22767 Hamburg']],
#  ['https://ctr-fahrzeuge.de', []],
#  ['https://ctr-fahrzeuge.de/kontakt/',
#   ['Norwegen (NO, +47 2024 CTR-Fahrzeugtechnik GmbH']],
#  ['https://ctr-fahrzeuge.de/impressum/', []],
#  ['https://ctr-fahrzeuge.de/unternehmen/datenschutz/',
#   ['Am Rosenberg 2 1601 S',
#    'Am Rosenberg 2 54518 Osann-Monzel',
#    'Am Rosenberg 2 2024 CTR-Fahrzeugtechnik GmbH',
#    'Am Rosenberg 2 1600 Amphitheatre Parkway']],
#  ['https://tophotelprojects.com', []],
#  ['https://tophotelprojects.com/contact-us/', []],
#  ['https://cliffstevens.com', []],
#  ['https://appel.de', []],
#  ['https://tobaccofreeliving.org', []],
#  ['https://hotel-badischerhof-badenbaden.de', []],
#  ['https://consulegis.com', ['Bradandstrasse 7 22297 Hamburg']],
#  ['https://consulegis.com/contact-us',
#   ['Brabandstrasse 7 20354 Hamburg', 'Poststrasse 14-16 20354 Hamburg']],
#  ['https://leagasdelaney.de/kontakt',
#   ['Elbstraße 145a 20124 Milano', 'Elbstraße 145a 22767 Hamburg']],
#  ['https://leagasdelaney.de/impressum',
#   ['Elbstraße 145a 22767\xa0Hamburg', 'Elbstraße 145a 22767 Hamburg']],
#  ['https://leagasdelaney.de',
#   ['Elbstraße 145a 2020 und',
#    'Elbstraße 145a 2021 für Gustavo Gusto',
#    'Elbstraße 145a 22767 Hamburg']],
#  ['https://cellsystems.eu', ['Junkersring 5 53844 Troisdorf']],
#  ['https://cellsystems.eu/contact/', ['Junkersring 5 53844 Troisdorf']],
#  ['https://getrental.de', []],
#  ['https://thedailyjournalist.com', []],
#  ['http://dr-estrich.com', ['Industriestraße 12 86609 Donauwörth']],
#  ['https://makers.do', ['Münzstr. 21 10178 Berlin']],
#  ['https://nature-trails-events.de', []],
#  ['https://evoloop.com', []],
#  ['https://nugzblacky.com', []],
#  ['https://mobi-test.de/impressum-haftungsausschluss/',
#   ['Poststraße 49 1601 S', 'Poststraße 49 63801 Kleinostheim']],
#  ['https://mobi-test.de/datenschutz/',
#   ['Carl-Bosch-Str. 14 63814 Mainaschaff',
#    'Carl-Bosch-Str. 14 1601 Willow Road',
#    'Carl-Bosch-Str. 14 1355 Market Street',
#    'Carl-Bosch-Str. 14 1600 Amphitheatre Parkway']],
#  ['https://mobi-test.de', []],
#  ['https://m-cube.de', []],
#  ['https://review-troll.com', []],
#  ['https://horst-busch.de/elektro-technik/kontakt/', []],
#  ['https://horst-busch.de/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/pelka-seib/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/elektro-technik/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de',
#   ['Emmy-Noether-Straße 25 25524 Itzehoe',
#    'Emmy-Noether-Straße 25 21079 Hamburg']],
#  ['https://horst-busch.de/pelka-seib/kontakt/', []],
#  ['https://horst-busch.de/alarm-und-sicherheitstechnik/kontakt/',
#   ['Emmy-Noether-Straße 25 25524 Itzehoe',
#    'Emmy-Noether-Straße 25 21079 Hamburg']],
#  ['https://viridicon.de/impressum/', []],
#  ['https://viridicon.de/kontakt/',
#   ['Präsident-Herwig-Straße 24 36119 Neuhof-Dorfborn',
#    'Präsident-Herwig-Straße 24 27472 Cuxhaven',
#    'Präsident-Herwig-Straße 24 21079 Hamburg']],
#  ['https://horst-busch.de/horst-busch-elektro-grosprojekte-gmbh/kontakt/', []],
#  ['https://horst-busch.de/datenschutz/',
#   ['Rechtsgrundlage ist Art. 6 1600 Amphitheater Parkway',
#    'Rechtsgrundlage ist Art. 6 65232 Taunusstein',
#    'Rechtsgrundlage ist Art. 6 1355 Market St',
#    'Mainstraße 6 2029 Stierlin Court',
#    'Gänsemarkt 43 21079 Hamburg',
#    'Gänsemarkt 43 1595 Spring Hill Road',
#    'Mainstraße 6 1601 S California Ave',
#    'Gänsemarkt 43 65232 Taunusstein',
#    'Gänsemarkt 43 1600 Amphitheater Parkway',
#    'Rechtsgrundlage ist Art. 6 2029 Stierlin Court',
#    'Mainstraße 6 1600 Amphitheater Parkway',
#    'Rechtsgrundlage ist Art. 6 20354 Hamburg',
#    'Gänsemarkt 43 2029 Stierlin Court',
#    'Gänsemarkt 43 1601 S California Ave',
#    'Mainstraße 6 1355 Market St',
#    'Mainstraße 6 21079 Hamburg',
#    'Mainstraße 6 20354 Hamburg',
#    'Gänsemarkt 43 1355 Market St',
#    'Rechtsgrundlage ist Art. 6 21079 Hamburg',
#    'Mainstraße 6 1595 Spring Hill Road',
#    'Mainstraße 6 65232 Taunusstein',
#    'Gänsemarkt 43 20354 Hamburg']],
#  ['https://horst-busch.de/kontakt/', []],
#  ['https://horst-busch.de/alarm-und-sicherheitstechnik/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://viridicon.de/datenschutz/', []],
#  ['https://horst-busch.de/horst-busch-elektro-grosprojekte-gmbh/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/planung-personal-technik/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/planung-personal-technik/kontakt/',
#   ['Emmy-Noether-Straße 25 25524 Itzehoe',
#    'Emmy-Noether-Straße 25 21079 Hamburg']],
#  ['https://werbemax.de/impressum', []],
#  ['https://werbemax.de/kontakt', []],
#  ['https://werbemax.de', []],
#  ['https://werbemax.de/datenschutz', []],
#  ['https://stephanieforryan.com/contact', []],
#  ['https://stephanieforryan.com', []],
#  ['https://stephanieforryan.com/home', []],
#  ['https://mitsicherheitbesser.de', []],
#  ['https://charcotfootcourses.org',
#   ['Frankenburgstr. 31 48431 Rheine',
#    'Frankenburgstr. 31 2000 Frederiksberg']],
#  ['https://elitegermanshepherds.com', []],
#  ['https://poison-berlin.com/impressum/', ['Planufer 92e 10967 Berlin']],
#  ['https://poison-berlin.com', []],
#  ['https://poison-berlin.com/kontakt/', ['Planufer 92e 10967 Berlin']],
#  ['https://poison-berlin.com/datenschutz/',
#   ['Planufer 92e 10967 Berlin',
#    'Planufer 92e 1601 S California Ave',
#    'Planufer 92e 1601 Willow Road']],
#  ['https://kulmens.de', []],
#  ['https://kulmens.de/kontakt-mode-landshut', []],
#  ['https://kulmens.de/impressum', []],
#  ['https://kulmens.de/datenschutz',
#   ['Rechtsgrundlage ist Art.\xa06 2021 KULMENS',
#    'Rechtsgrundlage ist Art.\xa06 84028 Landshut']],
#  ['https://paintballpark.de/datenschutz.html',
#   ['Hammer Straße 341 59229 Ahlen']],
#  ['https://paintballpark.de/impressum.html',
#   ['Hammer Straße 341 59229 Ahlen']],
#  ['https://paintballpark.de', []],
#  ['https://tacalyx.com', ['Magnusstr. 11 12489 Berlin']],
#  ['https://mylsp.de', ['Christinenstraße 7 40880 Ratingen']],
#  ['https://mylsp.de/kontakt/',
#   ['Christinenstr. 7-7a 40880 Ratingen', 'Christinenstraße 7 40880 Ratingen']],
#  ['https://leon-nanodrugs.com/contact/', []],
#  ['https://leon-nanodrugs.com', []],
#  ['https://ux3d.io', []],
#  ['https://junges-uno-netzwerk.de', ['Zimmermannstraße 26 10969 Berlin']],
#  ['https://flugsam.de/impressum', ['Fruchtallee 23 20259 Hamburg']],
#  ['https://flugsam.de', ['Fruchtallee 23 20259 Hamburg']],
#  ['https://proxy-studios.com', []],
#  ['https://voya.ai/kontakt/', ['Stadthausbrücke 5 20355 Hamburg']],
#  ['https://voya.ai', ['Stadthausbrücke 5 20355 Hamburg']],
#  ['https://voya.ai/datenschutz/',
#   ['Rechtsgrundlage des Art. 6 20355 Hamburg',
#    'Stadthausbrücke 5 02141 USA',
#    'Rechtsgrundlage von Art. 6 20355 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 20459 Hamburg',
#    'Rechtsgrundlage des Art. 6 20459 Hamburg',
#    'Rechtsgrundlage von Art. 6 20459 Hamburg',
#    'Rechtsgrundlage in Art. 6 20459 Hamburg',
#    'Rechtsgrundlage des Art. 6 02141 USA',
#    'Stadthausbrücke 5 20459 Hamburg',
#    'Rechtsgrundlage in Art. 6 20355 Hamburg',
#    'Stadthausbrücke 5 20355 Hamburg',
#    'Rechtsgrundlage von Art. 6 02141 USA',
#    'Rechtsgrundlage hierfür ist Art. 6 02141 USA',
#    'Rechtsgrundlage in Art. 6 02141 USA',
#    'Rechtsgrundlage hierfür ist Art. 6 20355 Hamburg']],
#  ['https://voya.ai/impressum/',
#   ['Stadthausbrücke 5 20095 Hamburg', 'Stadthausbrücke 5 20355 Hamburg']],
#  ['https://atrium2000.com', []],
#  ['https://atrium2000.com/index.php/datenschutz',
#   ['Waldstr. 22 1600 Amphitheatre Parkway',
#    'Waldstr. 22 2024 ATRIUM Invest GmbH',
#    'Waldstr. 22 1601 S',
#    'Waldstr. 22 91189 Rohr']],
#  ['https://atrium2000.com/index.php/impressum',
#   ['Oberbayern, Max-Joseph-Str. 2 91154 Roth',
#    'Waldstr. 22 91154 Roth',
#    'Waldstr. 22 91189 Rohr b',
#    'Oberbayern, Max-Joseph-Str. 2 2024 ATRIUM Invest GmbH',
#    'Weinbergweg 1 2024 ATRIUM Invest GmbH',
#    'Weinbergweg 1 91154 Roth',
#    'Nürnberg HRB 33145 80333 München',
#    'Waldstr. 22 80333 München',
#    'Weinbergweg 1 91189 Rohr b',
#    'Weinbergweg 1 80333 München',
#    'Nürnberg HRB 33145 2024 ATRIUM Invest GmbH',
#    'Waldstr. 22 2024 ATRIUM Invest GmbH',
#    'Nürnberg HRB 33145 91154 Roth',
#    'Oberbayern, Max-Joseph-Str. 2 91189 Rohr b',
#    'Oberbayern, Max-Joseph-Str. 2 80333 München',
#    'Nürnberg HRB 33145 91189 Rohr b']],
#  ['https://atrium2000.com/index.php/nehmen-sie-kontakt-auf', []],
#  ['https://software-architecture-camp.de', []],
#  ['https://software-architecture-camp.de/impressum/',
#   ['Schwedlerstr. 8 60314 Frankfurt am Main']],
#  ['https://software-architecture-camp.de/kontakt/', []],
#  ['https://software-architecture-camp.de/datenschutz/',
#   ['Schwedlerstr. 8 10117 Berlin', 'Albrechtstraße 10 10117 Berlin']],
#  ['https://fame-creativelab.com',
#   ['Vordergrund stehen. Am 27 2023 was',
#    'Vordergrund stehen. Am 27 2022 levels',
#    'Vordergrund stehen. Am 27 60314 Frankfurt',
#    'Vordergrund stehen. Am 27 1963 reichen',
#    'Landstr. 146 2023 um',
#    'Landstr. 146 60314 Frankfurt',
#    'Vordergrund stehen. Am 27 2023 in Switzerland',
#    'Landstr. 146 2022 levels',
#    'Landstr. 146 1963 reichen',
#    'Vordergrund stehen. Am 27 2023 um',
#    'Landstr. 146 2023 was',
#    'Landstr. 146 2023 in Switzerland']],
#  ['https://fame-creativelab.com/impressum/',
#   ['Burgstrasse, 27 60316 Frankfurt',
#    'Landstr. 146 60314 Frankfurt',
#    'Burgstrasse, 27 2017 fame creative lab',
#    'Burgstrasse, 27 60314 Frankfurt',
#    'Landstr. 146 60316 Frankfurt',
#    'Landstr. 146 2017 fame creative lab']],
#  ['https://fame-creativelab.com/en/home/',
#   ['Landstr. 146 60314 Frankfurt',
#    'Landstr. 146 2222 islands',
#    'Landstr. 146 2023 World Travel Awards']],
#  ['https://fame-creativelab.com/datenschutz/',
#   ['Landstr. 146 1601 S',
#    'Landstr. 146 2029 Stierlin Court',
#    'Landstr. 146 60314 Frankfurt',
#    'Gänsemarkt 43 1601 S',
#    'Landstr. 146 1600 Amphitheatre Parkway',
#    'Gänsemarkt 43 60314 Frankfurt',
#    'Gänsemarkt 43 20354 Hamburg',
#    'Landstr. 146 20354 Hamburg',
#    'Gänsemarkt 43 1600 Amphitheatre Parkway',
#    'Gänsemarkt 43 2029 Stierlin Court']],
#  ['https://mwaysolutions.com', []],
#  ['https://www.bzweic.de/impressum/',
#   ['Jesinger Straße 52 73230 Kirchheim unter Teck']],
#  ['https://www.bzweic.de/datenschutz/',
#   ['Jesinger Straße 52 1600 Amphitheatre Parkway',
#    'Jesinger Straße 52 73230 Kirchheim unter Teck',
#    'Jesinger Straße 52 94066 San Bruno']],
#  ['https://bzweic.de', []],
#  ['https://www.bzweic.de/kontakt/', []],
#  ['https://ajrwebdesign.com/impressum/', []],
#  ['https://ajrwebdesign.com/contact/', []],
#  ['https://ajrwebdesign.com', []],
#  ['https://apartment-hotel.de', []],
#  ['https://apartment-hotel.de/uebersicht/a-home-from-home.html', []],
#  ['https://apartment-hotel.de/datenschutz.html',
#   ['Ohlrattweg 5 20537 Hamburg',
#    'Ullsteinstraße 130 25497 Prisdorf',
#    'Borstelmannsweg 133 12109 Berlin',
#    'Ohlrattweg 5 1021 KP Amsterdam',
#    'Ohlrattweg 5 12109 Berlin',
#    'Ullsteinstraße 130 02494 USA',
#    'Rechtsgrundlage ist Art. 6 25497 Prisdorf',
#    'Ullsteinstraße 130 1021 KP Amsterdam',
#    'Ullsteinstraße 130 12109 Berlin',
#    'Rechtsgrundlage ist Art. 6 1021 KP Amsterdam',
#    'Borstelmannsweg 133 1021 KP Amsterdam',
#    'Borstelmannsweg 133 20537 Hamburg',
#    'Borstelmannsweg 133 25497 Prisdorf',
#    'Rechtsgrundlage ist Art. 6 12109 Berlin',
#    'Ohlrattweg 5 25497 Prisdorf',
#    'Ohlrattweg 5 02494 USA',
#    'Rechtsgrundlage ist Art. 6 20537 Hamburg',
#    'Rechtsgrundlage ist Art. 6 02494 USA',
#    'Ullsteinstraße 130 20537 Hamburg',
#    'Borstelmannsweg 133 02494 USA']],
#  ['https://apartment-hotel.de/impressum.html',
#   ['Borstelmannsweg 133 20537 Hamburg']],
#  ['https://apartment-hotel.de/kontakt.html',
#   ['Borstelmannsweg 133 20537 Hamburg']],
#  ['https://www.klingel-group.com/impressum/',
#   ['Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://klingel-med.de',
#   ['Hanauer Straße 6 1500 Mitarbeitern an',
#    'Hanauer Straße 6 75181 Pforzheim',
#    'Hanauer Straße 7 75181 Pforzheim',
#    'Hanauer Straße 7 1500 Mitarbeitern an',
#    'Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://www.klingel-group.com/kontakt/',
#   ['Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://www.klingel-group.com/datenschutz/',
#   ['Baden-Württemberg, Postfach 10 1500 Mitarbeitern an',
#    'Baden-Württemberg, Postfach 10 70025 Stuttgart',
#    'Baden-Württemberg, Postfach 10 75181 Pforzheim',
#    'Hanauer Straße 5-7 70025 Stuttgart',
#    'Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://connectivisten.de/datenschutz',
#   ['Westhafenplatz 1 60327 Frankfurt am Main',
#    'Berliner Allee 47 64295 Darmstadt',
#    'Berliner Allee 47 60327 Frankfurt am Main',
#    'Westhafenplatz 1 64295 Darmstadt']],
#  ['https://connectivisten.de/impressum',
#   ['Westhafenplatz 1 60327 Frankfurt am Main',
#    'Berliner Allee 47 64295 Darmstadt',
#    'Berliner Allee 47 60327 Frankfurt am Main',
#    'Westhafenplatz 1 64295 Darmstadt']],
#  ['https://connectivisten.de',
#   ['Westhafenplatz 1 60327 Frankfurt am Main',
#    'Berliner Allee 47 64295 Darmstadt',
#    'Berliner Allee 47 60327 Frankfurt am Main',
#    'Westhafenplatz 1 64295 Darmstadt']],
#  ['https://venista-ventures.com', []],
#  ['https://geco-event.com',
#   ['Scheuermann stiegen 2009 68199 Mannheim',
#    'Kiesteichweg 21 68199 Mannheim']],
#  ['https://geco-event.com/impressum.html', ['Kiesteichweg 21 68199 Mannheim']],
#  ['https://fs-etit.de/impressum-forum/',
#   ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['https://fs-etit.de', ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['https://fs-etit.de/impressum/',
#   ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['https://fs-etit.de/datenschutz-verein/',
#   ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['http://private-arbeitsagentur.eu', ['Zeughausgasse 4 91154 Roth']],
#  ['https://purchaze.com/en/contact.html', []],
#  ['https://purchaze.com', []],
#  ['https://hausambergshepherds.com', []],
#  ['https://hausambergshepherds.com/contact/', []],
#  ['https://kellerkommando.de', []],
#  ['https://zeninvest.de/impressum/',
#   ['Oberneuhofstrasse 1 2023 ZenInvest', 'Oberneuhofstrasse 1 6340 Baar']],
#  ['https://zeninvest.de', []],
#  ['https://poggemoeller.co', []],
#  ['https://corporate-karma.de', []],
#  ['https://corporate-karma.de/kontakt/', []],
#  ['https://laokoongruppe.com/kontakt/', []],
#  ['https://laokoongruppe.com/impressum/',
#   ['Schwamberger/Volkergasse 4 1150 Wien']],
#  ['https://laokoongruppe.com', []],
#  ['https://wrestleking.de', []],
#  ['https://weigelworld.org', []],
#  ['https://apo-buy.com', []],
#  ['https://quartier-theater.de/datenschutz', []],
#  ['https://quartier-theater.de/kontakt', ['Kornstraße 31 30167 Hannover']],
#  ['https://quartier-theater.de', []],
#  ['https://quartier-theater.de/impressum', ['Kornstraße 31 30167 Hannover']],
#  ['https://postuning.com/contact/#phone', []],
#  ['https://postuning.com', []],
#  ['https://postuning.com/contact/', []],
#  ['https://postuning.com/contact/#mail', []],
#  ['https://simple-fax.de/impressum',
#   ['Salzdahlumer Str. 196 2024 simple-fax',
#    'Salzdahlumer Str. 196 38126 Braunschweig']],
#  ['https://simple-fax.de/kontakt', []],
#  ['https://simple-fax.de', []],
#  ['https://b-s.de', []],
#  ['https://frents.com', []],
#  ['https://start-online-therapie.de', []],
#  ['https://global-mobility.com', []],
#  ['https://sternen-schluchsee.de/kontakt/', []],
#  ['https://sternen-schluchsee.de/datenschutz/',
#   ['Talstraße 126 79194 Gundelfingen']],
#  ['https://sternen-schluchsee.de/impressum/',
#   ['Stadtstraße 2 10900 Berlin', 'Stadtstraße 2 79104 Freiburg']],
#  ['https://sternen-schluchsee.de', []],
#  ['https://cinepostproduction.de/contact/',
#   ['Ringbahnstraße 16 2023 CinePostproduction GmbH',
#    'Beta-Straße 1 85774 Unterföhring',
#    'Beta-Straße 1 2023 CinePostproduction GmbH',
#    'Beta-Straße 1 12099 Berlin',
#    'Ringbahnstraße 16 12099 Berlin',
#    'Ringbahnstraße 16 85774 Unterföhring']],
#  ['https://cinepostproduction.de/datenschutz/',
#   ['Beta-Straße 1 85774 Unterföhring',
#    'Beta-Straße 1 1600 Amphitheatre Parkway',
#    'Beta-Straße 1 2023 CinePostproduction GmbH']],
#  ['https://cinepostproduction.de', []],
#  ['https://neu.cinepost.de/impressum/',
#   ['Beta-Straße 1 85774 Unterföhring',
#    'Beta-Straße 1 2023 CinePostproduction GmbH']],
#  ['https://kreutzer-consulting.com/impressum.html',
#   ['Lindwurmstr. 109 80337 München']],
#  ['https://kreutzer-consulting.com/kontakt.html',
#   ['Lindwurmstr. 109 80337 München']],
#  ['https://kreutzer-consulting.com', ['Lindwurmstr. 109 80337 München']],
#  ['https://isystems-integration.com', []],
#  ['https://isystems-integration.com/contact/', []],
#  ['https://monocrom.de', []],
#  ['https://lysicom.de', []],
#  ['https://mooc-beratung.de/impressum/',
#   ['Schmilinskystraße 45 20099 Hamburg']],
#  ['https://mooc-beratung.de', []],
#  ['https://mooc-beratung.de/kontakt/', ['Schmilinskystr. 45 20099 Hamburg']],
#  ['https://hirschen.com/impressum/', ['Schlesische Straße 26 10997 Berlin']],
#  ['https://hirschen.com', []],
#  ['https://hirschen.com/kontakt/', []],
#  ['http://hochseilgarten-neutraubling.net', []],
#  ['https://studdex.com', []],
#  ['https://phrase.com', []],
#  ['https://phrase.com/contact/', []],
#  ['https://honeymoments.de/datenschutz/',
#   ['Atoomweg 6 20457\xa0Hamburg',
#    'Eichhornstraße 3 20457\xa0Hamburg',
#    'Eichhornstraße 3 10785 Berlin',
#    'Rosenfelder Str. 15-16 20459 Hamburg',
#    'Rosenfelder Str. 15-16 9743 AK Groningen',
#    'Rosenfelder Str. 15-16 10315 Berlin',
#    'Eichhornstraße 3 2338 Luxemburg',
#    'Rosenfelder Str. 15-16 10785 Berlin',
#    'Atoomweg 6 1600 Amphitheatre Parkway',
#    'Rosenfelder Str. 15-16 20457\xa0Hamburg',
#    'Atoomweg 6 2338 Luxemburg',
#    'Atoomweg 6 9743 AK Groningen',
#    'Rosenfelder Str. 15-16 2338 Luxemburg',
#    'Eichhornstraße 3 1600 Amphitheatre Parkway',
#    'Eichhornstraße 3 20459 Hamburg',
#    'Atoomweg 6 10315 Berlin',
#    'Eichhornstraße 3 10315 Berlin',
#    'Eichhornstraße 3 9743 AK Groningen',
#    'Atoomweg 6 20459 Hamburg',
#    'Atoomweg 6 10785 Berlin',
#    'Rosenfelder Str. 15-16 1600 Amphitheatre Parkway']],
#  ['https://honeymoments.de', []],
#  ['https://honeymoments.de/impressum/',
#   ['Rathausallee 72-76 22846 Norderstedt',
#    'Rathausallee 72-76 20457 Hamburg']],
#  ['https://wedding-youandme.com', []],
#  ['https://wedding-youandme.com/kontakt/', []],
#  ['https://nandurion.de', []],
#  ['https://nandurion.de/impressum-nach-%c2%a75-tmg/', []],
#  ['http://4dgo.de/contact.shtml', []],
#  ['http://4dgo.de/impressum.shtml', []],
#  ['http://4dgo.de/datenschutz.shtml', []],
#  ['http://4dgo.de', []],
#  ['https://plu.de/blog/let-s-connect-around-the-globe-with-tain',
#   ['Landsberger Straße 392 81241 München']],
#  ['https://plu.de/kontakt',
#   ['Grafenberger Allee 277-287 40237 Düsseldorf',
#    'Grafenberger Allee 277-287 81241 München',
#    'Heilbronner Strasse 150 10557 Berlin',
#    'Landsberger Straße 392 81241 München',
#    'Poststraße 2-4 20095 Hamburg',
#    'Poststraße 2-4 40237 Düsseldorf',
#    'Heilbronner Strasse 150 60329 Frankfurt a',
#    'Grafenberger Allee 277-287 20095 Hamburg',
#    'Bertha-Benz-Straße 5 60329 Frankfurt a',
#    'Bertha-Benz-Straße 5 40237 Düsseldorf',
#    'Landsberger Straße 392 40237 Düsseldorf',
#    'Poststraße 2-4 60329 Frankfurt a',
#    'Grafenberger Allee 277-287 60329 Frankfurt a',
#    'Landsberger Straße 392 10557 Berlin',
#    'Poststraße 2-4 10557 Berlin',
#    'Heilbronner Strasse 150 40237 Düsseldorf',
#    'Heilbronner Strasse 150 81241 München',
#    'Poststraße 2-4 81241 München',
#    'Grafenberger Allee 277-287 10557 Berlin',
#    'Heilbronner Strasse 150 20095 Hamburg',
#    'Landsberger Straße 392 60329 Frankfurt a',
#    'Bertha-Benz-Straße 5 10557 Berlin',
#    'Landsberger Straße 392 20095 Hamburg',
#    'Bertha-Benz-Straße 5 20095 Hamburg',
#    'Bertha-Benz-Straße 5 81241 München']],
#  ['https://plu.de/impressum', ['Landsberger Straße 392 81241 München']],
#  ['https://plu.de', ['Landsberger Straße 392 81241 München']],
#  ['https://plu.de/datenschutz', ['Landsberger Straße 392 81241 München']],
#  ['https://statt-theater.net', []],
#  ['https://statt-theater.net/kontakt/', []],
#  ['https://statt-theater.net/kontakt/presse/', []],
#  ['https://statt-theater.net/kontakt/impressum/',
#   ['Lange Straße 14 2017 Fehldiagnose',
#    'Lange Straße 14 2017 Räuber Hotzenplotz',
#    'Lange Straße 14 34454 Bad Arolsen-Mengeringhausen',
#    'Lange Straße 14 2022 Taxi Taxi',
#    'Lange Straße 14 2023 Das Oslo-Syndrom',
#    'Lange Straße 14 2023 Das kalte Herz',
#    'Lange Straße 14 2018 Aufguss',
#    'Lange Straße 14 2019 Stumm',
#    'Lange Straße 14 2019 Die Feuerzangenbowle',
#    'Lange Straße 14 2019 Jubiläum',
#    'Lange Straße 14 2017 Sebastian Sternenputtzer',
#    'Lange Straße 14 2021 Jakobs-Wunder-Abend',
#    'Lange Straße 14 2018 Ein Jedermann']],
#  ['https://www.nexworld.tv/nexworldtv/datenschutz/',
#   ['Altostr. 25f 82319 Starnberg']],
#  ['https://nexworld.tv', []],
#  ['https://www.nexworld.tv/nexworldtv/impressum/',
#   ['Altostr. 25f 10117 Berlin',
#    'Reinhardtstr.52 10117 Berlin',
#    'Reinhardtstr.52 83219 Starnberg',
#    'Altostr. 25f 83219 Starnberg']],
#  ['https://lcs-schlieben.de/impressum',
#   ['Gartenstraße 45 04936 Schlieben', 'Gartenstr.45 04936 Schlieben']],
#  ['https://lcs-schlieben.de', []],
#  ['https://lcs-schlieben.de/kontakt', ['Gartenstraße 45 04936 Schlieben']],
#  ['https://semprebonita.de', []],
#  ['https://semprebonita.de/kontakt/', []],
#  ['https://pferdebild.de/kontakt/', ['Heider Weg 42 27777 Ganderkesee']],
#  ['https://pferdebild.de',
#   ['Heider Weg 42 27777 Ganderkesee',
#    'Heider Weg 42 2000 digital fotografiert',
#    'Heider Weg 42 1968 bis Hongkong']],
#  ['https://pferdebild.de/impressum/',
#   ['Heider Weg 42 27777 Ganderkesee', 'Heider Weg 42 77694 Kehl am Rhein']],
#  ['https://p-21.de', []],
#  ['https://printus.de', []],
#  ['https://berlinlofts.com/en/impressum',
#   ['Stephanstraße 60 2024 berlinlofts', 'Stephanstraße 60 10559 Berlin']],
#  None,
#  ['https://berlinlofts.com', []],
#  ['https://bowlers-inn.de', []],
#  ['https://microdoc.com', ['Elektrastraße 6a 81925 Munich']],
#  ['https://microdoc.com/contact/',
#   ['Elektrastrasse 6 10115 Berlin',
#    'Elektrastrasse 6 70469 Stuttgart Germany',
#    'Elektrastrasse 6 81925 Munich',
#    'Novalisstrasse 12 81925 Munich',
#    'Elektrastraße 6a 10115 Berlin',
#    'Elektrastraße 6a 81925 Munich',
#    'Bludenzer Str. 6 81925 Munich',
#    'Elektrastraße 6a 70469 Stuttgart Germany',
#    'Novalisstrasse 12 10115 Berlin',
#    'Bludenzer Str. 6 70469 Stuttgart Germany',
#    'Novalisstrasse 12 70469 Stuttgart Germany',
#    'Bludenzer Str. 6 10115 Berlin']],
#  ['https://pia.me', []],
#  ['https://prostinternational.com/contact-us-writers/', []],
#  ['https://prostinternational.com', []],
#  ['https://trelock.de/de/kontakt',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de/de/schloss/schloesser/rahmenschloesser/protect-o-connect-kabel',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de/de/schloss/schloesser/rahmenschloesser/protect-o-connect-ketten',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de/de/impressum',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://prosanova.net', []],
#  ['https://schmeckthal-gruppe.de/datenschutz/',
#   ['I-Gebiet Weidenbusch · Boschring 7 55252 Mainz-Kastel',
#    'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel',
#    'Waldring 43 56422 Wirges',
#    'Waldring 43 44789 Bochum',
#    'Fritz-Ullmann-Straße 4 56422 Wirges',
#    'I-Gebiet Weidenbusch · Boschring 7 44789 Bochum',
#    'Fritz-Ullmann-Straße 4 44789 Bochum',
#    'Waldring 43 55252 Mainz-Kastel',
#    'I-Gebiet Weidenbusch · Boschring 7 56422 Wirges']],
#  ['https://schmeckthal-gruppe.de/impressum/',
#   ['Boschring 7 56422 Wirges',
#    'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel',
#    'Boschring 7 55252 Mainz-Kastel',
#    'Fritz-Ullmann-Straße 4 56422 Wirges']],
#  ['https://schmeckthal-gruppe.de',
#   ['Boschring 7 56422 Wirges',
#    'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel',
#    'Boschring 7 55252 Mainz-Kastel',
#    'Fritz-Ullmann-Straße 4 56422 Wirges']],
#  ['https://airnergy.shop/info/mein-kontakt.html',
#   ['Wehrstraße 24-26 53773 Hennef']],
#  ['https://airnergy.shop/info/impressum.html',
#   ['Wehrstr. 24-26 1601 S',
#    'Wehrstraße 24-26 1601 S',
#    'Wehrstraße 24-26 2011 by Airnergy International GmbH',
#    'Wehrstr. 24-26 53773 Hennef',
#    'Wehrstr. 24-26 2011 by Airnergy International GmbH',
#    'Wehrstraße 24-26 53773 Hennef']],
#  ['https://airnergy.shop',
#   ['Wehrstraße 24-26 93300 an',
#    'Wehrstraße 24-26 2022 mit verbesserten Duokats',
#    'Wehrstraße 24-26 53773 Hennef']],
#  ['https://airnergy.shop/info/privatsphaere-und-datenschutz.html',
#   ['Wehrstraße 24-26 53773 Hennef Telefon',
#    'Wehrstraße 24-26 2029 Stierlin Court',
#    'Dammtorstraße 29-32 1600 Amphitheatre Parkway',
#    'Wehrstraße 24-26 1600 Amphitheatre Parkway',
#    'Wehrstr. 26 53773 Hennef Telefon',
#    'Wehrstraße 24-26 53773 Hennef',
#    'Wehrstr. 26 2029 Stierlin Court',
#    'Dammtorstraße 29-32 53773 Hennef Telefon',
#    'Dammtorstraße 29-32 53773 Hennef',
#    'Wehrstr. 26 1355 Market Street',
#    'Wehrstr. 26 1601 Willow Road',
#    'Wehrstr. 26 20354 Hamburg',
#    'Wehrstr. 26 53773 Hennef',
#    'Wehrstr. 26 1600 Amphitheatre Parkway',
#    'Dammtorstraße 29-32 20354 Hamburg',
#    'Dammtorstraße 29-32 2029 Stierlin Court',
#    'Wehrstraße 24-26 1355 Market Street',
#    'Dammtorstraße 29-32 1355 Market Street',
#    'Dammtorstraße 29-32 1601 Willow Road',
#    'Wehrstraße 24-26 1601 Willow Road',
# ...
#    'Kantstraße 99 10627 Berlin',
#    'Lise-Meitner-Straße 6 28359 Bremen',
#    'Kantstraße 99 28359 Bremen']],
#  ['https://mekos.de', []],
#  ['https://mekos.de/datenschutz/', ['Lise-Meitner-Str. 6 28359 Bremen']],
#  ['https://www.businesswire.com/news/home/20230522005734/en/Peru-wins-gold-at-Chinese-Tourism-Welcome-Award-2023',
#   []],
#  ['https://knnit.com/global-travel-tourism-market-to-reach-us-13566-4-bn-by-2027/?__cf_chl_jschl_tk__=2a959e7dc533b33296100647ff415099ee3ee2fc-1622015105-0-AUlPvT7A5GL3-O8slLeusUYRBWuxGxKbQ8Y4gYPPxJzZKb0D89E972RbCtR5TJ3C3_7TjTlIi5NDN9GwLTvsebiP2xzywjK9GFb8b4RqhKHMRH1MGO0QHkEG3zsCAUYCNWrRamxK4pTCt3gTZgvgcDXvKWevBI5v5ABU2fW0xLpkiRYYV2ZyPF0kFKiEjOfj4G0Yj2vVt_mLn_6D6hqQiX0BH7p5-Eh378XA_JjOo3ntz8CSHGDtZJKkGqg6t-3h-UhszMs0vUlI-8oM2o6xh7BHVn4l2gOAqITnSrNh51EZ6ANsls3vlhqmNxquVWfvfsOOYqz9LaiuXof1-GKXT-nscO02-7zOcTdfgeCPtZCDMLRxdS1XG_AeVO3ONqwI4gWWWwvyH3G2ujLp9bjsz6J8t_GFE4j4c0JSEet6UlGt8mvdXANQvfVTU96ONXORO9pAC85RyC5fqvpSAUKCNQd6E2nLHExoSkdgklrGQjGA',
#   []],
#  ['https://china-outbound.com',
#   ['Gluckstr. 57 2016 COTRI moves to Hamburg',
#    'Gluckstr. 57 2002 PhD',
#    'Gluckstr. 57 2023 and beyond',
#    'Gluckstr. 57 2023 Start COTMI weekly publication',
#    'Gluckstr. 57 2023 Restart China outbound tourism',
#    'Gluckstr. 57 1978 First visit of Prof',
#    'Gluckstr. 57 22081 Hamburg',
#    'Gluckstr. 57 2008 COTRI moves to Heide',
#    'Gluckstr. 57 1957 in West-Berlin']],
#  ['https://openwallsgallery.com', []],
#  ['https://das-comitee.com/kontakt/',
#   ['Oberaltenallee 20 22081 Hamburg', 'Oberaltenallee 20 20457 Hamburg']],
#  ['https://das-comitee.com', []],
#  ['https://das-comitee.com/impressum/',
#   ['Thadenstrasse 134 07819 Nuestra Sra', 'Thadenstrasse 134 22767 Hamburg']],
#  ['http://altec-cs.com/assets/Datenschutz.pdf', []],
#  ['http://altec-cs.com', []],
#  ['http://altec-cs.com/assets/datenschutz.pdf', []],
#  ['http://altec-cs.com/Impressum', ['Bayernstraße 10 30855 Langenhagen']],
#  ['http://altec-cs.com/Kontakt', ['Bayernstraße 10 30855 Langenhagen']],
#  ['https://www.scoop-yard.de/impressum/',
#   ['Hoheluftchaussee 40 20253 Hamburg']],
#  ['https://scoop-yard.de',
#   ['Turnringen, Girevoy (Wettkampf-Kettlebells), Concept2 20253 Hamburg',
#    'Hoheluftchaussee 40 20253 Hamburg']],
#  ['https://www.scoop-yard.de/kontakt/',
#   ['Hoheluftbrücke\xa0+ 6 20253 Hamburg',
#    'Hoheluftchaussee 40 20253 Hamburg',
#    'Hoheluftbrücke\xa0+ 5 20253 Hamburg',
#    'Eppendorfer Weg (Ost)\xa0+ 4 20253 Hamburg']],
#  ['https://www.scoop-yard.de/datenschutz/',
#   ['Dammtorstraße 29-32 20354 Hamburg',
#    'Rechtsgrundlage der Verarbeitung Art. 6 20354 Hamburg',
#    'Rechtsgrundlage der Verarbeitung Art. 6 20253 Hamburg',
#    'Dammtorstraße 29-32 1355 Market Street',
#    'Hoheluftchaussee 40 20354 Hamburg',
#    'Hoheluftchaussee 40 1601 Willow Road',
#    'Dammtorstraße 29-32 1601 Willow Road',
#    'Hoheluftchaussee 40 20253 Hamburg',
#    'Hoheluftchaussee 40 1355 Market Street',
#    'Rechtsgrundlage dieser Verarbeitung Art. 6 20253 Hamburg',
#    'Rechtsgrundlage dieser Verarbeitung Art. 6 20354 Hamburg',
#    'Dammtorstraße 29-32 20253 Hamburg']],
#  ['https://danhills.de', []],
#  ['https://drk-rhein-nahe.de/impressum/',
#   ['Binger Straße 25 2024 aktualisiert']],
#  ['https://drk-rhein-nahe.de/kontakt/anregungen-und-kritik/', []],
#  ['https://drk-rhein-nahe.de', []],
#  ['https://drk-rhein-nahe.de/kontakt/medizinproduktesicherheit/', []],
#  ['https://drk-rhein-nahe.de/kontakt/ansprechpartner/', []],
#  ['https://drk-rhein-nahe.de/kontakt/', []],
#  ['https://drk-rhein-nahe.de/kontakt/anfahrtshinweis/',
#   ['Hauptbahnhofs ist nur 500m 55131 Mainz', 'Binger Straße 25 55131 Mainz']],
#  ['https://drk-rhein-nahe.de/kontakt/kontaktformular/', []],
#  ['https://rheinruhronline.de/impressum.htm', []],
#  ['https://rheinruhronline.de', []],
#  ['https://rheinruhronline.de/datenschutz.htm', []],
#  ['https://rheinruhronline.de/kontakt.php', []],
#  ['https://flyair41.de', []],
#  ['https://flyair41.de/contact/contact.html', []],
#  ['https://jur.solutions/impressum', []],
#  ['https://jur.solutions', []],
#  ['https://mester.de', []],
#  ['https://mester.de/impressum/',
#   ['Königinstraße 28 33609 Bielefeld',
#    'Königinstraße 28 33613 Bielefeld',
#    'Königinstraße 28 80802 München',
#    'Königinstraße 28 2024 Mester']],
#  ['https://xell-consulting.de/impressum',
#   ['Seegarten 44 97297 Waldbüttelbrunn']],
#  ['https://xell-consulting.de', []],
#  ['https://agbf.com/de/kontakt', ['Seehofstr. 15 14169 Berlin']],
#  ['https://agbf.com', ['Seehofstr. 15 14169 Berlin']],
#  ['https://agbf.com/en/contact', ['Seehofstr. 15 14169 Berlin']],
#  ['https://agbf.com/de/impressum', ['Seehofstr. 15 14169 Berlin']],
#  ['https://starface.com/kontakt/', ['Adlerstraße 61 76137 Karlsruhe']],
#  ['https://starface.com/produktwelt/connect-sip-trunk/',
#   ['Adlerstraße 61 76137 Karlsruhe']],
#  ['https://starface.com', ['Adlerstraße 61 76137 Karlsruhe']],
#  ['https://starface.com/impressum/',
#   ['Adlerstraße 61 2489 Berlin',
#    'Sandner Straße 3 76137 Karlsruhe',
#    'Max-Planck-Straße 3 1100 Wien',
#    'Zimmerstraße 6 76137\xa0Karlsruhe',
#    'Max-Planck-Straße 3 76137 Karlsruhe',
#    'Zimmerstraße 6 2489 Berlin',
#    'Sandner Straße 3 1100 Wien',
#    'Max-Planck-Straße 3 76137\xa0Karlsruhe',
#    'Adlerstraße 61 76137\xa0Karlsruhe',
#    'Sandner Straße 3 76137\xa0Karlsruhe',
#    'Sandner Straße 3 2489 Berlin',
#    'Adlerstraße 61 76137 Karlsruhe',
#    'Adlerstraße 61 1100 Wien',
#    'Zimmerstraße 6 76137 Karlsruhe',
#    'Max-Planck-Straße 3 2489 Berlin',
#    'Zimmerstraße 6 1100 Wien']],
#  ['https://fgk-cro.com/contact-de-com', ['Heimeranstrasse 35 80339 Munich']],
#  ['https://fgk-cro.com', ['Heimeranstrasse 35 80339 Munich']],
#  ['https://fgk-cro.com/about-us/locations-contact',
#   ['Friedrichstraße 95 1027 Budapest',
#    'Friedrichstraße 95 80339 Munich',
#    'Heimeranstrasse 35 80339 Munich',
#    'Friedrichstraße 95 10117 Berlin',
#    'Heimeranstrasse 35 1027 Budapest',
#    'Heimeranstrasse 35 10117 Berlin']],
#  ['https://beds24.com', []],
#  ['https://beds24.com/impressum.html', ['Davoser Str. 1g 14199 Berlin']],
#  ['https://agenturhuette.de', []],
#  None,
#  ['https://imiconsulting.com/contact/', []],
#  ['https://junge-presse.de/datenschutz/',
#   ['Frankenstraße 185 45134 Essen',
#    'Frankenstraße 185 1600 Amphitheatre Parkway']],
#  ['https://junge-presse.de/kontakt/impressum/',
#   ['Frankenstraße 185 45134 Essen']],
#  ['https://junge-presse.de', []],
#  ['https://subsiege-game.com', []],
#  ['https://raeume-zum-feiern.de/kontakt.html', []],
#  ['https://raeume-zum-feiern.de/impressum.html',
#   ['Am Staudamm 24 02906 Quitzdorf am See']],
#  ['https://raeume-zum-feiern.de', []],
#  ['https://raeume-zum-feiern.de/datenschutz.html',
#   ['Am Staudamm 24 91710 Gunzenhausen',
#    'Am Staudamm 24 02906 Quitzdorf am See',
#    'Industriestr. 25 94043 USA',
#    'Am Staudamm 24 1600 Amphitheatre Parkway',
#    'Am Staudamm 24 94043 USA',
#    'Industriestr. 25 1600 Amphitheatre Parkway',
#    'Industriestr. 25 91710 Gunzenhausen',
#    'Industriestr. 25 02906 Quitzdorf am See']],
#  ['https://cupcino.com/kontakt/', ['Paderborner Straße 33 33161 Hövelhof']],
#  ['https://cupcino.com/datenschutz/',
#   ['Pamplonastraße 19 30539 Hannover',
#    'Pamplonastraße 19 33106 Paderborn',
#    'Dammtorstraße 30 1601 Willow Road',
#    'Dammtorstraße 30 01801 USA',
#    'Paderborner Straße 33 40213 Düsseldorf',
#    'Paderborner Straße 33 20354 Hamburg',
#    'Kavalleriestraße 2-4 40213 Düsseldorf',
#    'Kavalleriestraße 2-4 33106 Paderborn',
#    'Kavalleriestraße 2-4 30539 Hannover',
#    'Pamplonastraße 19 33161 Hövelhof',
#    'Dammtorstraße 30 30539 Hannover',
#    'Dammtorstraße 30 33106 Paderborn',
#    'Paderborner Straße 33 01801 USA',
#    'Pamplonastraße 19 20354 Hamburg',
#    'Kavalleriestraße 2-4 1601 Willow Road',
#    'Dammtorstraße 30 33161 Hövelhof',
#    'Pamplonastraße 19 1601 Willow Road',
#    'Pamplonastraße 19 01801 USA',
#    'Kavalleriestraße 2-4 01801 USA',
#    'Paderborner Straße 33 30539 Hannover',
#    'Dammtorstraße 30 40213 Düsseldorf',
#    'Paderborner Straße 33 33106 Paderborn',
#    'Kavalleriestraße 2-4 20354 Hamburg',
#    'Paderborner Straße 33 1601 Willow Road',
#    'Pamplonastraße 19 40213 Düsseldorf',
#    'Paderborner Straße 33 33161 Hövelhof',
#    'Dammtorstraße 30 20354 Hamburg',
#    'Kavalleriestraße 2-4 33161 Hövelhof']],
#  ['https://cupcino.com/impressum/', ['Paderborner Straße 33 33161 Hövelhof']],
#  ['https://cupcino.com', []],
#  ['https://metalized.de', []],
#  ['https://pulscamp.de', ['Kaskelstr. 53 10317 Berlin']],
#  ['https://pulscamp.de/impressum', ['Kaskelstraße 53 10317 Berlin']],
#  ['https://a-maze.net', ['Brunnenstr. 153 10115 Berlin']],
#  ['https://vsda.de/impressum/',
#   ['Zimmermannweg 28 64285 Darmstadt',
#    'Bessunger Str. 5 64285 Darmstadt',
#    'Zimmermannweg 28 64289 Darmstadt',
#    'Bessunger Str. 5 64289 Darmstadt']],
#  ['https://vsda.de/datenschutz/',
#   ['Rechtsgrundlagen: Einwilligung (Art. 6 64289 Darmstadt',
#    'Zimmermannweg 28 64289 Darmstadt']],
#  ['https://vsda.de/kontakt/', ['Zimmermannweg 28 64289 Darmstadt']],
#  ['https://vsda.de', []],
#  ['https://spindash.de/impressum', ['Baselstrasse 47 6003 Luzern']],
#  ['https://spindash.de', []],
#  ['https://unwomen.de/datenschutz/',
#   ['Anklamer Straße 38 53115 Bonn',
#    'Anklamer Straße 38 10115 Berlin',
#    'Rechtsgrundlage ist Art. 6 86150 Augsburg',
#    'Schießgrabenstr. 32 86150 Augsburg',
#    'Wittelsbacherring 9 2449 Luxemburg',
#    'Schießgrabenstr. 32 1601 S',
#    'Anklamer Straße 38 1601 S',
#    'Konrad-Adenauer-Ufer 85 1355 Market St',
#    'Rechtsgrundlage ist Art. 6 1600 Amphitheatre Parkway',
#    'Wittelsbacherring 9 10115 Berlin',
#    'Konrad-Adenauer-Ufer 85 1601 Willow Road',
#    'Rechtsgrundlage ist Art. 6 1601 Willow Road',
#    'Wittelsbacherring 9 1600 Amphitheatre Parkway',
#    'Wittelsbacherring 9 1601 S',
#    'Konrad-Adenauer-Ufer 85 80339 München',
#    'Anklamer Straße 38 1601 Willow Road',
#    'Rechtsgrundlage ist Art. 6 1355 Market St',
#    'Rechtsgrundlage ist Art. 6 1601 S',
#    'Schießgrabenstr. 32 1601 Willow Road',
#    'Konrad-Adenauer-Ufer 85 1600 Amphitheatre Parkway',
#    'Schießgrabenstr. 32 80339 München',
#    'Wittelsbacherring 9 1355 Market St',
#    'Konrad-Adenauer-Ufer 85 50668 Köln',
#    'Anklamer Straße 38 1600 Amphitheatre Parkway',
#    'Konrad-Adenauer-Ufer 85 86150 Augsburg',
#    'Rechtsgrundlage ist Art. 6 50668 Köln',
#    'Wittelsbacherring 9 53115 Bonn',
#    'Konrad-Adenauer-Ufer 85 2449 Luxemburg',
#    'Konrad-Adenauer-Ufer 85 1601 S',
#    'Anklamer Straße 38 2449 Luxemburg',
#    'Anklamer Straße 38 80339 München',
#    'Schießgrabenstr. 32 50668 Köln',
#    'Rechtsgrundlage ist Art. 6 53115 Bonn',
#    'Rechtsgrundlage ist Art. 6 10115 Berlin',
#    'Anklamer Straße 38 50668 Köln',
#    'Wittelsbacherring 9 86150 Augsburg',
#    'Anklamer Straße 38 1355 Market St',
#    'Konrad-Adenauer-Ufer 85 53115 Bonn',
#    'Rechtsgrundlage ist Art. 6 2449 Luxemburg',
#    'Rechtsgrundlage ist Art. 6 80339 München',
#    'Schießgrabenstr. 32 10115 Berlin',
#    'Schießgrabenstr. 32 2449 Luxemburg',
#    'Schießgrabenstr. 32 53115 Bonn',
#    'Schießgrabenstr. 32 1355 Market St',
#    'Anklamer Straße 38 86150 Augsburg',
#    'Wittelsbacherring 9 1601 Willow Road',
#    'Wittelsbacherring 9 50668 Köln',
#    'Schießgrabenstr. 32 1600 Amphitheatre Parkway',
#    'Wittelsbacherring 9 80339 München',
#    'Konrad-Adenauer-Ufer 85 10115 Berlin']],
#  ['https://unwomen.de/kontakt/',
#   ['Wittelsbacherring 9 10115 Berlin',
#    'Anklamer Straße 38 53115 Bonn',
#    'Anklamer Straße 38 10115 Berlin',
#    'Wittelsbacherring 9 53115 Bonn']],
#  ['https://unwomen.de/impressum/',
#   ['Wittelsbacherring 9 53115 Bonn',
#    'Stahlgruberring 3 81829 München',
#    'Wittelsbacherring 9 81829 München',
#    'Wittelsbacherring 9 6363 eingetragen',
#    'Stahlgruberring 3 6363 eingetragen',
#    'Stahlgruberring 3 53115 Bonn']],
#  ['https://unwomen.de',
#   ['Bundesgartenschau 2023 2021 nach',
#    'Bundesgartenschau 2023 2022 lautet das Motto',
#    'Bundesgartenschau 2023 2024 statt',
#    'Bundesgartenschau 2023 2023 gemeinsam mit Partner',
#    'Bundesgartenschau 2023 2023 lautet das Motto']],
#  ['https://fgk-rs.com/footer/contact',
#   ['Vaartweg 36 80339 München',
#    'Heimeranstraße 35 4731 RA Oudenbosch',
#    'Heimeranstraße 35 5637 Beinwil',
#    'Vaartweg 36 5637 Beinwil',
#    'Heimeranstraße 35 80339 München',
#    'Vaartweg 36 4731 RA Oudenbosch']],
#  ['https://fgk-rs.com', []],
#  ['https://andymagro.com/contact/',
#   ['Horneckgasse 6 3950 Arrowhead Street',
#    'Marienstraße 13 1123 Kamehameha Hwy Ste D',
#    'Marienstraße 13 1170 Vienna',
#    'Horneckgasse 6 1170 Vienna',
#    'Horneckgasse 6 1010 Common Street',
#    'Horneckgasse 6 1430 Broadway',
#    'Horneckgasse 6 06526 Sangerhausen',
#    'Marienstraße 13 06526 Sangerhausen',
#    'Marienstraße 13 1430 Broadway',
#    'Horneckgasse 6 9440\xa0S',
#    'Horneckgasse 6 1123 Kamehameha Hwy Ste D',
#    'Horneckgasse 6 4150 Santa Monica Blvd',
#    'Marienstraße 13 1010 Common Street',
#    'Marienstraße 13 3950 Arrowhead Street',
#    'Marienstraße 13 4150 Santa Monica Blvd',
#    'Marienstraße 13 9440\xa0S']],
#  ['https://andymagro.com', []],
#  ['https://andymagro.com/home/', []],
#  None,
#  None,
#  ['https://weareforeal.com',
#   ['Seizstraße 2-4 54290 Trier',
#    'Seizstraße 2-4 2023 Titles',
#    'Seizstraße 2-4 2024 by FOREAL']],
#  ['https://mysumtu.com', []],
#  ['https://mysumtu.com/datenschutz/',
#   ['Luther Weg 77 1601 Willow Road',
#    'Dammtorstraße 29-32 20354 Hamburg',
#    'Luther Weg 77 20354 Hamburg',
#    'Luther Weg 77 31515 Wunstorf',
#    'Dammtorstraße 29-32 1600 Amphitheatre Parkway',
#    'Dammtorstraße 29-32 1355 Market Street',
#    'Luther Weg 77 1600 Amphitheatre Parkway',
#    'Luther Weg 77 2029 Stierlin Court',
#    'Dammtorstraße 29-32 31515 Wunstorf',
#    'Dammtorstraße 29-32 1601 Willow Road',
#    'Luther Weg 77 1601 South California Avenue',
#    'Dammtorstraße 29-32 2029 Stierlin Court',
#    'Dammtorstraße 29-32 1601 South California Avenue',
#    'Luther Weg 77 1355 Market Street']],
#  ['https://mysumtu.com/impressum/', ['Luther Weg 77 31515 Wunstorf']],
#  ['https://pyrotechnik24.com/datenschutz/',
#   ['Rigistr. 8-10 12277 Berlin',
#    'Subbelrather Str. 15 50823 Köln',
#    'Rigistr. 8-10 50823 Köln',
#    'Rigistr. 8-10 2019 by',
#    'Subbelrather Str. 15 2019 by',
#    'Subbelrather Str. 15 12277 Berlin']],
#  ['https://pyrotechnik24.com/impressum/',
#   ['Hermsheimer Straße 3 2019 by',
#    'Rigistraße 8 12277 Berlin',
#    'Rigistr. 8 2019 by',
#    'Rigistraße 8 68163 Mannheim',
#    'Hermsheimer Straße 3 10559 Berlin',
#    'Turmstraße 21 68163 Mannheim',
#    'Turmstraße 21 10559 Berlin',
#    'Rigistraße 8 2019 by',
#    'Hermsheimer Straße 3 12277 Berlin',
#    'Rigistraße 8 10559 Berlin',
#    'Rigistr. 8 10559 Berlin',
#    'Hermsheimer Straße 3 68163 Mannheim',
#    'Rigistr. 8 12277 Berlin',
#    'Turmstraße 21 12277 Berlin',
#    'Rigistr. 8 68163 Mannheim',
#    'Turmstraße 21 2019 by']],
#  ['https://pyrotechnik24.com/produkte/datenschutz',
#   ['Subbelrather Str. 15 2018 by',
#    'Rigistr. 8-10 12277 Berlin',
#    'Friedensallee 254 81373 München',
#    'Friedensallee 254 50823 Köln',
#    'Radlkoferstraße 2 2018 by',
#    'Rigistr. 8-10 22763 Hamburg',
#    'Radlkoferstraße 2 81373 München',
#    'Radlkoferstraße 2 50823 Köln',
#    'Friedensallee 254 2018 by',
#    'Friedensallee 254 22763 Hamburg',
#    'Rigistr. 8-10 50823 Köln',
#    'Subbelrather Str. 15 81373 München',
#    'Rigistr. 8-10 81373 München',
#    'Radlkoferstraße 2 22763 Hamburg',
#    'Subbelrather Str. 15 50823 Köln',
#    'Radlkoferstraße 2 12277 Berlin',
#    'Subbelrather Str. 15 12277 Berlin',
#    'Friedensallee 254 12277 Berlin',
#    'Subbelrather Str. 15 22763 Hamburg',
#    'Rigistr. 8-10 2018 by']],
#  ['https://pyrotechnik24.com/kontakt/',
#   ['Rigistraße 8-10 2019 by', 'Rigistraße 8-10 12277 Berlin']],
#  ['https://pyrotechnik24.com',
#   ['Rigistraße 10 12277 Berlin', 'Rigistraße 10 2019 by']],
#  ['https://uniboxapp.com', []],
#  ['https://www.uniboxapp.com/contact', []],
#  ['http://ihc-solutions.de', []],
#  ['http://neuromerchandisinggroup.com/contact/', []],
#  ['http://neuromerchandisinggroup.com', []],
#  ['http://theblankswebsite.com', []],
#  ['http://theblankswebsite.com/contact', []],
#  ['http://gletschercola.de', []],
#  ['http://fernbus24.de', []]]

# %%
addresses_listD = [element for element in final_addressesD if element is not None and element[1]]

# %%
addresses_listD
# Out:
# [['https://www.cantus-bahn.de/metamenu/impressum',
#   ['Franz-Ulrich-Straße 18 34117 Kassel']],
#  ['https://www.cantus-bahn.de/metamenu/datenschutz',
#   ['Rechtsgrundlage Richtlinie 2004 34369 Hofgeismar',
#    'Neue Straße 22 34369 Hofgeismar',
#    'Rechtsgrundlage ist Art. 6 34369 Hofgeismar']],
#  ['https://pastisani.com/impressum/', ['Orber Straße 30 60386 Frankfurt']],
#  ['https://pastisani.com/datenschutz/',
#   ['Rechtsgrundlage hierfür ist Art. 6 60386 Frankfurt',
#    'Elgendorfer Str. 57 56410 Montabaur',
#    'Elgendorfer Str. 57 60386 Frankfurt',
#    'Orber Straße 30 56410 Montabaur',
#    'Orber Straße 30 60386 Frankfurt',
#    'Rechtsgrundlage hierfür ist Art. 6 56410 Montabaur']],
#  ['https://marry-jim.com/impressum/', ['Am Wacholderberg 9 61462 Königstein']],
#  ['https://weinanzeiger.com', ['Denkmalgasse 18 2172 Schrattenbe']],
#  ['https://weinanzeiger.com/impressum-p32', ['Kraus Straße 16 2123 Kronberg']],
#  ['https://infinity-reisen.com/impressum/',
#   ['Schorndorferstr. 27 70734 Fellbach',
#    'Schorndorferstr. 27 10006 Berlin',
#    'Schorndorfer Straße 27 70734 Fellbach',
#    'Schorndorferstr. 27 77694 Kehl',
#    'Schorndorfer Straße 27 70736 Fellbach',
#    'Sonnenbühlstr. 23 10006 Berlin',
#    'Schorndorferstr. 27 70736 Fellbach',
#    'Sonnenbühlstr. 23 70736 Fellbach',
#    'Sonnenbühlstr. 23 77694 Kehl',
#    'Sonnenbühlstr. 23 70734 Fellbach',
#    'Schorndorfer Straße 27 77694 Kehl',
#    'Schorndorfer Straße 27 10006 Berlin']],
#  ['https://infinity-reisen.com', ['Schorndorfer Straße 27 70736 Fellbach']],
#  ['https://infinity-reisen.com/datenschutz/',
#   ['Schorndorfer Straße 27 70734 Fellbach',
#    'Schorndorfer Straße 27 70736 Fellbach',
#    'Sonnenbühlstr. 23 70736 Fellbach',
#    'Sonnenbühlstr. 23 70734 Fellbach',
#    'Schorndorfer Straße 27 1600 Amphitheatre Parkway',
#    'Sonnenbühlstr. 23 1600 Amphitheatre Parkway']],
#  ['https://infinity-reisen.com/kontakt/',
#   ['Schorndorfer Straße 27 70736 Fellbach',
#    'Schorndorferstraße 27 70736 Fellbach']],
#  ['http://rtc-c.com',
#   ['Maffeistr. 12 2023 Weltkonferenz AHK',
#    'Maffeistrasse 12 93059 Regensburg',
#    'Augustenstr. 3 93049 Regensburg',
#    'Augustenstr. 3 2023 Weltkonferenz AHK',
#    'Maffeistr. 12 93049 Regensburg',
#    'Maffeistrasse 12 2023 Weltkonferenz AHK',
#    'Augustenstr. 3 93059 Regensburg',
#    'Maffeistrasse 12 8568  Handelsregister',
#    'Maffeistrasse 12 93049 Regensburg',
#    'Maffeistr. 12 93059 Regensburg',
#    'Augustenstr. 3 8568  Handelsregister',
#    'Maffeistr. 12 8568  Handelsregister']],
#  ['https://hopegala.de/kontakt',
#   ['Enderstraße 94 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Enderstraße 94 2021 by HOPE-Gala',
#    'Münsterstraße 1853111 01277 Dresden']],
#  ['https://hopegala.de/impressum',
#   ['Enderstraße 94 01277 Dresden',
#    'Münsterstraße 18 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Münsterstraße 1853111 53111 Bonn',
#    'Münsterstraße 1853111 01277 Dresden',
#    'Münsterstraße 18 2021 by HOPE-Gala',
#    'Münsterstraße 18 53111 Bonn',
#    'Enderstraße 94 53111 Bonn',
#    'Enderstraße 94 2021 by HOPE-Gala']],
#  ['https://hopegala.de/datenschutz',
#   ['Enderstraße 94 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Enderstraße 94 2021 by HOPE-Gala',
#    'Münsterstraße 1853111 01277 Dresden']],
#  ['https://hopegala.de',
#   ['Münsterstraße 1853111 2023 von',
#    'Enderstraße 94 01277 Dresden',
#    'Münsterstraße 1853111 2021 by HOPE-Gala',
#    'Enderstraße 94 2023 zur',
#    'Enderstraße 94 2021 und',
#    'Münsterstraße 1853111 2023 zur',
#    'Münsterstraße 1853111 2021 und',
#    'Münsterstraße 1853111 01277 Dresden',
#    'Enderstraße 94 2023 von',
#    'Enderstraße 94 2021 by HOPE-Gala']],
#  ['https://schuhhause.de', ['Kuhstraße 3 47918 Tönisvorst']],
#  ['https://bdia.de/impressum/',
#   ['Wilhelmine-Gemberg-Weg 6 33209 B',
#    'Bänschstr. 58 27628 Hagen im Bremischen',
#    'Bänschstr. 58 10247 Berlin',
#    'Wilhelmine-Gemberg-Weg 6 10179 Berlin',
#    'Wilhelmine-Gemberg-Weg 6 27628 Hagen im Bremischen',
#    'Bänschstr. 58 33209 B',
#    'Wilhelmine-Gemberg-Weg 6 10247 Berlin',
#    'Bänschstr. 58 10179 Berlin']],
#  ['https://bdia.de',
#   ['Wilhelmine-Gemberg-Weg 6 2024 werden über',
#    'Wilhelmine-Gemberg-Weg 6 2023 in Frankfurt am Main',
#    'Wilhelmine-Gemberg-Weg 6 10179 Berlin']],
#  ['https://www.winnerbatterien.de/Privatsphaere-und-Datenschutz',
#   ['Casterfeldstr. 66-72 68199 Mannheim']],
#  ['https://www.winnerbatterien.de/Impressum',
#   ['Casterfeldstr. 66-72 68199 Mannheim']],
#  ['https://begehbares-glas.com/datenschutz-2/',
#   ['Rechtsgrundlage hierfür ist § 26 33659 Bielefeld',
#    'Rechtsgrundlage hierfür ist § 26 10587 Berlin',
#    'Pascalstraße 10 33659 Bielefeld',
#    'Nordfeldweg 87 33659 Bielefeld',
#    'Nordfeldweg 87 10587 Berlin',
#    'Pascalstraße 10 10587 Berlin']],
#  ['https://begehbares-glas.com/impressum/',
#   ['Nordfeldweg 87 33659 Bielefeld']],
#  ['https://begehbares-glas.com', ['Nordfeldweg 87 33659 Bielefeld']],
#  ['https://begehbares-glas.com/en/home-en/',
#   ['Nordfeldweg 87 33659 Bielefeld']],
#  ['https://begehbares-glas.com/kontakt/', ['Nordfeldweg 87 33659 Bielefeld']],
#  ['https://polizeioldtimer.de',
#   ['Cyriaxstraße 103 2020 bereits  aus über',
#    'Cyriaxstraße 103 2000 die Gründungsfeier zum',
#    'Raiffeisenstraße 1 35043 Marburg',
#    'Raiffeisenstraße 1 35037 Marburg',
#    'Cyriaxstraße 103 1990 e',
#    'Cyriaxstraße 103 35037 Marburg',
#    'Raiffeisenstraße 1 2020 bereits  aus über',
#    'Cyriaxstraße 103 35043 Marburg',
#    'Raiffeisenstraße 1 1990 e',
#    'Raiffeisenstraße 1 2000 die Gründungsfeier zum']],
#  ['https://polizeioldtimer.de/impressum-datenschutz',
#   ['Raiffeisenstr. 1 06618\xa0nach',
#    'Raiffeisenstraße 1 35043 Marburg',
#    'Raiffeisenstr. 1 1990 e',
#    'Raiffeisenstr. 1 35043 Marburg',
#    'Raiffeisenstraße 1 1990 e',
#    'Raiffeisenstraße 1 06618\xa0nach']],
#  ['https://go-east.de/impressum',
#   ['Woyrschweg 54 22761 Hamburg',
#    'Walther-von-Cronberg-Platz 15 60594 Frankfurt am Main',
#    'Walther-von-Cronberg-Platz 15 22761 Hamburg',
#    'Woyrschweg 54 60594 Frankfurt am Main']],
#  ['https://go-east.de/impressum#bildnachweis',
#   ['Woyrschweg 54 22761 Hamburg',
#    'Walther-von-Cronberg-Platz 15 60594 Frankfurt am Main',
#    'Walther-von-Cronberg-Platz 15 22761 Hamburg',
#    'Woyrschweg 54 60594 Frankfurt am Main']],
#  ['https://fogra.org/impressum', ['Einsteinring 1a 85609 Aschheim b']],
#  ['https://fogra.org/kontakt', ['Einsteinring 1a 85609 Aschheim b']],
#  ['https://joest-racing.de/datenschutz/',
#   ['Rechtsgrundlage hierfür ist Art. 6 66571 Eppelborn',
#    'Bahnhofstraße 34 22305 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 69483 Wald-Michelbach',
#    'Bahnhofstraße 34 69483 Wald-Michelbach',
#    'Bahnhofstraße 34 66571 Eppelborn',
#    'Bahnstr. 14 22305 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 22305 Hamburg',
#    'Bahnstr. 14 66571 Eppelborn',
#    'Bahnstr. 14 69483 Wald-Michelbach']],
#  ['https://joest-racing.de/impressum/', ['Bahnstr. 14 69483 Wald-Michelbach']],
#  ['https://gini.net/impressum/',
#   ['Ridlerstr. 57 27001 zertifiziert', 'Ridlerstr. 57 80339 München']],
#  ['https://gini.net/datenschutz/',
#   ['Ridlerstr. 57 48153 Münster',
#    'Marienplatz 2 80339 München',
#    'Hafenstrasse 32 80339 München',
#    'Marienplatz 2 80331 München',
#    'Hafenstrasse 32 80331 München',
#    'Hafenstrasse 32 02141 USA',
#    'Ridlerstr. 57 02141 USA',
#    'Marienplatz 2 27001 zertifiziert',
#    'Hafenstrasse 32 48153 Münster',
#    'Ridlerstr. 57 27001 zertifiziert',
#    'Marienplatz 2 02141 USA',
#    'Ridlerstr. 57 80339 München',
#    'Marienplatz 2 48153 Münster',
#    'Ridlerstr. 57 80331 München',
#    'Hafenstrasse 32 27001 zertifiziert']],
#  ['https://kamps.de/datenschutz',
#   ['Rechtsgrundlage ist Art. 6 2024 Kamps GmbH',
#    'Rechtsgrundlage ist Art. 6 59000 Lille']],
#  ['https://academyconsult.de/unternehmen/impressum/',
#   ['Leopoldstraße 62 80802 München',
#    'Leopoldstraße 62 2023 Academy Consult e']],
#  ['https://academyconsult.de/impressum/',
#   ['Leopoldstraße 62 80802 München',
#    'Leopoldstraße 62 2023 Academy Consult e']],
#  ['https://academyconsult.de/unternehmen/datenschutz/',
#   ['Rechtsgrundlage hierfür ist § 26 91710 Gunzenhausen',
#    'Leopoldstraße 62 91710 Gunzenhausen',
#    'Rechtsgrundlage hierfür ist Art. 6 91710 Gunzenhausen',
#    'Kalmarweg 14-5 2023 Academy Consult e',
#    'Rechtsgrundlage hierfür ist § 26 02141 USA',
#    'Rechtsgrundlage hierfür ist Art. 6 02141 USA',
#    'Industriestr. 25 80802 München',
#    'Kalmarweg 14-5 80802 München',
#    'Leopoldstraße 62 80802 München',
#    'Leopoldstraße 62 02141 USA',
#    'Kalmarweg 14-5 02141 USA',
#    'Industriestr. 25 02141 USA',
#    'Industriestr. 25 9723 JG Groningen',
#    'Kalmarweg 14-5 91710 Gunzenhausen',
#    'Rechtsgrundlage hierfür ist Art. 6 80802 München',
#    'Industriestr. 25 91710 Gunzenhausen',
#    'Industriestr. 25 2023 Academy Consult e',
#    'Leopoldstraße 62 2023 Academy Consult e',
#    'Leopoldstraße 62 9723 JG Groningen',
#    'Rechtsgrundlage hierfür ist § 26 80802 München',
#    'Kalmarweg 14-5 9723 JG Groningen']],
#  ['https://solaranlagen-portal.de/infoseiten/datenschutz',
#   ['Kressengartenstraße 10 90402 Nürnberg',
#    'Kressengartenstraße 10 22763 Hamburg',
#    'Rechtsgrundlage ist Artikel 6 90402 Nürnberg',
#    'Rechtsgrundlage ist Artikel 6 22763 Hamburg']],
#  ['https://solaranlagen-portal.de/infoseiten/impressum',
#   ['Kressengartenstraße 10 90402 Nürnberg']],
#  ['https://big-picture.com',
#   ['Köpenicker Str. 18-20 5000 Models', 'Köpenicker Str. 18-20 10997 Berlin']],
#  ['https://skalar.marketing/datenschutz',
#   ['Hüfferstr. 54 79098 Freiburg i',
#    'Augustinerplatz 2 79098 Freiburg i',
#    'Augustinerplatz 2 33378 Rheda-Wiedenbrück',
#    'Hüfferstr. 54 33378 Rheda-Wiedenbrück']],
#  ['https://www.bioanalyt.com/impressum/', ['Rheinstraße 17 14513 Teltow']],
#  ['https://www.bioanalyt.com/contact/', ['Rheinstraße 17 14513 Teltow']],
#  ['https://golocal.de/kontakt/', ['Landsberger Straße 94 80339 München']],
#  ['https://golocal.de/impressum/',
#   ['Landsberger Straße 94 2024 GoLocal GmbH',
#    'Landsberger Straße 94 80339 München']],
#  ['https://ammt.com/contact/',
#   ['Anselm-Feuerbach-Str. 6 67227 Frankenthal',
#    'Anselm-Feuerbach-Str. 6 1345 Gwangmyeong-Si']],
#  ['http://inbalance-yoga.net/Datenschutz.html',
#   ['Swiggerweg 1 74523 Schwäbisch Hall']],
#  ['http://inbalance-yoga.net/impressum.php',
#   ['Klingenberg 35 74523 Schwäbisch Hall']],
#  ['https://teamwire.eu/impressum/', ['Tittmoninger Strasse 11 81679 München']],
#  ['https://teamwire.eu/datenschutz/',
#   ['Hohenzollernring 54 50672 Köln',
#    'Hohenzollernring 54 2029 Stierlin Court',
#    'Köpenicker Str. 126 81679 München',
#    'Tittmoninger Strasse 11 50672 Köln',
#    'Hohenzollernring 54 6011 Wellington',
#    'Köpenicker Str. 126 1355 Market St',
#    'Köpenicker Str. 126 10179 Berlin',
#    'Hohenzollernring 54 10179 Berlin',
#    'Tittmoninger Strasse 11 94043 USA',
#    'Hohenzollernring 54 1600 Amphitheatre Parkway',
#    'Tittmoninger Strasse 11 81679 München',
#    'Tittmoninger Strasse 11 10179 Berlin',
#    'Hohenzollernring 54 1355 Market St',
#    'Tittmoninger Strasse 11 1600 Amphitheatre Parkway',
#    'Köpenicker Str. 126 94043 USA',
#    'Hohenzollernring 54 81679 München',
#    'Tittmoninger Strasse 11 6011 Wellington',
#    'Köpenicker Str. 126 1600 Amphitheatre Parkway',
#    'Köpenicker Str. 126 6011 Wellington',
#    'Tittmoninger Strasse 11 1355 Market St',
#    'Hohenzollernring 54 94043 USA',
#    'Köpenicker Str. 126 50672 Köln',
#    'Köpenicker Str. 126 2029 Stierlin Court',
#    'Tittmoninger Strasse 11 2029 Stierlin Court']],
#  ['https://teamwire.eu/kontakt/',
#   ['Tittmoninger Strasse 11 81679 München',
#    'Tittmoninger Strasse 11 28013 Madrid',
#    'Tittmoninger Strasse 11 40219 Düsseldorf']],
#  ['https://realcube.com/datenschutz/',
#   ['Kurfürstendamm 21 20354 Hamburg',
#    'Stollbergstraße 22 80539 München',
#    'Grünstraße 17 80539 München',
#    'Stollbergstraße 22 20354 Hamburg',
#    'Stollbergstraße 22 10719 Berlin',
#    'Grünstraße 17 10719 Berlin',
#    'Kurfürstendamm 21 10719 Berlin',
#    'Kurfürstendamm 21 80539 München',
#    'Grünstraße 17 20354 Hamburg']],
#  ['https://realcube.com/impressum/', ['Stollbergstraße 22 80539 München']],
#  ['https://frankfurt-holm.de/impressum/',
#   ['Bessie-Coleman-Straße 7 60549 Frankfurt am Main',
#    'Bessie-Coleman-Str. 7 60549 Frankfurt am Main']],
#  ['https://frankfurt-holm.de/datenschutz/',
#   ['Köpenicker Str. 126 2018 geltenden Datenschutzgrundverordnung',
#    'Solmsstraße 83 2018 geltenden Datenschutzgrundverordnung',
#    'Rechtsgrundlage hierfür ist Art. 6 10179 Berlin',
#    'Rechtsgrundlage dafür ist Art. 6 10179 Berlin',
#    'Köpenicker Str. 126 60549 Frankfurt am Main',
#    'Bessie-Coleman-Str. 7 60549 Frankfurt am Main',
#    'Bessie-Coleman-Straße 7 2018 geltenden Datenschutzgrundverordnung',
#    'Bessie-Coleman-Straße 7 60549 Frankfurt am Main',
#    'Solmsstraße 83 10179 Berlin',
#    'Bessie-Coleman-Str. 7 10179 Berlin',
#    'Rechtsgrundlage ist Art. 6 10179 Berlin',
#    'Köpenicker Str. 126 10179 Berlin',
#    'Bessie-Coleman-Straße 7 10179 Berlin',
#    'Bessie-Coleman-Str. 7 2018 geltenden Datenschutzgrundverordnung',
#    'Rechtsgrundlage ist Art. 6 2018 geltenden Datenschutzgrundverordnung',
#    'Solmsstraße 83 60486 Frankfurt am Main',
#    'Köpenicker Str. 126 60486 Frankfurt am Main',
#    'Bessie-Coleman-Str. 7 60486 Frankfurt am Main',
#    'Solmsstraße 83 60549 Frankfurt am Main',
#    'Bessie-Coleman-Straße 7 60486 Frankfurt am Main']],
#  ['https://frankfurt-holm.de/kontakt/',
#   ['Bessie-Coleman-Straße 7 60549 Frankfurt am Main']],
#  ['https://kiwi-consulting.de/datenschutz',
#   ['Haller Straße 54 74189 Weinsberg',
#    'Elgendorfer Straße 57 56410 Montabaur',
#    'Haller Straße 54 56410 Montabaur',
#    'Elgendorfer Straße 57 74189 Weinsberg']],
#  ['https://kiwi-consulting.de',
#   ['Weinsberg, 08 2023 von KIWI Consulting',
#    'Weinsberg, 01 2023 von KIWI Consulting',
#    'Weinsberg, 08 2024 von KIWI Consulting',
#    'Weinsberg, 01 2024 von KIWI Consulting',
#    'Weinsberg, 09 2024 von KIWI Consulting',
#    'Weinsberg, 09 2023 von KIWI Consulting',
#    'Weinsberg, 03 2024 von KIWI Consulting',
#    'Weinsberg, 03 2023 von KIWI Consulting']],
#  ['https://kiwi-consulting.de/impressum',
#   ['Haller Straße 54 74189 Weinsberg',
#    'Odenwaldstr. 14 69190 Walldorf',
#    'Haller Straße 54 22297 Hamburg',
#    'Haller Straße 54 69190 Walldorf',
#    'Odenwaldstr. 14 74189 Weinsberg',
#    'Odenwaldstr. 14 22297 Hamburg']],
#  ['https://sams-think-special.de/kontakt/',
#   ['Wandlhamerstraße 25 82166 Gräfelfing']],
#  ['https://sams-think-special.de', ['Wandlhamerstraße 25 82166 Gräfelfing']],
#  ['https://sams-think-special.de/datenschutz/',
#   ['Wandlhamerstraße 25 82166 Gräfelfing']],
#  ['https://aopn.com/content/7-Datenschutz',
#   ['Steinkirchring 35 1601 S',
#    'Steinkirchring 35 1601 Willow Road',
#    'Steinkirchring 35 1600 Amphitheatre Parkway',
#    'Steinkirchring 35 78056 VS-Schwenningen',
#    'Steinkirchring 35 1355 Market St']],
#  ['https://aopn.com/content/5-impressum',
#   ['Steinkirchring 35 78056 VS-Schwenningen']],
#  ['https://drehmoment-gmbh.de/impressum/',
#   ['Holzmarkt 7 72070 Tübingen',
#    'Doblerstraße 14 72074 Tübingen',
#    'Doblerstraße 14 72070 Tübingen',
#    'Holzmarkt 7 72074 Tübingen']],
#  ['https://oezgen-senol.de/datenschutz/', ['Sonnenstr. 6 90537 Feucht']],
#  ['https://oezgen-senol.de/impressum/',
#   ['Sonnenstr. 6 90537 Feucht bei Nürnberg']],
#  ['https://haasehof.de/kontakt',
#   ['Lindenstraße.5 27419 Sittensen', 'Lindenstraße 5 27419 Sittensen']],
#  ['https://haasehof.de', ['Lindenstraße.5 27419 Sittensen']],
#  ['https://haasehof.de/datenschutz',
#   ['Lindenstraße.5 27419 Sittensen',
#    'Lindenstraße 5 27419 Sittensen',
#    'Lindenstraße.5 1600 Amphitheatre Parkway',
#    'Lindenstraße 5 1600 Amphitheatre Parkway']],
#  ['https://haasehof.de/impressum',
#   ['Lindenstraße.5 27419 Sittensen', 'Lindenstraße 5 27419 Sittensen']],
#  ['https://element.de/kontakt/',
#   ['Wiesenhüttenplatz 25 60329 Frankfurt am Main',
#    'Wiesenhüttenplatz 25 08523 Plauen',
#    'Wettiner Platz 10 08523 Plauen',
#    'Reichsstraße 3 60329 Frankfurt am Main',
#    'Reichsstraße 3 08523 Plauen',
#    'Wiesenhüttenplatz 25 01067 Dresden',
#    'Wettiner Platz 10 01067 Dresden',
#    'Reichsstraße 3 01067 Dresden',
#    'Wettiner Platz 10 60329 Frankfurt am Main']],
#  ['https://element.de/datenschutz/',
#   ['Leopoldstr. 21 6011 Wellington', 'Leopoldstr. 21 80802 München']],
#  ['https://element.de/impressum/',
#   ['Wiesenhüttenplatz 25 60329 Frankfurt am Main']],
#  ['https://jazzradio.net/impressum/', ['Passauer Str. 8-9 10789 Berlin']],
#  ['https://eps-personal.org/impressum',
#   ['Werderstraße 16 78048 Villingen-Schwenningen',
#    'Nelkenstraße 36 78048 Villingen-Schwenningen',
#    'Robert-Bosch-Straße 9 71272 Renningen',
#    'Robert-Bosch-Straße 9 78048 Villingen-Schwenningen',
#    'Nelkenstraße 36 78532 Tuttlingen',
#    'Werderstraße 16 78532 Tuttlingen',
#    'Werderstraße 16 71272 Renningen',
#    'Nelkenstraße 36 71272 Renningen',
#    'Robert-Bosch-Straße 9 78532 Tuttlingen']],
#  ['https://eps-personal.org/datenschutz',
#   ['Rechtsgrundlage hierfür ist Art. 6 1058 Kopenhagen',
#    'Rechtsgrundlage hierfür ist § 26 78532 Tuttlingen',
#    'Werderstraße 16 71272 Renningen',
#    'Rechtsgrundlage hierfür ist Art. 6 20354 Hamburg',
#    'Rechtsgrundlage hierfür ist § 26 71272 Renningen',
#    'Dammtorstraße 30 1058 Kopenhagen',
#    'Nelkenstraße 36 20354 Hamburg',
#    'Werderstraße 16 1058 Kopenhagen',
#    'Rechtsgrundlage hierfür ist § 26 1058 Kopenhagen',
#    'Dammtorstraße 30 78532 Tuttlingen',
#    'Rechtsgrundlage hierfür ist Art. 6 78532 Tuttlingen',
#    'Nelkenstraße 36 78532 Tuttlingen',
#    'Werderstraße 16 78532 Tuttlingen',
#    'Werderstraße 16 20354 Hamburg',
#    'Rechtsgrundlage hierfür ist § 26 20354 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 71272 Renningen',
#    'Dammtorstraße 30 71272 Renningen',
#    'Dammtorstraße 30 20354 Hamburg',
#    'Nelkenstraße 36 1058 Kopenhagen',
#    'Nelkenstraße 36 71272 Renningen']],
#  ['https://aetka.de/datenschutz',
#   ['Rechtsgrundlage hierfür ist Art. 6 10719 Berlin',
#    'Rechtsgrundlage ist Art. 6 10719 Berlin',
#    'Kurfürstendamm 212 10719 Berlin',
#    'Kurfürstendamm 21 10719 Berlin']],
#  ['https://studio-ahoi.de/datenschutz/', ['Brunnenstraße 120 22763 Hamburg']],
#  ['https://studio-ahoi.de/impressum-kontakt/',
#   ['Brunnenstraße 120 22767 Hamburg']],
#  ['https://ctr-fahrzeuge.de/kontakt/',
#   ['Norwegen (NO, +47 2024 CTR-Fahrzeugtechnik GmbH']],
#  ['https://ctr-fahrzeuge.de/unternehmen/datenschutz/',
#   ['Am Rosenberg 2 1601 S',
#    'Am Rosenberg 2 54518 Osann-Monzel',
#    'Am Rosenberg 2 2024 CTR-Fahrzeugtechnik GmbH',
#    'Am Rosenberg 2 1600 Amphitheatre Parkway']],
#  ['https://consulegis.com', ['Bradandstrasse 7 22297 Hamburg']],
#  ['https://consulegis.com/contact-us',
#   ['Brabandstrasse 7 20354 Hamburg', 'Poststrasse 14-16 20354 Hamburg']],
#  ['https://leagasdelaney.de/kontakt',
#   ['Elbstraße 145a 20124 Milano', 'Elbstraße 145a 22767 Hamburg']],
#  ['https://leagasdelaney.de/impressum',
#   ['Elbstraße 145a 22767\xa0Hamburg', 'Elbstraße 145a 22767 Hamburg']],
#  ['https://leagasdelaney.de',
#   ['Elbstraße 145a 2020 und',
#    'Elbstraße 145a 2021 für Gustavo Gusto',
#    'Elbstraße 145a 22767 Hamburg']],
#  ['https://cellsystems.eu', ['Junkersring 5 53844 Troisdorf']],
#  ['https://cellsystems.eu/contact/', ['Junkersring 5 53844 Troisdorf']],
#  ['http://dr-estrich.com', ['Industriestraße 12 86609 Donauwörth']],
#  ['https://makers.do', ['Münzstr. 21 10178 Berlin']],
#  ['https://mobi-test.de/impressum-haftungsausschluss/',
#   ['Poststraße 49 1601 S', 'Poststraße 49 63801 Kleinostheim']],
#  ['https://mobi-test.de/datenschutz/',
#   ['Carl-Bosch-Str. 14 63814 Mainaschaff',
#    'Carl-Bosch-Str. 14 1601 Willow Road',
#    'Carl-Bosch-Str. 14 1355 Market Street',
#    'Carl-Bosch-Str. 14 1600 Amphitheatre Parkway']],
#  ['https://horst-busch.de/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/pelka-seib/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/elektro-technik/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de',
#   ['Emmy-Noether-Straße 25 25524 Itzehoe',
#    'Emmy-Noether-Straße 25 21079 Hamburg']],
#  ['https://horst-busch.de/alarm-und-sicherheitstechnik/kontakt/',
#   ['Emmy-Noether-Straße 25 25524 Itzehoe',
#    'Emmy-Noether-Straße 25 21079 Hamburg']],
#  ['https://viridicon.de/kontakt/',
#   ['Präsident-Herwig-Straße 24 36119 Neuhof-Dorfborn',
#    'Präsident-Herwig-Straße 24 27472 Cuxhaven',
#    'Präsident-Herwig-Straße 24 21079 Hamburg']],
#  ['https://horst-busch.de/datenschutz/',
#   ['Rechtsgrundlage ist Art. 6 1600 Amphitheater Parkway',
#    'Rechtsgrundlage ist Art. 6 65232 Taunusstein',
#    'Rechtsgrundlage ist Art. 6 1355 Market St',
#    'Mainstraße 6 2029 Stierlin Court',
#    'Gänsemarkt 43 21079 Hamburg',
#    'Gänsemarkt 43 1595 Spring Hill Road',
#    'Mainstraße 6 1601 S California Ave',
#    'Gänsemarkt 43 65232 Taunusstein',
#    'Gänsemarkt 43 1600 Amphitheater Parkway',
#    'Rechtsgrundlage ist Art. 6 2029 Stierlin Court',
#    'Mainstraße 6 1600 Amphitheater Parkway',
#    'Rechtsgrundlage ist Art. 6 20354 Hamburg',
#    'Gänsemarkt 43 2029 Stierlin Court',
#    'Gänsemarkt 43 1601 S California Ave',
#    'Mainstraße 6 1355 Market St',
#    'Mainstraße 6 21079 Hamburg',
#    'Mainstraße 6 20354 Hamburg',
#    'Gänsemarkt 43 1355 Market St',
#    'Rechtsgrundlage ist Art. 6 21079 Hamburg',
#    'Mainstraße 6 1595 Spring Hill Road',
#    'Mainstraße 6 65232 Taunusstein',
#    'Gänsemarkt 43 20354 Hamburg']],
#  ['https://horst-busch.de/alarm-und-sicherheitstechnik/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/horst-busch-elektro-grosprojekte-gmbh/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/planung-personal-technik/impressum/',
#   ['Mainstraße 6 65232 Taunusstein', 'Mainstraße 6 21079 Hamburg']],
#  ['https://horst-busch.de/planung-personal-technik/kontakt/',
#   ['Emmy-Noether-Straße 25 25524 Itzehoe',
#    'Emmy-Noether-Straße 25 21079 Hamburg']],
#  ['https://charcotfootcourses.org',
#   ['Frankenburgstr. 31 48431 Rheine',
#    'Frankenburgstr. 31 2000 Frederiksberg']],
#  ['https://poison-berlin.com/impressum/', ['Planufer 92e 10967 Berlin']],
#  ['https://poison-berlin.com/kontakt/', ['Planufer 92e 10967 Berlin']],
#  ['https://poison-berlin.com/datenschutz/',
#   ['Planufer 92e 10967 Berlin',
#    'Planufer 92e 1601 S California Ave',
#    'Planufer 92e 1601 Willow Road']],
#  ['https://kulmens.de/datenschutz',
#   ['Rechtsgrundlage ist Art.\xa06 2021 KULMENS',
#    'Rechtsgrundlage ist Art.\xa06 84028 Landshut']],
#  ['https://paintballpark.de/datenschutz.html',
#   ['Hammer Straße 341 59229 Ahlen']],
#  ['https://paintballpark.de/impressum.html',
#   ['Hammer Straße 341 59229 Ahlen']],
#  ['https://tacalyx.com', ['Magnusstr. 11 12489 Berlin']],
#  ['https://mylsp.de', ['Christinenstraße 7 40880 Ratingen']],
#  ['https://mylsp.de/kontakt/',
#   ['Christinenstr. 7-7a 40880 Ratingen', 'Christinenstraße 7 40880 Ratingen']],
#  ['https://junges-uno-netzwerk.de', ['Zimmermannstraße 26 10969 Berlin']],
#  ['https://flugsam.de/impressum', ['Fruchtallee 23 20259 Hamburg']],
#  ['https://flugsam.de', ['Fruchtallee 23 20259 Hamburg']],
#  ['https://voya.ai/kontakt/', ['Stadthausbrücke 5 20355 Hamburg']],
#  ['https://voya.ai', ['Stadthausbrücke 5 20355 Hamburg']],
#  ['https://voya.ai/datenschutz/',
#   ['Rechtsgrundlage des Art. 6 20355 Hamburg',
#    'Stadthausbrücke 5 02141 USA',
#    'Rechtsgrundlage von Art. 6 20355 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 20459 Hamburg',
#    'Rechtsgrundlage des Art. 6 20459 Hamburg',
#    'Rechtsgrundlage von Art. 6 20459 Hamburg',
#    'Rechtsgrundlage in Art. 6 20459 Hamburg',
#    'Rechtsgrundlage des Art. 6 02141 USA',
#    'Stadthausbrücke 5 20459 Hamburg',
#    'Rechtsgrundlage in Art. 6 20355 Hamburg',
#    'Stadthausbrücke 5 20355 Hamburg',
#    'Rechtsgrundlage von Art. 6 02141 USA',
#    'Rechtsgrundlage hierfür ist Art. 6 02141 USA',
#    'Rechtsgrundlage in Art. 6 02141 USA',
#    'Rechtsgrundlage hierfür ist Art. 6 20355 Hamburg']],
#  ['https://voya.ai/impressum/',
#   ['Stadthausbrücke 5 20095 Hamburg', 'Stadthausbrücke 5 20355 Hamburg']],
#  ['https://atrium2000.com/index.php/datenschutz',
#   ['Waldstr. 22 1600 Amphitheatre Parkway',
#    'Waldstr. 22 2024 ATRIUM Invest GmbH',
#    'Waldstr. 22 1601 S',
#    'Waldstr. 22 91189 Rohr']],
#  ['https://atrium2000.com/index.php/impressum',
#   ['Oberbayern, Max-Joseph-Str. 2 91154 Roth',
#    'Waldstr. 22 91154 Roth',
#    'Waldstr. 22 91189 Rohr b',
#    'Oberbayern, Max-Joseph-Str. 2 2024 ATRIUM Invest GmbH',
#    'Weinbergweg 1 2024 ATRIUM Invest GmbH',
#    'Weinbergweg 1 91154 Roth',
#    'Nürnberg HRB 33145 80333 München',
#    'Waldstr. 22 80333 München',
#    'Weinbergweg 1 91189 Rohr b',
#    'Weinbergweg 1 80333 München',
#    'Nürnberg HRB 33145 2024 ATRIUM Invest GmbH',
#    'Waldstr. 22 2024 ATRIUM Invest GmbH',
#    'Nürnberg HRB 33145 91154 Roth',
#    'Oberbayern, Max-Joseph-Str. 2 91189 Rohr b',
#    'Oberbayern, Max-Joseph-Str. 2 80333 München',
#    'Nürnberg HRB 33145 91189 Rohr b']],
#  ['https://software-architecture-camp.de/impressum/',
#   ['Schwedlerstr. 8 60314 Frankfurt am Main']],
#  ['https://software-architecture-camp.de/datenschutz/',
#   ['Schwedlerstr. 8 10117 Berlin', 'Albrechtstraße 10 10117 Berlin']],
#  ['https://fame-creativelab.com',
#   ['Vordergrund stehen. Am 27 2023 was',
#    'Vordergrund stehen. Am 27 2022 levels',
#    'Vordergrund stehen. Am 27 60314 Frankfurt',
#    'Vordergrund stehen. Am 27 1963 reichen',
#    'Landstr. 146 2023 um',
#    'Landstr. 146 60314 Frankfurt',
#    'Vordergrund stehen. Am 27 2023 in Switzerland',
#    'Landstr. 146 2022 levels',
#    'Landstr. 146 1963 reichen',
#    'Vordergrund stehen. Am 27 2023 um',
#    'Landstr. 146 2023 was',
#    'Landstr. 146 2023 in Switzerland']],
#  ['https://fame-creativelab.com/impressum/',
#   ['Burgstrasse, 27 60316 Frankfurt',
#    'Landstr. 146 60314 Frankfurt',
#    'Burgstrasse, 27 2017 fame creative lab',
#    'Burgstrasse, 27 60314 Frankfurt',
#    'Landstr. 146 60316 Frankfurt',
#    'Landstr. 146 2017 fame creative lab']],
#  ['https://fame-creativelab.com/en/home/',
#   ['Landstr. 146 60314 Frankfurt',
#    'Landstr. 146 2222 islands',
#    'Landstr. 146 2023 World Travel Awards']],
#  ['https://fame-creativelab.com/datenschutz/',
#   ['Landstr. 146 1601 S',
#    'Landstr. 146 2029 Stierlin Court',
#    'Landstr. 146 60314 Frankfurt',
#    'Gänsemarkt 43 1601 S',
#    'Landstr. 146 1600 Amphitheatre Parkway',
#    'Gänsemarkt 43 60314 Frankfurt',
#    'Gänsemarkt 43 20354 Hamburg',
#    'Landstr. 146 20354 Hamburg',
#    'Gänsemarkt 43 1600 Amphitheatre Parkway',
#    'Gänsemarkt 43 2029 Stierlin Court']],
#  ['https://www.bzweic.de/impressum/',
#   ['Jesinger Straße 52 73230 Kirchheim unter Teck']],
#  ['https://www.bzweic.de/datenschutz/',
#   ['Jesinger Straße 52 1600 Amphitheatre Parkway',
#    'Jesinger Straße 52 73230 Kirchheim unter Teck',
#    'Jesinger Straße 52 94066 San Bruno']],
#  ['https://apartment-hotel.de/datenschutz.html',
#   ['Ohlrattweg 5 20537 Hamburg',
#    'Ullsteinstraße 130 25497 Prisdorf',
#    'Borstelmannsweg 133 12109 Berlin',
#    'Ohlrattweg 5 1021 KP Amsterdam',
#    'Ohlrattweg 5 12109 Berlin',
#    'Ullsteinstraße 130 02494 USA',
#    'Rechtsgrundlage ist Art. 6 25497 Prisdorf',
#    'Ullsteinstraße 130 1021 KP Amsterdam',
#    'Ullsteinstraße 130 12109 Berlin',
#    'Rechtsgrundlage ist Art. 6 1021 KP Amsterdam',
#    'Borstelmannsweg 133 1021 KP Amsterdam',
#    'Borstelmannsweg 133 20537 Hamburg',
#    'Borstelmannsweg 133 25497 Prisdorf',
#    'Rechtsgrundlage ist Art. 6 12109 Berlin',
#    'Ohlrattweg 5 25497 Prisdorf',
#    'Ohlrattweg 5 02494 USA',
#    'Rechtsgrundlage ist Art. 6 20537 Hamburg',
#    'Rechtsgrundlage ist Art. 6 02494 USA',
#    'Ullsteinstraße 130 20537 Hamburg',
#    'Borstelmannsweg 133 02494 USA']],
#  ['https://apartment-hotel.de/impressum.html',
#   ['Borstelmannsweg 133 20537 Hamburg']],
#  ['https://apartment-hotel.de/kontakt.html',
#   ['Borstelmannsweg 133 20537 Hamburg']],
#  ['https://www.klingel-group.com/impressum/',
#   ['Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://klingel-med.de',
#   ['Hanauer Straße 6 1500 Mitarbeitern an',
#    'Hanauer Straße 6 75181 Pforzheim',
#    'Hanauer Straße 7 75181 Pforzheim',
#    'Hanauer Straße 7 1500 Mitarbeitern an',
#    'Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://www.klingel-group.com/kontakt/',
#   ['Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://www.klingel-group.com/datenschutz/',
#   ['Baden-Württemberg, Postfach 10 1500 Mitarbeitern an',
#    'Baden-Württemberg, Postfach 10 70025 Stuttgart',
#    'Baden-Württemberg, Postfach 10 75181 Pforzheim',
#    'Hanauer Straße 5-7 70025 Stuttgart',
#    'Hanauer Straße 5-7 75181 Pforzheim',
#    'Hanauer Straße 5-7 1500 Mitarbeitern an']],
#  ['https://connectivisten.de/datenschutz',
#   ['Westhafenplatz 1 60327 Frankfurt am Main',
#    'Berliner Allee 47 64295 Darmstadt',
#    'Berliner Allee 47 60327 Frankfurt am Main',
#    'Westhafenplatz 1 64295 Darmstadt']],
#  ['https://connectivisten.de/impressum',
#   ['Westhafenplatz 1 60327 Frankfurt am Main',
#    'Berliner Allee 47 64295 Darmstadt',
#    'Berliner Allee 47 60327 Frankfurt am Main',
#    'Westhafenplatz 1 64295 Darmstadt']],
#  ['https://connectivisten.de',
#   ['Westhafenplatz 1 60327 Frankfurt am Main',
#    'Berliner Allee 47 64295 Darmstadt',
#    'Berliner Allee 47 60327 Frankfurt am Main',
#    'Westhafenplatz 1 64295 Darmstadt']],
#  ['https://geco-event.com',
#   ['Scheuermann stiegen 2009 68199 Mannheim',
#    'Kiesteichweg 21 68199 Mannheim']],
#  ['https://geco-event.com/impressum.html', ['Kiesteichweg 21 68199 Mannheim']],
#  ['https://fs-etit.de/impressum-forum/',
#   ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['https://fs-etit.de', ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['https://fs-etit.de/impressum/',
#   ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['https://fs-etit.de/datenschutz-verein/',
#   ['Landgraf-Georg-Straße 4 64283 Darmstadt']],
#  ['http://private-arbeitsagentur.eu', ['Zeughausgasse 4 91154 Roth']],
#  ['https://zeninvest.de/impressum/',
#   ['Oberneuhofstrasse 1 2023 ZenInvest', 'Oberneuhofstrasse 1 6340 Baar']],
#  ['https://laokoongruppe.com/impressum/',
#   ['Schwamberger/Volkergasse 4 1150 Wien']],
#  ['https://quartier-theater.de/kontakt', ['Kornstraße 31 30167 Hannover']],
#  ['https://quartier-theater.de/impressum', ['Kornstraße 31 30167 Hannover']],
#  ['https://simple-fax.de/impressum',
#   ['Salzdahlumer Str. 196 2024 simple-fax',
#    'Salzdahlumer Str. 196 38126 Braunschweig']],
#  ['https://sternen-schluchsee.de/datenschutz/',
#   ['Talstraße 126 79194 Gundelfingen']],
#  ['https://sternen-schluchsee.de/impressum/',
#   ['Stadtstraße 2 10900 Berlin', 'Stadtstraße 2 79104 Freiburg']],
#  ['https://cinepostproduction.de/contact/',
#   ['Ringbahnstraße 16 2023 CinePostproduction GmbH',
#    'Beta-Straße 1 85774 Unterföhring',
#    'Beta-Straße 1 2023 CinePostproduction GmbH',
#    'Beta-Straße 1 12099 Berlin',
#    'Ringbahnstraße 16 12099 Berlin',
#    'Ringbahnstraße 16 85774 Unterföhring']],
#  ['https://cinepostproduction.de/datenschutz/',
#   ['Beta-Straße 1 85774 Unterföhring',
#    'Beta-Straße 1 1600 Amphitheatre Parkway',
#    'Beta-Straße 1 2023 CinePostproduction GmbH']],
#  ['https://neu.cinepost.de/impressum/',
#   ['Beta-Straße 1 85774 Unterföhring',
#    'Beta-Straße 1 2023 CinePostproduction GmbH']],
#  ['https://kreutzer-consulting.com/impressum.html',
#   ['Lindwurmstr. 109 80337 München']],
#  ['https://kreutzer-consulting.com/kontakt.html',
#   ['Lindwurmstr. 109 80337 München']],
#  ['https://kreutzer-consulting.com', ['Lindwurmstr. 109 80337 München']],
#  ['https://mooc-beratung.de/impressum/',
#   ['Schmilinskystraße 45 20099 Hamburg']],
#  ['https://mooc-beratung.de/kontakt/', ['Schmilinskystr. 45 20099 Hamburg']],
#  ['https://hirschen.com/impressum/', ['Schlesische Straße 26 10997 Berlin']],
#  ['https://honeymoments.de/datenschutz/',
#   ['Atoomweg 6 20457\xa0Hamburg',
#    'Eichhornstraße 3 20457\xa0Hamburg',
#    'Eichhornstraße 3 10785 Berlin',
#    'Rosenfelder Str. 15-16 20459 Hamburg',
#    'Rosenfelder Str. 15-16 9743 AK Groningen',
#    'Rosenfelder Str. 15-16 10315 Berlin',
#    'Eichhornstraße 3 2338 Luxemburg',
#    'Rosenfelder Str. 15-16 10785 Berlin',
#    'Atoomweg 6 1600 Amphitheatre Parkway',
#    'Rosenfelder Str. 15-16 20457\xa0Hamburg',
#    'Atoomweg 6 2338 Luxemburg',
#    'Atoomweg 6 9743 AK Groningen',
#    'Rosenfelder Str. 15-16 2338 Luxemburg',
#    'Eichhornstraße 3 1600 Amphitheatre Parkway',
#    'Eichhornstraße 3 20459 Hamburg',
#    'Atoomweg 6 10315 Berlin',
#    'Eichhornstraße 3 10315 Berlin',
#    'Eichhornstraße 3 9743 AK Groningen',
#    'Atoomweg 6 20459 Hamburg',
#    'Atoomweg 6 10785 Berlin',
#    'Rosenfelder Str. 15-16 1600 Amphitheatre Parkway']],
#  ['https://honeymoments.de/impressum/',
#   ['Rathausallee 72-76 22846 Norderstedt',
#    'Rathausallee 72-76 20457 Hamburg']],
#  ['https://plu.de/blog/let-s-connect-around-the-globe-with-tain',
#   ['Landsberger Straße 392 81241 München']],
#  ['https://plu.de/kontakt',
#   ['Grafenberger Allee 277-287 40237 Düsseldorf',
#    'Grafenberger Allee 277-287 81241 München',
#    'Heilbronner Strasse 150 10557 Berlin',
#    'Landsberger Straße 392 81241 München',
#    'Poststraße 2-4 20095 Hamburg',
#    'Poststraße 2-4 40237 Düsseldorf',
#    'Heilbronner Strasse 150 60329 Frankfurt a',
#    'Grafenberger Allee 277-287 20095 Hamburg',
#    'Bertha-Benz-Straße 5 60329 Frankfurt a',
#    'Bertha-Benz-Straße 5 40237 Düsseldorf',
#    'Landsberger Straße 392 40237 Düsseldorf',
#    'Poststraße 2-4 60329 Frankfurt a',
#    'Grafenberger Allee 277-287 60329 Frankfurt a',
#    'Landsberger Straße 392 10557 Berlin',
#    'Poststraße 2-4 10557 Berlin',
#    'Heilbronner Strasse 150 40237 Düsseldorf',
#    'Heilbronner Strasse 150 81241 München',
#    'Poststraße 2-4 81241 München',
#    'Grafenberger Allee 277-287 10557 Berlin',
#    'Heilbronner Strasse 150 20095 Hamburg',
#    'Landsberger Straße 392 60329 Frankfurt a',
#    'Bertha-Benz-Straße 5 10557 Berlin',
#    'Landsberger Straße 392 20095 Hamburg',
#    'Bertha-Benz-Straße 5 20095 Hamburg',
#    'Bertha-Benz-Straße 5 81241 München']],
#  ['https://plu.de/impressum', ['Landsberger Straße 392 81241 München']],
#  ['https://plu.de', ['Landsberger Straße 392 81241 München']],
#  ['https://plu.de/datenschutz', ['Landsberger Straße 392 81241 München']],
#  ['https://statt-theater.net/kontakt/impressum/',
#   ['Lange Straße 14 2017 Fehldiagnose',
#    'Lange Straße 14 2017 Räuber Hotzenplotz',
#    'Lange Straße 14 34454 Bad Arolsen-Mengeringhausen',
#    'Lange Straße 14 2022 Taxi Taxi',
#    'Lange Straße 14 2023 Das Oslo-Syndrom',
#    'Lange Straße 14 2023 Das kalte Herz',
#    'Lange Straße 14 2018 Aufguss',
#    'Lange Straße 14 2019 Stumm',
#    'Lange Straße 14 2019 Die Feuerzangenbowle',
#    'Lange Straße 14 2019 Jubiläum',
#    'Lange Straße 14 2017 Sebastian Sternenputtzer',
#    'Lange Straße 14 2021 Jakobs-Wunder-Abend',
#    'Lange Straße 14 2018 Ein Jedermann']],
#  ['https://www.nexworld.tv/nexworldtv/datenschutz/',
#   ['Altostr. 25f 82319 Starnberg']],
#  ['https://www.nexworld.tv/nexworldtv/impressum/',
#   ['Altostr. 25f 10117 Berlin',
#    'Reinhardtstr.52 10117 Berlin',
#    'Reinhardtstr.52 83219 Starnberg',
#    'Altostr. 25f 83219 Starnberg']],
#  ['https://lcs-schlieben.de/impressum',
#   ['Gartenstraße 45 04936 Schlieben', 'Gartenstr.45 04936 Schlieben']],
#  ['https://lcs-schlieben.de/kontakt', ['Gartenstraße 45 04936 Schlieben']],
#  ['https://pferdebild.de/kontakt/', ['Heider Weg 42 27777 Ganderkesee']],
#  ['https://pferdebild.de',
#   ['Heider Weg 42 27777 Ganderkesee',
#    'Heider Weg 42 2000 digital fotografiert',
#    'Heider Weg 42 1968 bis Hongkong']],
#  ['https://pferdebild.de/impressum/',
#   ['Heider Weg 42 27777 Ganderkesee', 'Heider Weg 42 77694 Kehl am Rhein']],
#  ['https://berlinlofts.com/en/impressum',
#   ['Stephanstraße 60 2024 berlinlofts', 'Stephanstraße 60 10559 Berlin']],
#  ['https://microdoc.com', ['Elektrastraße 6a 81925 Munich']],
#  ['https://microdoc.com/contact/',
#   ['Elektrastrasse 6 10115 Berlin',
#    'Elektrastrasse 6 70469 Stuttgart Germany',
#    'Elektrastrasse 6 81925 Munich',
#    'Novalisstrasse 12 81925 Munich',
#    'Elektrastraße 6a 10115 Berlin',
#    'Elektrastraße 6a 81925 Munich',
#    'Bludenzer Str. 6 81925 Munich',
#    'Elektrastraße 6a 70469 Stuttgart Germany',
#    'Novalisstrasse 12 10115 Berlin',
#    'Bludenzer Str. 6 70469 Stuttgart Germany',
#    'Novalisstrasse 12 70469 Stuttgart Germany',
#    'Bludenzer Str. 6 10115 Berlin']],
#  ['https://trelock.de/de/kontakt',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de/de/schloss/schloesser/rahmenschloesser/protect-o-connect-kabel',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de/de/schloss/schloesser/rahmenschloesser/protect-o-connect-ketten',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://trelock.de/de/impressum',
#   ['Johann-Krane-Weg 37 2022 TRELOCK GmbH',
#    'Johann-Krane-Weg 37 48149 Münster',
#    'Johann-Krane-Weg 37 48042 Münster']],
#  ['https://schmeckthal-gruppe.de/datenschutz/',
#   ['I-Gebiet Weidenbusch · Boschring 7 55252 Mainz-Kastel',
#    'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel',
#    'Waldring 43 56422 Wirges',
#    'Waldring 43 44789 Bochum',
#    'Fritz-Ullmann-Straße 4 56422 Wirges',
#    'I-Gebiet Weidenbusch · Boschring 7 44789 Bochum',
#    'Fritz-Ullmann-Straße 4 44789 Bochum',
#    'Waldring 43 55252 Mainz-Kastel',
#    'I-Gebiet Weidenbusch · Boschring 7 56422 Wirges']],
#  ['https://schmeckthal-gruppe.de/impressum/',
#   ['Boschring 7 56422 Wirges',
#    'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel',
#    'Boschring 7 55252 Mainz-Kastel',
#    'Fritz-Ullmann-Straße 4 56422 Wirges']],
#  ['https://schmeckthal-gruppe.de',
#   ['Boschring 7 56422 Wirges',
#    'Fritz-Ullmann-Straße 4 55252 Mainz-Kastel',
#    'Boschring 7 55252 Mainz-Kastel',
#    'Fritz-Ullmann-Straße 4 56422 Wirges']],
#  ['https://airnergy.shop/info/mein-kontakt.html',
#   ['Wehrstraße 24-26 53773 Hennef']],
#  ['https://airnergy.shop/info/impressum.html',
#   ['Wehrstr. 24-26 1601 S',
#    'Wehrstraße 24-26 1601 S',
#    'Wehrstraße 24-26 2011 by Airnergy International GmbH',
#    'Wehrstr. 24-26 53773 Hennef',
#    'Wehrstr. 24-26 2011 by Airnergy International GmbH',
#    'Wehrstraße 24-26 53773 Hennef']],
#  ['https://airnergy.shop',
#   ['Wehrstraße 24-26 93300 an',
#    'Wehrstraße 24-26 2022 mit verbesserten Duokats',
#    'Wehrstraße 24-26 53773 Hennef']],
#  ['https://airnergy.shop/info/privatsphaere-und-datenschutz.html',
#   ['Wehrstraße 24-26 53773 Hennef Telefon',
#    'Wehrstraße 24-26 2029 Stierlin Court',
#    'Dammtorstraße 29-32 1600 Amphitheatre Parkway',
#    'Wehrstraße 24-26 1600 Amphitheatre Parkway',
#    'Wehrstr. 26 53773 Hennef Telefon',
#    'Wehrstraße 24-26 53773 Hennef',
#    'Wehrstr. 26 2029 Stierlin Court',
#    'Dammtorstraße 29-32 53773 Hennef Telefon',
#    'Dammtorstraße 29-32 53773 Hennef',
#    'Wehrstr. 26 1355 Market Street',
#    'Wehrstr. 26 1601 Willow Road',
#    'Wehrstr. 26 20354 Hamburg',
#    'Wehrstr. 26 53773 Hennef',
#    'Wehrstr. 26 1600 Amphitheatre Parkway',
#    'Dammtorstraße 29-32 20354 Hamburg',
#    'Dammtorstraße 29-32 2029 Stierlin Court',
#    'Wehrstraße 24-26 1355 Market Street',
#    'Dammtorstraße 29-32 1355 Market Street',
#    'Dammtorstraße 29-32 1601 Willow Road',
#    'Wehrstraße 24-26 1601 Willow Road',
#    'Wehrstraße 24-26 20354 Hamburg']],
#  ['https://littlesun.org/contact/', ['Zehdenicker Str. 21 10119 Berlin']],
#  ['https://fogjoggers.com/contact/',
#   ['Zülpicher Straße 221 50937 Köln',
#    'Rechtsgrundlage von Art. 6 1600 Amphitheatre Parkway',
#    'Rechtsgrundlage hierbei ist Art. 6 50823 Köln',
#    'Rechtsgrundlage ist Art. 6 50823 Köln',
#    'Rechtsgrundlage ist Art. 6 1600 Amphitheatre Parkway',
#    'Rechtsgrundlage ist Art. 6 50937 Köln',
#    'Zülpicher Straße 221 1600 Amphitheatre Parkway',
#    'Rechtsgrundlage hierbei ist Art. 6 50937 Köln',
#    'Rechtsgrundlage von Art. 6 94043 USA',
#    'Rechtsgrundlage hierbei ist Art. 6 94043 USA',
#    'Vogelsanger Str. 82 1600 Amphitheatre Parkway',
#    'Rechtsgrundlage ist Art. 6 94043 USA',
#    'Rechtsgrundlage von Art. 6 50937 Köln',
#    'Vogelsanger Str. 82 94043 USA',
#    'Rechtsgrundlage von Art. 6 50823 Köln',
#    'Vogelsanger Str. 82 50823 Köln',
#    'Zülpicher Straße 221 50823 Köln',
#    'Vogelsanger Str. 82 50937 Köln',
#    'Zülpicher Straße 221 94043 USA']],
#  ['https://lightweb-media.de/impressum/',
#   ['Gebirgspionierstr. 22 60486 Frankfurt',
#    'Voltastraße 84 60486 Frankfurt',
#    'Gebirgspionierstr. 22 82481 Mittenwald',
#    'Voltastraße 84 82481 Mittenwald']],
#  ['https://lightweb-media.de/datenschutz/',
#   ['Rechtsgrundlage sind Art. 6 82481 Mittenwald',
#    'Rechtsgrundlage ist Art. 6 82481 Mittenwald',
#    'Rechtsgrundlage hierfür ist Art. 88 82481 Mittenwald']],
#  ['https://diekavallerie.de/datenschutz/',
#   ['Köpenicker Straße 126 91710 Gunzenhausen',
#    'Rosentalstraße 8 10179 Berlin',
#    'Rechtsgrundlage hierfür ist § 26 91710 Gunzenhausen',
#    'Rechtsgrundlage hierfür ist Art. 6 91710 Gunzenhausen',
#    'Industriestr. 25 22305 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 10179 Berlin',
#    'Rechtsgrundlage hierfür ist Art. 6 22305 Hamburg',
#    'Rosentalstraße 8 91710 Gunzenhausen',
#    'Köpenicker Straße 126 22305 Hamburg',
#    'Rechtsgrundlage hierfür ist § 26 72070 Tübingen',
#    'Rosentalstraße 8 22305 Hamburg',
#    'Rechtsgrundlage hierfür ist Art. 6 72070 Tübingen',
#    'Rechtsgrundlage hierfür ist § 26 10179 Berlin',
#    'Köpenicker Straße 126 72070 Tübingen',
#    'Industriestr. 25 91710 Gunzenhausen',
#    'Industriestr. 25 10179 Berlin',
#    'Rechtsgrundlage hierfür ist § 26 22305 Hamburg',
#    'Köpenicker Straße 126 10179 Berlin',
#    'Rosentalstraße 8 72070 Tübingen',
#    'Industriestr. 25 72070 Tübingen']],
#  ['https://diekavallerie.de/impressum/', ['Rosentalstraße 8 72070 Tübingen']],
#  ['https://severn.de',
#   ['Berner Straße 74 60437 Frankfurt am Main',
#    'Finanzmarktregulatorik 2023 60437 Frankfurt am Main']],
#  ['https://severn.de/kontakt/', ['Berner Straße 74 60437 Frankfurt am Main']],
#  ['https://hohnwerbetechnik.com',
#   ['Klingenberger Straße 4 74223 Flein',
#    'Fabrikstraße 8 74223 Flein',
#    'Klingenberger Straße 4 74232 Abstatt',
#    'Fabrikstraße 8 74232 Abstatt']],
#  ['https://wandres.com/datenschutz/',
#   ['Im Gewerbepark 8 79252 Stegen', 'Im Gewerbepark 8 41460 Neuss']],
#  ['https://wandres.com/impressum/', ['Im Gewerbepark 8 79252 Stegen']],
#  ['https://wiblishauser-seminare.de/impressum/',
#   ['Schellingstr. 109a 8078 München', 'Schellingstr. 109a 80798 München']],
#  ['https://wiblishauser-seminare.de/datenschutz/',
#   ['Schellingstr. 109a 2449 Luxembourg', 'Schellingstr. 109a 80798 München']],
#  ['https://horizont.com/de/Metanavigation/datenschutz',
#   ['Rechtsgrundlage hierfür ist Art. 6 34497 Korbach',
#    'Mengeringhäuser Str. 15 34497 Korbach',
#    'Mengeringhäuser Str. 15 80331 München',
#    'Homberger Weg 4-6 80331 München',
#    'Homberger Weg 4-6 34497 Korbach',
#    'Homberger Weg 4-6 34454 Bad Arolsen',
#    'Rechtsgrundlage hierfür ist Art. 6 80331 München',
#    'Mengeringhäuser Str. 15 34454 Bad Arolsen']],
#  ['https://horizont.com/de/Metanavigation/impressum',
#   ['Homberger Weg 4-6 34497 Korbach']],
#  ['https://horizont.com', ['Homberger Weg 4-6 34497 Korbach']],
#  ['https://horizont.com/de/c/kontakt',
#   ['Homberger Weg 4-6 34497 Korbach',
#    'Homberger Weg 4-6 67360 Eschbach',
#    'Homberger Weg 4-6 1215 SL - Medvode']],
#  ['https://alexander-training.de/impressum',
#   ['Goethestr. 112 63067 Offenbach']],
#  ['https://alexander-training.de/datenschutz',
#   ['Alexander-Training, Robert Brandl, Oskar-Stalf-Str. 37 85665 Moosach']],
#  ['https://mekos.de/impressum/',
#   ['Lise-Meitner-Straße 6 10627 Berlin',
#    'Kantstraße 99 10627 Berlin',
#    'Lise-Meitner-Straße 6 28359 Bremen',
#    'Kantstraße 99 28359 Bremen']],
#  ['https://mekos.de/datenschutz/', ['Lise-Meitner-Str. 6 28359 Bremen']],
#  ['https://china-outbound.com',
#   ['Gluckstr. 57 2016 COTRI moves to Hamburg',
#    'Gluckstr. 57 2002 PhD',
#    'Gluckstr. 57 2023 and beyond',
#    'Gluckstr. 57 2023 Start COTMI weekly publication',
#    'Gluckstr. 57 2023 Restart China outbound tourism',
#    'Gluckstr. 57 1978 First visit of Prof',
#    'Gluckstr. 57 22081 Hamburg',
#    'Gluckstr. 57 2008 COTRI moves to Heide',
#    'Gluckstr. 57 1957 in West-Berlin']],
#  ['https://das-comitee.com/kontakt/',
#   ['Oberaltenallee 20 22081 Hamburg', 'Oberaltenallee 20 20457 Hamburg']],
#  ['https://das-comitee.com/impressum/',
#   ['Thadenstrasse 134 07819 Nuestra Sra', 'Thadenstrasse 134 22767 Hamburg']],
#  ['http://altec-cs.com/Impressum', ['Bayernstraße 10 30855 Langenhagen']],
#  ['http://altec-cs.com/Kontakt', ['Bayernstraße 10 30855 Langenhagen']],
#  ['https://www.scoop-yard.de/impressum/',
#   ['Hoheluftchaussee 40 20253 Hamburg']],
#  ['https://scoop-yard.de',
#   ['Turnringen, Girevoy (Wettkampf-Kettlebells), Concept2 20253 Hamburg',
#    'Hoheluftchaussee 40 20253 Hamburg']],
#  ['https://www.scoop-yard.de/kontakt/',
#   ['Hoheluftbrücke\xa0+ 6 20253 Hamburg',
#    'Hoheluftchaussee 40 20253 Hamburg',
#    'Hoheluftbrücke\xa0+ 5 20253 Hamburg',
#    'Eppendorfer Weg (Ost)\xa0+ 4 20253 Hamburg']],
#  ['https://www.scoop-yard.de/datenschutz/',
#   ['Dammtorstraße 29-32 20354 Hamburg',
#    'Rechtsgrundlage der Verarbeitung Art. 6 20354 Hamburg',
#    'Rechtsgrundlage der Verarbeitung Art. 6 20253 Hamburg',
#    'Dammtorstraße 29-32 1355 Market Street',
#    'Hoheluftchaussee 40 20354 Hamburg',
#    'Hoheluftchaussee 40 1601 Willow Road',
#    'Dammtorstraße 29-32 1601 Willow Road',
#    'Hoheluftchaussee 40 20253 Hamburg',
#    'Hoheluftchaussee 40 1355 Market Street',
#    'Rechtsgrundlage dieser Verarbeitung Art. 6 20253 Hamburg',
#    'Rechtsgrundlage dieser Verarbeitung Art. 6 20354 Hamburg',
#    'Dammtorstraße 29-32 20253 Hamburg']],
#  ['https://drk-rhein-nahe.de/impressum/',
#   ['Binger Straße 25 2024 aktualisiert']],
#  ['https://drk-rhein-nahe.de/kontakt/anfahrtshinweis/',
#   ['Hauptbahnhofs ist nur 500m 55131 Mainz', 'Binger Straße 25 55131 Mainz']],
#  ['https://mester.de/impressum/',
#   ['Königinstraße 28 33609 Bielefeld',
#    'Königinstraße 28 33613 Bielefeld',
#    'Königinstraße 28 80802 München',
#    'Königinstraße 28 2024 Mester']],
#  ['https://xell-consulting.de/impressum',
#   ['Seegarten 44 97297 Waldbüttelbrunn']],
#  ['https://agbf.com/de/kontakt', ['Seehofstr. 15 14169 Berlin']],
#  ['https://agbf.com', ['Seehofstr. 15 14169 Berlin']],
#  ['https://agbf.com/en/contact', ['Seehofstr. 15 14169 Berlin']],
#  ['https://agbf.com/de/impressum', ['Seehofstr. 15 14169 Berlin']],
#  ['https://starface.com/kontakt/', ['Adlerstraße 61 76137 Karlsruhe']],
#  ['https://starface.com/produktwelt/connect-sip-trunk/',
#   ['Adlerstraße 61 76137 Karlsruhe']],
#  ['https://starface.com', ['Adlerstraße 61 76137 Karlsruhe']],
#  ['https://starface.com/impressum/',
#   ['Adlerstraße 61 2489 Berlin',
#    'Sandner Straße 3 76137 Karlsruhe',
#    'Max-Planck-Straße 3 1100 Wien',
#    'Zimmerstraße 6 76137\xa0Karlsruhe',
#    'Max-Planck-Straße 3 76137 Karlsruhe',
#    'Zimmerstraße 6 2489 Berlin',
#    'Sandner Straße 3 1100 Wien',
#    'Max-Planck-Straße 3 76137\xa0Karlsruhe',
#    'Adlerstraße 61 76137\xa0Karlsruhe',
#    'Sandner Straße 3 76137\xa0Karlsruhe',
#    'Sandner Straße 3 2489 Berlin',
#    'Adlerstraße 61 76137 Karlsruhe',
#    'Adlerstraße 61 1100 Wien',
#    'Zimmerstraße 6 76137 Karlsruhe',
#    'Max-Planck-Straße 3 2489 Berlin',
#    'Zimmerstraße 6 1100 Wien']],
#  ['https://fgk-cro.com/contact-de-com', ['Heimeranstrasse 35 80339 Munich']],
#  ['https://fgk-cro.com', ['Heimeranstrasse 35 80339 Munich']],
#  ['https://fgk-cro.com/about-us/locations-contact',
#   ['Friedrichstraße 95 1027 Budapest',
#    'Friedrichstraße 95 80339 Munich',
#    'Heimeranstrasse 35 80339 Munich',
#    'Friedrichstraße 95 10117 Berlin',
#    'Heimeranstrasse 35 1027 Budapest',
#    'Heimeranstrasse 35 10117 Berlin']],
#  ['https://beds24.com/impressum.html', ['Davoser Str. 1g 14199 Berlin']],
#  ['https://junge-presse.de/datenschutz/',
#   ['Frankenstraße 185 45134 Essen',
#    'Frankenstraße 185 1600 Amphitheatre Parkway']],
#  ['https://junge-presse.de/kontakt/impressum/',
#   ['Frankenstraße 185 45134 Essen']],
#  ['https://raeume-zum-feiern.de/impressum.html',
#   ['Am Staudamm 24 02906 Quitzdorf am See']],
#  ['https://raeume-zum-feiern.de/datenschutz.html',
#   ['Am Staudamm 24 91710 Gunzenhausen',
#    'Am Staudamm 24 02906 Quitzdorf am See',
#    'Industriestr. 25 94043 USA',
#    'Am Staudamm 24 1600 Amphitheatre Parkway',
#    'Am Staudamm 24 94043 USA',
#    'Industriestr. 25 1600 Amphitheatre Parkway',
#    'Industriestr. 25 91710 Gunzenhausen',
#    'Industriestr. 25 02906 Quitzdorf am See']],
#  ['https://cupcino.com/kontakt/', ['Paderborner Straße 33 33161 Hövelhof']],
#  ['https://cupcino.com/datenschutz/',
#   ['Pamplonastraße 19 30539 Hannover',
#    'Pamplonastraße 19 33106 Paderborn',
#    'Dammtorstraße 30 1601 Willow Road',
#    'Dammtorstraße 30 01801 USA',
#    'Paderborner Straße 33 40213 Düsseldorf',
#    'Paderborner Straße 33 20354 Hamburg',
#    'Kavalleriestraße 2-4 40213 Düsseldorf',
#    'Kavalleriestraße 2-4 33106 Paderborn',
#    'Kavalleriestraße 2-4 30539 Hannover',
#    'Pamplonastraße 19 33161 Hövelhof',
#    'Dammtorstraße 30 30539 Hannover',
#    'Dammtorstraße 30 33106 Paderborn',
#    'Paderborner Straße 33 01801 USA',
#    'Pamplonastraße 19 20354 Hamburg',
#    'Kavalleriestraße 2-4 1601 Willow Road',
#    'Dammtorstraße 30 33161 Hövelhof',
#    'Pamplonastraße 19 1601 Willow Road',
#    'Pamplonastraße 19 01801 USA',
#    'Kavalleriestraße 2-4 01801 USA',
#    'Paderborner Straße 33 30539 Hannover',
#    'Dammtorstraße 30 40213 Düsseldorf',
#    'Paderborner Straße 33 33106 Paderborn',
#    'Kavalleriestraße 2-4 20354 Hamburg',
#    'Paderborner Straße 33 1601 Willow Road',
#    'Pamplonastraße 19 40213 Düsseldorf',
#    'Paderborner Straße 33 33161 Hövelhof',
#    'Dammtorstraße 30 20354 Hamburg',
#    'Kavalleriestraße 2-4 33161 Hövelhof']],
#  ['https://cupcino.com/impressum/', ['Paderborner Straße 33 33161 Hövelhof']],
#  ['https://pulscamp.de', ['Kaskelstr. 53 10317 Berlin']],
#  ['https://pulscamp.de/impressum', ['Kaskelstraße 53 10317 Berlin']],
#  ['https://a-maze.net', ['Brunnenstr. 153 10115 Berlin']],
#  ['https://vsda.de/impressum/',
#   ['Zimmermannweg 28 64285 Darmstadt',
#    'Bessunger Str. 5 64285 Darmstadt',
#    'Zimmermannweg 28 64289 Darmstadt',
#    'Bessunger Str. 5 64289 Darmstadt']],
#  ['https://vsda.de/datenschutz/',
#   ['Rechtsgrundlagen: Einwilligung (Art. 6 64289 Darmstadt',
#    'Zimmermannweg 28 64289 Darmstadt']],
#  ['https://vsda.de/kontakt/', ['Zimmermannweg 28 64289 Darmstadt']],
#  ['https://spindash.de/impressum', ['Baselstrasse 47 6003 Luzern']],
#  ['https://unwomen.de/datenschutz/',
#   ['Anklamer Straße 38 53115 Bonn',
#    'Anklamer Straße 38 10115 Berlin',
#    'Rechtsgrundlage ist Art. 6 86150 Augsburg',
#    'Schießgrabenstr. 32 86150 Augsburg',
#    'Wittelsbacherring 9 2449 Luxemburg',
#    'Schießgrabenstr. 32 1601 S',
#    'Anklamer Straße 38 1601 S',
#    'Konrad-Adenauer-Ufer 85 1355 Market St',
#    'Rechtsgrundlage ist Art. 6 1600 Amphitheatre Parkway',
#    'Wittelsbacherring 9 10115 Berlin',
#    'Konrad-Adenauer-Ufer 85 1601 Willow Road',
#    'Rechtsgrundlage ist Art. 6 1601 Willow Road',
#    'Wittelsbacherring 9 1600 Amphitheatre Parkway',
#    'Wittelsbacherring 9 1601 S',
#    'Konrad-Adenauer-Ufer 85 80339 München',
#    'Anklamer Straße 38 1601 Willow Road',
#    'Rechtsgrundlage ist Art. 6 1355 Market St',
#    'Rechtsgrundlage ist Art. 6 1601 S',
#    'Schießgrabenstr. 32 1601 Willow Road',
#    'Konrad-Adenauer-Ufer 85 1600 Amphitheatre Parkway',
#    'Schießgrabenstr. 32 80339 München',
#    'Wittelsbacherring 9 1355 Market St',
#    'Konrad-Adenauer-Ufer 85 50668 Köln',
#    'Anklamer Straße 38 1600 Amphitheatre Parkway',
#    'Konrad-Adenauer-Ufer 85 86150 Augsburg',
#    'Rechtsgrundlage ist Art. 6 50668 Köln',
#    'Wittelsbacherring 9 53115 Bonn',
#    'Konrad-Adenauer-Ufer 85 2449 Luxemburg',
#    'Konrad-Adenauer-Ufer 85 1601 S',
#    'Anklamer Straße 38 2449 Luxemburg',
#    'Anklamer Straße 38 80339 München',
#    'Schießgrabenstr. 32 50668 Köln',
#    'Rechtsgrundlage ist Art. 6 53115 Bonn',
#    'Rechtsgrundlage ist Art. 6 10115 Berlin',
#    'Anklamer Straße 38 50668 Köln',
#    'Wittelsbacherring 9 86150 Augsburg',
#    'Anklamer Straße 38 1355 Market St',
#    'Konrad-Adenauer-Ufer 85 53115 Bonn',
#    'Rechtsgrundlage ist Art. 6 2449 Luxemburg',
#    'Rechtsgrundlage ist Art. 6 80339 München',
#    'Schießgrabenstr. 32 10115 Berlin',
#    'Schießgrabenstr. 32 2449 Luxemburg',
#    'Schießgrabenstr. 32 53115 Bonn',
#    'Schießgrabenstr. 32 1355 Market St',
#    'Anklamer Straße 38 86150 Augsburg',
#    'Wittelsbacherring 9 1601 Willow Road',
#    'Wittelsbacherring 9 50668 Köln',
#    'Schießgrabenstr. 32 1600 Amphitheatre Parkway',
#    'Wittelsbacherring 9 80339 München',
#    'Konrad-Adenauer-Ufer 85 10115 Berlin']],
#  ['https://unwomen.de/kontakt/',
#   ['Wittelsbacherring 9 10115 Berlin',
#    'Anklamer Straße 38 53115 Bonn',
#    'Anklamer Straße 38 10115 Berlin',
#    'Wittelsbacherring 9 53115 Bonn']],
#  ['https://unwomen.de/impressum/',
#   ['Wittelsbacherring 9 53115 Bonn',
#    'Stahlgruberring 3 81829 München',
#    'Wittelsbacherring 9 81829 München',
#    'Wittelsbacherring 9 6363 eingetragen',
#    'Stahlgruberring 3 6363 eingetragen',
#    'Stahlgruberring 3 53115 Bonn']],
#  ['https://unwomen.de',
#   ['Bundesgartenschau 2023 2021 nach',
#    'Bundesgartenschau 2023 2022 lautet das Motto',
#    'Bundesgartenschau 2023 2024 statt',
#    'Bundesgartenschau 2023 2023 gemeinsam mit Partner',
#    'Bundesgartenschau 2023 2023 lautet das Motto']],
#  ['https://fgk-rs.com/footer/contact',
#   ['Vaartweg 36 80339 München',
#    'Heimeranstraße 35 4731 RA Oudenbosch',
#    'Heimeranstraße 35 5637 Beinwil',
#    'Vaartweg 36 5637 Beinwil',
#    'Heimeranstraße 35 80339 München',
#    'Vaartweg 36 4731 RA Oudenbosch']],
#  ['https://andymagro.com/contact/',
#   ['Horneckgasse 6 3950 Arrowhead Street',
#    'Marienstraße 13 1123 Kamehameha Hwy Ste D',
#    'Marienstraße 13 1170 Vienna',
#    'Horneckgasse 6 1170 Vienna',
#    'Horneckgasse 6 1010 Common Street',
#    'Horneckgasse 6 1430 Broadway',
#    'Horneckgasse 6 06526 Sangerhausen',
#    'Marienstraße 13 06526 Sangerhausen',
#    'Marienstraße 13 1430 Broadway',
#    'Horneckgasse 6 9440\xa0S',
#    'Horneckgasse 6 1123 Kamehameha Hwy Ste D',
#    'Horneckgasse 6 4150 Santa Monica Blvd',
#    'Marienstraße 13 1010 Common Street',
#    'Marienstraße 13 3950 Arrowhead Street',
#    'Marienstraße 13 4150 Santa Monica Blvd',
#    'Marienstraße 13 9440\xa0S']],
#  ['https://weareforeal.com',
#   ['Seizstraße 2-4 54290 Trier',
#    'Seizstraße 2-4 2023 Titles',
#    'Seizstraße 2-4 2024 by FOREAL']],
#  ['https://mysumtu.com/datenschutz/',
#   ['Luther Weg 77 1601 Willow Road',
#    'Dammtorstraße 29-32 20354 Hamburg',
#    'Luther Weg 77 20354 Hamburg',
#    'Luther Weg 77 31515 Wunstorf',
#    'Dammtorstraße 29-32 1600 Amphitheatre Parkway',
#    'Dammtorstraße 29-32 1355 Market Street',
#    'Luther Weg 77 1600 Amphitheatre Parkway',
#    'Luther Weg 77 2029 Stierlin Court',
#    'Dammtorstraße 29-32 31515 Wunstorf',
#    'Dammtorstraße 29-32 1601 Willow Road',
#    'Luther Weg 77 1601 South California Avenue',
#    'Dammtorstraße 29-32 2029 Stierlin Court',
#    'Dammtorstraße 29-32 1601 South California Avenue',
#    'Luther Weg 77 1355 Market Street']],
#  ['https://mysumtu.com/impressum/', ['Luther Weg 77 31515 Wunstorf']],
#  ['https://pyrotechnik24.com/datenschutz/',
#   ['Rigistr. 8-10 12277 Berlin',
#    'Subbelrather Str. 15 50823 Köln',
#    'Rigistr. 8-10 50823 Köln',
#    'Rigistr. 8-10 2019 by',
#    'Subbelrather Str. 15 2019 by',
#    'Subbelrather Str. 15 12277 Berlin']],
#  ['https://pyrotechnik24.com/impressum/',
#   ['Hermsheimer Straße 3 2019 by',
#    'Rigistraße 8 12277 Berlin',
#    'Rigistr. 8 2019 by',
#    'Rigistraße 8 68163 Mannheim',
#    'Hermsheimer Straße 3 10559 Berlin',
#    'Turmstraße 21 68163 Mannheim',
#    'Turmstraße 21 10559 Berlin',
#    'Rigistraße 8 2019 by',
#    'Hermsheimer Straße 3 12277 Berlin',
#    'Rigistraße 8 10559 Berlin',
#    'Rigistr. 8 10559 Berlin',
#    'Hermsheimer Straße 3 68163 Mannheim',
#    'Rigistr. 8 12277 Berlin',
#    'Turmstraße 21 12277 Berlin',
#    'Rigistr. 8 68163 Mannheim',
#    'Turmstraße 21 2019 by']],
#  ['https://pyrotechnik24.com/produkte/datenschutz',
#   ['Subbelrather Str. 15 2018 by',
#    'Rigistr. 8-10 12277 Berlin',
#    'Friedensallee 254 81373 München',
#    'Friedensallee 254 50823 Köln',
#    'Radlkoferstraße 2 2018 by',
#    'Rigistr. 8-10 22763 Hamburg',
#    'Radlkoferstraße 2 81373 München',
#    'Radlkoferstraße 2 50823 Köln',
#    'Friedensallee 254 2018 by',
#    'Friedensallee 254 22763 Hamburg',
#    'Rigistr. 8-10 50823 Köln',
#    'Subbelrather Str. 15 81373 München',
#    'Rigistr. 8-10 81373 München',
#    'Radlkoferstraße 2 22763 Hamburg',
#    'Subbelrather Str. 15 50823 Köln',
#    'Radlkoferstraße 2 12277 Berlin',
#    'Subbelrather Str. 15 12277 Berlin',
#    'Friedensallee 254 12277 Berlin',
#    'Subbelrather Str. 15 22763 Hamburg',
#    'Rigistr. 8-10 2018 by']],
#  ['https://pyrotechnik24.com/kontakt/',
#   ['Rigistraße 8-10 2019 by', 'Rigistraße 8-10 12277 Berlin']],
#  ['https://pyrotechnik24.com',
#   ['Rigistraße 10 12277 Berlin', 'Rigistraße 10 2019 by']]]

# %% [markdown]
# #### Loading the existing data (previous found addresses)

# %%
existing_data = pd.read_csv('Addresses.csv')

# %% [markdown]
# #### For each URL we will check if the found address is real and put the valid ones into the CSV
# - we can't make this step asynchronous because the Geopy library allows only 1 request per second

# %%
real_addressesD = []

# %%
for elem in addresses_listD:
    # print(elem[0])
    for adresa in elem[1]:
        # print(adresa)
        real_address = extract_address(adresa)
        if real_address != None:
            print("valid")
            if 'country' in real_address:
                country = real_address['country']
            else:
                country = ""
                
            if 'county' in real_address:
                region = real_address['county']
            else:
                region = ""
                
            if 'city' in real_address:
                city = real_address['city']
            elif 'village' in real_address:
                city = real_address['village']
            else:
                city = ""
                
            if 'postcode' in real_address:
                postcode = real_address['postcode']
            else:
                postcode = ""
                
            if 'road' in real_address:
                road = real_address['road']
            else:
                road = ""
                
            if 'house_number' in real_address:
                no_road = real_address['house_number']
            else:
                no_road = ""
            # Adding the new data rows in the list
            real_addressesD.append([elem[0], country, region, city, postcode, road, no_road])
            
        else:
            print("invalid")
# Out:
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid

# %%
len(real_addressesD)
# Out:
# 479

# %% [markdown]
# #### Making a DataFrame with the extracted addresses

# %%
new_data_df = pd.DataFrame(real_addressesD, columns=['URL', 'Country', 'Region', 'City', 'Postcode', 'Road', 'Road number'])

# %%
new_data_df
# Out:
#                                                  URL      Country  \
# 0      https://www.cantus-bahn.de/metamenu/impressum  Deutschland
# 1    https://www.cantus-bahn.de/metamenu/datenschutz  Deutschland
# 2                   https://pastisani.com/impressum/  Deutschland
# 3                 https://pastisani.com/datenschutz/  Deutschland
# 4                 https://pastisani.com/datenschutz/  Deutschland
# ..                                               ...          ...
# 474   https://pyrotechnik24.com/produkte/datenschutz  Deutschland
# 475               https://pyrotechnik24.com/kontakt/  Deutschland
# 476               https://pyrotechnik24.com/kontakt/  Deutschland
# 477                        https://pyrotechnik24.com  Deutschland
# 478                        https://pyrotechnik24.com  Deutschland
#
#                           Region               City Postcode  \
# 0                                            Kassel    34117
# 1               Landkreis Kassel                       34369
# 2                                 Frankfurt am Main    60386
# 3                Westerwaldkreis                       56410
# 4                                 Frankfurt am Main    60386
# ..                           ...                ...      ...
# 474  Landkreis Weilheim-Schongau    Hohenpeißenberg    82383
# 475  Landkreis Weilheim-Schongau    Hohenpeißenberg    82383
# 476                                          Berlin    12277
# 477                                          Berlin    12277
# 478  Landkreis Weilheim-Schongau    Hohenpeißenberg    82383
#
#                     Road Road number
# 0    Franz-Ulrich-Straße          18
# 1            Neue Straße          22
# 2           Orber Straße          30
# 3     Elgendorfer Straße          57
# 4           Orber Straße          30
# ..                   ...         ...
# 474           Rigistraße
# 475           Rigistraße
# 476           Rigistraße
# 477           Rigistraße          10
# 478           Rigistraße
#
# [479 rows x 7 columns]

# %% [markdown]
# #### Adding them to the existent data (from the US)

# %%
final_data = pd.concat([existing_data, new_data_df], ignore_index=True)

# %%
final_data
# Out:
#                                                 URL        Country  \
# 0                            https://embcmonroe.org  United States
# 1                            https://embcmonroe.org  United States
# 2           https://embcmonroe.org/connect-with-us/  United States
# 3                 https://casepaper.com/contact-us/  United States
# 4                 https://casepaper.com/contact-us/  United States
# ..                                              ...            ...
# 581  https://pyrotechnik24.com/produkte/datenschutz    Deutschland
# 582              https://pyrotechnik24.com/kontakt/    Deutschland
# 583              https://pyrotechnik24.com/kontakt/    Deutschland
# 584                       https://pyrotechnik24.com    Deutschland
# 585                       https://pyrotechnik24.com    Deutschland
#
#                           Region              City Postcode  \
# 0                   Union County            Monroe  28112.0
# 1                   Union County            Monroe  28112.0
# 2                   Union County            Monroe  28112.0
# 3            Philadelphia County      Philadelphia  19134.0
# 4          San Bernardino County  Rancho Cucamonga  91730.0
# ..                           ...               ...      ...
# 581  Landkreis Weilheim-Schongau   Hohenpeißenberg    82383
# 582  Landkreis Weilheim-Schongau   Hohenpeißenberg    82383
# 583                                         Berlin    12277
# 584                                         Berlin    12277
# 585  Landkreis Weilheim-Schongau   Hohenpeißenberg    82383
#
#                   Road Road number
# 0       Maurice Street         503
# 1       Maurice Street         503
# 2       Maurice Street         503
# 3    East Tioga Street         499
# 4       Hermosa Avenue        9168
# ..                 ...         ...
# 581         Rigistraße
# 582         Rigistraße
# 583         Rigistraße
# 584         Rigistraße          10
# 585         Rigistraße
#
# [586 rows x 7 columns]

# %% [markdown]
# #### Export the data to the CSV

# %%
final_data.to_csv('Addresses.csv', index=False)

# %% [markdown]
# ## United Kingdom

# %%
# the Deutsch domains are from to 1622 to the end
domainsUK = df_parquet.iloc[1622:]['domain']

# %%
domainsUK
# Out:
# 1622                      liamjcurtin.com
# 1623                           trinyx.org
# 1624                       crystalage.com
# 1625                       datasafexl.com
# 1626                         enigmacs.com
#                       ...
# 2474          northernirelandscreen.co.uk
# 2475                      birdbrand.co.uk
# 2476    thorntonlodgenorthyorkshire.co.uk
# 2477              peasholmecharity.org.uk
# 2478                         mackay.co.uk
# Name: domain, Length: 857, dtype: object

# %% [markdown]
# - Asynchronous main function where for the domains list we obtain the url scheme

# %%
async def main(domains):
    tasks = [get_url_scheme(domain) for domain in domains]
    results = await asyncio.gather(*tasks, return_exceptions=True)
    return results

# %%
# Rulează funcția principală
resultsUK = await main(domainsUK)

# %%
len(resultsUK)
# Out:
# 857

# %%
# Printing the results
complete_urlsUK = []
for result in resultsUK:
    if isinstance(result, tuple):
        domain, scheme = result
        complete_url = f"{scheme}://{domain}"
        print(f"Url complet: {complete_url}")
        complete_urlsUK.append(complete_url)
    else:
        print(f"Rezultat neașteptat: {result}")
# Out:
# Url complet: https://liamjcurtin.com
# Url complet: https://trinyx.org
# Url complet: https://crystalage.com
# Url complet: https://datasafexl.com
# Url complet: https://enigmacs.com
# Url complet: https://pennyanderson.com
# Url complet: https://inovix.net
# Url complet: https://rosybee.com
# Url complet: https://newfield.co.uk
# Url complet: https://dscsoundandlighting.co.uk
# Url complet: https://neseafood.com
# Url complet: https://web-design-studios.com
# Url complet: https://oppobrothers.com
# Url complet: http://lionheart-security.co.uk
# Url complet: http://miltonkeynesphotography.com
# Url complet: https://classichandtools.com
# Url complet: https://pcacoach.com
# Url complet: https://carinaskinnermanagement.co.uk
# Url complet: https://sentiment.io
# Url complet: https://urbanstrides.com
# Url complet: https://easthams.co.uk
# Url complet: https://bergsonandeaton.com
# Url complet: https://vasek.co.uk
# Url complet: https://truebeautyaesthetic.com
# Url complet: https://kentscp.com
# Url complet: https://snaresbrookprep.org
# Url complet: https://peytonandbyrne.co.uk
# Url complet: https://rgr-garages.co.uk
# Url complet: https://essentialsurrey.co.uk
# Url complet: http://fpsgconnect.co.uk
# Url complet: https://zeroh.net
# Url complet: http://connaughthousehotel.com
# Url complet: https://cyclesolutions.co.uk
# Url complet: https://fordandslatercoventry.co.uk
# Url complet: https://laywheeler.com
# Url complet: https://sixphysio.com
# Url complet: https://crg1.co.uk
# Url complet: https://mcvideo.co.uk
# Url complet: https://rising-records.com
# Url complet: https://penn-elcom.com
# Url complet: http://bannerfy.com
# Url complet: https://aberdeenpattestservices.com
# Url complet: http://cforl.co.uk
# Url complet: https://rmsrecruitment.com
# Url complet: https://dsnmltd.com
# Url complet: http://goldexapp.com
# Url complet: https://burnhamgarage.co.uk
# Url complet: https://cambriancruisers.co.uk
# Url complet: https://gleanin.com
# Url complet: http://profit-loss.com
# Url complet: https://joolsstone.com
# Url complet: https://nicholsonstransport.co.uk
# Url complet: https://themartialartscentre.com
# Url complet: https://tnsfurniture.co.uk
# Url complet: https://learningconnexions.com
# Url complet: https://interchangepd.com
# Url complet: https://rokit.co.uk
# Url complet: https://localedge.co.uk
# Url complet: https://thediceshoponline.com
# Url complet: https://drg.global
# Url complet: https://kjnhomeimprovements.co.uk
# Url complet: http://mcaaviation.com
# Url complet: https://slipstreammarketing.co.uk
# Url complet: https://derby-exp.co.uk
# Url complet: https://ebrattridge.com
# Url complet: https://standard-alarms.com
# Url complet: https://humphreyfeedsandpullets.co.uk
# Url complet: https://sortoffilms.co.uk
# Url complet: https://sharondavidson.co.uk
# Url complet: https://perfectprofilesclinics.co.uk
# Url complet: http://northern-broadsides.co.uk
# Url complet: http://farshidmoussaviarchitecture.com
# Url complet: https://wisdomtree.eu
# Url complet: https://sure-line.com
# Url complet: https://bodosperlein.com
# Url complet: https://threemotion.co.uk
# Url complet: https://thechilespecialists.com
# Url complet: https://studioslipware.com
# Url complet: https://iconrelocation.com
# Url complet: http://logis-tech.co.uk
# Url complet: https://liberis.com
# Url complet: https://lowygroup.co.uk
# Url complet: https://tamba.co.uk
# Url complet: https://kcrtransport.co.uk
# Url complet: https://digitaleyesmedia.co.uk
# Url complet: https://yazda.org
# Url complet: https://inkdrawn.com
# Url complet: https://wedgwoodvisitorcentre.com
# Url complet: https://pro-vale.com
# Url complet: https://hankinson.co.uk
# Url complet: https://oakwood-estates.co.uk
# Url complet: http://falmouthhotels.co.uk
# Url complet: https://nglos.co.uk
# Url complet: https://washerwise.co.uk
# Url complet: https://practicalpoetry.co.uk
# Url complet: https://iadcontrol.com
# Url complet: http://livias.co.uk
# Url complet: https://deediganmartialarts.co.uk
# Rezultat neașteptat: [SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1006)
# Url complet: https://mathews.co.uk
# Url complet: http://buyorganic.co.uk
# Url complet: https://wolf.live
# Url complet: https://fullfataudio.com
# Url complet: https://signcompeurope.com
# Url complet: https://lewisashleygroup.com
# Url complet: http://metfilm.co.uk
# Url complet: https://digibee.co.uk
# Url complet: https://palmunderwear.co.uk
# Url complet: http://corioliscapital.com
# Url complet: https://shibdenmillinn.com
# Url complet: https://retreathousepleshey.com
# Url complet: https://apptivation.co.uk
# Url complet: https://fgenergy.com
# Url complet: http://nationalgridusaco.com
# Url complet: https://carteraccountants.co.uk
# Url complet: https://deekay.co.uk
# Url complet: https://deli22.co.uk
# Url complet: https://allaboutvenues.com
# Url complet: https://ratio.co.uk
# Url complet: http://tritonrestoration.co.uk
# Url complet: https://serocor.com
# Url complet: https://wheelgatepark.com
# Url complet: https://tokyoto-luggage.com
# Url complet: https://osadoorparts.co.uk
# Url complet: https://kgd.co.uk
# Url complet: https://maclarenjones.com
# Url complet: https://sedumgreenroof.co.uk
# Url complet: https://liverpoolairport.com
# Url complet: https://optilan.com
# Url complet: https://paynes-heating.co.uk
# Url complet: https://thechillilodge.co.uk
# Url complet: http://m2msecuritysims.com
# Url complet: https://cspc.co.uk
# Url complet: http://voodoovaudeville.com
# Url complet: https://candooconcierge.com
# Url complet: https://chequermead.org.uk
# Url complet: https://digipress.co.uk
# Url complet: https://jeanettekidd.com
# Url complet: https://viduppu.com
# Url complet: https://airtattoo.com
# Url complet: https://optima-life.com
# Url complet: https://allinonelondon.com
# Url complet: https://renaultalpine.co.uk
# Url complet: https://bosscabins.co.uk
# Url complet: https://threlfallart.co.uk
# Url complet: https://bandbinnovations.co.uk
# Url complet: https://mentorgroup.co.uk
# Url complet: https://farmgarden.org.uk
# Url complet: https://meguiars.co.uk
# Url complet: https://w-co.co.uk
# Url complet: https://jr-roofing.co.uk
# Url complet: https://kellergreen.com
# Url complet: https://nickystephenmarketing.co.uk
# Url complet: http://wellnessinmotion.co.uk
# Url complet: http://salaequilibrio.com
# Url complet: https://bsp-if.com
# Url complet: http://reemjewellers.com
# Url complet: https://bjcplanning.co.uk
# Url complet: https://nuplansurveys.com
# Url complet: https://frostsgardencentres.co.uk
# Url complet: https://sjhub.org.uk
# Url complet: https://sandbbuilders.co.uk
# Url complet: https://stationcars.co.uk
# Url complet: https://londonshootfighters.com
# Url complet: https://auduskitchens.co.uk
# Url complet: https://touchscreens-direct.co.uk
# Url complet: http://superyachtuniforms.com
# Url complet: https://hcpautomotive.com
# Url complet: https://standardgroup.co.uk
# Url complet: https://xclusivedecor.com
# Url complet: https://pixelboost.co.uk
# Url complet: https://woodlandadventurers.org
# Url complet: https://beemercy.com
# Url complet: https://revolutionkarting.com
# Url complet: https://eocharging.com
# Url complet: https://twentytwenty.co
# Url complet: https://carsite.co.uk
# Url complet: https://millwoodeducation.co.uk
# Url complet: https://comfygroup.co.uk
# Url complet: https://gews.co.uk
# Url complet: https://onerockinternational.com
# Url complet: https://reflexgroup.co.uk
# Url complet: https://thefamilyofficer.com
# Url complet: https://cgoecology.com
# Url complet: https://awsworthmotors.co.uk
# Url complet: http://neudrive.com
# Url complet: https://telelease.com
# Url complet: https://halothermalimaging.co.uk
# Url complet: http://ngagephotography.com
# Url complet: https://cornerstone.photography
# Url complet: http://watkinspayne.co.uk
# Url complet: https://withoutwalls.uk.com
# Url complet: https://piperscrisps.com
# Url complet: https://mobilepie.com
# Url complet: https://go-clean.co.uk
# Url complet: https://remploy.co.uk
# Url complet: https://london-ghost-tour.com
# Url complet: https://nucleargrads.com
# Url complet: https://mjabbott.co.uk
# Url complet: https://whitecliffsvets.co.uk
# Url complet: http://chepstowhotels.co.uk
# Url complet: https://landau-forte.org.uk
# Url complet: https://enderlegard.com
# Url complet: https://dollyrose.co.uk
# Url complet: https://stone-zone.uk
# Url complet: https://corporateentertainmentco.co.uk
# Url complet: https://plasma-clean.com
# Url complet: https://ukindustrialflooring.co.uk
# Url complet: https://seatingmatters.com
# Url complet: https://watts1874.co.uk
# Url complet: https://alfiebest.com
# Url complet: https://nextstepcentre.com
# Url complet: https://metricell.com
# Url complet: https://spinal-physiotherapy.com
# Url complet: https://urbanescape.co.uk
# Url complet: http://thefundingco.co.uk
# Url complet: http://predictablesales.com
# Url complet: https://martinsfarmmarket.net
# Url complet: https://burgessyachts.com
# Url complet: https://partydoctors.co.uk
# Url complet: https://netmera.com
# Url complet: https://platipus-anchors.com
# Url complet: https://armchairmarketing.co.uk
# Url complet: https://briankirwan.co.uk
# Url complet: https://soulbrother.com
# Url complet: https://ashleymilton.com
# Url complet: https://pdq1.com
# Url complet: https://pinehills.com
# Url complet: http://gighahalibut.co.uk
# Url complet: https://wilderfilms.co.uk
# Url complet: https://arabartsfestival.com
# Url complet: https://allawayacoustics.co.uk
# Url complet: https://ungagged.com
# Url complet: http://acorn-training.com
# Url complet: https://listertennis.com
# Url complet: http://slatersports.com
# Url complet: https://greentimber.com
# Url complet: https://exhibitionfreighting.co.uk
# Url complet: https://lagomdesign.co.uk
# Url complet: http://stcltd.co.uk
# Url complet: https://royalacademyofculinaryarts.org.uk
# Url complet: https://purplefizz.co.uk
# Url complet: https://wardblawg.com
# Url complet: https://influxpress.com
# Url complet: https://icamarchive.co.uk
# Url complet: https://butlerrose.com
# Url complet: https://pelgar.co.uk
# Url complet: https://belhavensmokehouse.co.uk
# Url complet: https://destinationbasingstoke.co.uk
# Url complet: https://zavvi.es
# Url complet: https://qxlva.com
# Url complet: https://everydaychampions.tv
# Url complet: https://robertdanielsjewellers.co.uk
# Url complet: https://deborahedwardsdesign.co.uk
# Url complet: http://balkongmobler-guide.com
# Url complet: https://psychosynthesis.org
# Url complet: https://knowhowtraining.co.uk
# Url complet: https://bedfordrugby.co.uk
# Url complet: https://wcm.com
# Url complet: https://holdsworthchocolates.co.uk
# Url complet: https://vauxhalltavern.com
# Url complet: https://swaleviewpark.co.uk
# Url complet: https://adboards.com
# Url complet: https://giftsvouchers.co.uk
# Url complet: https://kingsmead-school.com
# Url complet: https://thompsonbrothers.net
# Url complet: http://sorbethq.com
# Url complet: https://cash-for-houses.co.uk
# Rezultat neașteptat: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)
# Url complet: https://trentvineyard.org
# Url complet: http://bodyboarding-shop.co.uk
# Url complet: https://edwardbulmerpaint.co.uk
# Url complet: https://srgtalent.com
# Url complet: https://atranubesstudio.co.uk
# Url complet: https://theheavenlycakecompany.co.uk
# Url complet: https://malonesedinburgh.com
# Url complet: https://fusionbc.co.uk
# Url complet: https://b-r.co.uk
# Url complet: https://dentalmarketingexpert.co.uk
# Url complet: https://thepixelate.com
# Url complet: http://futurumltd.co.uk
# Url complet: https://forensicseuropeexpo.com
# Url complet: https://osteopathineastleigh.com
# Url complet: https://mjexecutivecars.co.uk
# Url complet: https://londoncouncils.gov.uk
# Rezultat neașteptat: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)
# Url complet: https://codelife.org
# Url complet: https://acecic.co.uk
# Url complet: https://gamemaker.io
# Url complet: http://pirean.com
# Url complet: https://bigfinish.com
# Url complet: http://devoted2home.co.uk
# Url complet: https://laidlawcontracts.co.uk
# Url complet: https://blubambu.co.uk
# Url complet: https://tojoandnellyscattales.com
# Url complet: https://breezem.co.uk
# Url complet: https://bonds-confectionery.co.uk
# Url complet: https://entrustit.co.uk
# Url complet: https://yourofficeandpa.co.uk
# Url complet: https://dmb.uk.com
# Url complet: https://highperformanceproductions.net
# Url complet: https://animalstory.co.uk
# Url complet: https://astrolutely.com
# Url complet: https://ers.com
# Url complet: https://carlypress.co.uk
# Url complet: https://oysteryachts.com
# Url complet: https://whiteshadowweddingfilms.com
# Url complet: http://hiteluk.com
# Url complet: https://lemontreerentals.com
# Url complet: http://ilovethisshop.co.uk
# Url complet: https://softswiss.com
# Url complet: https://imajica.com
# Url complet: https://marlboroughhousetherapycentre.co.uk
# Url complet: https://whiltonmill.co.uk
# Url complet: https://flysoftware.com
# Url complet: https://wake-smith.co.uk
# Url complet: https://realworldholidays.co.uk
# Url complet: https://redbluemechanical.co.uk
# Url complet: https://darksteve.com
# Url complet: https://thelionatfarnsfield.com
# Url complet: https://pier64.co.uk
# Url complet: https://ipmpestcontrol.co.uk
# Url complet: https://emmamoorephotography.co.uk
# Url complet: https://mariastarling.com
# Url complet: https://zendrillscaffolding.co.uk
# Url complet: https://securexpoeastafrica.com
# Url complet: http://pompdefranc.co.uk
# Url complet: http://marketingunity.com
# Url complet: https://andersonhoare.co.uk
# Url complet: https://pyemotors.co.uk
# Url complet: https://conisboroughcollege.co.uk
# Url complet: https://richfieldsfirth.co.uk
# Url complet: https://dpdlocal.co.uk
# Url complet: http://lollie.co.uk
# Url complet: https://inoutsolutions.co.uk
# Url complet: https://maruhub.com
# Url complet: https://rentalsandsales.co.uk
# Url complet: https://brickweb.co.uk
# Url complet: https://howtohandlehecklers.com
# Url complet: https://warmemorialconservation.com
# Url complet: https://worldoffootball.com
# Url complet: https://deeperthanblue.co.uk
# Url complet: https://thermometersdirect.co.uk
# Url complet: https://lsmflooringmanchester.co.uk
# Url complet: https://lincolnhotel.co.uk
# Url complet: https://harlowsalvationarmy.org.uk
# Url complet: https://hexaservices.co.uk
# Url complet: https://pelicanprocurement.co.uk
# Url complet: https://instantasp.co.uk
# Url complet: https://theshipsphotographer.com
# Url complet: https://affinitywater.co.uk
# Url complet: https://pandr.online
# Url complet: https://digibound.net
# Url complet: http://josephandkhansolicitors.com
# Url complet: https://alto-marketing.com
# Url complet: https://causalens.com
# Url complet: https://rbkc.gov.uk
# Url complet: http://spreadgoodvibes.co.uk
# Url complet: https://bbfc.co.uk
# Url complet: https://thevoipshop.co.uk
# Url complet: https://architecturalplants.com
# Url complet: https://oxwichwatersports.co.uk
# Url complet: https://flowtech.org.uk
# Url complet: http://mooresecure.co.uk
# Url complet: https://albany-pumps.co.uk
# Url complet: http://pctengineering.co.uk
# Url complet: http://castang-wines.co.uk
# Url complet: https://chestnutcaregloucester.co.uk
# Url complet: https://fisu.org
# Url complet: https://mapometer.com
# Url complet: https://eggarforresterinsurance.com
# Url complet: http://prospecttraining.co.uk
# Url complet: https://barts-choir.com
# Url complet: https://classicbikepartscheshire.com
# Url complet: https://consysequip.com
# Url complet: https://bluestemgroup.co.uk
# Url complet: https://emmamcneil.co.uk
# Url complet: https://appliancerepairmanchester.co.uk
# Url complet: https://thegainsboroughbathspa.co.uk
# Url complet: https://hastingsoloughlin.co.uk
# Url complet: https://snsg.co.uk
# Url complet: https://nicheworks.co.uk
# Url complet: https://millingtonassociates.com
# Url complet: https://adfertech.com
# Url complet: https://buckhill.co.uk
# Url complet: https://thinkvideo.net
# Url complet: https://oakover.co.uk
# Url complet: https://noisegatemedia.com
# Url complet: https://millsselig.com
# Url complet: https://livinghouse.co.uk
# Url complet: https://balconyshirts.co.uk
# Url complet: https://kuchedesign.co.uk
# Url complet: https://higginshomes.co.uk
# Url complet: https://daymer.com
# Url complet: http://screeninguk.com
# Url complet: https://tatucouture.com
# Url complet: https://freedomdestinations.co.uk
# Url complet: https://salisburycitycouncil.gov.uk
# Url complet: https://grand-union.org.uk
# Url complet: https://helenlee.co.uk
# Url complet: http://butlerz.co.uk
# Url complet: https://destinyentertainments.net
# Url complet: https://pmkcivilengineering.com
# Url complet: https://pfponline.com
# Url complet: https://smcompliance.com
# Url complet: https://regenteng.com
# Url complet: https://rndcore.com
# Url complet: https://praestoconsulting.com
# Url complet: https://connive.co.uk
# Url complet: https://revlifter.com
# Url complet: https://doglawsos.co.uk
# Url complet: https://thestove.org
# Url complet: https://mailsure-it.com
# Url complet: https://purerecharge.com
# Url complet: https://poolmarket.co.uk
# Url complet: https://recruitmentmarketinginternational.com
# Url complet: https://mse-uk.com
# Url complet: https://ihc-uk.com
# Url complet: https://spettro.net
# Url complet: https://azizisearch.com
# Url complet: https://wrssolutions.com
# Url complet: https://xpressgate.com
# Url complet: https://surreysoftplayhire.com
# Url complet: https://longhornbeef.co.uk
# Url complet: https://scandinavianloft.com
# Url complet: https://oakleyproperty.com
# Url complet: https://cornwalldentists.co.uk
# Url complet: https://bakers-solicitors.com
# Url complet: https://class.agency
# Url complet: https://walternewbury.co.uk
# Url complet: https://mannering-rubber.co.uk
# Url complet: https://monalisasmiles.co.uk
# Url complet: https://snowbizz.co.uk
# Url complet: https://glowtelecom.co.uk
# Url complet: https://mylanderpages.com
# Url complet: https://samanthasage.com
# Url complet: https://sk-design.co.uk
# Url complet: http://modern-office.co.uk
# Url complet: http://babyfat.co.uk
# Url complet: https://kabi.co.uk
# Url complet: https://bostmusicals.co.uk
# Url complet: https://sapori-e-saperi.com
# Url complet: https://buildersinbristol.net
# Url complet: http://rostrevorholidays.com
# Url complet: https://rfs.org.uk
# Url complet: https://naturesraincoats.com
# Url complet: http://obsidianir.com
# Url complet: http://artbronze.co.uk
# Url complet: https://flourish.training
# Url complet: https://freedom-fence.co.uk
# Url complet: http://ocultd.co.uk
# Url complet: https://firstrecruitmentgroup.com
# Url complet: https://pacheshamgolf.co.uk
# Url complet: https://pepper.so
# Url complet: https://pe-systems.co.uk
# Url complet: https://lakesanddales.coop
# Url complet: https://shutterworld.co.uk
# Url complet: https://hummingbirdeservices.com
# Url complet: https://athertonstone.com
# Url complet: http://centric-advisors.co.uk
# Url complet: https://laplacesolutions.com
# Url complet: https://alliancecarimports.co.uk
# Url complet: https://hoteliona.co.uk
# Url complet: https://weddingmakeupandhair.com
# Url complet: https://dizzysquirrel.com
# Url complet: https://opag.co.uk
# Url complet: https://heckfordnorton.co.uk
# Url complet: https://citycollegeoxford.co.uk
# Url complet: http://fellowsmc.co.uk
# Url complet: https://iccopr.com
# Url complet: http://irrigationcontrol.co.uk
# Url complet: https://clogau.co.uk
# Url complet: https://tbscg.com
# Url complet: https://midlandsgynaecology.co.uk
# Url complet: https://sussexgold.co.uk
# Url complet: https://catchacab.com
# Url complet: https://teneightytwo.co.uk
# Url complet: https://diskingcomputers.com
# Url complet: https://thehungerproject.org.uk
# Url complet: https://ivfbioscience.com
# Url complet: https://digitaloriented.co.uk
# Url complet: https://indigoone.co.uk
# Url complet: https://woodstock-motorparts.co.uk
# Url complet: https://akstoddart.co.uk
# Url complet: https://languagebusiness.co.uk
# Url complet: https://shiresequestrian.com
# Url complet: https://desynit.com
# Url complet: https://middleeastinvestmentnetwork.com
# Url complet: https://pyedesign.com
# Url complet: https://ezy-clean.co.uk
# Url complet: http://dhsigns.co.uk
# Url complet: https://monarch-equestrian.co.uk
# Url complet: https://thehardedge.com
# Url complet: https://epcarlson.co.uk
# Url complet: https://deversoftware.com
# Url complet: https://pfsc.co.uk
# Url complet: http://tri-sphere.co.uk
# Url complet: https://wjec.co.uk
# Url complet: http://hochschildmining.com
# Url complet: https://s-sewing.co.uk
# Url complet: https://chartwellfs.com
# Url complet: https://nordicwalkingcambridgeshire.com
# Url complet: https://rosalindwhitephotography.com
# Url complet: https://navitassafety.com
# Url complet: https://zoegilby.co.uk
# Url complet: https://blackheathproducts.co.uk
# Url complet: https://mvfglobal.com
# Url complet: http://claspers.co.uk
# Url complet: https://clarity4d.com
# Url complet: https://ayeshagiselle.com
# Url complet: https://aclautomotive.co.uk
# Url complet: https://headtotoetherapy.co.uk
# Url complet: https://hoxtonfarms.com
# Url complet: http://ashford.gov.uk
# Url complet: http://britanniatowers.co.uk
# Url complet: https://tinsmiths.co.uk
# Url complet: https://londoncorinthians.com
# Url complet: https://avalon-guns.com
# Url complet: https://mirabellabeautysalon.co.uk
# Url complet: https://gunrepair.co.uk
# Url complet: http://passion-for-food.co.uk
# Url complet: https://trailpictures.co.uk
# Url complet: https://brunsdonfinancial.co.uk
# Url complet: https://water-garden.co.uk
# Url complet: http://allianceleisure.co.uk
# Url complet: https://lovelyjubblyfabrics.co.uk
# Url complet: http://jkwlaw.com
# Url complet: https://fernwoodcommercials.co.uk
# Url complet: http://lawnturfnottingham.com
# Url complet: https://horsematshop.co.uk
# Url complet: http://thriller-school.com
# Url complet: http://photographylane.com
# Url complet: http://blakeleysofbrighouse.co.uk
# Url complet: http://paintball-worcester.co.uk
# Url complet: http://pugetsoundlimiteds.com
# Url complet: http://quickits.co.uk
# Url complet: http://comeround.com
# Url complet: http://worthing-coaches.co.uk
# Url complet: http://markettiers.com
# Url complet: http://howe-engineering.co.uk
# Url complet: http://irishmethodist.org
# Url complet: http://brizebox.com
# Url complet: http://polarisagency.com
# Url complet: http://eurotech-computers.com
# Url complet: http://depaulfrance.org
# Url complet: http://thetoydetectives.com
# Url complet: http://optionschelmsford.com
# Url complet: http://allwaysmedia.com
# Url complet: http://kingfishershopping.co.uk
# Url complet: http://purepic.co.uk
# Url complet: http://primadollar.com
# Url complet: http://running4women.com
# Url complet: http://thecoolhunter.co.uk
# Url complet: http://pupilrewardpoints.co.uk
# Url complet: http://llanhillethinstitute.com
# Url complet: http://veritekglobal.com
# Url complet: http://thesafetysupplycompany.co.uk
# Url complet: http://tubesounds.com
# Url complet: http://signseen.co.uk
# Url complet: http://crueltyfreeinternational.org
# Url complet: http://armourclass.co.uk
# Url complet: http://maudinteriors.com
# Url complet: http://hartlepool-jobs.co.uk
# Url complet: http://foamtechniques.co.uk
# Url complet: http://victoriafalls-zambiatravel-safaris.com
# Url complet: http://bogiez.com
# Url complet: http://barchester.com
# Url complet: http://pulsemedia.uk.com
# Url complet: http://brunelcare.org.uk
# Url complet: http://opex-group.com
# Url complet: http://etc-inter.net
# Url complet: http://workbooks.com
# Url complet: http://lktelectricalservices.com
# Url complet: http://afaprojects.com
# Url complet: http://77agency.com
# Url complet: http://coxhire.co.uk
# Url complet: http://thesummitclinic.co.uk
# Url complet: http://yendis.co.uk
# Url complet: http://theoutletclub.com
# Url complet: http://silvercrossus.com
# Url complet: http://williamloughran.co.uk
# Url complet: http://essexinjectionmouldings.co.uk
# Url complet: http://club-insure.co.uk
# Url complet: http://nationalplastics.co.uk
# Url complet: http://risk-partnership.com
# Url complet: http://poppycottages.co.uk
# Url complet: http://networkscaffolding.co.uk
# Url complet: http://cassette2cd.co.uk
# Url complet: http://redrockconsultants.co.uk
# Url complet: http://mysilo.co.uk
# Url complet: http://jennieden.com
# Url complet: http://albaamicorum.com
# Url complet: http://maxevents.co.uk
# Url complet: http://hillers.co.uk
# Url complet: http://sonaspection.com
# Url complet: http://dunnsfoodanddrinks.co.uk
# Url complet: http://bettymiller.com
# Url complet: http://fanplay4sports.com
# Url complet: http://eurodrive.co.uk
# Url complet: http://paulmattysportscars.co.uk
# Url complet: http://theacupuncturestudio.webs.com
# Url complet: http://carstorageltd.co.uk
# Url complet: http://bbconsult.co.uk
# Url complet: http://inkaesthetics.co.uk
# Url complet: http://reform-gym.co.uk
# Url complet: http://covermagazine.co.uk
# Url complet: http://garringtoneast.co.uk
# Url complet: http://hyalofemme.co.uk
# Url complet: http://poweredbypie.co.uk
# Url complet: http://1stforairportparkinguk.co.uk
# Url complet: http://avcon.co.uk
# Url complet: http://oliverharvey.co.uk
# Url complet: http://rachaeltroughton.com
# Url complet: http://southamptoncruisecentre.com
# Url complet: http://newbridgegreen.com
# Url complet: http://yorkshireholidaycottages.co.uk
# Url complet: http://raxel.co.uk
# Url complet: http://scpersonaltraining.com
# Url complet: http://fleetevolution.com
# Url complet: http://innovation-productions.com
# Url complet: http://rhi-stitched.com
# Url complet: http://techmarketview.com
# Url complet: http://schoolfurniture.co.uk
# Url complet: http://europlan-uk.com
# Url complet: http://nctilesandbathrooms.com
# Url complet: http://vpsl.co.uk
# Url complet: http://drawrecruitment.com
# Url complet: http://metalline.co.uk
# Url complet: http://marlinservices.co.uk
# Url complet: http://royaloakkeswick.co.uk
# Url complet: http://opendays.com
# Url complet: http://hicksandhicks.com
# Url complet: http://greavesbrewster.co.uk
# Url complet: http://sixteenfeet.co.uk
# Url complet: http://baks.co.uk
# Url complet: http://hevva.co.uk
# Url complet: http://mediapool.co.uk
# Url complet: http://swiftroofing.co.uk
# Url complet: http://afsuk.com
# Url complet: http://dukesbrewandque.com
# Url complet: http://webuyyourscrapcars.com
# Url complet: http://redcircledigital.co.uk
# Url complet: http://intellegentia.co.uk
# Url complet: http://montalt.co.uk
# Url complet: http://principalge.com
# Url complet: http://moheri.gov.om
# Url complet: http://burgonandball.com
# Url complet: http://pollock.co.uk
# Url complet: http://costumeswithcharacter.com
# Url complet: http://nuttall.co.uk
# Url complet: http://vectormanagement.co.uk
# Url complet: http://ciob.org
# Url complet: http://cookeryacademy.co.uk
# Url complet: http://boxtedhall.co.uk
# Url complet: http://kiconnections.com
# Url complet: http://tedxbristol.com
# Url complet: http://bathroomslocally.co.uk
# Url complet: http://mccalls.co.uk
# Url complet: http://lenzieunion.org
# Url complet: http://localex.co.uk
# Url complet: http://peachymondays.com
# Url complet: http://sk-landscapes.com
# Url complet: http://worldconferencecalendar.com
# Url complet: http://sentisum.com
# Url complet: http://eagledesign.net
# Url complet: http://radioactivepromotions.co.uk
# Url complet: http://thegoodguest.com
# Url complet: http://verveproductions.co.uk
# Url complet: http://mrchippyyork.co.uk
# Url complet: http://fertilityroad.com
# Url complet: http://sinclairvans.co.uk
# Url complet: http://professional-hc.com
# Url complet: http://erikapineros.com
# Url complet: http://nhsforthvalley.com
# Url complet: http://seenit.io
# Url complet: http://cerberusnetworks.co.uk
# Url complet: http://northgatevehiclehire.co.uk
# Url complet: http://trederwensprings.co.uk
# Url complet: http://hitechsigns.co.uk
# Url complet: http://drewbuckleyphotography.com
# Url complet: http://resinboundsurfacing.co.uk
# Url complet: http://silver-drum.com
# Url complet: http://elitesportsuk.com
# Url complet: http://priorandwillisantiques.co.uk
# Url complet: http://woollybabs.com
# Url complet: http://zumajay.co.uk
# Url complet: http://jupitercreativemedia.co.uk
# Url complet: http://sjacymru.org.uk
# Url complet: http://blancmind.com
# Url complet: http://depinna.com
# Url complet: http://miketibbatts.co.uk
# Url complet: http://pj-signs.com
# Url complet: http://maxeyewear.com
# Url complet: http://bluemonkeyweb.com
# Url complet: http://durhambox.co.uk
# Url complet: http://gasmithplant.co.uk
# Url complet: http://medicaldevice.co.uk
# Url complet: http://exquisite-salon.co.uk
# Url complet: http://whiteblancmange.com
# Url complet: http://portogramltd.co.uk
# Url complet: http://milnecraig.co.uk
# Url complet: http://hillsounduk.com
# Url complet: http://caremeds.co.uk
# Url complet: http://edch.org.uk
# Url complet: http://marsdencontractservices.co.uk
# Url complet: http://pescodsquare.com
# Url complet: http://jbrcapital.com
# Url complet: http://supremesunbeds.co.uk
# Url complet: http://bossdriving.co.uk
# Url complet: http://altirium.com
# Url complet: http://cooksandpartners.co.uk
# Url complet: http://clarendonhotel.com
# Url complet: http://floatglassdesign.co.uk
# Url complet: http://girtonphysio.co.uk
# Url complet: http://fishtank.cc
# Url complet: http://letterboxdistribution.com
# Url complet: http://langham-hotel.com
# Url complet: http://mamaowl.net
# Url complet: http://inoapps.com
# Url complet: http://redkitebaby.co.uk
# Url complet: http://cablemonkey.co.uk
# Url complet: http://ahfreestyle.co.uk
# Url complet: http://burotec.co.uk
# Url complet: http://teetransfers.co.uk
# Url complet: http://cloud2.co.uk
# Url complet: http://wildflowers.co.uk
# Url complet: http://firesecelec.net
# Url complet: http://macaroonjewellery.co.uk
# Url complet: http://twinpet.com
# Url complet: http://brc.ltd.uk
# Url complet: http://mobileppl.uk
# Url complet: http://schooladvice.co.uk
# Url complet: http://tonydagostino.co.uk
# Url complet: http://hlegal.co.uk
# Url complet: http://hytera-europe.com
# Url complet: http://duckbarn.co.uk
# Url complet: http://modu-europe.com
# Url complet: http://ffsreferee.co.uk
# Url complet: http://basiccharity.org.uk
# Url complet: http://sportabroad.co.uk
# Url complet: http://trlibdems.org.uk
# Url complet: http://cardinalpointstrategies.com
# Url complet: http://nugentbuilders.co.uk
# Url complet: http://browntroutinn.com
# Url complet: http://v-maxx.co.uk
# Url complet: http://ct-engineering.co.uk
# Url complet: http://acmmosconsultancy.co.uk
# Url complet: http://maritimedevelopments.com
# Url complet: http://queensberryrealestate.com
# Url complet: http://bedmaxshavings.com
# Url complet: http://londontaxiadvertising.com
# Url complet: http://cybertrax.net
# Url complet: http://marubeni-komatsu.co.uk
# Url complet: http://tiddley-pom.com
# Url complet: http://picturethis-framing.co.uk
# Url complet: http://royalegraphics.co.uk
# Url complet: http://pouringpounds.com
# Url complet: http://coralbay.tv
# Url complet: http://finderskeepersrecords.com
# Url complet: http://worldsaparttravel.co.uk
# Url complet: http://calderengineering.co.uk
# Url complet: http://thewoolroom.com
# Url complet: http://thefinancialfairytales.com
# Url complet: http://flackleyashhotel.co.uk
# Url complet: http://intheclouds.com
# Url complet: http://voipswitch.com
# Url complet: http://djrmarketing.co.uk
# Url complet: http://hivepharmacy.com
# Url complet: http://jccars.co.uk
# Url complet: http://thirtyseven.agency
# Url complet: http://arcovohotelloyalty.com
# Url complet: http://clarkfoysterwines.co.uk
# Url complet: http://dai-lewis.co.uk
# Url complet: http://humatica.com
# Url complet: http://slikmedia.co.uk
# Url complet: http://heritageconservatories.co.uk
# Url complet: http://dragapp.com
# Url complet: http://vizion4it.com
# Url complet: http://ricksedinburgh.co.uk
# Url complet: http://edinburghbiketours.co.uk
# Url complet: http://crosslanehouse.com
# Url complet: http://thebelfieldgroup.com
# Url complet: http://samstransport.co.uk
# Url complet: http://principio.co.uk
# Url complet: http://plus15.co.uk
# Url complet: http://thesupplydesk.co.uk
# Url complet: http://concreteplatform.com
# Url complet: http://edgecumbe.co.uk
# Url complet: http://porterfieldbrakes.co.uk
# Url complet: http://cotswoldcottageholidays.co.uk
# Url complet: http://intelligent-protection.co.uk
# Url complet: http://tillylondon.com
# Url complet: http://cjei.co.uk
# Url complet: http://ilovebodega.com
# Url complet: http://coochycoonappycakes.co.uk
# Url complet: http://radhanathswami.com
# Url complet: http://dissertationproposal.co.uk
# Url complet: http://surecps-group.com
# Url complet: http://presentations.co.uk
# Url complet: http://caritassalford.org.uk
# Url complet: http://cornerfridge.com
# Url complet: http://quadranet.co.uk
# Url complet: http://moderntyres.com
# Url complet: http://lodestar.org.uk
# Url complet: http://topmeadow.co.uk
# Url complet: http://editorskeys.com
# Url complet: http://healys.com
# Url complet: http://insidecareers.co.uk
# Url complet: http://missionlimited.com
# Url complet: http://hackaball.com
# Url complet: http://houseclearanceteam.co.uk
# Url complet: http://satchiuk.com
# Url complet: http://bill-medical.co.uk
# Url complet: http://coastscotland.com
# Url complet: http://ericht.co.uk
# Url complet: http://vcut.co.uk
# Url complet: http://surreywildlifetrust.org
# Url complet: http://snugglebundl.co.uk
# Url complet: http://mmiengineering.com
# Url complet: http://motivationalleadership.co.uk
# Url complet: http://ka-boukie.com
# Url complet: http://affordablecleaning.co.uk
# Url complet: http://porthavallen.co.uk
# Url complet: http://arroll.co.uk
# Url complet: http://vegetarianexpress.co.uk
# Url complet: http://ansaltd.com
# Url complet: http://marlin.com
# Url complet: http://careerwise.com
# Url complet: http://burrowfieldautos.com
# Url complet: http://firstrate.co.uk
# Url complet: http://wearecameron.com
# Url complet: http://birminghamgymclub.org.uk
# Url complet: http://exchequersolutions.co.uk
# Url complet: http://laycockinternational.com
# Url complet: http://proformbasketball.com
# Url complet: http://henshaw.uk.com
# Url complet: http://fishplant.co.uk
# Url complet: http://sgrcs.co.uk
# Url complet: http://bikespokes.co.uk
# Url complet: http://yucpc.org.uk
# Url complet: http://thepheasant-keyston.co.uk
# Url complet: http://atpi.org
# Url complet: http://moreideas.co.uk
# Url complet: http://orbitresearch.co.uk
# Url complet: http://combemill.co.uk
# Url complet: http://essexcommunityfoundation.org.uk
# Url complet: http://polocini.com
# Url complet: http://sw-electrical.co.uk
# Url complet: http://cakesuppliers.co.uk
# Url complet: http://nuvoteq.cloud
# Url complet: http://crossfitkirkintilloch.com
# Url complet: http://parallel.fi
# Url complet: http://northernirelandscreen.co.uk
# Url complet: http://birdbrand.co.uk
# Url complet: http://thorntonlodgenorthyorkshire.co.uk
# Url complet: http://peasholmecharity.org.uk
# Url complet: http://mackay.co.uk

# %%
len(complete_urlsUK)
# Out:
# 854

# %% [markdown]
# - Asynchronously main function where we apply the filter to the list of urls and obtain the valid ones

# %%
async def main():
    valid_urls = await filter_urls_async(complete_urlsUK)
    return valid_urls

# %%
valid_urlsUK = await main()

# %%
len(valid_urlsUK)
# Out:
# 229

# %% [markdown]
# - Async main function that for a list of urls generate a bigger list with the urls that have a high chance to have an address

# %%
async def main(valid_urls):
    keywords = ['connect', 'contact', 'kontakt', 'impressum', 'adresse', 'reach', 'datenschutz', 'home']
    tasks = [find_urls_with_keywords(url, keywords) for url in valid_urls]
    final_urls = await asyncio.gather(*tasks)
    return final_urls

# %%
final_urlsUK = await main(valid_urlsUK)

# %%
urls_listUK = []
for set_elem in final_urlsUK:
    for elem in set_elem:
        urls_listUK.append(elem)

# %%
len(urls_listUK)
# Out:
# 427

# %% [markdown]
# #### Checking the new list of URLS and the invalid ones will be eliminated

# %%
async def main():
    valid_urls = await filter_urls_async(urls_listUK)
    return valid_urls

# %%
urls_listUK = await main()

# %%
len(urls_listUK)
# Out:
# 400

# %% [markdown]
# #### Making a DataFrame to save the valid URLS into a .csv to using them later

# %%
import pandas as pd

df = pd.DataFrame(columns = ["URL"])

df
# Out:
# Empty DataFrame
# Columns: [URL]
# Index: []

# %%
for url in urls_listUK:
    individual_row_data = [url]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                              URL
# 0                             https://trinyx.org
# 1                           https://enigmacs.com
# 2                  https://enigmacs.com/contact/
# 3          https://www.pennyanderson.com/contact
# 4                      https://pennyanderson.com
# ..                                           ...
# 395                    http://missionlimited.com
# 396            http://bill-medical.co.uk/contact
# 397                    http://bill-medical.co.uk
# 398              http://affordablecleaning.co.uk
# 399  http://affordablecleaning.co.uk/contact.php
#
# [400 rows x 1 columns]

# %% [markdown]
# #### Reading the urls from the CSV

# %%
df.to_csv("UK_URLS.csv", index=False)

# %%
import pandas as pd
urlsUK = pd.read_csv("UK_URLS.csv")

# %%
print(urlsUK['URL'])
# Out:
# 0                               https://trinyx.org
# 1                             https://enigmacs.com
# 2                    https://enigmacs.com/contact/
# 3            https://www.pennyanderson.com/contact
# 4                        https://pennyanderson.com
#                           ...
# 395                      http://missionlimited.com
# 396              http://bill-medical.co.uk/contact
# 397                      http://bill-medical.co.uk
# 398                http://affordablecleaning.co.uk
# 399    http://affordablecleaning.co.uk/contact.php
# Name: URL, Length: 400, dtype: object

# %% [markdown]
# #### Function that extracts the address from a page if it's possible

# %%
async def extract_addresses_from_url_uk_async(url):
    async with aiohttp.ClientSession() as session:
        try:
            async with session.get(url, ssl=False, timeout=60) as response:
                if response.status != 200:
                    return None
                
                binary_data = await response.read()
                page_text = binary_data.decode('latin-1')
                
        except asyncio.TimeoutError:
            print(f"Timeout occurred while fetching URL: {url}")
            return None
        except aiohttp.ClientError as e:
            print(f"Error occurred while fetching URL '{url}': {e}")
            return None
        except aiohttp.ClientConnectorError as e:
            print(f"Error connecting to server: {e}")
            return None
        
        # State Code 429 (Too Many Requests)
        if response.status == 429:
            print(f"Too Many Requests received. Retrying after waiting.")
            await asyncio.sleep(5)  # Wait 5 seconds to retry
            return await extract_addresses_from_url_async(url)  # Recall the function
        
        try:
            # extracts all the html content from the page
            soup = BeautifulSoup(page_text, 'html.parser')
        except:
            return None
        
        try:
            # extracts all the text from the page
            page_text = soup.get_text()
        except:
            return None
        
        try:
            # find an UK address in the text using pyap.parse function (from the pyap library)
            addresses = pyap.parse(page_text, country='GB')
        except:
            return None
        
        return [url, addresses]

# %% [markdown]
# - Asynchronous main function where with the list of URLS we extract addresses asynchronously

# %%
async def main(urls_list):
    tasks = [extract_addresses_from_url_uk_async(url) for url in urls_list]
    final_addresses = await asyncio.gather(*tasks, return_exceptions=True)
    return final_addresses

# %%
final_addressesUK = await main(urlsUK['URL'])
# Out:
# Error occurred while fetching URL 'https://twentytwenty.co': Cannot write to closing transport
# Error occurred while fetching URL 'https://seatingmatters.com': Cannot write to closing transport
# Error occurred while fetching URL 'https://seatingmatters.com/contact': Cannot write to closing transport
# Error occurred while fetching URL 'https://highperformanceproductions.net/contact.html': Cannot connect to host highperformanceproductions.net:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://highperformanceproductions.net': Cannot connect to host highperformanceproductions.net:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://thelionatfarnsfield.com/contact-us/': Cannot connect to host thelionatfarnsfield.com:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://andersonhoare.co.uk': Cannot connect to host andersonhoare.co.uk:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://thelionatfarnsfield.com': Cannot connect to host thelionatfarnsfield.com:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://andersonhoare.co.uk/contact': Cannot connect to host andersonhoare.co.uk:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://landau-forte.org.uk/contact/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://landau-forte.org.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com/collections/home-cement-tiles-and-porcelain-tiles/products/porcelain-tile-meena': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com/collections/home-cement-tiles-and-porcelain-tiles/products/porcelain-tile-petal': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com/collections/home-cement-tiles-and-porcelain-tiles/products/petal-porcelain-tile-sand-pink': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://ukindustrialflooring.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://ukindustrialflooring.co.uk/contact-us/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com/collections/home-cement-tiles-and-porcelain-tiles': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com/collections/home-cement-tiles-and-porcelain-tiles/products/green-stripe-porcelain-tile': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com/collections/home-cement-tiles-and-porcelain-tiles/products/starz-porcelain-tile-1': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mariastarling.com/collections/home-cement-tiles-and-porcelain-tiles/products/luz-black-and-white-porcelain-tile': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://gasmithplant.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://gasmithplant.co.uk/contact/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://redrockconsultants.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://afaprojects.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://artbronze.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://bakers-solicitors.com': Cannot connect to host bakers-solicitors.com:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'http://babyfat.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://mailsure-it.com': Cannot connect to host mailsure-it.com:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'http://babyfat.co.uk/contact-us/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://epcarlson.co.uk/landlords-decent-safe-home-review-what-is-it-and-why-should-you-do-it/': Cannot connect to host epcarlson.co.uk:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://epcarlson.co.uk/contact-us/': Cannot connect to host epcarlson.co.uk:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'http://ricksedinburgh.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://carstorageltd.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://epcarlson.co.uk': Cannot connect to host epcarlson.co.uk:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'http://rhi-stitched.com/contact.html': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://rhi-stitched.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://redrockconsultants.co.uk/contact/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://epcarlson.co.uk/what-is-a-home-buyer-or-condition-survey/': Cannot connect to host epcarlson.co.uk:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'https://oakover.co.uk': Cannot connect to host oakover.co.uk:443 ssl:False [An established connection was aborted by the software in your host machine]
# Error occurred while fetching URL 'http://afaprojects.com/contact-us/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://nugentbuilders.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://langham-hotel.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'http://cjei.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://trentvineyard.org/connect': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://trentvineyard.org': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://oysteryachts.com/contact-us/careers/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://trentvineyard.org/connect/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://oysteryachts.com/contact-us/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://oysteryachts.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://www.eset.com/uk/download-home/': 400, message='Got more than 8190 bytes (11758) when reading Header value is too long.', url=URL('https://www.eset.com/uk/download-home/')
# Error occurred while fetching URL 'https://imajica.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://pandr.online': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://thestove.org': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://athertonstone.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://freedomdestinations.co.uk': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://class.agency/contact/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://azizisearch.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://samanthasage.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://wrssolutions.com': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://wrssolutions.com/contact-us': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://class.agency': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://thestove.org/contact/': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://azizisearch.com/contact': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://imajica.com/contact': [WinError 10053] An established connection was aborted by the software in your host machine
# Error occurred while fetching URL 'https://pandr.online/pages/contact-us': [WinError 10053] An established connection was aborted by the software in your host machine

# %%
final_addressesUK
# Out:
# [['https://trinyx.org', [160 Road City, London, United Kingdom EC1V 2NX]],
#  ['https://enigmacs.com',
#   [UK StudioSt. Stephens House, Arthur Road, Windsor Berkshire, SL4 1RU, United Kingdom]],
#  ['https://enigmacs.com/contact/',
#   [se Arthur Road WindsorBerkshire, SL4 1RU, United Kingdom,
#    se Arthur Road WindsorBerkshire, SL4 1RU, United Kingdom]],
#  ['https://www.pennyanderson.com/contact',
#   [60 Park Road, Buxton, Derbyshire, SK17 6SN]],
#  ['https://pennyanderson.com', []],
#  ['https://inovix.net/contact-us/',
#   [Wyvern Business Park, Stanier Way, Derby. DE21 6BF]],
#  ['https://inovix.net', [83 Friar Gate, Derby, DE1 1FL]],
#  ['https://dscsoundandlighting.co.uk', []],
#  ['https://neseafood.com',
#   [48 Cox Lane, Chessington, Surrey, KT9 1TW, United Kingdom]],
#  ['https://neseafood.com/pages/contact',
#   [48 Cox Lane, Chessington, Surrey, KT9 1TW, Great Britain,
#    Europarc, Healing, Grimsby, DN37 9TU, Great Britain,
#    48 Cox Lane, Chessington, Surrey, KT9 1TW, United Kingdom]],
#  ['https://web-design-studios.com', []],
#  ['https://web-design-studios.com/gainsborough/web-studios/contact-us.html',
#   [Strafford Street, Gainsborough, Lincolnshire., DN21 1DU]],
#  ['https://urbanstrides.com', []],
#  ['https://kentscp.com/contact-us/',
#   [Abbeyfield Court, Abbeyfield Road, Nottingham, NG7 2SZ,
#    Abbeyfield Court, Abbeyfield Road, Nottingham, NG7 2SZ]],
#  ['https://kentscp.com',
#   [Abbeyfield Court, Abbeyfield Road, Nottingham, NG7 2SZ]],
#  ['https://snaresbrookprep.org/about-us/contact-us',
#   [Woodford Road, London, E18 2EA,
#    Policies, Find Us Here 75 Woodford Road, London, E18 2EA]],
#  ['https://snaresbrookprep.org',
#   [Woodford Road, London, E18 2EA,
#    Leave EmptySend the message, Find Us Here 75 Woodford Road, London, E18 2EA]],
#  ['https://rgr-garages.co.uk',
#   [01234 750207 Cranfield MK43 0DG,
#    01234 750207 Cranfield MK43 0DG,
#    01234 750207 Cranfield MK43 0DG,
#    High Street, Cranfield, BedfordBedfordshire, MK43 0DG,
#    High Street, Cranfield, Bedfordshire, MK43 0DG]],
#  ['http://fpsgconnect.co.uk', []],
#  ['https://www.fasthosts.co.uk/contact?utm_source=domainparking&utm_medium=referral&utm_campaign=fh_parking_contact',
#   [154 Southgate Street, Gloucester, GL1 2EX]],
#  ['https://zeroh.net/work/cardboard-citizens-cathy-come-home/', []],
#  ['https://zeroh.net/work/madeon-home/', []],
#  ['https://zeroh.net', []],
#  ['http://connaughthousehotel.com', []],
#  ['https://sixphysio.com', []],
#  ['https://sixphysio.com/services/home-physio', []],
#  ['https://sixphysio.com/contact-us', []],
#  ['https://mcvideo.co.uk', []],
#  ['https://mcvideo.co.uk/contact/', []],
#  ['https://mcvideo.co.uk/home/privacy-policy/', []],
#  ['https://rising-records.com', []],
#  ['https://aberdeenpattestservices.com/contact.htm',
#   [6 International Drive, Aberdeen, AB21 0BH]],
#  ['https://aberdeenpattestservices.com', []],
#  ['http://cforl.co.uk', []],
#  ['https://burnhamgarage.co.uk', []],
#  ['https://www.cambriancruisers.co.uk/contact',
#   [Ty Newydd, Pencelli, Brecon LD3 7LJ,
#    Ty Newydd, Pencelli, Brecon LD3 7LJ,
#    Ty Newydd, Pencelli, Brecon LD3 7LJ]],
#  ['https://www.cambriancruisers.co.uk/index.php/contact',
#   [Ty Newydd, Pencelli, Brecon LD3 7LJ,
#    Ty Newydd, Pencelli, Brecon LD3 7LJ,
#    Ty Newydd, Pencelli, Brecon LD3 7LJ]],
#  ['https://cambriancruisers.co.uk',
#   [Ty Newydd, Pencelli, Brecon LD3 7LJ, Ty Newydd, Pencelli, Brecon LD3 7LJ]],
#  ['https://joolsstone.com/contact/', []],
#  ['https://joolsstone.com', []],
#  ['https://nicholsonstransport.co.uk', []],
#  ['https://slipstreammarketing.co.uk', []],
#  ['https://standard-alarms.com',
#   [51 Bowes St, Blyth, Northumberland, NE24 1EB,
#    51 Bowes Street, Blyth, Northumberland, NE24 1EB]],
#  ['https://standard-alarms.com/contact',
#   [51 Bowes St, Blyth, Northumberland, NE24 1EB]],
#  ['https://perfectprofilesclinics.co.uk',
#   [27 Bedford Square, Houghton Regis, LU5 5ES]],
#  ['https://bodosperlein.com/pages/contact',
#   [WharfBarge House StreetLondon SE1 9PH]],
#  ['https://bodosperlein.com', []],
#  ['https://bodosperlein.com/pages/shop-home-page', []],
#  ['https://iconrelocation.com', []],
#  ['https://iconrelocation.com/our-services/home-search-and-orientation/', []],
#  ['https://iconrelocation.com/why-icon/global-reach-and-partners/', []],
#  ['https://iconrelocation.com/contact-us/',
#   [Street CrowboroughEast Sussex TN6 2QY,
#    1 King William StreetLondon EC4N 7AF,
#    11 Bon Accord CrescentAberdeen AB11 6DE]],
#  ['https://kcrtransport.co.uk',
#   [447 Burton Road, Midway, Swadlincote, DE11 7NB]],
#  ['https://kcrtransport.co.uk/contact-us/', []],
#  ['https://digitaleyesmedia.co.uk', []],
#  ['https://oakwood-estates.co.uk',
#   [Manor House Lane, Datchet, Berks, SL3 9EG]],
#  ['https://oakwood-estates.co.uk/selling-your-home-with-us',
#   [Manor House Lane, Datchet, Berks, SL3 9EG]],
#  ['https://nglos.co.uk', []],
#  ['https://nglos.co.uk/contact-us',
#   [1 Leisure Centre, Bruton Way, Gloucester GL1 1DT]],
#  ['https://washerwise.co.uk', []],
#  ['https://washerwise.co.uk/contact/', []],
#  ['https://practicalpoetry.co.uk', []],
#  ['https://iadcontrol.com/contact-us.html', []],
#  ['https://iadcontrol.com', []],
#  ['https://deediganmartialarts.co.uk', []],
#  ['http://buyorganic.co.uk', []],
#  ['https://wolf.live', []],
#  ['https://palmunderwear.co.uk',
#   [Sketchley Meadows Ind. Est, Hinckley, Leicestershire, LE10 3ER]],
#  ['https://palmunderwear.co.uk/contact-us/',
#   [Sketchley Meadows Ind. Est, Hinckley, Leicestershire, LE10 3ER]],
#  ['https://shibdenmillinn.com', []],
#  ['https://apptivation.co.uk',
#   [16 Brune Street, London, E1 7NJ,
#    3701 8 Walworth Road, London, SE1 6EL, England]],
#  ['https://carteraccountants.co.uk',
#   [The Warrens Business Park, Enderby, Leicester, LE19 4SA]],
#  ['https://carteraccountants.co.uk/contact-us.php',
#   [The Warrens Business Park, Enderby, Leicester, LE19 4SA]],
#  ['https://allaboutvenues.com/contact/',
#   [allaboutvenues.com, VISIT US, CW12 2FQ,
#    Shellow Lane, Congleton, Cheshire, CW12 2FQ]],
#  ['https://allaboutvenues.com', [Shellow Lane, Congleton, Cheshire, CW12 2FQ]],
#  ['https://ratio.co.uk/contact/',
#   [18 Albert RoadBournemouth BH1 1BZ, 18 Albert Road Bournemouth BH1 1BZ]],
#  ['https://ratio.co.uk', [18 Albert Road Bournemouth BH1 1BZ]],
#  ['https://tokyoto-luggage.com/contact-us/', []],
#  ['https://tokyoto-luggage.com', []],
#  ['https://kgd.co.uk/contact/',
#   [Our Address, Netherwood RoadRotherwas, Hereford, HR2 6JU,
#    OUR INFO, KGDNetherwood RoadRotherwas, HerefordHR2 6JU]],
#  ['https://kgd.co.uk',
#   [OUR INFO, KGDNetherwood RoadRotherwas, HerefordHR2 6JU]],
#  ['https://sedumgreenroof.co.uk/contact-us/',
#   [Lower Woodford, Salisbury, Wiltshire, SP4 6NQ,
#    Lower Woodford, Salisbury, SP4 6NQ]],
#  ['https://sedumgreenroof.co.uk', [Lower Woodford, Salisbury, SP4 6NQ]],
#  ['https://paynes-heating.co.uk/contact',
#   [Lewes Road, Blackboys, East Sussex, TN22 5JL]],
#  ['https://paynes-heating.co.uk',
#   [Lewes Road, Blackboys, East Sussex, TN22 5JL]],
#  ['http://m2msecuritysims.com', []],
#  ['https://cspc.co.uk/contact-us/',
#   [184 Otley Rd, Leeds LS16 5LW, 184 Otley Rd, Leeds LS16 5LW]],
#  ['https://cspc.co.uk', [184 Otley Rd, Leeds LS16 5LW]],
#  ['http://voodoovaudeville.com', []],
#  ['http://voodoovaudeville.com/contact/', []],
#  ['https://jeanettekidd.com/contact-us/',
#   [13 Antrim St, Lisburn BT28 1AU, 13 Antrim St, Lisburn BT28 1AU]],
#  ['https://jeanettekidd.com',
#   [13 Antrim St, Lisburn BT28 1AU, 13 Antrim St, Lisburn BT28 1AU]],
#  ['https://viduppu.com/contact', []],
#  ['https://viduppu.com', []],
#  ['https://optima-life.com', []],
#  ['https://optima-life.com/contact-us/',
#   [14 Waverley Road, St Albans, Hertfordshire, AL3 5PA,
#    Great Marlings, Luton, Bedfordshire, LU2 8DL]],
#  ['https://allinonelondon.com', [12 Lea Rd, London, Waltham Abbey EN9 1AS]],
#  ['https://renaultalpine.co.uk', []],
#  ['https://kellergreen.com', []],
#  ['https://kellergreen.com/contact', [42-46 Princelet StLondon, E1 5LP]],
#  ['http://salaequilibrio.com', []],
#  ['https://sjhub.org.uk/sjfc-u11s-reach-chiltern-church-league-plate-final/',
#   [Amersham Town F.C, Spratleys Meadow, School Lane Amersham. HP7 0EJ,
#    2019 POPULAR CATEGORYLATEST NEWS681SJ,
#    NOW FEATURED162SJ,
#    Cycling142LA,
#    HQ News106Ru,
#    nning83Re]],
#  ['https://sjhub.org.uk/sjfc-u11s-reach-chiltern-church-league-plate-final/#respond',
#   [Amersham Town F.C, Spratleys Meadow, School Lane Amersham. HP7 0EJ,
#    2019 POPULAR CATEGORYLATEST NEWS681SJ,
#    NOW FEATURED162SJ,
#    Cycling142LA,
#    HQ News106Ru,
#    nning83Re]],
#  ['https://sjhub.org.uk/contact/',
#   [2019 POPULAR CATEGORYLATEST NEWS680SJ,
#    NOW FEATURED162SJ,
#    Cycling142LA,
#    HQ News106Ru,
#    nning83Re]],
#  ['https://sjhub.org.uk',
#   [m School Aldenham Road Elstree WD6 3AJ,
#    Northwood HA6 2DR,
#    Equatus Vehicle Services Ltd HA3 5BD,
#    mansworth School Rickmansworth WD3 3AQ,
#    School for Girls Rickmansworth WD3 4HF,
#    School Eastbury Road Northwood HA6 3AS,
#    9 6E Tithe Farm 151, RAYNERS LANE, HARROW, HA2 0XH,
#    2019 POPULAR CATEGORYLATEST NEWS681SJ,
#    NOW FEATURED162SJ,
#    Cycling142LA,
#    HQ News106Ru,
#    nning83Re]],
#  ['https://stationcars.co.uk', [100 Upper Tooting Road LONDON SW17 7EN]],
#  ['https://londonshootfighters.com',
#   [4 The Atlip Centre, Atlip Road, Wembley HA0 4LU]],
#  ['https://londonshootfighters.com/contact/',
#   [4 The Atlip Centre, Atlip Road, Wembley HA0 4LU,
#    4 Atlpib Centre, Atlib Road, Wembley, HA0 4LU]],
#  ['https://xclusivedecor.com/home/159-somerset-outdoor-kitchen-5060473850576.html',
#   [Exchange House Centre, Exchange Street, NorfolkNR17 2AB]],
#  ['https://xclusivedecor.com',
#   [Exchange House Centre, Exchange Street, NorfolkNR17 2AB]],
#  ['https://xclusivedecor.com/contact-us',
#   [Exchange House Centre, Exchange Street, NorfolkNR17 2AB]],
#  ['https://pixelboost.co.uk', []],
#  ['https://revolutionkarting.com',
#   [422-424 Burdett road, Mile end, London, E3 4AA]],
#  None,
#  ['https://millwoodeducation.co.uk/contact',
#   [Skelmanthorpe Business Park, Skelmanthorpe, Huddersfield, HD8 9DZ]],
#  ['https://millwoodeducation.co.uk', []],
#  ['https://millwoodeducation.co.uk/products/learning-from-home', []],
#  ['https://comfygroup.co.uk', []],
#  ['https://comfygroup.co.uk/contact',
#   [hurch Street Wilmslow Cheshire SK9 1AX,
#    kehill Industrial Est Middleton, Manchester M24 2RW,
#    kehill Industrial Est Middleton, Manchester M24 2RW,
#    Hanson Close, Middleton, Manchester, M24 2HD]],
#  ['https://gews.co.uk', []],
#  ['https://onerockinternational.com',
#   [Central Hall Westminster, Storey's Gate, London SW1H 9NH]],
#  ['https://onerockinternational.com/contact/',
#   [s Gate, London SW1H 9NH,
#    Central Hall Westminster, Storey's Gate, London SW1H 9NH]],
#  ['http://ngagephotography.com', []],
#  ['http://ngagephotography.com/Contact-wedding-photography.html', []],
#  ['https://cornerstone.photography', []],
#  ['https://cornerstone.photography/contact-devon-photographer-scot-baston/',
#   []],
#  ['https://withoutwalls.uk.com', []],
#  ['https://london-ghost-tour.com', [PO Box 53131 London E18 1UW]],
#  ['https://nucleargrads.com', []],
#  None,
#  None,
#  ['https://dollyrose.co.uk', []],
#  ['https://corporateentertainmentco.co.uk',
#   [Ringles Cross, Uckfield, East Sussex, TN22 1HB,
#    Ringles Cross, Uckfield, East Sussex, TN22 1HB]],
#  ['https://corporateentertainmentco.co.uk/contact/',
#   [Ringles Cross, Uckfield, East Sussex, TN22 1HB,
#    Ringles Cross, Uckfield, East Sussex, TN22 1HB]],
#  ['https://plasma-clean.com',
#   [Dowry Street, Oldham, Greater Manchester, OL8 2PF, United Kingdom]],
#  ['https://plasma-clean.com/contact-us/',
#   [Dowry Street, Oldham, Greater Manchester, OL8 2PF, United Kingdom,
#    Newtownards, Co. Down, Northern Ireland, BT23 7SU,
#    Dowry Street, Oldham, Greater Manchester, OL8 2PF, United Kingdom]],
#  None,
#  None,
#  None,
#  None,
#  ['https://watts1874.co.uk/pages/contact-us',
#   [Design Centre Chelsea Harbour, London, SW10 0XE, United Kingdom]],
#  ['https://watts1874.co.uk', []],
#  ['https://netmera.com/contact-us/', [1 Primrose St. London EC2A 2EX]],
#  ['https://netmera.com', []],
#  ['https://platipus-anchors.com/contact-us/',
#   [Philanthropic Road, Redhill, Surrey, RH1 4DP,
#    Philanthropic Road, Redhill, Surrey, RH1 4DP]],
#  ['https://platipus-anchors.com',
#   [Philanthropic Road, Redhill, Surrey, RH1 4DP]],
#  ['https://armchairmarketing.co.uk',
#   [The Old Dairy, Blisworth Hill Farm, Stoke Road Northampton, NN73DB]],
#  ['https://soulbrother.com', [1 Keswick Rd, East Putney, London SW15 2HL]],
#  ['https://soulbrother.com/shop/back-home-6/',
#   [1 Keswick Rd, East Putney, London SW15 2HL]],
#  ['https://soulbrother.com/shop/back-home-5/',
#   [1 Keswick Rd, East Putney, London SW15 2HL]],
#  ['https://soulbrother.com/shop/spank-i-wanna-go-home-with-you/',
#   [1 Keswick Rd, East Putney, London SW15 2HL]],
#  ['https://pdq1.com/contact',
#   [Marshgate Trading Estate, Hitcham Road Taplow, Berkshire, SL6 0LX, England,
#    Marshgate Trading Estate, Hitcham Road Taplow, Berkshire, SL6 0LX]],
#  ['https://pdq1.com',
#   [Emily Jackson, Honda CBR600RR,
#    Marshgate Trading Estate, Hitcham Road Taplow, Berkshire, SL6 0LX]],
#  ['https://pdq1.com/contact-us',
#   [Marshgate Trading Estate, Hitcham Road Taplow, Berkshire, SL6 0LX, England,
#    Marshgate Trading Estate, Hitcham Road Taplow, Berkshire, SL6 0LX]],
#  ['https://www.pinehills.com/home/12-dawns-light-2', []],
#  ['https://pinehills.com/homes/home-types/custom-homes', []],
#  ['https://pinehills.com/contact', []],
#  ['https://pinehills.com/homes/home-types', []],
#  ['https://pinehills.com', []],
#  ['https://pinehills.com/homes/home-types/apartments', []],
#  ['https://www.ungagged.com/contact/', [88 Turnmill Street, London EC1M 5QU]],
#  ['https://ungagged.com', []],
#  ['http://acorn-training.com', []],
#  ['https://www.fasthosts.co.uk/contact?utm_source=domainparking&utm_medium=referral&utm_campaign=fh_parking_contact',
#   [154 Southgate Street, Gloucester, GL1 2EX]],
#  ['https://greentimber.com',
#   [Parsonage Lane, Sawbridgeworth, Hertfordshire. CM21 0LX, UK]],
#  ['https://royalacademyofculinaryarts.org.uk',
#   [76 Vincent Square, London SW1P 2PD]],
#  ['https://royalacademyofculinaryarts.org.uk/contact-1', []],
#  None,
#  ['https://royalacademyofculinaryarts.org.uk/contact',
#   [76 Vincent SquareLondon SW1P 2PD]],
#  ['https://wardblawg.com', []],
#  ['https://wardblawg.com/contact/', []],
#  ['https://belhavensmokehouse.co.uk/contact-us/',
#   [Beltonford, Dunbar, East Lothian, EH42 1ST,
#    mokehouse ShopBeltonfordDunbar EH42 1ST,
#    Belhaven Smokehouse Shop, Beltonford, Dunbar, EH42 1ST]],
#  ['https://belhavensmokehouse.co.uk/contact-us/#anchor-subscribe',
#   [Beltonford, Dunbar, East Lothian, EH42 1ST,
#    mokehouse ShopBeltonfordDunbar EH42 1ST,
#    Belhaven Smokehouse Shop, Beltonford, Dunbar, EH42 1ST]],
#  ['https://belhavensmokehouse.co.uk',
#   [Belhaven Smokehouse Shop, Beltonford, Dunbar, EH42 1ST]],
#  ['https://bedfordrugby.co.uk', []],
#  ['https://bedfordrugby.co.uk/events/contact', []],
#  ['https://swaleviewpark.co.uk/contact/',
#   [Reeth Road, Richmond, North Yorkshire, DL10 4SF,
#    Reeth Road, Richmond, North Yorkshire, DL10 4SF]],
#  ['https://swaleviewpark.co.uk',
#   [Reeth Road, Richmond, North Yorkshire, DL10 4SF]],
#  ['https://adboards.com', [6-8 Watermead Works, Slater Lane, Bolton, BL1 2TE]],
#  ['https://giftsvouchers.co.uk', []],
#  ['https://thompsonbrothers.net/contact/', [55 Mark Lane, London, EC3R 7NE]],
#  ['https://thompsonbrothers.net', [55 Mark Lane, London, EC3R 7NE]],
#  ['https://cash-for-houses.co.uk', []],
#  ['https://cash-for-houses.co.uk/contact-us.html',
#   [Universal Square, Devonshire Street North, Manchester, M12 6JH]],
#  ['https://cash-for-houses.co.uk/cash-for-home.html', []],
#  None,
#  None,
#  None,
#  ['https://atranubesstudio.co.uk', []],
#  ['https://malonesedinburgh.com/contact/', []],
#  ['https://malonesedinburgh.com',
#   [90 Shiprow Aberdeen, UK, AB11 5BZ, Leith, Edinburgh, UK EH6 6RS]],
#  ['https://dentalmarketingexpert.co.uk', []],
#  ['https://dentalmarketingexpert.co.uk/contact-us/',
#   [321 Elder House WestMilton KeynesMK9 1LR]],
#  ['https://forensicseuropeexpo.com', [oria DockWestern GatewayLondon E16 1XL]],
#  ['https://codelife.org', [Chesterfield Road, Stavele, Chesterfield, S43 3XD]],
#  ['https://acecic.co.uk', []],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['https://flysoftware.com/company/contact-us',
#   [Suite 315, Bridge House, Taunton, Somerset, TA1 1TG, United Kingdom]],
#  ['https://flysoftware.com', []],
#  ['https://realworldholidays.co.uk',
#   [5329 Suite 6 Gledhow Mount Mansions, Roxholme Grove, Leeds, LS7 4JJ]],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['https://maruhub.com', []],
#  ['https://rentalsandsales.co.uk/contact',
#   [s Rd, Wimbledon, London SW19 8YE, UK]],
#  ['https://rentalsandsales.co.uk',
#   [For Rent, A SPACIOUS SPLIT LEVEL ONE BEDROOM, Church Road, CR4 3BU]],
#  ['https://howtohandlehecklers.com', []],
#  ['https://warmemorialconservation.com',
#   [285 Cowbridge Road West, Cardiff, South Wales, CF5 5TD]],
#  ['https://worldoffootball.com',
#   [10 Newmarket Road Edinburgh EH14 1RJ, 25 Marine Dr, Edinburgh EH4 5EJ]],
#  ['https://worldoffootball.com/contact-us/',
#   [11 Newmarket Road, Edinburgh, EH14 1RJ,
#    25 Marine Dr, Edinburgh, EH4 5EJ,
#    10 Newmarket Road Edinburgh EH14 1RJ,
#    25 Marine Dr, Edinburgh EH4 5EJ]],
#  ['https://lsmflooringmanchester.co.uk', []],
#  ['https://pelicanprocurement.co.uk',
#   [Farnborough Aerospace Centre, Farnborough, GU14 6XN]],
#  ['https://instantasp.co.uk', []],
#  None,
#  None,
#  ['https://alto-marketing.com', []],
#  ['https://alto-marketing.com/contact/', []],
#  ['https://causalens.com/contact-us/', [149 Hammersmith Rd, W14 0QL]],
#  ['https://causalens.com', []],
#  ['https://chestnutcaregloucester.co.uk',
#   [20 Podsmead Road, Gloucester, GL1 5PA]],
#  ['https://eggarforresterinsurance.com',
#   [40 Basinghall Street, London EC2V 5DE]],
#  ['https://eggarforresterinsurance.com/contact/',
#   [40 Basinghall Street, London, EC2V 5DE,
#    40 Basinghall Street, London EC2V 5DE]],
#  ['http://prospecttraining.co.uk', []],
#  ['http://prospecttraining.co.uk/index.php/contact-us/',
#   [48 Doncaster Road, Mexborough, South Yorkshire. S64 0LU]],
#  ['https://barts-choir.com/contact-us/', []],
#  ['https://barts-choir.com', []],
#  ['https://appliancerepairmanchester.co.uk', []],
#  ['https://thegainsboroughbathspa.co.uk',
#   [NEWSLETTER SIGN UP, THE GAINSBOROUGH BATH SPABEAU STREET, BATH BA1 1QY, ENGLAND]],
#  ['https://thegainsboroughbathspa.co.uk/pages/contact-us.html',
#   [The Gainsborough Bath Spa, Beau Street, Bath BA1 1QY, England,
#    12 Southgate Street, Bath, BA1 1AQ,
#    Avon Street, Bath, BA1 1UF,
#    NEWSLETTER SIGN UP, THE GAINSBOROUGH BATH SPABEAU STREET, BATH BA1 1QY, ENGLAND]],
#  ['https://hastingsoloughlin.co.uk', []],
#  ['https://snsg.co.uk',
#   [rms, Accreditations, Contact Us 27 Kenyon Street, Birmingham B18 6AR]],
#  ['https://snsg.co.uk/contact-us/',
#   [Your Message, Our Office27 Kenyon Street, Birmingham B18 6AR, United Kingdom,
#    rms, Accreditations, Contact Us 27 Kenyon Street, Birmingham B18 6AR]],
#  ['https://nicheworks.co.uk', [32a Duddingston Park, Edinburgh, EH15 1JU]],
#  ['https://nicheworks.co.uk/contact/',
#   [32a Duddingston Park, Edinburgh EH15 1JU,
#    32a Duddingston Park, Edinburgh, EH15 1JU]],
#  ['https://adfertech.com', []],
#  ['https://adfertech.com/contact.html',
#   [63 UNIVERSITY ROAD, BELFAST, NORTHERN IRELAND, BT7 1NF]],
#  ['https://thinkvideo.net/contact-us/', [Butcher Row, Shrewsbury, SY1 1UW]],
#  ['https://thinkvideo.net/contact-us', [Butcher Row, Shrewsbury, SY1 1UW]],
#  ['https://thinkvideo.net', [Butcher Row, Shrewsbury, SY1 1UW]],
#  ['https://oakover.co.uk/contact', [MareSomersetBS23 1DA]],
#  None,
#  ['https://millsselig.com/contact-us/',
#   [21 Arthur Street, Belfast, BT1 4GA, Northern Ireland,
#    21 Arthur Street, Belfast BT1 4GA,
#    21 Arthur Street, Belfast, BT1 4GA]],
#  ['https://millsselig.com',
#   [21 Arthur Street, Belfast BT1 4GA, 21 Arthur Street, Belfast, BT1 4GA]],
#  ['https://balconyshirts.co.uk', []],
#  ['https://balconyshirts.co.uk/contact',
#   [52 Windsor Street, Uxbridge, UB8 1AB]],
#  None,
#  ['http://pmkcivilengineering.com/contact-us/', []],
#  ['https://pmkcivilengineering.com/wp-content/gallery/homepage/home-14-3.jpg',
#   []],
#  ['https://pmkcivilengineering.com/wp-content/gallery/homepage/home-14-1a.jpg',
#   []],
#  ['https://pmkcivilengineering.com', []],
#  ['https://pmkcivilengineering.com/contact-us/', []],
#  ['https://pmkcivilengineering.com/wp-content/gallery/homepage/home-14-5.jpg',
#   []],
#  ['https://pmkcivilengineering.com/wp-content/gallery/homepage/home-14-2.jpg',
#   []],
#  ['https://pfponline.com', [2 Minster Court, Mincing Lane, London EC3R 7PD]],
#  ['https://pfponline.com/contact-us/',
#   [5 Sylvan Court, Basildon, Essex, SS15 6TH,
#    2 Minster Court, Mincing Lane, London EC3R 7PD]],
#  ['https://rndcore.com', []],
#  ['https://praestoconsulting.com', [Hurworth, Darlington, England, DL2 2HD]],
#  ['https://praestoconsulting.com/contact-us/',
#   [5 Lotus Park, Staines-upon-Thames, TW18 3AG,
#    Hurworth, Darlington, England, DL2 2HD]],
#  None,
#  None,
#  None,
#  ['https://recruitmentmarketinginternational.com/contact/',
#   [17 King Edwards Road, RUISLIP, London, HA4 7AE, UNITED KINGDOM]],
#  ['https://recruitmentmarketinginternational.com', []],
#  ['https://ihc-uk.com', [Apex Park, Hailsham, East Sussex, BN27 3JU]],
#  None,
#  None,
#  None,
#  None,
#  ['https://surreysoftplayhire.com', []],
#  ['https://scandinavianloft.com', []],
#  ['https://bakers-solicitors.com/contact-us',
#   [15A BERNARD STREET, GLOSSOP, DERBYSHIRE, SK13 7AA]],
#  None,
#  None,
#  None,
#  ['https://walternewbury.co.uk/Contact-Us',
#   [123 Rainham Road North, Dagenham, Essex RM10 7FD,
#    enrex Investment Management Llp, London, England, W8 5HD,
#    123 Rainham Road North, Dagenham, Essex, RM10 7FD, United Kingdom]],
#  ['https://walternewbury.co.uk',
#   [123 Rainham Road North, Dagenham, Essex, RM10 7FD, United Kingdom]],
#  ['https://mannering-rubber.co.uk/contact-us.php.html',
#   [Bowling Park Close, Bradford, BD4 7HG]],
#  ['https://mannering-rubber.co.uk', []],
#  ['https://monalisasmiles.co.uk/contact-us/',
#   [83 Station Road, Barnet, EN5 1PX,
#    83 Station Road, Barnet, EN5 1PX,
#    83 Station Road, Barnet, EN5 1PX]],
#  ['https://monalisasmiles.co.uk',
#   [83 Station Road, Barnet, EN5 1PX, 83 Station Road, Barnet, EN5 1PX]],
#  None,
#  None,
#  None,
#  ['https://naturesraincoats.com/contact-us/', []],
#  ['https://naturesraincoats.com', []],
#  None,
#  ['https://shutterworld.co.uk',
#   [Wilman Post, Ossett, West Yorkshire, WF5 8DL]],
#  ['https://shutterworld.co.uk/contact-us/',
#   [Wilman Post, Ossett, West Yorkshire, WF5 8DL]],
#  None,
#  ['https://alliancecarimports.co.uk', []],
#  ['https://weddingmakeupandhair.com', []],
#  ['https://weddingmakeupandhair.com/pam-wrigley-hair-and-makeup-contact/', []],
#  ['https://heckfordnorton.co.uk/contact/',
#   [hworth Garden CityHertfordshireSG6 3EB,
#    Hill StreetSaffron WaldenEssexCB10 1JD,
#    more RoadStevenageHertfordshireSG1 3HU]],
#  ['https://heckfordnorton.co.uk', [Letchmore Road, Stevenage, SG1 3HU]],
#  ['https://iccopr.com', [EicwEu94sq]],
#  ['https://sussexgold.co.uk', []],
#  ['https://catchacab.com', []],
#  ['https://teneightytwo.co.uk', []],
#  ['https://diskingcomputers.com',
#   [Beaver Industrial Estate, Liphook, GU30 7EU]],
#  ['https://diskingcomputers.com/contact/',
#   [Glenmore Business Park, Chichester, PO19 7BJ,
#    5 South Street, Farnham, Surrey, GU9 7QU,
#    Royal Parade, Hindhead, GU26 6TD,
#    Beaver Industrial Est, Liphook, GU30 7EU,
#    g Computers Tourist Info Centre, North Street, Midhurst, GU29 9DW,
#    7a Dragon Street, Petersfield, Hampshire, GU31 4JN,
#    Beaver Industrial Estate, Liphook, GU30 7EU]],
#  None,
#  ['https://thehungerproject.org.uk', [7 Bell Yard, London, WC2A 2JR]],
#  ['https://thehungerproject.org.uk/contact-us/',
#   [7 Bell Yard, London, WC2A 2JR]],
#  ['https://ivfbioscience.com',
#   [Bickland Industrial Park, Falmouth, Cornwall, TR11 4TA, United Kingdom]],
#  ['https://woodstock-motorparts.co.uk/contact/',
#   [Woodstock Motorparts, Ravenhill Business Park, Belfast, BT6 8AW]],
#  ['https://woodstock-motorparts.co.uk',
#   [Woodstock Motorparts, Ravenhill Business Park, Belfast, BT6 8AW]],
#  ['https://akstoddart.co.uk', []],
#  ['https://shiresequestrian.com/contact/contactshires.html',
#   [15 Southern Avenue, Leominster, HR6 0QF]],
#  ['https://shiresequestrian.com/horse/horse-boots/brushing-boots-protection/over-reach-boots',
#   [15 Southern Avenue, Leominster, HR6 0QF]],
#  ['https://shiresequestrian.com', [15 Southern Avenue, Leominster, HR6 0QF]],
#  ['https://ezy-clean.co.uk',
#   [rm Oast, Plough Wents Road, Chart Sutton, Kent, ME17 3SA]],
#  ['https://ezy-clean.co.uk/contact-us',
#   [rm Oast, Plough Wents Road, Chart Sutton, Kent, ME17 3SA,
#    rm Oast, Plough Wents Road, Chart Sutton, Kent, ME17 3SA]],
#  ['https://ezy-clean.co.uk/home',
#   [rm Oast, Plough Wents Road, Chart Sutton, Kent, ME17 3SA]],
#  None,
#  None,
#  None,
#  None,
#  ['https://deversoftware.com/contact-dever-software/',
#   [fficeMeadow BarnCullomptonDevonEX15 1RB,
#    mwood CloseBasingstokeHampshireRG21 3BL]],
#  ['https://deversoftware.com', []],
#  ['https://s-sewing.co.uk', []],
#  ['https://s-sewing.co.uk/contact', []],
#  ['https://clarity4d.com',
#   [3 Broad StreetStamford, Lincolnshire, PE9 1PG,
#    3 Broad Street, Stamford, Lincolnshire, PE9 1PG]],
#  ['https://aclautomotive.co.uk/contact',
#   [East Dorset Trade Park, Wimborne, Dorset BH21 7UH]],
#  ['https://aclautomotive.co.uk', []],
#  ['https://headtotoetherapy.co.uk', []],
#  ['https://hoxtonfarms.com/contact', []],
#  ['https://hoxtonfarms.com', []],
#  ['http://britanniatowers.co.uk',
#   [Harriet House, Erdington, Birmingham, B23 6BG]],
#  ['http://passion-for-food.co.uk', []],
#  ['https://trailpictures.co.uk', []],
#  ['https://brunsdonfinancial.co.uk/contact-us/',
#   [pmAddressGoodridge House, Goodridge Avenue, Gloucester, GL2 5EA,
#    Goodridge House, Goodridge Avenue, Gloucester, GL2 5EA]],
#  ['https://brunsdonfinancial.co.uk',
#   [Goodridge House, Goodridge Avenue, Gloucester, GL2 5EA]],
#  ['http://photographylane.com', []],
#  ['http://blakeleysofbrighouse.co.uk', [1 Canal Street, Brighouse, HD6 1JX]],
#  None,
#  None,
#  None,
#  ['http://risk-partnership.com', []],
#  None,
#  None,
#  ['http://mysilo.co.uk', []],
#  ['http://eurodrive.co.uk', []],
#  ['http://paulmattysportscars.co.uk', []],
#  None,
#  None,
#  None,
#  ['http://europlan-uk.com/eng/contact-us/contact-form',
#   [68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, United Kingdom,
#    68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, UK]],
#  ['http://europlan-uk.com',
#   [68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, UK]],
#  ['http://europlan-uk.com/eng/contact-us/representative-offices',
#   [68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, United Kingdom,
#    68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, UK]],
#  ['http://europlan-uk.com/eng/contact-us',
#   [68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, United Kingdom,
#    68 Braithwaite House Dunhill Row, London EC1Y 8NQ, United Kingdom,
#    68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, UK]],
#  ['http://europlan-uk.com/eng/contact-us/careers-opportunities',
#   [68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, United Kingdom,
#    68 Braithwaite House, Bunhill Row, London EC1Y 8NQ, UK]],
#  ['http://dukesbrewandque.com', [33 Downham Road, Haggerston, London N1 5AA]],
#  ['http://vectormanagement.co.uk/contact-us.php',
#   [Tomo Ind Estate, Stowmarket, Suffolk, IP14 5AY,
#    Tomo Ind Estate, Stowmarket, Suffolk, IP14 5AY]],
#  ['http://vectormanagement.co.uk',
#   [Tomo Ind Estate, Stowmarket, Suffolk, IP14 5AY]],
#  ['http://lenzieunion.org', []],
#  ['http://localex.co.uk', []],
#  ['http://professional-hc.com', []],
#  ['http://hitechsigns.co.uk/contact.html',
#   [81 Townsend Street, Port Dundas Industrial Estate, Glasgow G4 0LA]],
#  ['http://hitechsigns.co.uk', []],
#  None,
#  None,
#  None,
#  ['http://caremeds.co.uk',
#   [Brickfield Lane, Chandlers Ford, Eastleigh, SO53 4DR]],
#  ['http://floatglassdesign.co.uk',
#   [rm, Staplefield Road, Cuckfield, Haywards Heath, RH17 5JF]],
#  None,
#  ['http://ahfreestyle.co.uk', []],
#  ['http://firesecelec.net', [Water Orton, Birmingham, West Midlands, B46 1NQ]],
#  ['http://basiccharity.org.uk', []],
#  None,
#  ['http://picturethis-framing.co.uk',
#   [20 Stony Lane, Eccleshill, West Yorkshire, BD2 2HN]],
#  ['http://picturethis-framing.co.uk/contact-us/',
#   [20 Stony Lane, Eccleshill, West Yorkshire, BD2 2HN]],
#  ['http://royalegraphics.co.uk',
#   [Stapleford, Nottingham, Nottinghamshire, NG9 7EP]],
#  ['https://www.royalegraphics.co.uk/html/contact-us.html',
#   [Stapleford, Nottingham, Nottinghamshire, NG9 7EP,
#    White House, Wollaton Street, Nottingham, NG1 5GF,
#    Stapleford, Nottingham, Nottinghamshire, NG9 7EP]],
#  ['http://intheclouds.com', []],
#  ['http://intheclouds.com/contact.htm',
#   [Ightfield, Whitchurch, Shropshire, SY13 4BW, England]],
#  ['http://arcovohotelloyalty.com', [152 City Road, London EC1V 2NX, UK]],
#  ['http://arcovohotelloyalty.com/contact-us/',
#   [152 City Road, London EC1V 2NX, UK]],
#  None,
#  None,
#  None,
#  ['http://missionlimited.com',
#   [2 Upper Teddington Road, Kingston-Upon-Thames, Surrey. KT1 4DY]],
#  ['http://bill-medical.co.uk/contact',
#   [33-41 Chiltern Avenue, Amersham, Buckinghamshire., HP6 5AE,
#    33-41 Chiltern Avenue, Amersham, Buckinghamshire., HP6 5AE]],
#  ['http://bill-medical.co.uk',
#   [33-41 Chiltern Avenue, Amersham, Buckinghamshire., HP6 5AE]],
#  ['http://affordablecleaning.co.uk', []],
#  ['http://affordablecleaning.co.uk/contact.php',
#   [1-7 Smyth Road, Bristol BS3 2BX]]]

# %%
addresses_listUK = [element for element in final_addressesUK if element is not None and element[1]]

# %%
len(addresses_listUK)
# Out:
# 187

# %% [markdown]
# #### Loading the existing data (previous found addresses)

# %%
existing_data = pd.read_csv('Addresses.csv')

# %% [markdown]
# #### For each URL we will check if the found address is real and put the valid ones into the CSV
# - we can't make this step asynchronous because the Geopy library allows only 1 request per second

# %%
real_addressesUK = []

# %%
for elem in addresses_listUK:
    # print(elem[0])
    for adresa in elem[1]:
        # print(adresa)
        real_address = extract_address(adresa)
        if real_address != None:
            print("valid")
            if 'country' in real_address:
                country = real_address['country']
            else:
                country = ""
                
            if 'county' in real_address:
                region = real_address['county']
            else:
                region = ""
                
            if 'city' in real_address:
                city = real_address['city']
            elif 'village' in real_address:
                city = real_address['village']
            else:
                city = ""
                
            if 'postcode' in real_address:
                postcode = real_address['postcode']
            else:
                postcode = ""
                
            if 'road' in real_address:
                road = real_address['road']
            else:
                road = ""
                
            if 'house_number' in real_address:
                no_road = real_address['house_number']
            else:
                no_road = ""
            # Adaugă noile date în listă
            real_addressesUK.append([elem[0], country, region, city, postcode, road, no_road])
            
        else:
            print("invalid")
# Out:
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# The address is not valid
# invalid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# The address is not valid
# invalid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid
# Locatia este corecta
# valid

# %%
len(real_addressesUK)
# Out:
# 115

# %% [markdown]
# #### Making a DataFrame with the extracted addresses

# %%
new_data_df = pd.DataFrame(real_addressesUK, columns=['URL', 'Country', 'Region', 'City', 'Postcode', 'Road', 'Road number'])

# %%
new_data_df
# Out:
#                                                    URL         Country  \
# 0                https://www.pennyanderson.com/contact  United Kingdom
# 1                                   https://inovix.net  United Kingdom
# 2    https://web-design-studios.com/gainsborough/we...  United Kingdom
# 3      https://snaresbrookprep.org/about-us/contact-us  United Kingdom
# 4                          https://snaresbrookprep.org  United Kingdom
# ..                                                 ...             ...
# 110          http://arcovohotelloyalty.com/contact-us/  United Kingdom
# 111                  http://bill-medical.co.uk/contact  United Kingdom
# 112                  http://bill-medical.co.uk/contact  United Kingdom
# 113                          http://bill-medical.co.uk  United Kingdom
# 114        http://affordablecleaning.co.uk/contact.php  United Kingdom
#
#               Region          City  Postcode              Road Road number
# 0         Derbyshire     High Peak  SK17 6NS         Park Road
# 1              Derby         Derby   DE1 1DF        Friar Gate          83
# 2       Lincolnshire  West Lindsey  DN21 1DU  Strafford Street
# 3                           London   E18 2EB     Woodford Road
# 4                           London   E18 2EB     Woodford Road
# ..               ...           ...       ...               ...         ...
# 110                         London  EC1V 2NX         City Road         152
# 111  Buckinghamshire  Chesham Bois   HP6 5AE   Chiltern Avenue
# 112  Buckinghamshire  Chesham Bois   HP6 5AE   Chiltern Avenue
# 113  Buckinghamshire  Chesham Bois   HP6 5AE   Chiltern Avenue
# 114  City of Bristol       Bristol   BS3 2BX        Smyth Road
#
# [115 rows x 7 columns]

# %% [markdown]
# #### Adding them to the existent data (from the US and Deutsch)

# %%
final_data = pd.concat([existing_data, new_data_df], ignore_index=True)

# %%
final_data
# Out:
#                                              URL         Country  \
# 0                         https://embcmonroe.org   United States
# 1                         https://embcmonroe.org   United States
# 2        https://embcmonroe.org/connect-with-us/   United States
# 3              https://casepaper.com/contact-us/   United States
# 4              https://casepaper.com/contact-us/   United States
# ..                                           ...             ...
# 696    http://arcovohotelloyalty.com/contact-us/  United Kingdom
# 697            http://bill-medical.co.uk/contact  United Kingdom
# 698            http://bill-medical.co.uk/contact  United Kingdom
# 699                    http://bill-medical.co.uk  United Kingdom
# 700  http://affordablecleaning.co.uk/contact.php  United Kingdom
#
#                     Region              City  Postcode               Road  \
# 0             Union County            Monroe   28112.0     Maurice Street
# 1             Union County            Monroe   28112.0     Maurice Street
# 2             Union County            Monroe   28112.0     Maurice Street
# 3      Philadelphia County      Philadelphia   19134.0  East Tioga Street
# 4    San Bernardino County  Rancho Cucamonga   91730.0     Hermosa Avenue
# ..                     ...               ...       ...                ...
# 696                                   London  EC1V 2NX          City Road
# 697        Buckinghamshire      Chesham Bois   HP6 5AE    Chiltern Avenue
# 698        Buckinghamshire      Chesham Bois   HP6 5AE    Chiltern Avenue
# 699        Buckinghamshire      Chesham Bois   HP6 5AE    Chiltern Avenue
# 700        City of Bristol           Bristol   BS3 2BX         Smyth Road
#
#     Road number
# 0           503
# 1           503
# 2           503
# 3           499
# 4          9168
# ..          ...
# 696         152
# 697
# 698
# 699
# 700
#
# [701 rows x 7 columns]

# %% [markdown]
# #### Export the data to the CSV

# %%
final_data.to_csv('Addresses.csv', index=False)
